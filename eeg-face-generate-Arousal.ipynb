# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import scipy as sp
from tqdm import auto, tqdm
import torch
from sklearn.model_selection import train_test_split

import sys
sys.path.append('/content/drive/MyDrive/11777-Project-xs/LGG/')
sys.path.append('/content/drive/MyDrive/11777-Project-xs/MLP/')
from prepare_data_DEAP import PrepareData
from cross_validation import CrossValidation
from train_model import *
from mlp_networks import SimpleMLP
from mlp_train_model import train_simpleMLP, test_simpleMLP

CUDA = torch.cuda.is_available()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-acd0564da141> in <cell line: 10>()
#       8 sys.path.append('/content/drive/MyDrive/11777-Project-xs/LGG/')
#       9 sys.path.append('/content/drive/MyDrive/11777-Project-xs/MLP/')
# ---> 10 from prepare_data_DEAP import PrepareData
#      11 from cross_validation import CrossValidation
#      12 from train_model import *
#
# ModuleNotFoundError: No module named 'prepare_data_DEAP'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# Define default parameters
default_args = {
    'dataset': 'DEAP',
    'data_path': './data_preprocessed_python/',
    'subjects': 22,
    'num_class': 2,
    'label_type': 'A',
    'segment': 4,
    'overlap': 0,
    'sampling_rate': 128,
    'scale_coefficient': 1,
    'input_shape': (1, 32, 512),
    'data_format': 'eeg',
    'random_seed': 2021,
    'max_epoch': 50, #200
    'patient': 5, #20,
    'patient_cmb': 8,
    'max_epoch_cmb': 20,
    'batch_size': 64,
    'learning_rate': 1e-3,
    'step_size': 5,
    'dropout': 0.5,
    'LS': True,
    'LS_rate': 0.1,
    'save_path': '/content/drive/MyDrive/11777-Project-xs/LGG/save/',
    'load_path': '/content/drive/MyDrive/11777-Project-xs/LGG/save/max-acc.pth',
    'load_path_final': '/content/drive/MyDrive/11777-Project-xs/LGG/save/final_model.pth',
    'mlp_save_path': '/content/drive/MyDrive/11777-Project-xs/MLP/save/',
    'mlp_load_path': '/content/drive/MyDrive/11777-Project-xs/MLP/save/max-acc.pth',
    'mlp_load_path_final': '/content/drive/MyDrive/11777-Project-xs/MLP/save/final_model.pth',
    'gpu': '0',
    'save_model': True,
    'model': 'LGGNet',
    'pool': 16,
    'pool_step_rate': 0.25,
    'T': 64,
    'graph_type': 'hem',
    'hidden': 32
}

# %%
######## Reproduce the result using the saved model ######
# parser.add_argument('--reproduce', action='store_true')
# args = parser.parse_args()
class Args:
    def __init__(self, param_dict):
        for key, value in param_dict.items():
            setattr(self, key, value)

default_args['data_path'] = '/content/drive/MyDrive/11777-Project-xs/data_preprocessed_python/'
default_args['reproduce'] = 'store_true'
# Create an Args object with default parameters
args = Args(default_args)

# %%
# only need to run once
sub_to_run = np.arange(args.subjects)
prepdt = PrepareData(args)
prepdt.run(sub_to_run, split=True, expand=True)
# Out:
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------

# %%
participant_ids = list(range(1, 23))
data_save_folder = '/content/drive/MyDrive/11777-Project-xs/data_face_seg_mean'

def delete_file(path):
    '''
    used to remove temporal file generated
    '''
    if os.path.exists(path):
        os.remove(path)

# # only need to run once
# for participant_id in auto.tqdm(participant_ids):
#     participant_id = '{:02d}'.format(participant_id)
#     for trial_id in auto.tqdm(range(1, 41)):
#         file_name = 's{0}_trial{1}_mean_frames.npy'.format(participant_id, trial_id)
#         if not os.path.exists(os.path.join(data_save_folder, file_name)):
#             print('No face data found for s{0}_trial{1}'.format(participant_id, trial_id))
#             continue

#         file_name2 = 's{0}_trial{1}_mean_frames_embed.npy'.format(participant_id, trial_id)
#         if os.path.exists(os.path.join(data_save_folder, file_name2)):
#             continue
#         participant_trial_seg = np.load(os.path.join(data_save_folder, file_name))
#         participant_trial_embed = []
#         for image in participant_trial_seg:
#             delete_file('curr_face_image.png')
#             plt.imsave('curr_face_image.png', np.uint8(participant_trial_seg[0]),
#                        cmap=plt.cm.Spectral)
#             embedding_objs = DeepFace.represent(img_path = 'curr_face_image.png', enforce_detection = False)
#             embedding = embedding_objs[0]['embedding']
#             assert isinstance(embedding, list)
#             assert len(embedding) == 2622
#             participant_trial_embed.append(np.array(embedding))

#         participant_trial_embed = np.stack(participant_trial_embed, axis=0)
#         np.save(os.path.join(data_save_folder, file_name2), participant_trial_embed)

# %%
import os
data_save_folder = '/content/drive/MyDrive/11777-Project-xs/data_face_seg_mean'
face_embed_file_list = os.listdir(data_save_folder)
# print(len(face_embed_file_list))
face_embed_file_list = [e for e in face_embed_file_list if 'embed.npy' in e]
sub_trial_list = {}
for file in face_embed_file_list:
    # print(file)
    sub, trial, _, _, _ = file.split('_')
    sub, trial = int(sub[1:]), int(trial[5:])
    if sub in sub_trial_list.keys():
        sub_trial_list[sub].append(trial)
    else:
        sub_trial_list[sub] = [trial]

for sub in range(1,23):
    print('sub {}, {} trials with facial video'.format(sub, len(sub_trial_list[sub])))
# Out:
# sub 1, 40 trials with facial video
# sub 2, 40 trials with facial video
# sub 3, 39 trials with facial video
# sub 4, 40 trials with facial video
# sub 5, 39 trials with facial video
# sub 6, 40 trials with facial video
# sub 7, 40 trials with facial video
# sub 8, 40 trials with facial video
# sub 9, 40 trials with facial video
# sub 10, 40 trials with facial video
# sub 11, 37 trials with facial video
# sub 12, 40 trials with facial video
# sub 13, 40 trials with facial video
# sub 14, 39 trials with facial video
# sub 15, 40 trials with facial video
# sub 16, 40 trials with facial video
# sub 17, 40 trials with facial video
# sub 18, 40 trials with facial video
# sub 19, 40 trials with facial video
# sub 20, 40 trials with facial video
# sub 21, 40 trials with facial video
# sub 22, 40 trials with facial video

# %%
def load_mean_frames_embed(sub, data_save_folder):
    '''
    sub starting index from 1 (not 0)
    '''
    face_embed_file_list = os.listdir(data_save_folder)
    sub_face_embed_file_list = [e for e in face_embed_file_list if 'embed' in e and sub==int(e[1:3])]
    sorted(sub_face_embed_file_list)
    # print(sub_face_embed_file_list)
    sub_frame_embed = []
    for file in auto.tqdm(sub_face_embed_file_list):
        embed = np.load(os.path.join(data_save_folder, file))
        sub_frame_embed.append(embed)
    sub_frame_embed = np.stack(sub_frame_embed, axis=0)
    print(sub_frame_embed.shape)
    return sub_frame_embed

# 's01_trial1_mean_frames_embed.npy'

data_save_folder = '/content/drive/MyDrive/11777-Project-xs/data_face_seg_mean'
all_sub_frame_embed = []
for sub in auto.tqdm(range(1,23)):
    sub_frame_embed = load_mean_frames_embed(sub, data_save_folder)
    all_sub_frame_embed.append(sub_frame_embed)
# Out:
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/39 [00:00<?, ?it/s]
# (39, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/39 [00:00<?, ?it/s]
# (39, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/37 [00:00<?, ?it/s]
# (37, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/39 [00:00<?, ?it/s]
# (39, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)

# %%
import pickle
file_name = 'all_sub_frame_embed.pkl'
# with open(os.path.join(data_save_folder, file_name), 'wb') as file:
#     pickle.dump(all_sub_frame_embed, file)

with open(os.path.join(data_save_folder, file_name), 'rb') as file:
    all_sub_frame_embed = pickle.load(file)

# %%
def generate_eeg_embed(eeg_data, LGG, CUDA=True):
    LGG.eval()
    eeg_embed = []
    # eeg_data = np.concatenate(eeg_data, axis=0)
    for eeg_data_trial in eeg_data:
        eeg_data_trial = torch.from_numpy(eeg_data_trial).float()
        if CUDA:
            eeg_data_trial = eeg_data_trial.cuda()
            LGG = LGG.cuda()
        with torch.no_grad():
            eeg_embed_trial = LGG.get_embed(eeg_data_trial)
        eeg_embed_trial = eeg_embed_trial.to('cpu')
        eeg_embed_trial = eeg_embed_trial.numpy()
        eeg_embed.append(eeg_embed_trial)
    eeg_embed = np.stack(eeg_embed, axis=0)
    return eeg_embed

# %%
def get_model_embed(args):
    if args.model == 'LGGNet':
        idx_local_graph = list(np.array(h5py.File('num_chan_local_graph_{}.hdf'.format(args.graph_type), 'r')['data']))
        channels = sum(idx_local_graph)
        input_size = (args.input_shape[0], channels, args.input_shape[2])
        model = LGGNet2(
            num_classes=args.num_class, input_size=input_size,
            sampling_rate=int(args.sampling_rate*args.scale_coefficient),
            num_T=args.T, out_graph=args.hidden,
            dropout_rate=args.dropout,
            pool=args.pool, pool_step_rate=args.pool_step_rate,
            idx_graph=idx_local_graph)

    return model

def transfer_weight(LGG, LGG_embed):
    for i, (pre_trained_layer, custom_layer) in enumerate(zip(LGG.children(), LGG_embed.children())):
        custom_layer.load_state_dict(pre_trained_layer.state_dict())
    return LGG_embed

# %%
import torch.nn as nn

class ComplexMLP(nn.Module):
    def __init__(self, eeg_embed_dim, face_embed_dim, output_dim, dropout_prob=0.5):
        super(ComplexMLP, self).__init__()
        self.eeg_embed_dim = eeg_embed_dim
        self.face_embed_dim = face_embed_dim
        self.combine_embed_dim = eeg_embed_dim + face_embed_dim//8
        ### transform facial embedding into lower dimension
        self.MLP1 = SimpleMLP(face_embed_dim, face_embed_dim//2, face_embed_dim//8)
        ### transform EEG embedding to facial embedding
        self.MLP2 = SimpleMLP(eeg_embed_dim, eeg_embed_dim//2, face_embed_dim//8)
        ### predictor
        self.predictor = SimpleMLP(self.combine_embed_dim, self.combine_embed_dim//2, 2)


    def forward(self, x):
        eeg_embed  = x[:, :self.eeg_embed_dim]
        face_embed = x[:, self.eeg_embed_dim:]
        face_embed_low = self.MLP1(face_embed)
        face_embed_pred = self.MLP2(eeg_embed)
        combine_embed = torch.concat([eeg_embed, face_embed_pred], axis=1)
        out = self.predictor(combine_embed)
        return out, face_embed_pred, face_embed_low

# %%
from utils import *

def train_one_epoch_cmlp(data_loader, net, loss_fn, loss_2, alpha, optimizer):
    net.train()
    tl, tl_mse, tl_total = Averager(), Averager(), Averager()

    pred_train = []
    act_train = []
    for i, (x_batch, y_batch) in enumerate(data_loader):
        if CUDA:
            x_batch, y_batch = x_batch.cuda(), y_batch.cuda()

        out, face_embed_pred, face_embed_low = net(x_batch)
        loss1 = loss_fn(out, y_batch)
        loss2 = loss_2(face_embed_pred, face_embed_low)
        loss_total = loss1 + alpha * loss2
        _, pred = torch.max(out, 1)
        pred_train.extend(pred.data.tolist())
        act_train.extend(y_batch.data.tolist())
        optimizer.zero_grad()
        loss_total.backward()
        optimizer.step()
        tl.add(loss1.item())
        tl_mse.add(loss_total.item())
        tl_total.add(loss2.item())
    return tl.item(), tl_mse.item(), tl_total.item(), pred_train, act_train


def predict_cmlp(data_loader, net, loss_fn, loss_2, alpha, ):
    net.eval()
    pred_val = []
    act_val = []
    vl, vl_mse, vl_total = Averager(), Averager(), Averager()
    with torch.no_grad():
        for i, (x_batch, y_batch) in enumerate(data_loader):
            if CUDA:
                x_batch, y_batch = x_batch.cuda(), y_batch.cuda()

            out, face_embed_pred, face_embed_low = net(x_batch)
            loss1 = loss_fn(out, y_batch)
            loss2 = loss_2(face_embed_pred, face_embed_low)
            loss_total = loss1 + alpha * loss2
            _, pred = torch.max(out, 1)
            vl.add(loss1.item())
            vl_mse.add(loss2.item())
            vl_total.add(loss_total.item())
            pred_val.extend(pred.data.tolist())
            act_val.extend(y_batch.data.tolist())
    return vl.item(), vl_mse.item(), vl_total.item(), pred_val, act_val

def mlp_set_up(args):
    set_gpu(args.gpu)
    ensure_path(args.mlp_save_path)
    torch.manual_seed(args.random_seed)
    torch.backends.cudnn.deterministic = True

# %%
def train_complexMLP(model, args, data_train, label_train, data_val, label_val, subject, alpha=1):
    '''
    alpha: trade of between two loss terms --> loss = loss_fn + alpha * loss_2
    '''
    seed_all(args.random_seed)
    save_name = '_sub' + str(subject) + '_mlp'
    mlp_set_up(args)

    train_loader = get_dataloader(data_train, label_train, args.batch_size)

    val_loader = get_dataloader(data_val, label_val, args.batch_size)

    # model = get_model(args)
    if CUDA:
        model = model.cuda()

    optimizer = torch.optim.Adam(model.parameters(), lr=args.learning_rate)

    ### binary classification prediction loss
    if args.LS:
        loss_fn = LabelSmoothing(args.LS_rate)
    else:
        loss_fn = nn.CrossEntropyLoss()
    ### facial embedding prediction loss
    loss_2 = nn.MSELoss()


    def save_model(name):
        previous_model = osp.join(args.mlp_save_path, '{}_cmlp.pth'.format(name))
        if os.path.exists(previous_model):
            os.remove(previous_model)
        torch.save(model.state_dict(), osp.join(args.mlp_save_path, '{}_cmlp.pth'.format(name)))

    trlog = {}
    trlog['args'] = vars(args)
    trlog['train_loss'] = []
    trlog['val_loss'] = []
    trlog['train_acc'] = []
    trlog['val_acc'] = []
    trlog['max_acc'] = 0.0
    trlog['F1'] = 0.0

    timer = Timer()
    patient = args.patient
    counter = 0

    for epoch in range(1, args.max_epoch + 1):

        loss_bi_train, loss_mse_train, loss_total_train, pred_train, act_train = train_one_epoch_cmlp(
            data_loader=train_loader, net=model, loss_fn=loss_fn, loss_2=loss_2, alpha=alpha, optimizer=optimizer)

        acc_train, f1_train, _ = get_metrics(y_pred=pred_train, y_true=act_train)
        print('epoch {}, loss_bi={:.4f} loss_mse={:.4f} loss_total={:.4f} acc={:.4f} f1={:.4f}'
              .format(epoch, loss_bi_train, loss_mse_train, loss_total_train, acc_train, f1_train))

        loss_bi_val, loss_mse_val, loss_total_val, pred_val, act_val = predict_cmlp(
            data_loader=val_loader, net=model, loss_fn=loss_fn, loss_2=loss_2, alpha=alpha
        )
        acc_val, f1_val, _ = get_metrics(y_pred=pred_val, y_true=act_val)
        print('epoch {}, val, loss_bi={:.4f} loss_mse={:.4f} loss_total={:.4f} acc={:.4f} f1={:.4f}'.
              format(epoch, loss_bi_val, loss_mse_val, loss_total_val, acc_val, f1_val))

        if acc_val >= trlog['max_acc']:
            trlog['max_acc'] = acc_val
            trlog['F1'] = f1_val
            save_model('candidate')
            counter = 0
        else:
            counter += 1
            if counter >= patient:
                print('early stopping')
                break

        trlog['train_loss'].append(loss_total_train)
        trlog['train_acc'].append(acc_train)
        trlog['val_loss'].append(loss_total_val)
        trlog['val_acc'].append(acc_val)

        print('ETA:{}/{} SUB:{}'.format(timer.measure(), timer.measure(epoch / args.max_epoch),
                                                 subject))
    # save the training log file
    save_name = 'trlog' + save_name
    experiment_setting = 'T_{}_pool_{}'.format(args.T, args.pool)
    save_path = osp.join(args.mlp_save_path, experiment_setting, 'log_train')
    ensure_path(save_path)
    torch.save(trlog, osp.join(save_path, save_name))

    return trlog['max_acc'], trlog['F1']

# %%
def test_complexMLP(model, args, data, label, reproduce, subject, alpha=1):
    mlp_set_up(args)
    seed_all(args.random_seed)
    test_loader = get_dataloader(data, label, args.batch_size)

    # model = get_model(args)
    if CUDA:
        model = model.cuda()
    ### binary classification prediction loss
    loss_fn = nn.CrossEntropyLoss()
    ### facial embedding prediction loss
    loss_2 = nn.MSELoss()

    if reproduce:
        model_name_reproduce = 'sub' + str(subject) + '_cmlp' + '.pth'
        data_type = 'model_{}_{}'.format(args.data_format, args.label_type)
        experiment_setting = 'T_{}_pool_{}'.format(args.T, args.pool)
        load_path_final = osp.join(args.mlp_save_path, experiment_setting, data_type, model_name_reproduce)
        model.load_state_dict(torch.load(load_path_final))
    else:
        model.load_state_dict(torch.load(args.mlp_load_path_final))
    loss_bi, loss_mse, loss_total, pred, act = predict_cmlp(
        data_loader=test_loader, net=model, loss_fn=loss_fn, loss_2=loss_2, alpha=alpha
    )
    acc, f1, cm = get_metrics(y_pred=pred, y_true=act)
    print('>>> Test:  loss_bi={:.4f} loss_mse={:.4f} loss_total={:.4f} acc={:.4f} f1={:.4f}'\
              .format(loss_bi, loss_mse, loss_total, acc, f1))
    return acc, pred, act

# %%
CUDA = torch.cuda.is_available()
fold = 'noFold'

with open(os.path.join(data_save_folder, file_name), 'rb') as file:
    all_sub_frame_embed = pickle.load(file)

for sub in range(22):

    print('='*48)
    cv = CrossValidation(args)
    eeg_data, label = cv.load_per_subject(sub)
    trial_to_remove = [i-1 for i in range(1,41) if i not in sub_trial_list[sub+1]]
    ### face embeddings
    sub_frame_embed = all_sub_frame_embed[sub]

    if len(trial_to_remove) > 0:
        mask = np.ones(eeg_data.shape[0], dtype=bool)
        mask[trial_to_remove] = False
        eeg_data = eeg_data[mask]
        label = label[mask]

    ### Load pre-trained LGG model weights
    ### and generate the EEG embeddings
    lgg_model = get_model(args)
    lgg_model_embed = get_model_embed(args)
    if CUDA:
        lgg_model = lgg_model.cuda()
    model_name_reproduce = 'sub' + str(sub+1) + '.pth'
    data_type = 'model_{}_{}'.format(args.data_format, args.label_type)
    experiment_setting = 'T_{}_pool_{}'.format(args.T, args.pool)
    save_path = os.path.join(args.save_path, experiment_setting, data_type)
    ensure_path(save_path)
    model_name_reproduce = os.path.join(save_path, model_name_reproduce)
    lgg_model.load_state_dict(torch.load(model_name_reproduce))
    lgg_model_embed = transfer_weight(lgg_model, lgg_model_embed)
    eeg_embed = generate_eeg_embed(eeg_data, lgg_model_embed, CUDA)

    ### concat eeg + face embedding
    eeg_face_embed = np.concatenate([eeg_embed, sub_frame_embed], axis=2)
    eeg_embed_dim, face_embed_dim = eeg_embed.shape[2], sub_frame_embed.shape[2]

    print(sub+1, trial_to_remove, sub_frame_embed.shape[0])
    trial_id = np.arange(eeg_data.shape[0])
    trial_id_train, trial_id_test = train_test_split(trial_id, test_size=0.2, random_state=42)
    trial_id_tra, trial_id_val = train_test_split(trial_id_train, test_size=0.2, random_state=42)
    print(trial_id_tra.shape[0], trial_id_val.shape[0], trial_id_test.shape[0])

    data_train, data_val, label_train, label_val = \
        eeg_face_embed[trial_id_tra], eeg_face_embed[trial_id_val], label[trial_id_tra], label[trial_id_val]
    data_train, data_val, label_train, label_val = \
        np.concatenate(data_train, axis=0), np.concatenate(data_val, axis=0), np.concatenate(label_train, axis=0), np.concatenate(label_val, axis=0)
    print(data_train.shape, data_val.shape, label_train.shape, label_val.shape)

    data_test, label_test = \
        eeg_face_embed[trial_id_test], label[trial_id_test]
    data_test, label_test = \
        np.concatenate(data_test, axis=0), np.concatenate(label_test, axis=0)
    print(data_test.shape, label_test.shape)

    data_train = torch.from_numpy(data_train).float()
    label_train = torch.from_numpy(label_train).long()
    data_val = torch.from_numpy(data_val).float()
    label_val = torch.from_numpy(label_val).long()
    data_test = torch.from_numpy(data_test).float()
    label_test = torch.from_numpy(label_test).long()


    ### define a complex MLP as the predictor
    predictor = ComplexMLP(eeg_embed_dim, face_embed_dim, 2)

    acc_val, F1_val = train_complexMLP(model=predictor, args=args,
                                      data_train=data_train,
                                      label_train=label_train,
                                      data_val=data_val,
                                      label_val=label_val,
                                      subject = str(sub+1))

    if CUDA:
        predictor = predictor.cuda()
    predictor.load_state_dict(torch.load(os.path.join(args.mlp_save_path, 'candidate_cmlp.pth')))

    model_name_reproduce = 'sub' + str(sub+1) + '_cmlp.pth'
    data_type = 'model_{}_{}'.format(args.data_format, args.label_type)
    experiment_setting = 'T_{}_pool_{}'.format(args.T, args.pool)
    save_path = os.path.join(args.mlp_save_path, experiment_setting, data_type)
    ensure_path(save_path)
    model_name_reproduce = os.path.join(save_path, model_name_reproduce)
    print(model_name_reproduce)
    torch.save(predictor.state_dict(), model_name_reproduce)

    acc_test, pred, act = test_complexMLP(model=predictor, args=args, data=data_test, label=label_test,
                                               reproduce=args.reproduce,
                                               subject=str(sub+1))
# Out:
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 1 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss_bi=0.6901 loss_mse=0.6924 loss_total=0.0023 acc=0.5280 f1=0.6550
# epoch 1, val, loss_bi=0.6882 loss_mse=0.0002 loss_total=0.6884 acc=0.5714 f1=0.7273
# ETA:0s/6s SUB:1
# epoch 2, loss_bi=0.6828 loss_mse=0.6833 loss_total=0.0005 acc=0.5947 f1=0.7379
# epoch 2, val, loss_bi=0.6881 loss_mse=0.0001 loss_total=0.6882 acc=0.5714 f1=0.7273
# ETA:0s/6s SUB:1
# epoch 3, loss_bi=0.6690 loss_mse=0.6693 loss_total=0.0003 acc=0.6000 f1=0.7414
# epoch 3, val, loss_bi=0.6929 loss_mse=0.0001 loss_total=0.6930 acc=0.5714 f1=0.7273
# ETA:0s/6s SUB:1
# epoch 4, loss_bi=0.6675 loss_mse=0.6679 loss_total=0.0004 acc=0.6000 f1=0.7466
# epoch 4, val, loss_bi=0.6871 loss_mse=0.0002 loss_total=0.6873 acc=0.5714 f1=0.7273
# ETA:0s/6s SUB:1
# epoch 5, loss_bi=0.6524 loss_mse=0.6530 loss_total=0.0006 acc=0.6347 f1=0.7642
# epoch 5, val, loss_bi=0.7025 loss_mse=0.0004 loss_total=0.7029 acc=0.5714 f1=0.7273
# ETA:0s/6s SUB:1
# epoch 6, loss_bi=0.6339 loss_mse=0.6346 loss_total=0.0007 acc=0.6533 f1=0.7628
# epoch 6, val, loss_bi=0.7160 loss_mse=0.0006 loss_total=0.7166 acc=0.5714 f1=0.7273
# ETA:0s/6s SUB:1
# epoch 7, loss_bi=0.6109 loss_mse=0.6117 loss_total=0.0008 acc=0.7147 f1=0.7938
# epoch 7, val, loss_bi=0.8063 loss_mse=0.0006 loss_total=0.8069 acc=0.5714 f1=0.7273
# ETA:0s/6s SUB:1
# epoch 8, loss_bi=0.5969 loss_mse=0.5983 loss_total=0.0014 acc=0.7040 f1=0.7683
# epoch 8, val, loss_bi=0.8388 loss_mse=0.0004 loss_total=0.8392 acc=0.5714 f1=0.7239
# ETA:1s/6s SUB:1
# epoch 9, loss_bi=0.5697 loss_mse=0.5706 loss_total=0.0009 acc=0.7253 f1=0.7832
# epoch 9, val, loss_bi=0.8351 loss_mse=0.0007 loss_total=0.8358 acc=0.5810 f1=0.7284
# ETA:1s/6s SUB:1
# epoch 10, loss_bi=0.5386 loss_mse=0.5394 loss_total=0.0008 acc=0.7920 f1=0.8361
# epoch 10, val, loss_bi=0.8059 loss_mse=0.0006 loss_total=0.8065 acc=0.5810 f1=0.7105
# ETA:1s/6s SUB:1
# epoch 11, loss_bi=0.5078 loss_mse=0.5087 loss_total=0.0009 acc=0.7867 f1=0.8347
# epoch 11, val, loss_bi=0.8271 loss_mse=0.0004 loss_total=0.8275 acc=0.5333 f1=0.6142
# ETA:1s/6s SUB:1
# epoch 12, loss_bi=0.4702 loss_mse=0.4714 loss_total=0.0012 acc=0.8240 f1=0.8559
# epoch 12, val, loss_bi=0.8758 loss_mse=0.0005 loss_total=0.8762 acc=0.5333 f1=0.6142
# ETA:1s/5s SUB:1
# epoch 13, loss_bi=0.4780 loss_mse=0.4792 loss_total=0.0012 acc=0.8027 f1=0.8341
# epoch 13, val, loss_bi=1.0096 loss_mse=0.0006 loss_total=1.0102 acc=0.5810 f1=0.7067
# ETA:1s/5s SUB:1
# epoch 14, loss_bi=0.4624 loss_mse=0.4635 loss_total=0.0011 acc=0.7947 f1=0.8293
# epoch 14, val, loss_bi=0.9443 loss_mse=0.0005 loss_total=0.9447 acc=0.5905 f1=0.7190
# ETA:1s/5s SUB:1
# epoch 15, loss_bi=0.4795 loss_mse=0.4803 loss_total=0.0008 acc=0.8027 f1=0.8426
# epoch 15, val, loss_bi=0.9192 loss_mse=0.0005 loss_total=0.9197 acc=0.5810 f1=0.7143
# ETA:1s/5s SUB:1
# epoch 16, loss_bi=0.4563 loss_mse=0.4571 loss_total=0.0008 acc=0.8107 f1=0.8460
# epoch 16, val, loss_bi=0.9506 loss_mse=0.0006 loss_total=0.9512 acc=0.5810 f1=0.7105
# ETA:1s/5s SUB:1
# epoch 17, loss_bi=0.4241 loss_mse=0.4250 loss_total=0.0009 acc=0.8587 f1=0.8870
# epoch 17, val, loss_bi=0.9609 loss_mse=0.0006 loss_total=0.9615 acc=0.5905 f1=0.6815
# ETA:1s/5s SUB:1
# epoch 18, loss_bi=0.4042 loss_mse=0.4054 loss_total=0.0013 acc=0.8480 f1=0.8747
# epoch 18, val, loss_bi=0.9650 loss_mse=0.0005 loss_total=0.9655 acc=0.5333 f1=0.6142
# ETA:1s/5s SUB:1
# epoch 19, loss_bi=0.3786 loss_mse=0.3798 loss_total=0.0012 acc=0.8987 f1=0.9167
# epoch 19, val, loss_bi=0.9685 loss_mse=0.0005 loss_total=0.9689 acc=0.5619 f1=0.6515
# ETA:1s/5s SUB:1
# epoch 20, loss_bi=0.4767 loss_mse=0.4779 loss_total=0.0012 acc=0.8240 f1=0.8565
# epoch 20, val, loss_bi=0.9569 loss_mse=0.0006 loss_total=0.9575 acc=0.4476 f1=0.4082
# ETA:1s/4s SUB:1
# epoch 21, loss_bi=0.4421 loss_mse=0.4429 loss_total=0.0008 acc=0.8267 f1=0.8602
# epoch 21, val, loss_bi=0.8667 loss_mse=0.0004 loss_total=0.8670 acc=0.4762 f1=0.4762
# ETA:2s/4s SUB:1
# epoch 22, loss_bi=0.3915 loss_mse=0.3922 loss_total=0.0007 acc=0.8987 f1=0.9177
# epoch 22, val, loss_bi=0.9572 loss_mse=0.0006 loss_total=0.9578 acc=0.5333 f1=0.5812
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_A/sub1_cmlp.pth
# using gpu: 0
# >>> Test:  loss_bi=0.8512 loss_mse=0.0006 loss_total=0.8518 acc=0.5667 f1=0.6790
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 2 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss_bi=0.7005 loss_mse=0.7045 loss_total=0.0040 acc=0.4880 f1=0.5429
# epoch 1, val, loss_bi=0.6245 loss_mse=0.0004 loss_total=0.6248 acc=0.8571 f1=0.9231
# ETA:0s/6s SUB:2
# epoch 2, loss_bi=0.6923 loss_mse=0.6929 loss_total=0.0005 acc=0.5600 f1=0.7048
# epoch 2, val, loss_bi=0.6514 loss_mse=0.0001 loss_total=0.6516 acc=0.8571 f1=0.9231
# ETA:0s/7s SUB:2
# epoch 3, loss_bi=0.6858 loss_mse=0.6860 loss_total=0.0002 acc=0.5387 f1=0.6311
# epoch 3, val, loss_bi=0.5974 loss_mse=0.0001 loss_total=0.5975 acc=0.8571 f1=0.9231
# ETA:0s/7s SUB:2
# epoch 4, loss_bi=0.6874 loss_mse=0.6875 loss_total=0.0001 acc=0.5627 f1=0.7018
# epoch 4, val, loss_bi=0.6301 loss_mse=0.0000 loss_total=0.6301 acc=0.8571 f1=0.9231
# ETA:0s/6s SUB:2
# epoch 5, loss_bi=0.6821 loss_mse=0.6822 loss_total=0.0001 acc=0.5893 f1=0.7210
# epoch 5, val, loss_bi=0.6306 loss_mse=0.0000 loss_total=0.6306 acc=0.8571 f1=0.9231
# ETA:0s/6s SUB:2
# epoch 6, loss_bi=0.6699 loss_mse=0.6700 loss_total=0.0001 acc=0.5893 f1=0.7094
# epoch 6, val, loss_bi=0.6237 loss_mse=0.0001 loss_total=0.6237 acc=0.8381 f1=0.9119
# ETA:0s/6s SUB:2
# epoch 7, loss_bi=0.6651 loss_mse=0.6654 loss_total=0.0003 acc=0.6320 f1=0.7315
# epoch 7, val, loss_bi=0.5967 loss_mse=0.0003 loss_total=0.5969 acc=0.8381 f1=0.9119
# ETA:0s/5s SUB:2
# epoch 8, loss_bi=0.6479 loss_mse=0.6484 loss_total=0.0004 acc=0.6480 f1=0.7306
# epoch 8, val, loss_bi=0.5996 loss_mse=0.0001 loss_total=0.5998 acc=0.7810 f1=0.8743
# ETA:0s/5s SUB:2
# epoch 9, loss_bi=0.6272 loss_mse=0.6278 loss_total=0.0006 acc=0.6747 f1=0.7359
# epoch 9, val, loss_bi=0.6241 loss_mse=0.0004 loss_total=0.6245 acc=0.6476 f1=0.7702
# ETA:0s/4s SUB:2
# epoch 10, loss_bi=0.5987 loss_mse=0.5998 loss_total=0.0010 acc=0.7253 f1=0.7746
# epoch 10, val, loss_bi=0.7796 loss_mse=0.0006 loss_total=0.7802 acc=0.4381 f1=0.5354
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_A/sub2_cmlp.pth
# using gpu: 0
# >>> Test:  loss_bi=0.6999 loss_mse=0.0000 loss_total=0.7000 acc=0.5000 f1=0.6667
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 3 [39] 39
# 24 7 8
# (360, 3166) (105, 3166) (360,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss_bi=0.8678 loss_mse=0.9557 loss_total=0.0879 acc=0.6139 f1=0.2723
# epoch 1, val, loss_bi=0.2403 loss_mse=0.0042 loss_total=0.2445 acc=1.0000 f1=0.0000
# ETA:0s/6s SUB:3
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# epoch 2, loss_bi=0.6229 loss_mse=0.6260 loss_total=0.0031 acc=0.7472 f1=0.0000
# epoch 2, val, loss_bi=0.4547 loss_mse=0.0010 loss_total=0.4557 acc=1.0000 f1=0.0000
# ETA:0s/6s SUB:3
# epoch 3, loss_bi=0.5939 loss_mse=0.5947 loss_total=0.0008 acc=0.7528 f1=0.0825
# epoch 3, val, loss_bi=0.3119 loss_mse=0.0002 loss_total=0.3122 acc=1.0000 f1=0.0000
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# ETA:0s/6s SUB:3
# epoch 4, loss_bi=0.6042 loss_mse=0.6044 loss_total=0.0002 acc=0.7500 f1=0.0000
# epoch 4, val, loss_bi=0.3972 loss_mse=0.0000 loss_total=0.3972 acc=1.0000 f1=0.0000
# ETA:0s/6s SUB:3
# epoch 5, loss_bi=0.5873 loss_mse=0.5875 loss_total=0.0001 acc=0.7500 f1=0.0000
# epoch 5, val, loss_bi=0.3554 loss_mse=0.0000 loss_total=0.3555 acc=1.0000 f1=0.0000
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# ETA:0s/6s SUB:3
# epoch 6, loss_bi=0.5793 loss_mse=0.5793 loss_total=0.0001 acc=0.7500 f1=0.0000
# epoch 6, val, loss_bi=0.3507 loss_mse=0.0000 loss_total=0.3507 acc=1.0000 f1=0.0000
# ETA:0s/6s SUB:3
# epoch 7, loss_bi=0.5828 loss_mse=0.5828 loss_total=0.0001 acc=0.7500 f1=0.0000
# epoch 7, val, loss_bi=0.3875 loss_mse=0.0000 loss_total=0.3875 acc=1.0000 f1=0.0000
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# ETA:0s/6s SUB:3
# epoch 8, loss_bi=0.5704 loss_mse=0.5705 loss_total=0.0001 acc=0.7472 f1=0.0000
# epoch 8, val, loss_bi=0.3326 loss_mse=0.0001 loss_total=0.3327 acc=1.0000 f1=0.0000
# ETA:1s/6s SUB:3
# epoch 9, loss_bi=0.5671 loss_mse=0.5672 loss_total=0.0001 acc=0.7500 f1=0.0000
# epoch 9, val, loss_bi=0.4521 loss_mse=0.0000 loss_total=0.4521 acc=1.0000 f1=0.0000
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# ETA:1s/6s SUB:3
# epoch 10, loss_bi=0.5664 loss_mse=0.5664 loss_total=0.0000 acc=0.7500 f1=0.0000
# epoch 10, val, loss_bi=0.2901 loss_mse=0.0000 loss_total=0.2901 acc=1.0000 f1=0.0000
# ETA:1s/6s SUB:3
# epoch 11, loss_bi=0.5616 loss_mse=0.5617 loss_total=0.0000 acc=0.7500 f1=0.0000
# epoch 11, val, loss_bi=0.4129 loss_mse=0.0000 loss_total=0.4129 acc=1.0000 f1=0.0000
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# ETA:1s/6s SUB:3
# epoch 12, loss_bi=0.5531 loss_mse=0.5531 loss_total=0.0000 acc=0.7500 f1=0.0000
# epoch 12, val, loss_bi=0.3908 loss_mse=0.0000 loss_total=0.3908 acc=1.0000 f1=0.0000
# ETA:1s/6s SUB:3
# epoch 13, loss_bi=0.5425 loss_mse=0.5425 loss_total=0.0000 acc=0.7500 f1=0.0000
# epoch 13, val, loss_bi=0.4162 loss_mse=0.0000 loss_total=0.4162 acc=1.0000 f1=0.0000
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# ETA:1s/6s SUB:3
# epoch 14, loss_bi=0.5298 loss_mse=0.5299 loss_total=0.0000 acc=0.7500 f1=0.0000
# epoch 14, val, loss_bi=0.4244 loss_mse=0.0000 loss_total=0.4244 acc=1.0000 f1=0.0000
# ETA:1s/6s SUB:3
# epoch 15, loss_bi=0.5351 loss_mse=0.5351 loss_total=0.0000 acc=0.7639 f1=0.1053
# epoch 15, val, loss_bi=0.4653 loss_mse=0.0000 loss_total=0.4653 acc=0.9905 f1=0.0000
# ETA:1s/6s SUB:3
# epoch 16, loss_bi=0.5251 loss_mse=0.5251 loss_total=0.0000 acc=0.7639 f1=0.2202
# epoch 16, val, loss_bi=0.3893 loss_mse=0.0000 loss_total=0.3893 acc=1.0000 f1=0.0000
# ETA:2s/6s SUB:3
# epoch 17, loss_bi=0.5202 loss_mse=0.5202 loss_total=0.0000 acc=0.7778 f1=0.2593
# epoch 17, val, loss_bi=0.4339 loss_mse=0.0000 loss_total=0.4339 acc=0.9619 f1=0.0000
# ETA:2s/6s SUB:3
# epoch 18, loss_bi=0.5083 loss_mse=0.5084 loss_total=0.0000 acc=0.7889 f1=0.3448
# epoch 18, val, loss_bi=0.4168 loss_mse=0.0000 loss_total=0.4168 acc=0.9429 f1=0.0000
# ETA:2s/5s SUB:3
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# epoch 19, loss_bi=0.5148 loss_mse=0.5148 loss_total=0.0000 acc=0.8167 f1=0.4500
# epoch 19, val, loss_bi=0.2832 loss_mse=0.0000 loss_total=0.2832 acc=1.0000 f1=0.0000
# ETA:2s/5s SUB:3
# epoch 20, loss_bi=0.5005 loss_mse=0.5005 loss_total=0.0000 acc=0.7917 f1=0.3363
# epoch 20, val, loss_bi=0.4013 loss_mse=0.0000 loss_total=0.4013 acc=0.9333 f1=0.0000
# ETA:2s/5s SUB:3
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# epoch 21, loss_bi=0.4642 loss_mse=0.4642 loss_total=0.0000 acc=0.8306 f1=0.5344
# epoch 21, val, loss_bi=0.4349 loss_mse=0.0000 loss_total=0.4349 acc=0.8667 f1=0.0000
# ETA:2s/5s SUB:3
# epoch 22, loss_bi=0.4559 loss_mse=0.4560 loss_total=0.0000 acc=0.8500 f1=0.6197
# epoch 22, val, loss_bi=0.3541 loss_mse=0.0000 loss_total=0.3541 acc=0.9524 f1=0.0000
# ETA:2s/5s SUB:3
# epoch 23, loss_bi=0.4700 loss_mse=0.4700 loss_total=0.0000 acc=0.8444 f1=0.5942
# epoch 23, val, loss_bi=0.6014 loss_mse=0.0000 loss_total=0.6014 acc=0.6952 f1=0.0000
# ETA:2s/5s SUB:3
# epoch 24, loss_bi=0.4627 loss_mse=0.4627 loss_total=0.0000 acc=0.8250 f1=0.6272
# epoch 24, val, loss_bi=0.2658 loss_mse=0.0000 loss_total=0.2658 acc=1.0000 f1=0.0000
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# ETA:2s/5s SUB:3
# epoch 25, loss_bi=0.4697 loss_mse=0.4697 loss_total=0.0000 acc=0.7972 f1=0.5166
# epoch 25, val, loss_bi=0.2553 loss_mse=0.0000 loss_total=0.2553 acc=1.0000 f1=0.0000
# ETA:2s/5s SUB:3
# epoch 26, loss_bi=0.4739 loss_mse=0.4739 loss_total=0.0000 acc=0.7972 f1=0.5521
# epoch 26, val, loss_bi=0.2233 loss_mse=0.0000 loss_total=0.2233 acc=1.0000 f1=0.0000
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# ETA:2s/5s SUB:3
# epoch 27, loss_bi=0.5021 loss_mse=0.5021 loss_total=0.0000 acc=0.8222 f1=0.5733
# epoch 27, val, loss_bi=0.2804 loss_mse=0.0000 loss_total=0.2804 acc=1.0000 f1=0.0000
# ETA:3s/5s SUB:3
# epoch 28, loss_bi=0.4660 loss_mse=0.4660 loss_total=0.0000 acc=0.8111 f1=0.4333
# epoch 28, val, loss_bi=0.7089 loss_mse=0.0000 loss_total=0.7089 acc=0.5143 f1=0.0000
# ETA:3s/5s SUB:3
# epoch 29, loss_bi=0.4869 loss_mse=0.4869 loss_total=0.0000 acc=0.8028 f1=0.5235
# epoch 29, val, loss_bi=0.5053 loss_mse=0.0000 loss_total=0.5053 acc=0.7810 f1=0.0000
# ETA:3s/5s SUB:3
# epoch 30, loss_bi=0.4203 loss_mse=0.4203 loss_total=0.0000 acc=0.8806 f1=0.7152
# epoch 30, val, loss_bi=0.2981 loss_mse=0.0000 loss_total=0.2981 acc=0.9810 f1=0.0000
# ETA:3s/5s SUB:3
# epoch 31, loss_bi=0.4377 loss_mse=0.4377 loss_total=0.0000 acc=0.8361 f1=0.6093
# epoch 31, val, loss_bi=0.3653 loss_mse=0.0000 loss_total=0.3653 acc=0.8762 f1=0.0000
# ETA:3s/5s SUB:3
# epoch 32, loss_bi=0.4170 loss_mse=0.4170 loss_total=0.0000 acc=0.8722 f1=0.7051
# epoch 32, val, loss_bi=0.8317 loss_mse=0.0000 loss_total=0.8317 acc=0.4762 f1=0.0000
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_A/sub3_cmlp.pth
# using gpu: 0
# >>> Test:  loss_bi=0.5285 loss_mse=0.0000 loss_total=0.5285 acc=0.7750 f1=0.1818
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 4 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss_bi=0.6193 loss_mse=0.6225 loss_total=0.0032 acc=0.7227 f1=0.0545
# epoch 1, val, loss_bi=0.9719 loss_mse=0.0003 loss_total=0.9722 acc=0.4286 f1=0.0000
# ETA:0s/7s SUB:4
# epoch 2, loss_bi=0.6058 loss_mse=0.6063 loss_total=0.0005 acc=0.7200 f1=0.0000
# epoch 2, val, loss_bi=0.7887 loss_mse=0.0001 loss_total=0.7888 acc=0.4286 f1=0.0000
# ETA:0s/7s SUB:4
# epoch 3, loss_bi=0.5961 loss_mse=0.5964 loss_total=0.0003 acc=0.7200 f1=0.0000
# epoch 3, val, loss_bi=0.7712 loss_mse=0.0003 loss_total=0.7715 acc=0.4286 f1=0.0000
# ETA:0s/7s SUB:4
# epoch 4, loss_bi=0.5883 loss_mse=0.5886 loss_total=0.0003 acc=0.7200 f1=0.0367
# epoch 4, val, loss_bi=0.8697 loss_mse=0.0001 loss_total=0.8698 acc=0.4286 f1=0.0000
# ETA:0s/7s SUB:4
# epoch 5, loss_bi=0.5717 loss_mse=0.5722 loss_total=0.0005 acc=0.7307 f1=0.1062
# epoch 5, val, loss_bi=0.8705 loss_mse=0.0003 loss_total=0.8708 acc=0.4381 f1=0.0328
# ETA:0s/7s SUB:4
# epoch 6, loss_bi=0.5446 loss_mse=0.5455 loss_total=0.0009 acc=0.7387 f1=0.1967
# epoch 6, val, loss_bi=0.7772 loss_mse=0.0004 loss_total=0.7776 acc=0.4762 f1=0.1791
# ETA:0s/7s SUB:4
# epoch 7, loss_bi=0.5094 loss_mse=0.5102 loss_total=0.0008 acc=0.7520 f1=0.3758
# epoch 7, val, loss_bi=0.8299 loss_mse=0.0005 loss_total=0.8305 acc=0.4571 f1=0.2400
# ETA:0s/6s SUB:4
# epoch 8, loss_bi=0.4611 loss_mse=0.4626 loss_total=0.0015 acc=0.8160 f1=0.6387
# epoch 8, val, loss_bi=1.2032 loss_mse=0.0013 loss_total=1.2045 acc=0.4952 f1=0.2090
# ETA:1s/6s SUB:4
# epoch 9, loss_bi=0.4859 loss_mse=0.4881 loss_total=0.0023 acc=0.7947 f1=0.5792
# epoch 9, val, loss_bi=0.8851 loss_mse=0.0007 loss_total=0.8858 acc=0.4857 f1=0.5000
# ETA:1s/6s SUB:4
# epoch 10, loss_bi=0.4364 loss_mse=0.4377 loss_total=0.0014 acc=0.8347 f1=0.6900
# epoch 10, val, loss_bi=0.9226 loss_mse=0.0006 loss_total=0.9232 acc=0.4857 f1=0.4255
# ETA:1s/5s SUB:4
# epoch 11, loss_bi=0.4251 loss_mse=0.4263 loss_total=0.0013 acc=0.8587 f1=0.7415
# epoch 11, val, loss_bi=0.9608 loss_mse=0.0005 loss_total=0.9613 acc=0.4952 f1=0.4301
# ETA:1s/5s SUB:4
# epoch 12, loss_bi=0.4047 loss_mse=0.4057 loss_total=0.0010 acc=0.8773 f1=0.7677
# epoch 12, val, loss_bi=0.9746 loss_mse=0.0004 loss_total=0.9750 acc=0.4857 f1=0.4255
# ETA:1s/5s SUB:4
# epoch 13, loss_bi=0.3943 loss_mse=0.3954 loss_total=0.0011 acc=0.8853 f1=0.7943
# epoch 13, val, loss_bi=1.1221 loss_mse=0.0005 loss_total=1.1226 acc=0.4762 f1=0.3038
# ETA:1s/5s SUB:4
# epoch 14, loss_bi=0.3698 loss_mse=0.3709 loss_total=0.0010 acc=0.8880 f1=0.7835
# epoch 14, val, loss_bi=1.0535 loss_mse=0.0004 loss_total=1.0540 acc=0.4571 f1=0.3294
# ETA:1s/5s SUB:4
# epoch 15, loss_bi=0.3885 loss_mse=0.3896 loss_total=0.0011 acc=0.8693 f1=0.7538
# epoch 15, val, loss_bi=1.0996 loss_mse=0.0005 loss_total=1.1001 acc=0.4667 f1=0.3488
# ETA:1s/4s SUB:4
# epoch 16, loss_bi=0.3860 loss_mse=0.3870 loss_total=0.0010 acc=0.8800 f1=0.7716
# epoch 16, val, loss_bi=0.8989 loss_mse=0.0005 loss_total=0.8993 acc=0.5905 f1=0.6195
# ETA:1s/5s SUB:4
# epoch 17, loss_bi=0.3733 loss_mse=0.3741 loss_total=0.0008 acc=0.8880 f1=0.7981
# epoch 17, val, loss_bi=1.0920 loss_mse=0.0004 loss_total=1.0924 acc=0.4667 f1=0.2821
# ETA:1s/4s SUB:4
# epoch 18, loss_bi=0.3496 loss_mse=0.3506 loss_total=0.0010 acc=0.9173 f1=0.8426
# epoch 18, val, loss_bi=1.0275 loss_mse=0.0005 loss_total=1.0281 acc=0.5048 f1=0.4348
# ETA:1s/4s SUB:4
# epoch 19, loss_bi=0.3452 loss_mse=0.3464 loss_total=0.0012 acc=0.9120 f1=0.8342
# epoch 19, val, loss_bi=1.0713 loss_mse=0.0007 loss_total=1.0720 acc=0.5333 f1=0.5051
# ETA:1s/4s SUB:4
# epoch 20, loss_bi=0.3664 loss_mse=0.3674 loss_total=0.0010 acc=0.8907 f1=0.7980
# epoch 20, val, loss_bi=0.9169 loss_mse=0.0004 loss_total=0.9172 acc=0.5714 f1=0.5794
# ETA:1s/4s SUB:4
# epoch 21, loss_bi=0.3532 loss_mse=0.3540 loss_total=0.0008 acc=0.9093 f1=0.8365
# epoch 21, val, loss_bi=1.1154 loss_mse=0.0005 loss_total=1.1159 acc=0.4762 f1=0.3210
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_A/sub4_cmlp.pth
# using gpu: 0
# >>> Test:  loss_bi=0.8782 loss_mse=0.0007 loss_total=0.8789 acc=0.5500 f1=0.5645
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 5 [39] 39
# 24 7 8
# (360, 3166) (105, 3166) (360,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss_bi=0.6594 loss_mse=0.6640 loss_total=0.0046 acc=0.6250 f1=0.2932
# epoch 1, val, loss_bi=0.9567 loss_mse=0.0005 loss_total=0.9572 acc=0.2857 f1=0.0000
# ETA:0s/6s SUB:5
# epoch 2, loss_bi=0.6399 loss_mse=0.6406 loss_total=0.0007 acc=0.6444 f1=0.2289
# epoch 2, val, loss_bi=0.9209 loss_mse=0.0003 loss_total=0.9212 acc=0.2857 f1=0.0000
# ETA:0s/6s SUB:5
# epoch 3, loss_bi=0.6076 loss_mse=0.6081 loss_total=0.0005 acc=0.6639 f1=0.2484
# epoch 3, val, loss_bi=0.8006 loss_mse=0.0002 loss_total=0.8008 acc=0.3714 f1=0.3265
# ETA:0s/6s SUB:5
# epoch 4, loss_bi=0.5623 loss_mse=0.5630 loss_total=0.0007 acc=0.7556 f1=0.6036
# epoch 4, val, loss_bi=0.8820 loss_mse=0.0003 loss_total=0.8823 acc=0.4000 f1=0.3883
# ETA:0s/6s SUB:5
# epoch 5, loss_bi=0.5196 loss_mse=0.5205 loss_total=0.0009 acc=0.8056 f1=0.7177
# epoch 5, val, loss_bi=0.8784 loss_mse=0.0007 loss_total=0.8791 acc=0.4762 f1=0.5378
# ETA:0s/6s SUB:5
# epoch 6, loss_bi=0.4838 loss_mse=0.4855 loss_total=0.0017 acc=0.8333 f1=0.7727
# epoch 6, val, loss_bi=1.2390 loss_mse=0.0004 loss_total=1.2394 acc=0.4000 f1=0.3883
# ETA:0s/5s SUB:5
# epoch 7, loss_bi=0.4591 loss_mse=0.4603 loss_total=0.0012 acc=0.8389 f1=0.7899
# epoch 7, val, loss_bi=1.1638 loss_mse=0.0003 loss_total=1.1640 acc=0.4095 f1=0.4151
# ETA:0s/5s SUB:5
# epoch 8, loss_bi=0.4567 loss_mse=0.4576 loss_total=0.0008 acc=0.8222 f1=0.7576
# epoch 8, val, loss_bi=1.1661 loss_mse=0.0003 loss_total=1.1664 acc=0.4000 f1=0.4000
# ETA:0s/4s SUB:5
# epoch 9, loss_bi=0.4479 loss_mse=0.4486 loss_total=0.0007 acc=0.8222 f1=0.7612
# epoch 9, val, loss_bi=0.9979 loss_mse=0.0002 loss_total=0.9981 acc=0.4571 f1=0.5289
# ETA:0s/4s SUB:5
# epoch 10, loss_bi=0.3906 loss_mse=0.3912 loss_total=0.0006 acc=0.8861 f1=0.8487
# epoch 10, val, loss_bi=1.2636 loss_mse=0.0002 loss_total=1.2638 acc=0.4000 f1=0.3883
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_A/sub5_cmlp.pth
# using gpu: 0
# >>> Test:  loss_bi=0.8363 loss_mse=0.0007 loss_total=0.8370 acc=0.4833 f1=0.4655
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 6 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss_bi=0.6868 loss_mse=0.6891 loss_total=0.0023 acc=0.6080 f1=0.0755
# epoch 1, val, loss_bi=0.7610 loss_mse=0.0004 loss_total=0.7614 acc=0.4286 f1=0.0000
# ETA:0s/5s SUB:6
# epoch 2, loss_bi=0.6549 loss_mse=0.6558 loss_total=0.0009 acc=0.6240 f1=0.2915
# epoch 2, val, loss_bi=0.7098 loss_mse=0.0004 loss_total=0.7101 acc=0.4571 f1=0.4673
# ETA:0s/6s SUB:6
# epoch 3, loss_bi=0.6207 loss_mse=0.6217 loss_total=0.0010 acc=0.6640 f1=0.4220
# epoch 3, val, loss_bi=0.7546 loss_mse=0.0010 loss_total=0.7556 acc=0.4286 f1=0.4118
# ETA:0s/4s SUB:6
# epoch 4, loss_bi=0.5797 loss_mse=0.5814 loss_total=0.0017 acc=0.7200 f1=0.5946
# epoch 4, val, loss_bi=0.8578 loss_mse=0.0005 loss_total=0.8583 acc=0.4190 f1=0.3297
# ETA:0s/4s SUB:6
# epoch 5, loss_bi=0.5079 loss_mse=0.5099 loss_total=0.0019 acc=0.7947 f1=0.7200
# epoch 5, val, loss_bi=0.8646 loss_mse=0.0014 loss_total=0.8660 acc=0.4667 f1=0.5172
# ETA:0s/4s SUB:6
# epoch 6, loss_bi=0.4778 loss_mse=0.4802 loss_total=0.0024 acc=0.7947 f1=0.7508
# epoch 6, val, loss_bi=1.3027 loss_mse=0.0012 loss_total=1.3039 acc=0.4381 f1=0.0923
# ETA:0s/4s SUB:6
# epoch 7, loss_bi=0.4793 loss_mse=0.4811 loss_total=0.0018 acc=0.7920 f1=0.7329
# epoch 7, val, loss_bi=1.1189 loss_mse=0.0006 loss_total=1.1195 acc=0.4095 f1=0.1622
# ETA:0s/4s SUB:6
# epoch 8, loss_bi=0.4405 loss_mse=0.4417 loss_total=0.0012 acc=0.8320 f1=0.7934
# epoch 8, val, loss_bi=1.0116 loss_mse=0.0004 loss_total=1.0121 acc=0.4286 f1=0.3617
# ETA:0s/4s SUB:6
# epoch 9, loss_bi=0.3923 loss_mse=0.3934 loss_total=0.0010 acc=0.8907 f1=0.8581
# epoch 9, val, loss_bi=1.1173 loss_mse=0.0004 loss_total=1.1177 acc=0.4571 f1=0.4124
# ETA:0s/3s SUB:6
# epoch 10, loss_bi=0.3774 loss_mse=0.3788 loss_total=0.0014 acc=0.8853 f1=0.8522
# epoch 10, val, loss_bi=1.1158 loss_mse=0.0008 loss_total=1.1166 acc=0.4857 f1=0.5091
# ETA:0s/4s SUB:6
# epoch 11, loss_bi=0.3447 loss_mse=0.3462 loss_total=0.0015 acc=0.9307 f1=0.9139
# epoch 11, val, loss_bi=1.1199 loss_mse=0.0005 loss_total=1.1203 acc=0.4667 f1=0.4815
# ETA:0s/4s SUB:6
# epoch 12, loss_bi=0.3348 loss_mse=0.3360 loss_total=0.0012 acc=0.9173 f1=0.8956
# epoch 12, val, loss_bi=1.1226 loss_mse=0.0007 loss_total=1.1232 acc=0.4381 f1=0.5354
# ETA:0s/4s SUB:6
# epoch 13, loss_bi=0.3775 loss_mse=0.3789 loss_total=0.0013 acc=0.8800 f1=0.8571
# epoch 13, val, loss_bi=1.1187 loss_mse=0.0004 loss_total=1.1192 acc=0.4857 f1=0.4906
# ETA:1s/4s SUB:6
# epoch 14, loss_bi=0.3378 loss_mse=0.3389 loss_total=0.0011 acc=0.9093 f1=0.8844
# epoch 14, val, loss_bi=1.1198 loss_mse=0.0004 loss_total=1.1202 acc=0.4762 f1=0.4762
# ETA:1s/4s SUB:6
# epoch 15, loss_bi=0.3199 loss_mse=0.3210 loss_total=0.0011 acc=0.9307 f1=0.9116
# epoch 15, val, loss_bi=1.2286 loss_mse=0.0005 loss_total=1.2291 acc=0.4762 f1=0.4762
# ETA:1s/4s SUB:6
# epoch 16, loss_bi=0.3135 loss_mse=0.3146 loss_total=0.0011 acc=0.9440 f1=0.9302
# epoch 16, val, loss_bi=1.3481 loss_mse=0.0004 loss_total=1.3485 acc=0.4857 f1=0.4706
# ETA:1s/4s SUB:6
# epoch 17, loss_bi=0.3109 loss_mse=0.3118 loss_total=0.0009 acc=0.9493 f1=0.9365
# epoch 17, val, loss_bi=1.3664 loss_mse=0.0005 loss_total=1.3669 acc=0.4667 f1=0.4286
# ETA:1s/4s SUB:6
# epoch 18, loss_bi=0.3069 loss_mse=0.3078 loss_total=0.0009 acc=0.9413 f1=0.9257
# epoch 18, val, loss_bi=1.2941 loss_mse=0.0004 loss_total=1.2945 acc=0.4857 f1=0.4706
# ETA:1s/4s SUB:6
# epoch 19, loss_bi=0.2882 loss_mse=0.2893 loss_total=0.0011 acc=0.9547 f1=0.9428
# epoch 19, val, loss_bi=1.2720 loss_mse=0.0006 loss_total=1.2727 acc=0.4571 f1=0.4865
# ETA:1s/4s SUB:6
# epoch 20, loss_bi=0.2638 loss_mse=0.2649 loss_total=0.0011 acc=0.9707 f1=0.9635
# epoch 20, val, loss_bi=1.3728 loss_mse=0.0008 loss_total=1.3736 acc=0.4667 f1=0.5088
# ETA:1s/4s SUB:6
# epoch 21, loss_bi=0.2702 loss_mse=0.2714 loss_total=0.0012 acc=0.9573 f1=0.9481
# epoch 21, val, loss_bi=1.3272 loss_mse=0.0005 loss_total=1.3277 acc=0.4857 f1=0.4600
# ETA:1s/4s SUB:6
# epoch 22, loss_bi=0.2623 loss_mse=0.2635 loss_total=0.0012 acc=0.9680 f1=0.9597
# epoch 22, val, loss_bi=1.3609 loss_mse=0.0005 loss_total=1.3614 acc=0.4571 f1=0.4242
# ETA:1s/4s SUB:6
# epoch 23, loss_bi=0.2719 loss_mse=0.2728 loss_total=0.0009 acc=0.9573 f1=0.9463
# epoch 23, val, loss_bi=1.3353 loss_mse=0.0004 loss_total=1.3358 acc=0.4762 f1=0.4860
# ETA:1s/4s SUB:6
# epoch 24, loss_bi=0.2420 loss_mse=0.2428 loss_total=0.0009 acc=0.9893 f1=0.9868
# epoch 24, val, loss_bi=1.3778 loss_mse=0.0006 loss_total=1.3785 acc=0.4571 f1=0.4956
# ETA:1s/4s SUB:6
# epoch 25, loss_bi=0.2405 loss_mse=0.2415 loss_total=0.0010 acc=0.9893 f1=0.9868
# epoch 25, val, loss_bi=1.4052 loss_mse=0.0007 loss_total=1.4059 acc=0.4762 f1=0.5217
# ETA:2s/4s SUB:6
# epoch 26, loss_bi=0.2320 loss_mse=0.2329 loss_total=0.0009 acc=0.9893 f1=0.9866
# epoch 26, val, loss_bi=1.3904 loss_mse=0.0008 loss_total=1.3911 acc=0.4571 f1=0.5210
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_A/sub6_cmlp.pth
# using gpu: 0
# >>> Test:  loss_bi=1.0758 loss_mse=0.0005 loss_total=1.0763 acc=0.5667 f1=0.4222
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 7 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss_bi=0.6632 loss_mse=0.6756 loss_total=0.0124 acc=0.6267 f1=0.7611
# epoch 1, val, loss_bi=0.8150 loss_mse=0.0009 loss_total=0.8159 acc=0.2857 f1=0.4444
# ETA:0s/8s SUB:7
# epoch 2, loss_bi=0.6019 loss_mse=0.6029 loss_total=0.0009 acc=0.7600 f1=0.8632
# epoch 2, val, loss_bi=1.0801 loss_mse=0.0003 loss_total=1.0803 acc=0.2857 f1=0.4444
# ETA:0s/8s SUB:7
# epoch 3, loss_bi=0.5843 loss_mse=0.5847 loss_total=0.0004 acc=0.7600 f1=0.8636
# epoch 3, val, loss_bi=0.9568 loss_mse=0.0001 loss_total=0.9569 acc=0.2857 f1=0.4444
# ETA:0s/8s SUB:7
# epoch 4, loss_bi=0.5638 loss_mse=0.5640 loss_total=0.0002 acc=0.7600 f1=0.8636
# epoch 4, val, loss_bi=1.1129 loss_mse=0.0000 loss_total=1.1130 acc=0.2857 f1=0.4444
# ETA:0s/8s SUB:7
# epoch 5, loss_bi=0.5604 loss_mse=0.5605 loss_total=0.0001 acc=0.7600 f1=0.8636
# epoch 5, val, loss_bi=0.9572 loss_mse=0.0000 loss_total=0.9572 acc=0.2857 f1=0.4444
# ETA:0s/8s SUB:7
# epoch 6, loss_bi=0.5562 loss_mse=0.5564 loss_total=0.0002 acc=0.7600 f1=0.8636
# epoch 6, val, loss_bi=0.9650 loss_mse=0.0001 loss_total=0.9651 acc=0.2857 f1=0.4444
# ETA:0s/8s SUB:7
# epoch 7, loss_bi=0.5465 loss_mse=0.5468 loss_total=0.0003 acc=0.7600 f1=0.8636
# epoch 7, val, loss_bi=1.0455 loss_mse=0.0004 loss_total=1.0459 acc=0.2857 f1=0.4444
# ETA:1s/8s SUB:7
# epoch 8, loss_bi=0.5360 loss_mse=0.5366 loss_total=0.0006 acc=0.7653 f1=0.8663
# epoch 8, val, loss_bi=0.8611 loss_mse=0.0003 loss_total=0.8613 acc=0.3143 f1=0.4545
# ETA:1s/8s SUB:7
# epoch 9, loss_bi=0.5139 loss_mse=0.5143 loss_total=0.0005 acc=0.7707 f1=0.8685
# epoch 9, val, loss_bi=0.9079 loss_mse=0.0010 loss_total=0.9090 acc=0.3429 f1=0.4651
# ETA:1s/8s SUB:7
# epoch 10, loss_bi=0.4842 loss_mse=0.4867 loss_total=0.0025 acc=0.7867 f1=0.8754
# epoch 10, val, loss_bi=0.9373 loss_mse=0.0009 loss_total=0.9383 acc=0.3810 f1=0.4800
# ETA:1s/7s SUB:7
# epoch 11, loss_bi=0.4634 loss_mse=0.4669 loss_total=0.0035 acc=0.8320 f1=0.8969
# epoch 11, val, loss_bi=0.7796 loss_mse=0.0014 loss_total=0.7810 acc=0.5333 f1=0.4494
# ETA:1s/7s SUB:7
# epoch 12, loss_bi=0.4347 loss_mse=0.4366 loss_total=0.0019 acc=0.8373 f1=0.8971
# epoch 12, val, loss_bi=1.2287 loss_mse=0.0006 loss_total=1.2293 acc=0.3429 f1=0.4651
# ETA:1s/7s SUB:7
# epoch 13, loss_bi=0.4103 loss_mse=0.4123 loss_total=0.0021 acc=0.8587 f1=0.9094
# epoch 13, val, loss_bi=1.3302 loss_mse=0.0012 loss_total=1.3314 acc=0.3524 f1=0.4687
# ETA:1s/6s SUB:7
# epoch 14, loss_bi=0.3776 loss_mse=0.3805 loss_total=0.0029 acc=0.8880 f1=0.9281
# epoch 14, val, loss_bi=1.0398 loss_mse=0.0013 loss_total=1.0411 acc=0.4381 f1=0.4486
# ETA:1s/6s SUB:7
# epoch 15, loss_bi=0.3778 loss_mse=0.3797 loss_total=0.0019 acc=0.8907 f1=0.9292
# epoch 15, val, loss_bi=1.7437 loss_mse=0.0007 loss_total=1.7444 acc=0.3333 f1=0.4615
# ETA:1s/6s SUB:7
# epoch 16, loss_bi=0.4485 loss_mse=0.4497 loss_total=0.0012 acc=0.8240 f1=0.8878
# epoch 16, val, loss_bi=1.8236 loss_mse=0.0005 loss_total=1.8241 acc=0.3238 f1=0.4580
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_A/sub7_cmlp.pth
# using gpu: 0
# >>> Test:  loss_bi=0.9474 loss_mse=0.0012 loss_total=0.9486 acc=0.3917 f1=0.4895
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 8 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss_bi=0.6791 loss_mse=0.7167 loss_total=0.0376 acc=0.6320 f1=0.7527
# epoch 1, val, loss_bi=1.0868 loss_mse=0.0022 loss_total=1.0890 acc=0.2857 f1=0.4444
# ETA:0s/5s SUB:8
# epoch 2, loss_bi=0.6123 loss_mse=0.6146 loss_total=0.0023 acc=0.7200 f1=0.8372
# epoch 2, val, loss_bi=0.8476 loss_mse=0.0008 loss_total=0.8484 acc=0.2952 f1=0.4478
# ETA:0s/6s SUB:8
# epoch 3, loss_bi=0.5903 loss_mse=0.5911 loss_total=0.0008 acc=0.7307 f1=0.8394
# epoch 3, val, loss_bi=0.9330 loss_mse=0.0001 loss_total=0.9332 acc=0.3238 f1=0.4409
# ETA:0s/6s SUB:8
# epoch 4, loss_bi=0.5510 loss_mse=0.5512 loss_total=0.0002 acc=0.7707 f1=0.8567
# epoch 4, val, loss_bi=1.2498 loss_mse=0.0001 loss_total=1.2499 acc=0.3238 f1=0.4496
# ETA:0s/6s SUB:8
# epoch 5, loss_bi=0.5292 loss_mse=0.5294 loss_total=0.0002 acc=0.7787 f1=0.8596
# epoch 5, val, loss_bi=0.8723 loss_mse=0.0000 loss_total=0.8723 acc=0.3810 f1=0.4348
# ETA:0s/6s SUB:8
# epoch 6, loss_bi=0.4831 loss_mse=0.4832 loss_total=0.0002 acc=0.8133 f1=0.8805
# epoch 6, val, loss_bi=0.9340 loss_mse=0.0002 loss_total=0.9343 acc=0.4095 f1=0.4259
# ETA:0s/6s SUB:8
# epoch 7, loss_bi=0.4550 loss_mse=0.4552 loss_total=0.0002 acc=0.8320 f1=0.8893
# epoch 7, val, loss_bi=1.0972 loss_mse=0.0000 loss_total=1.0972 acc=0.3905 f1=0.4286
# ETA:0s/5s SUB:8
# epoch 8, loss_bi=0.4230 loss_mse=0.4231 loss_total=0.0001 acc=0.8400 f1=0.8932
# epoch 8, val, loss_bi=1.2471 loss_mse=0.0000 loss_total=1.2471 acc=0.3905 f1=0.4386
# ETA:0s/5s SUB:8
# epoch 9, loss_bi=0.4118 loss_mse=0.4120 loss_total=0.0002 acc=0.8507 f1=0.8996
# epoch 9, val, loss_bi=1.2100 loss_mse=0.0000 loss_total=1.2100 acc=0.3905 f1=0.4074
# ETA:0s/4s SUB:8
# epoch 10, loss_bi=0.3791 loss_mse=0.3792 loss_total=0.0001 acc=0.8880 f1=0.9234
# epoch 10, val, loss_bi=1.2014 loss_mse=0.0001 loss_total=1.2015 acc=0.3714 f1=0.3654
# ETA:0s/4s SUB:8
# epoch 11, loss_bi=0.3801 loss_mse=0.3809 loss_total=0.0008 acc=0.8880 f1=0.9236
# epoch 11, val, loss_bi=1.5120 loss_mse=0.0000 loss_total=1.5121 acc=0.3810 f1=0.4144
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_A/sub8_cmlp.pth
# using gpu: 0
# >>> Test:  loss_bi=0.9535 loss_mse=0.0002 loss_total=0.9537 acc=0.4167 f1=0.4853
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 9 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss_bi=0.8979 loss_mse=0.9474 loss_total=0.0495 acc=0.4880 f1=0.5271
# epoch 1, val, loss_bi=0.6938 loss_mse=0.0020 loss_total=0.6959 acc=0.5238 f1=0.5833
# ETA:0s/5s SUB:9
# epoch 2, loss_bi=0.7089 loss_mse=0.7107 loss_total=0.0018 acc=0.5840 f1=0.7143
# epoch 2, val, loss_bi=0.6897 loss_mse=0.0007 loss_total=0.6904 acc=0.5714 f1=0.7273
# ETA:0s/6s SUB:9
# epoch 3, loss_bi=0.7041 loss_mse=0.7045 loss_total=0.0005 acc=0.5280 f1=0.6274
# epoch 3, val, loss_bi=0.7010 loss_mse=0.0001 loss_total=0.7012 acc=0.5714 f1=0.7273
# ETA:0s/6s SUB:9
# epoch 4, loss_bi=0.6806 loss_mse=0.6807 loss_total=0.0002 acc=0.6000 f1=0.7405
# epoch 4, val, loss_bi=0.6877 loss_mse=0.0000 loss_total=0.6878 acc=0.5714 f1=0.7273
# ETA:0s/6s SUB:9
# epoch 5, loss_bi=0.6674 loss_mse=0.6675 loss_total=0.0001 acc=0.6080 f1=0.7443
# epoch 5, val, loss_bi=0.6925 loss_mse=0.0000 loss_total=0.6925 acc=0.5714 f1=0.7273
# ETA:0s/6s SUB:9
# epoch 6, loss_bi=0.6679 loss_mse=0.6679 loss_total=0.0001 acc=0.6080 f1=0.7504
# epoch 6, val, loss_bi=0.6875 loss_mse=0.0000 loss_total=0.6875 acc=0.5714 f1=0.7273
# ETA:0s/6s SUB:9
# epoch 7, loss_bi=0.6585 loss_mse=0.6585 loss_total=0.0000 acc=0.6320 f1=0.7500
# epoch 7, val, loss_bi=0.6958 loss_mse=0.0000 loss_total=0.6958 acc=0.5714 f1=0.7273
# ETA:0s/6s SUB:9
# epoch 8, loss_bi=0.6468 loss_mse=0.6468 loss_total=0.0000 acc=0.6507 f1=0.7486
# epoch 8, val, loss_bi=0.6988 loss_mse=0.0000 loss_total=0.6988 acc=0.5619 f1=0.7195
# ETA:1s/6s SUB:9
# epoch 9, loss_bi=0.6298 loss_mse=0.6298 loss_total=0.0000 acc=0.6773 f1=0.7755
# epoch 9, val, loss_bi=0.6976 loss_mse=0.0000 loss_total=0.6976 acc=0.5524 f1=0.6619
# ETA:1s/5s SUB:9
# epoch 10, loss_bi=0.6184 loss_mse=0.6184 loss_total=0.0000 acc=0.6667 f1=0.7664
# epoch 10, val, loss_bi=0.7684 loss_mse=0.0000 loss_total=0.7684 acc=0.4095 f1=0.1622
# ETA:1s/5s SUB:9
# epoch 11, loss_bi=0.6071 loss_mse=0.6071 loss_total=0.0000 acc=0.6827 f1=0.7576
# epoch 11, val, loss_bi=0.7186 loss_mse=0.0000 loss_total=0.7186 acc=0.5619 f1=0.6761
# ETA:1s/5s SUB:9
# epoch 12, loss_bi=0.6164 loss_mse=0.6164 loss_total=0.0000 acc=0.6800 f1=0.7436
# epoch 12, val, loss_bi=0.8121 loss_mse=0.0000 loss_total=0.8121 acc=0.5619 f1=0.7195
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_A/sub9_cmlp.pth
# using gpu: 0
# >>> Test:  loss_bi=0.6510 loss_mse=0.0000 loss_total=0.6510 acc=0.6250 f1=0.7692
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 10 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss_bi=0.8825 loss_mse=0.9935 loss_total=0.1110 acc=0.5520 f1=0.6680
# epoch 1, val, loss_bi=1.2237 loss_mse=0.0033 loss_total=1.2270 acc=0.2857 f1=0.4444
# ETA:0s/7s SUB:10
# epoch 2, loss_bi=0.6614 loss_mse=0.6641 loss_total=0.0026 acc=0.7253 f1=0.8373
# epoch 2, val, loss_bi=0.7630 loss_mse=0.0008 loss_total=0.7638 acc=0.2857 f1=0.4444
# ETA:0s/7s SUB:10
# epoch 3, loss_bi=0.6648 loss_mse=0.6655 loss_total=0.0007 acc=0.6773 f1=0.8039
# epoch 3, val, loss_bi=0.9949 loss_mse=0.0002 loss_total=0.9952 acc=0.2857 f1=0.4444
# ETA:0s/7s SUB:10
# epoch 4, loss_bi=0.6320 loss_mse=0.6323 loss_total=0.0002 acc=0.6853 f1=0.8078
# epoch 4, val, loss_bi=1.0110 loss_mse=0.0001 loss_total=1.0110 acc=0.2857 f1=0.4444
# ETA:0s/7s SUB:10
# epoch 5, loss_bi=0.6117 loss_mse=0.6119 loss_total=0.0001 acc=0.7173 f1=0.8349
# epoch 5, val, loss_bi=0.9401 loss_mse=0.0000 loss_total=0.9402 acc=0.2857 f1=0.4444
# ETA:0s/7s SUB:10
# epoch 6, loss_bi=0.5954 loss_mse=0.5955 loss_total=0.0001 acc=0.7253 f1=0.8398
# epoch 6, val, loss_bi=1.0157 loss_mse=0.0000 loss_total=1.0157 acc=0.2857 f1=0.4444
# ETA:0s/8s SUB:10
# epoch 7, loss_bi=0.6077 loss_mse=0.6077 loss_total=0.0001 acc=0.7253 f1=0.8398
# epoch 7, val, loss_bi=0.9883 loss_mse=0.0000 loss_total=0.9884 acc=0.2857 f1=0.4444
# ETA:1s/7s SUB:10
# epoch 8, loss_bi=0.5870 loss_mse=0.5870 loss_total=0.0000 acc=0.7147 f1=0.8336
# epoch 8, val, loss_bi=0.9692 loss_mse=0.0000 loss_total=0.9692 acc=0.2857 f1=0.4444
# ETA:1s/7s SUB:10
# epoch 9, loss_bi=0.5884 loss_mse=0.5885 loss_total=0.0001 acc=0.7200 f1=0.8372
# epoch 9, val, loss_bi=0.8959 loss_mse=0.0000 loss_total=0.8959 acc=0.2857 f1=0.4444
# ETA:1s/7s SUB:10
# epoch 10, loss_bi=0.5638 loss_mse=0.5638 loss_total=0.0000 acc=0.7333 f1=0.8423
# epoch 10, val, loss_bi=1.0562 loss_mse=0.0000 loss_total=1.0562 acc=0.2857 f1=0.4444
# ETA:1s/7s SUB:10
# epoch 11, loss_bi=0.5522 loss_mse=0.5522 loss_total=0.0000 acc=0.7573 f1=0.8530
# epoch 11, val, loss_bi=1.2266 loss_mse=0.0000 loss_total=1.2266 acc=0.2857 f1=0.4444
# ETA:2s/9s SUB:10
# epoch 12, loss_bi=0.5570 loss_mse=0.5570 loss_total=0.0000 acc=0.7440 f1=0.8389
# epoch 12, val, loss_bi=1.3899 loss_mse=0.0000 loss_total=1.3899 acc=0.2857 f1=0.4444
# ETA:2s/10s SUB:10
# epoch 13, loss_bi=0.5745 loss_mse=0.5745 loss_total=0.0000 acc=0.7600 f1=0.8490
# epoch 13, val, loss_bi=1.3627 loss_mse=0.0000 loss_total=1.3627 acc=0.2857 f1=0.4444
# ETA:2s/10s SUB:10
# epoch 14, loss_bi=0.5187 loss_mse=0.5188 loss_total=0.0000 acc=0.7920 f1=0.8696
# epoch 14, val, loss_bi=0.8586 loss_mse=0.0000 loss_total=0.8586 acc=0.3619 f1=0.4370
# ETA:2s/10s SUB:10
# epoch 15, loss_bi=0.5011 loss_mse=0.5011 loss_total=0.0000 acc=0.8000 f1=0.8735
# epoch 15, val, loss_bi=0.9808 loss_mse=0.0000 loss_total=0.9808 acc=0.3524 f1=0.4426
# ETA:2s/9s SUB:10
# epoch 16, loss_bi=0.4694 loss_mse=0.4695 loss_total=0.0000 acc=0.8107 f1=0.8782
# epoch 16, val, loss_bi=1.1419 loss_mse=0.0000 loss_total=1.1419 acc=0.3429 f1=0.4390
# ETA:3s/9s SUB:10
# epoch 17, loss_bi=0.4961 loss_mse=0.4961 loss_total=0.0000 acc=0.7893 f1=0.8621
# epoch 17, val, loss_bi=1.1892 loss_mse=0.0000 loss_total=1.1892 acc=0.3429 f1=0.4390
# ETA:3s/9s SUB:10
# epoch 18, loss_bi=0.4683 loss_mse=0.4684 loss_total=0.0000 acc=0.8133 f1=0.8746
# epoch 18, val, loss_bi=1.2257 loss_mse=0.0000 loss_total=1.2257 acc=0.3048 f1=0.4252
# ETA:3s/8s SUB:10
# epoch 19, loss_bi=0.4958 loss_mse=0.4959 loss_total=0.0000 acc=0.8187 f1=0.8807
# epoch 19, val, loss_bi=1.2553 loss_mse=0.0000 loss_total=1.2553 acc=0.2952 f1=0.4219
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_A/sub10_cmlp.pth
# using gpu: 0
# >>> Test:  loss_bi=0.7990 loss_mse=0.0000 loss_total=0.7990 acc=0.4250 f1=0.4202
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 11 [37, 38, 39] 37
# 23 6 8
# (345, 3166) (90, 3166) (345,) (90,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss_bi=0.6381 loss_mse=0.6619 loss_total=0.0238 acc=0.6957 f1=0.2657
# epoch 1, val, loss_bi=0.7345 loss_mse=0.0017 loss_total=0.7362 acc=0.6667 f1=0.0000
# ETA:0s/7s SUB:11
# epoch 2, loss_bi=0.4617 loss_mse=0.4633 loss_total=0.0016 acc=0.8406 f1=0.6707
# epoch 2, val, loss_bi=0.6603 loss_mse=0.0006 loss_total=0.6609 acc=0.7111 f1=0.3500
# ETA:0s/7s SUB:11
# epoch 3, loss_bi=0.3198 loss_mse=0.3207 loss_total=0.0009 acc=0.9565 f1=0.9275
# epoch 3, val, loss_bi=0.8517 loss_mse=0.0015 loss_total=0.8532 acc=0.5556 f1=0.5238
# ETA:0s/5s SUB:11
# epoch 4, loss_bi=0.3554 loss_mse=0.3564 loss_total=0.0011 acc=0.8928 f1=0.8326
# epoch 4, val, loss_bi=0.7954 loss_mse=0.0004 loss_total=0.7958 acc=0.6667 f1=0.3478
# ETA:0s/5s SUB:11
# epoch 5, loss_bi=0.2741 loss_mse=0.2746 loss_total=0.0005 acc=0.9652 f1=0.9439
# epoch 5, val, loss_bi=0.7204 loss_mse=0.0001 loss_total=0.7205 acc=0.6556 f1=0.3922
# ETA:0s/4s SUB:11
# epoch 6, loss_bi=0.2718 loss_mse=0.2720 loss_total=0.0002 acc=0.9652 f1=0.9429
# epoch 6, val, loss_bi=0.6975 loss_mse=0.0002 loss_total=0.6977 acc=0.6000 f1=0.4000
# ETA:0s/4s SUB:11
# epoch 7, loss_bi=0.2797 loss_mse=0.2798 loss_total=0.0001 acc=0.9681 f1=0.9479
# epoch 7, val, loss_bi=0.7448 loss_mse=0.0000 loss_total=0.7449 acc=0.6667 f1=0.4000
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_A/sub11_cmlp.pth
# using gpu: 0
# >>> Test:  loss_bi=0.8896 loss_mse=0.0006 loss_total=0.8902 acc=0.4667 f1=0.2195
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 12 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss_bi=0.5502 loss_mse=0.5572 loss_total=0.0070 acc=0.7280 f1=0.8381
# epoch 1, val, loss_bi=0.3248 loss_mse=0.0007 loss_total=0.3255 acc=1.0000 f1=1.0000
# ETA:0s/6s SUB:12
# epoch 2, loss_bi=0.4746 loss_mse=0.4757 loss_total=0.0011 acc=0.8400 f1=0.9130
# epoch 2, val, loss_bi=0.2842 loss_mse=0.0005 loss_total=0.2847 acc=1.0000 f1=1.0000
# ETA:0s/6s SUB:12
# epoch 3, loss_bi=0.4416 loss_mse=0.4425 loss_total=0.0009 acc=0.8400 f1=0.9130
# epoch 3, val, loss_bi=0.2753 loss_mse=0.0003 loss_total=0.2756 acc=1.0000 f1=1.0000
# ETA:0s/6s SUB:12
# epoch 4, loss_bi=0.3869 loss_mse=0.3883 loss_total=0.0014 acc=0.8480 f1=0.9170
# epoch 4, val, loss_bi=0.2603 loss_mse=0.0011 loss_total=0.2614 acc=0.9905 f1=0.9952
# ETA:0s/5s SUB:12
# epoch 5, loss_bi=0.3261 loss_mse=0.3294 loss_total=0.0033 acc=0.9280 f1=0.9587
# epoch 5, val, loss_bi=0.2823 loss_mse=0.0016 loss_total=0.2838 acc=0.9524 f1=0.9756
# ETA:0s/4s SUB:12
# epoch 6, loss_bi=0.2785 loss_mse=0.2830 loss_total=0.0046 acc=0.9680 f1=0.9811
# epoch 6, val, loss_bi=0.4133 loss_mse=0.0013 loss_total=0.4146 acc=0.8381 f1=0.9119
# ETA:0s/4s SUB:12
# epoch 7, loss_bi=0.2561 loss_mse=0.2594 loss_total=0.0034 acc=0.9840 f1=0.9905
# epoch 7, val, loss_bi=0.3319 loss_mse=0.0007 loss_total=0.3326 acc=0.9238 f1=0.9604
# ETA:0s/4s SUB:12
# epoch 8, loss_bi=0.2495 loss_mse=0.2518 loss_total=0.0023 acc=0.9813 f1=0.9890
# epoch 8, val, loss_bi=0.4150 loss_mse=0.0007 loss_total=0.4158 acc=0.8571 f1=0.9231
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_A/sub12_cmlp.pth
# using gpu: 0
# >>> Test:  loss_bi=0.7980 loss_mse=0.0003 loss_total=0.7984 acc=0.6250 f1=0.7692
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 13 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss_bi=0.5727 loss_mse=0.5751 loss_total=0.0024 acc=0.7067 f1=0.8243
# epoch 1, val, loss_bi=0.4566 loss_mse=0.0004 loss_total=0.4570 acc=0.8571 f1=0.9231
# ETA:0s/7s SUB:13
# epoch 2, loss_bi=0.5027 loss_mse=0.5035 loss_total=0.0008 acc=0.8400 f1=0.9130
# epoch 2, val, loss_bi=0.4749 loss_mse=0.0002 loss_total=0.4750 acc=0.8571 f1=0.9231
# ETA:0s/6s SUB:13
# epoch 3, loss_bi=0.5019 loss_mse=0.5023 loss_total=0.0004 acc=0.8400 f1=0.9130
# epoch 3, val, loss_bi=0.4777 loss_mse=0.0001 loss_total=0.4779 acc=0.8571 f1=0.9231
# ETA:0s/6s SUB:13
# epoch 4, loss_bi=0.5001 loss_mse=0.5004 loss_total=0.0003 acc=0.8400 f1=0.9130
# epoch 4, val, loss_bi=0.4644 loss_mse=0.0001 loss_total=0.4645 acc=0.8571 f1=0.9231
# ETA:0s/6s SUB:13
# epoch 5, loss_bi=0.4929 loss_mse=0.4931 loss_total=0.0002 acc=0.8400 f1=0.9130
# epoch 5, val, loss_bi=0.4700 loss_mse=0.0000 loss_total=0.4701 acc=0.8571 f1=0.9231
# ETA:0s/6s SUB:13
# epoch 6, loss_bi=0.4918 loss_mse=0.4919 loss_total=0.0001 acc=0.8400 f1=0.9130
# epoch 6, val, loss_bi=0.4817 loss_mse=0.0000 loss_total=0.4817 acc=0.8571 f1=0.9231
# ETA:0s/7s SUB:13
# epoch 7, loss_bi=0.4975 loss_mse=0.4976 loss_total=0.0002 acc=0.8400 f1=0.9130
# epoch 7, val, loss_bi=0.4739 loss_mse=0.0000 loss_total=0.4739 acc=0.8571 f1=0.9231
# ETA:1s/7s SUB:13
# epoch 8, loss_bi=0.4967 loss_mse=0.4968 loss_total=0.0001 acc=0.8400 f1=0.9130
# epoch 8, val, loss_bi=0.4721 loss_mse=0.0000 loss_total=0.4721 acc=0.8571 f1=0.9231
# ETA:1s/7s SUB:13
# epoch 9, loss_bi=0.5023 loss_mse=0.5024 loss_total=0.0001 acc=0.8400 f1=0.9130
# epoch 9, val, loss_bi=0.4916 loss_mse=0.0000 loss_total=0.4916 acc=0.8571 f1=0.9231
# ETA:1s/7s SUB:13
# epoch 10, loss_bi=0.5075 loss_mse=0.5076 loss_total=0.0001 acc=0.8400 f1=0.9130
# epoch 10, val, loss_bi=0.4695 loss_mse=0.0000 loss_total=0.4696 acc=0.8571 f1=0.9231
# ETA:1s/7s SUB:13
# epoch 11, loss_bi=0.4839 loss_mse=0.4840 loss_total=0.0001 acc=0.8400 f1=0.9130
# epoch 11, val, loss_bi=0.4620 loss_mse=0.0000 loss_total=0.4620 acc=0.8571 f1=0.9231
# ETA:1s/8s SUB:13
# epoch 12, loss_bi=0.4945 loss_mse=0.4946 loss_total=0.0001 acc=0.8400 f1=0.9130
# epoch 12, val, loss_bi=0.4591 loss_mse=0.0000 loss_total=0.4591 acc=0.8571 f1=0.9231
# ETA:1s/8s SUB:13
# ...
# ETA:1s/12s SUB:18
# epoch 8, loss_bi=0.6634 loss_mse=0.6635 loss_total=0.0000 acc=0.6400 f1=0.7805
# epoch 8, val, loss_bi=0.6262 loss_mse=0.0000 loss_total=0.6262 acc=0.7143 f1=0.8333
# ETA:1s/12s SUB:18
# epoch 9, loss_bi=0.6655 loss_mse=0.6655 loss_total=0.0000 acc=0.6400 f1=0.7805
# epoch 9, val, loss_bi=0.6297 loss_mse=0.0000 loss_total=0.6297 acc=0.7143 f1=0.8333
# ETA:2s/11s SUB:18
# epoch 10, loss_bi=0.6621 loss_mse=0.6621 loss_total=0.0000 acc=0.6400 f1=0.7805
# epoch 10, val, loss_bi=0.6254 loss_mse=0.0000 loss_total=0.6254 acc=0.7143 f1=0.8333
# ETA:2s/11s SUB:18
# epoch 11, loss_bi=0.6642 loss_mse=0.6642 loss_total=0.0000 acc=0.6400 f1=0.7805
# epoch 11, val, loss_bi=0.6312 loss_mse=0.0000 loss_total=0.6312 acc=0.7143 f1=0.8333
# ETA:2s/11s SUB:18
# epoch 12, loss_bi=0.6680 loss_mse=0.6680 loss_total=0.0000 acc=0.6400 f1=0.7805
# epoch 12, val, loss_bi=0.6330 loss_mse=0.0000 loss_total=0.6330 acc=0.7143 f1=0.8333
# ETA:2s/11s SUB:18
# epoch 13, loss_bi=0.6648 loss_mse=0.6648 loss_total=0.0000 acc=0.6400 f1=0.7805
# epoch 13, val, loss_bi=0.6215 loss_mse=0.0000 loss_total=0.6215 acc=0.7143 f1=0.8333
# ETA:2s/10s SUB:18
# epoch 14, loss_bi=0.6644 loss_mse=0.6644 loss_total=0.0000 acc=0.6400 f1=0.7805
# epoch 14, val, loss_bi=0.6246 loss_mse=0.0000 loss_total=0.6246 acc=0.7143 f1=0.8333
# ETA:3s/10s SUB:18
# epoch 15, loss_bi=0.6633 loss_mse=0.6633 loss_total=0.0000 acc=0.6400 f1=0.7805
# epoch 15, val, loss_bi=0.6430 loss_mse=0.0000 loss_total=0.6430 acc=0.7143 f1=0.8333
# ETA:3s/10s SUB:18
# epoch 16, loss_bi=0.6628 loss_mse=0.6628 loss_total=0.0000 acc=0.6400 f1=0.7805
# epoch 16, val, loss_bi=0.6273 loss_mse=0.0000 loss_total=0.6273 acc=0.7143 f1=0.8333
# ETA:3s/10s SUB:18
# epoch 17, loss_bi=0.6645 loss_mse=0.6645 loss_total=0.0000 acc=0.6400 f1=0.7805
# epoch 17, val, loss_bi=0.6262 loss_mse=0.0000 loss_total=0.6262 acc=0.7143 f1=0.8333
# ETA:3s/10s SUB:18
# epoch 18, loss_bi=0.6633 loss_mse=0.6633 loss_total=0.0000 acc=0.6400 f1=0.7805
# epoch 18, val, loss_bi=0.6370 loss_mse=0.0000 loss_total=0.6370 acc=0.7143 f1=0.8333
# ETA:3s/10s SUB:18
# epoch 19, loss_bi=0.6642 loss_mse=0.6642 loss_total=0.0000 acc=0.6400 f1=0.7805
# epoch 19, val, loss_bi=0.6382 loss_mse=0.0000 loss_total=0.6382 acc=0.7143 f1=0.8333
# ETA:3s/10s SUB:18
# epoch 20, loss_bi=0.6627 loss_mse=0.6627 loss_total=0.0000 acc=0.6400 f1=0.7805
# epoch 20, val, loss_bi=0.6351 loss_mse=0.0000 loss_total=0.6351 acc=0.7143 f1=0.8333
# ETA:4s/10s SUB:18
# epoch 21, loss_bi=0.6624 loss_mse=0.6624 loss_total=0.0000 acc=0.6400 f1=0.7805
# epoch 21, val, loss_bi=0.6206 loss_mse=0.0000 loss_total=0.6206 acc=0.7143 f1=0.8333
# ETA:4s/10s SUB:18
# epoch 22, loss_bi=0.6633 loss_mse=0.6633 loss_total=0.0000 acc=0.6400 f1=0.7805
# epoch 22, val, loss_bi=0.6311 loss_mse=0.0000 loss_total=0.6311 acc=0.7143 f1=0.8333
# ETA:4s/9s SUB:18
# epoch 23, loss_bi=0.6618 loss_mse=0.6618 loss_total=0.0000 acc=0.6400 f1=0.7805
# epoch 23, val, loss_bi=0.6316 loss_mse=0.0000 loss_total=0.6316 acc=0.7143 f1=0.8333
# ETA:4s/9s SUB:18
# epoch 24, loss_bi=0.6631 loss_mse=0.6631 loss_total=0.0000 acc=0.6400 f1=0.7805
# epoch 24, val, loss_bi=0.6383 loss_mse=0.0000 loss_total=0.6384 acc=0.7143 f1=0.8333
# ETA:4s/9s SUB:18
# epoch 25, loss_bi=0.6612 loss_mse=0.6612 loss_total=0.0000 acc=0.6400 f1=0.7805
# epoch 25, val, loss_bi=0.6228 loss_mse=0.0000 loss_total=0.6228 acc=0.7143 f1=0.8333
# ETA:4s/9s SUB:18
# epoch 26, loss_bi=0.6647 loss_mse=0.6647 loss_total=0.0000 acc=0.6400 f1=0.7805
# epoch 26, val, loss_bi=0.6282 loss_mse=0.0000 loss_total=0.6282 acc=0.7143 f1=0.8333
# ETA:4s/9s SUB:18
# epoch 27, loss_bi=0.6628 loss_mse=0.6628 loss_total=0.0000 acc=0.6400 f1=0.7805
# epoch 27, val, loss_bi=0.6257 loss_mse=0.0000 loss_total=0.6257 acc=0.7143 f1=0.8333
# ETA:5s/9s SUB:18
# epoch 28, loss_bi=0.6644 loss_mse=0.6644 loss_total=0.0000 acc=0.6400 f1=0.7805
# epoch 28, val, loss_bi=0.6372 loss_mse=0.0000 loss_total=0.6372 acc=0.7143 f1=0.8333
# ETA:5s/9s SUB:18
# epoch 29, loss_bi=0.6645 loss_mse=0.6645 loss_total=0.0000 acc=0.6400 f1=0.7805
# epoch 29, val, loss_bi=0.6270 loss_mse=0.0000 loss_total=0.6270 acc=0.7143 f1=0.8333
# ETA:5s/9s SUB:18
# epoch 30, loss_bi=0.6638 loss_mse=0.6638 loss_total=0.0000 acc=0.6400 f1=0.7805
# epoch 30, val, loss_bi=0.6248 loss_mse=0.0000 loss_total=0.6248 acc=0.7143 f1=0.8333
# ETA:5s/8s SUB:18
# epoch 31, loss_bi=0.6640 loss_mse=0.6640 loss_total=0.0000 acc=0.6400 f1=0.7805
# epoch 31, val, loss_bi=0.6333 loss_mse=0.0000 loss_total=0.6333 acc=0.7143 f1=0.8333
# ETA:5s/8s SUB:18
# epoch 32, loss_bi=0.6601 loss_mse=0.6601 loss_total=0.0000 acc=0.6400 f1=0.7805
# epoch 32, val, loss_bi=0.6284 loss_mse=0.0000 loss_total=0.6284 acc=0.7143 f1=0.8333
# ETA:5s/8s SUB:18
# epoch 33, loss_bi=0.6634 loss_mse=0.6634 loss_total=0.0000 acc=0.6400 f1=0.7805
# epoch 33, val, loss_bi=0.6273 loss_mse=0.0000 loss_total=0.6273 acc=0.7143 f1=0.8333
# ETA:5s/8s SUB:18
# epoch 34, loss_bi=0.6610 loss_mse=0.6610 loss_total=0.0000 acc=0.6400 f1=0.7805
# epoch 34, val, loss_bi=0.6322 loss_mse=0.0000 loss_total=0.6322 acc=0.7143 f1=0.8333
# ETA:5s/8s SUB:18
# epoch 35, loss_bi=0.6638 loss_mse=0.6638 loss_total=0.0000 acc=0.6400 f1=0.7805
# epoch 35, val, loss_bi=0.6292 loss_mse=0.0000 loss_total=0.6292 acc=0.7143 f1=0.8333
# ETA:6s/8s SUB:18
# epoch 36, loss_bi=0.6615 loss_mse=0.6615 loss_total=0.0000 acc=0.6400 f1=0.7805
# epoch 36, val, loss_bi=0.6255 loss_mse=0.0000 loss_total=0.6255 acc=0.7143 f1=0.8333
# ETA:6s/8s SUB:18
# epoch 37, loss_bi=0.6629 loss_mse=0.6629 loss_total=0.0000 acc=0.6400 f1=0.7805
# epoch 37, val, loss_bi=0.6272 loss_mse=0.0000 loss_total=0.6272 acc=0.7143 f1=0.8333
# ETA:6s/8s SUB:18
# epoch 38, loss_bi=0.6606 loss_mse=0.6606 loss_total=0.0000 acc=0.6400 f1=0.7805
# epoch 38, val, loss_bi=0.6314 loss_mse=0.0000 loss_total=0.6314 acc=0.7143 f1=0.8333
# ETA:6s/8s SUB:18
# epoch 39, loss_bi=0.6629 loss_mse=0.6629 loss_total=0.0000 acc=0.6400 f1=0.7805
# epoch 39, val, loss_bi=0.6290 loss_mse=0.0000 loss_total=0.6290 acc=0.7143 f1=0.8333
# ETA:6s/8s SUB:18
# epoch 40, loss_bi=0.6665 loss_mse=0.6665 loss_total=0.0000 acc=0.6400 f1=0.7805
# epoch 40, val, loss_bi=0.6366 loss_mse=0.0000 loss_total=0.6366 acc=0.7143 f1=0.8333
# ETA:6s/8s SUB:18
# epoch 41, loss_bi=0.6589 loss_mse=0.6589 loss_total=0.0000 acc=0.6400 f1=0.7805
# epoch 41, val, loss_bi=0.6358 loss_mse=0.0000 loss_total=0.6358 acc=0.7143 f1=0.8333
# ETA:6s/8s SUB:18
# epoch 42, loss_bi=0.6641 loss_mse=0.6641 loss_total=0.0000 acc=0.6400 f1=0.7805
# epoch 42, val, loss_bi=0.6255 loss_mse=0.0000 loss_total=0.6255 acc=0.7143 f1=0.8333
# ETA:6s/8s SUB:18
# epoch 43, loss_bi=0.6631 loss_mse=0.6631 loss_total=0.0000 acc=0.6400 f1=0.7805
# epoch 43, val, loss_bi=0.6415 loss_mse=0.0000 loss_total=0.6415 acc=0.7143 f1=0.8333
# ETA:7s/8s SUB:18
# epoch 44, loss_bi=0.6634 loss_mse=0.6634 loss_total=0.0000 acc=0.6400 f1=0.7805
# epoch 44, val, loss_bi=0.6334 loss_mse=0.0000 loss_total=0.6334 acc=0.7143 f1=0.8333
# ETA:7s/8s SUB:18
# epoch 45, loss_bi=0.6635 loss_mse=0.6635 loss_total=0.0000 acc=0.6400 f1=0.7805
# epoch 45, val, loss_bi=0.6215 loss_mse=0.0000 loss_total=0.6215 acc=0.7143 f1=0.8333
# ETA:7s/8s SUB:18
# epoch 46, loss_bi=0.6652 loss_mse=0.6652 loss_total=0.0000 acc=0.6400 f1=0.7805
# epoch 46, val, loss_bi=0.6262 loss_mse=0.0000 loss_total=0.6262 acc=0.7143 f1=0.8333
# ETA:7s/8s SUB:18
# epoch 47, loss_bi=0.6676 loss_mse=0.6676 loss_total=0.0000 acc=0.6400 f1=0.7805
# epoch 47, val, loss_bi=0.6441 loss_mse=0.0000 loss_total=0.6441 acc=0.7143 f1=0.8333
# ETA:7s/8s SUB:18
# epoch 48, loss_bi=0.6629 loss_mse=0.6629 loss_total=0.0000 acc=0.6400 f1=0.7805
# epoch 48, val, loss_bi=0.6265 loss_mse=0.0000 loss_total=0.6265 acc=0.7143 f1=0.8333
# ETA:7s/8s SUB:18
# epoch 49, loss_bi=0.6667 loss_mse=0.6667 loss_total=0.0000 acc=0.6400 f1=0.7805
# epoch 49, val, loss_bi=0.6187 loss_mse=0.0000 loss_total=0.6187 acc=0.7143 f1=0.8333
# ETA:7s/8s SUB:18
# epoch 50, loss_bi=0.6604 loss_mse=0.6604 loss_total=0.0000 acc=0.6400 f1=0.7805
# epoch 50, val, loss_bi=0.6270 loss_mse=0.0000 loss_total=0.6270 acc=0.7143 f1=0.8333
# ETA:8s/8s SUB:18
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_A/sub18_cmlp.pth
# using gpu: 0
# >>> Test:  loss_bi=0.7258 loss_mse=0.0000 loss_total=0.7258 acc=0.5000 f1=0.6667
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 19 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss_bi=0.6241 loss_mse=0.6420 loss_total=0.0179 acc=0.6693 f1=0.7926
# epoch 1, val, loss_bi=0.7653 loss_mse=0.0009 loss_total=0.7663 acc=0.5714 f1=0.7273
# ETA:0s/5s SUB:19
# epoch 2, loss_bi=0.6205 loss_mse=0.6212 loss_total=0.0008 acc=0.7547 f1=0.8598
# epoch 2, val, loss_bi=0.8246 loss_mse=0.0002 loss_total=0.8248 acc=0.5714 f1=0.7273
# ETA:0s/6s SUB:19
# epoch 3, loss_bi=0.5574 loss_mse=0.5577 loss_total=0.0003 acc=0.7493 f1=0.8567
# epoch 3, val, loss_bi=0.7668 loss_mse=0.0001 loss_total=0.7668 acc=0.5714 f1=0.7273
# ETA:0s/6s SUB:19
# epoch 4, loss_bi=0.5365 loss_mse=0.5366 loss_total=0.0001 acc=0.7680 f1=0.8676
# epoch 4, val, loss_bi=0.7508 loss_mse=0.0000 loss_total=0.7508 acc=0.5714 f1=0.7273
# ETA:0s/6s SUB:19
# epoch 5, loss_bi=0.5158 loss_mse=0.5159 loss_total=0.0002 acc=0.7707 f1=0.8677
# epoch 5, val, loss_bi=0.7714 loss_mse=0.0001 loss_total=0.7715 acc=0.5810 f1=0.7317
# ETA:0s/6s SUB:19
# epoch 6, loss_bi=0.4874 loss_mse=0.4884 loss_total=0.0010 acc=0.7760 f1=0.8683
# epoch 6, val, loss_bi=0.7748 loss_mse=0.0004 loss_total=0.7752 acc=0.6190 f1=0.7500
# ETA:0s/6s SUB:19
# epoch 7, loss_bi=0.4623 loss_mse=0.4627 loss_total=0.0004 acc=0.8187 f1=0.8924
# epoch 7, val, loss_bi=0.9335 loss_mse=0.0002 loss_total=0.9337 acc=0.6095 f1=0.7453
# ETA:0s/5s SUB:19
# epoch 8, loss_bi=0.4324 loss_mse=0.4332 loss_total=0.0008 acc=0.8373 f1=0.8992
# epoch 8, val, loss_bi=0.9879 loss_mse=0.0004 loss_total=0.9884 acc=0.6095 f1=0.7453
# ETA:0s/5s SUB:19
# epoch 9, loss_bi=0.4259 loss_mse=0.4262 loss_total=0.0003 acc=0.8480 f1=0.9061
# epoch 9, val, loss_bi=1.0002 loss_mse=0.0001 loss_total=1.0003 acc=0.6095 f1=0.7453
# ETA:0s/5s SUB:19
# epoch 10, loss_bi=0.3921 loss_mse=0.3922 loss_total=0.0001 acc=0.8693 f1=0.9165
# epoch 10, val, loss_bi=1.0672 loss_mse=0.0000 loss_total=1.0672 acc=0.6095 f1=0.7453
# ETA:0s/4s SUB:19
# epoch 11, loss_bi=0.3828 loss_mse=0.3829 loss_total=0.0000 acc=0.8800 f1=0.9228
# epoch 11, val, loss_bi=1.0357 loss_mse=0.0000 loss_total=1.0357 acc=0.6095 f1=0.7389
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_A/sub19_cmlp.pth
# using gpu: 0
# >>> Test:  loss_bi=0.8686 loss_mse=0.0004 loss_total=0.8691 acc=0.5000 f1=0.6591
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 20 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss_bi=0.5791 loss_mse=0.5919 loss_total=0.0128 acc=0.7493 f1=0.8549
# epoch 1, val, loss_bi=0.5245 loss_mse=0.0011 loss_total=0.5256 acc=0.8571 f1=0.9231
# ETA:0s/6s SUB:20
# epoch 2, loss_bi=0.5297 loss_mse=0.5309 loss_total=0.0012 acc=0.8427 f1=0.9144
# epoch 2, val, loss_bi=0.4659 loss_mse=0.0004 loss_total=0.4663 acc=0.8571 f1=0.9231
# ETA:0s/7s SUB:20
# epoch 3, loss_bi=0.4888 loss_mse=0.4891 loss_total=0.0003 acc=0.8427 f1=0.9144
# epoch 3, val, loss_bi=0.4680 loss_mse=0.0001 loss_total=0.4680 acc=0.8571 f1=0.9231
# ETA:0s/8s SUB:20
# epoch 4, loss_bi=0.4607 loss_mse=0.4608 loss_total=0.0002 acc=0.8453 f1=0.9157
# epoch 4, val, loss_bi=0.4825 loss_mse=0.0001 loss_total=0.4826 acc=0.8667 f1=0.9278
# ETA:0s/8s SUB:20
# epoch 5, loss_bi=0.4454 loss_mse=0.4455 loss_total=0.0001 acc=0.8507 f1=0.9184
# epoch 5, val, loss_bi=0.4769 loss_mse=0.0000 loss_total=0.4770 acc=0.8476 f1=0.9167
# ETA:0s/7s SUB:20
# epoch 6, loss_bi=0.4144 loss_mse=0.4145 loss_total=0.0000 acc=0.8613 f1=0.9235
# epoch 6, val, loss_bi=0.5219 loss_mse=0.0000 loss_total=0.5219 acc=0.8095 f1=0.8936
# ETA:0s/6s SUB:20
# epoch 7, loss_bi=0.4097 loss_mse=0.4097 loss_total=0.0000 acc=0.8747 f1=0.9302
# epoch 7, val, loss_bi=0.5458 loss_mse=0.0000 loss_total=0.5458 acc=0.8095 f1=0.8936
# ETA:0s/6s SUB:20
# epoch 8, loss_bi=0.3591 loss_mse=0.3591 loss_total=0.0000 acc=0.9280 f1=0.9585
# epoch 8, val, loss_bi=0.5775 loss_mse=0.0000 loss_total=0.5775 acc=0.7905 f1=0.8804
# ETA:0s/5s SUB:20
# epoch 9, loss_bi=0.3418 loss_mse=0.3419 loss_total=0.0000 acc=0.9280 f1=0.9587
# epoch 9, val, loss_bi=0.6004 loss_mse=0.0001 loss_total=0.6004 acc=0.7619 f1=0.8603
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_A/sub20_cmlp.pth
# using gpu: 0
# >>> Test:  loss_bi=1.0011 loss_mse=0.0001 loss_total=1.0012 acc=0.5000 f1=0.6667
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 21 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss_bi=0.6551 loss_mse=0.6616 loss_total=0.0065 acc=0.6587 f1=0.7860
# epoch 1, val, loss_bi=0.5277 loss_mse=0.0012 loss_total=0.5289 acc=0.8667 f1=0.9278
# ETA:0s/7s SUB:21
# epoch 2, loss_bi=0.6029 loss_mse=0.6047 loss_total=0.0018 acc=0.7707 f1=0.8669
# epoch 2, val, loss_bi=0.4738 loss_mse=0.0007 loss_total=0.4745 acc=0.8667 f1=0.9278
# ETA:0s/7s SUB:21
# epoch 3, loss_bi=0.5478 loss_mse=0.5487 loss_total=0.0009 acc=0.7733 f1=0.8698
# epoch 3, val, loss_bi=0.4549 loss_mse=0.0003 loss_total=0.4552 acc=0.8667 f1=0.9278
# ETA:0s/6s SUB:21
# epoch 4, loss_bi=0.5259 loss_mse=0.5263 loss_total=0.0005 acc=0.7787 f1=0.8729
# epoch 4, val, loss_bi=0.5048 loss_mse=0.0002 loss_total=0.5050 acc=0.8667 f1=0.9278
# ETA:0s/6s SUB:21
# epoch 5, loss_bi=0.4968 loss_mse=0.4972 loss_total=0.0004 acc=0.7840 f1=0.8756
# epoch 5, val, loss_bi=0.5002 loss_mse=0.0002 loss_total=0.5004 acc=0.8571 f1=0.9223
# ETA:0s/5s SUB:21
# epoch 6, loss_bi=0.4313 loss_mse=0.4319 loss_total=0.0006 acc=0.8453 f1=0.9076
# epoch 6, val, loss_bi=0.5727 loss_mse=0.0003 loss_total=0.5731 acc=0.7810 f1=0.8743
# ETA:0s/5s SUB:21
# epoch 7, loss_bi=0.3777 loss_mse=0.3786 loss_total=0.0009 acc=0.9040 f1=0.9390
# epoch 7, val, loss_bi=0.5773 loss_mse=0.0003 loss_total=0.5777 acc=0.8095 f1=0.8925
# ETA:0s/4s SUB:21
# epoch 8, loss_bi=0.3419 loss_mse=0.3431 loss_total=0.0011 acc=0.9173 f1=0.9463
# epoch 8, val, loss_bi=0.6051 loss_mse=0.0004 loss_total=0.6055 acc=0.8000 f1=0.8877
# ETA:0s/4s SUB:21
# epoch 9, loss_bi=0.3456 loss_mse=0.3469 loss_total=0.0012 acc=0.9120 f1=0.9430
# epoch 9, val, loss_bi=0.6230 loss_mse=0.0003 loss_total=0.6233 acc=0.7524 f1=0.8556
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_A/sub21_cmlp.pth
# using gpu: 0
# >>> Test:  loss_bi=0.4363 loss_mse=0.0002 loss_total=0.4364 acc=0.8833 f1=0.9375
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 22 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss_bi=0.6900 loss_mse=0.6923 loss_total=0.0023 acc=0.5707 f1=0.6721
# epoch 1, val, loss_bi=0.7337 loss_mse=0.0004 loss_total=0.7341 acc=0.2857 f1=0.0000
# ETA:0s/6s SUB:22
# epoch 2, loss_bi=0.6741 loss_mse=0.6748 loss_total=0.0007 acc=0.5653 f1=0.6479
# epoch 2, val, loss_bi=0.6139 loss_mse=0.0002 loss_total=0.6140 acc=0.7143 f1=0.8333
# ETA:0s/6s SUB:22
# epoch 3, loss_bi=0.6747 loss_mse=0.6750 loss_total=0.0004 acc=0.6133 f1=0.7461
# epoch 3, val, loss_bi=0.6729 loss_mse=0.0002 loss_total=0.6731 acc=0.6952 f1=0.8182
# ETA:0s/5s SUB:22
# epoch 4, loss_bi=0.6634 loss_mse=0.6638 loss_total=0.0003 acc=0.5867 f1=0.7285
# epoch 4, val, loss_bi=0.6127 loss_mse=0.0001 loss_total=0.6128 acc=0.7048 f1=0.8268
# ETA:0s/4s SUB:22
# epoch 5, loss_bi=0.6491 loss_mse=0.6493 loss_total=0.0002 acc=0.6320 f1=0.7604
# epoch 5, val, loss_bi=0.6540 loss_mse=0.0001 loss_total=0.6541 acc=0.6952 f1=0.8182
# ETA:0s/4s SUB:22
# epoch 6, loss_bi=0.6337 loss_mse=0.6340 loss_total=0.0003 acc=0.6507 f1=0.7665
# epoch 6, val, loss_bi=0.6516 loss_mse=0.0002 loss_total=0.6518 acc=0.6952 f1=0.8161
# ETA:0s/3s SUB:22
# epoch 7, loss_bi=0.6095 loss_mse=0.6102 loss_total=0.0007 acc=0.6960 f1=0.7824
# epoch 7, val, loss_bi=0.6706 loss_mse=0.0002 loss_total=0.6708 acc=0.7048 f1=0.8187
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_A/sub22_cmlp.pth
# using gpu: 0
# >>> Test:  loss_bi=0.7606 loss_mse=0.0002 loss_total=0.7608 acc=0.5000 f1=0.6667
