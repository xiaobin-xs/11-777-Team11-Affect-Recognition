# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cd /content/drive/MyDrive/11777-Project-xs

# %%
import numpy as np
import scipy as sp
from tqdm import tqdm
import torch

import sys
sys.path.append('/content/drive/MyDrive/11777-Project-xs/LGG/')
from prepare_data_DEAP import PrepareData
from cross_validation import CrossValidation
from train_model import *

# %%
# Define default parameters
default_args = {
    'dataset': 'DEAP',
    'data_path': './data_preprocessed_python/',
    'subjects': 22,
    'num_class': 2,
    'label_type': 'V',
    'segment': 4,
    'overlap': 0,
    'sampling_rate': 128,
    'scale_coefficient': 1,
    'input_shape': (1, 32, 512),
    'data_format': 'eeg',
    'random_seed': 2021,
    'max_epoch': 200,
    'patient': 20,
    'patient_cmb': 8,
    'max_epoch_cmb': 20,
    'batch_size': 64,
    'learning_rate': 1e-3,
    'step_size': 5,
    'dropout': 0.5,
    'LS': True,
    'LS_rate': 0.1,
    'save_path': '/content/drive/MyDrive/11777-Project-xs/LGG/save/',
    'load_path': '/content/drive/MyDrive/11777-Project-xs/LGG/save/max-acc.pth',
    'load_path_final': '/content/drive/MyDrive/11777-Project-xs/LGG/save/final_model.pth',
    'gpu': '0',
    'save_model': True,
    'model': 'LGGNet',
    'pool': 16,
    'pool_step_rate': 0.25,
    'T': 64,
    'graph_type': 'hem',
    'hidden': 32
}

# %%
######## Reproduce the result using the saved model ######
# parser.add_argument('--reproduce', action='store_true')
# args = parser.parse_args()
class Args:
    def __init__(self, param_dict):
        for key, value in param_dict.items():
            setattr(self, key, value)

default_args['data_path'] = '/content/drive/MyDrive/11777-Project-xs/data_preprocessed_python/'
default_args['reproduce'] = 'store_true'
# Create an Args object with default parameters
args = Args(default_args)

# %%
# only need to run once
sub_to_run = np.arange(args.subjects)
prepdt = PrepareData(args)
prepdt.run(sub_to_run, split=True, expand=True)
# Out:
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------

# %%
from sklearn.model_selection import train_test_split

participant_trial_id = np.arange(40*22)
participant_trial_id_train, participant_trial_id_test = train_test_split(participant_trial_id, test_size=0.2, random_state=42)
participant_trial_id_tra, participant_trial_id_val = train_test_split(participant_trial_id_train, test_size=0.2, random_state=42)
print(participant_trial_id_tra.shape[0], participant_trial_id_val.shape[0], participant_trial_id_test.shape[0])
# Out:
# 563 141 176

# %%
participant_id = np.arange(22)
participant_id_train, participant_id_test = train_test_split(participant_id, test_size=0.2, random_state=42)
participant_id_tra, participant_id_val = train_test_split(participant_id_train, test_size=0.2, random_state=42)
print(participant_id_tra.shape[0], participant_id_val.shape[0], participant_id_test.shape[0])
# Out:
# 13 4 5

# %%
## Participant 1-22 (22): w/ facial recording
## Participant 23-32 (10): w/o facial recording
cv = CrossValidation(args)
Data = np.zeros((22, 40, 15, 1, 32, 512)) #np.zeros((22*40, 15, 1, 32, 512))
Label = np.zeros((22, 40, 15)) #np.zeros((22*40, 15))

for sub in range(22):
    data, label = cv.load_per_subject(sub)
    for trial in range(40):
        for seg in range(15):
            # Data [sub*40 + trial, seg, :, :, :] = data[trial, seg, :, :, :]
            # Label[sub*40 + trial, seg] = label[trial, seg]
            Data [sub, trial, seg, :, :, :] = data[trial, seg, :, :, :]
            Label[sub, trial, seg] = label[trial, seg]
# Out:
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)

# %% [markdown]
# ### debug

# %%
from networks import LGGNet

original_order = ['Fp1', 'AF3', 'F3', 'F7', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'P3', 'P7', 'PO3', 'O1', 'Oz',
                  'Pz', 'Fp2', 'AF4', 'Fz', 'F4', 'F8', 'FC6', 'FC2', 'Cz', 'C4', 'T8', 'CP6', 'CP2', 'P4', 'P8',
                  'PO4', 'O2']

# Define proper channel orders for the local-global graphs in LGGNet. Please refer to three graph definitions (general, frontal, hemesphere).
graph_general_DEAP = [['Fp1', 'Fp2'], ['AF3', 'AF4'], ['F3', 'F7', 'Fz', 'F4', 'F8'],
                     ['FC5', 'FC1', 'FC6', 'FC2'], ['C3', 'Cz', 'C4'], ['CP5', 'CP1', 'CP2', 'CP6'],
                     ['P7', 'P3', 'Pz', 'P4', 'P8'], ['PO3', 'PO4'], ['O1', 'Oz', 'O2'],
                     ['T7'], ['T8']]

graph_idx = graph_general_DEAP   # The general graph definition for DEAP is used as an example.
idx = []
num_chan_local_graph = []
for i in range(len(graph_idx)):
    num_chan_local_graph.append(len(graph_idx[i]))
    for chan in graph_idx[i]:
        idx.append(original_order.index(chan))

data = torch.randn(1, 1, 32, 512)  # (batch_size=1, cnn_channel=1, EEG_channel=32, data_points=512)
data = data[:, :, idx, :]  # (batch_size=1, cnn_channel=1, EEG_channel=32, data_points=512)

LGG = LGGNet(
    num_classes=2,
    input_size=(1, 32, 512),
    sampling_rate=128,
    num_T=64,  # num_T controls the number of temporal filters
    out_graph=32,
    pool=16,
    pool_step_rate=0.25,
    idx_graph=num_chan_local_graph,
    dropout_rate=0.5
)

# %%
print(Data[participant_trial_id_tra].shape)
tmp = np.vstack(Data[participant_trial_id_tra])# Data[participant_trial_id_tra].reshape(563*15, 1, 32, 512)
tmp = np.concatenate(Data[participant_trial_id_tra], axis=0)
print(tmp.shape)
tmp[2*563+7, 0, 0, :5]

# %%
tmp[14, 0, 0, :5], Data[participant_trial_id_tra][0, 14, 0, 0, :5]
# Out:
# (array([-19.83967679,  -5.94046715, -12.88923806, -24.8860172 ,
#         -13.84577025]),
#  array([-19.83967679,  -5.94046715, -12.88923806, -24.8860172 ,
#         -13.84577025]))

# %%
tmp[15, 0, 0, :5], Data[participant_trial_id_tra][1, 0, 0, 0, :5]
# Out:
# (array([-16.4860614 ,  -8.09385624,  -4.91468391, -10.2296136 ,
#         -16.06645091]),
#  array([-16.4860614 ,  -8.09385624,  -4.91468391, -10.2296136 ,
#         -16.06645091]))

# %% [markdown]
# ### train

# %%
data_train, data_val, label_train, label_val = \
    Data[participant_id_tra], Data[participant_id_val], Label[participant_id_tra], Label[participant_id_val]
data_train, data_val, label_train, label_val = \
    np.concatenate(data_train, axis=0), np.concatenate(data_val, axis=0), np.concatenate(label_train, axis=0), np.concatenate(label_val, axis=0)
data_train, data_val, label_train, label_val = \
    np.concatenate(data_train, axis=0), np.concatenate(data_val, axis=0), np.concatenate(label_train, axis=0), np.concatenate(label_val, axis=0)
print(data_train.shape, data_val.shape, label_train.shape, label_val.shape)

data_test, label_test = \
    Data[participant_id_test], Label[participant_id_test]
data_test, label_test = \
    np.concatenate(data_test, axis=0), np.concatenate(label_test, axis=0)
data_test, label_test = \
    np.concatenate(data_test, axis=0), np.concatenate(label_test, axis=0)
print(data_test.shape, label_test.shape)
# Out:
# (7800, 1, 32, 512) (2400, 1, 32, 512) (7800,) (2400,)
# (3000, 1, 32, 512) (3000,)

# %%
# data_train, data_val, label_train, label_val = \
#     Data[participant_trial_id_tra], Data[participant_trial_id_val], Label[participant_trial_id_tra], Label[participant_trial_id_val]
# data_train, data_val, label_train, label_val = \
#     np.concatenate(data_train, axis=0), np.concatenate(data_val, axis=0), np.concatenate(label_train, axis=0), np.concatenate(label_val, axis=0)
# print(data_train.shape, data_val.shape, label_train.shape, label_val.shape)

data_train = torch.from_numpy(data_train).float()
label_train = torch.from_numpy(label_train).long()
data_val = torch.from_numpy(data_val).float()
label_val = torch.from_numpy(label_val).long()
data_test = torch.from_numpy(data_test).float()
label_test = torch.from_numpy(label_test).long()

# %%
# for sub in range()
acc_val, F1_val = train(args=args,
                        data_train=data_train,
                        label_train=label_train,
                        data_val=data_val,
                        label_val=label_val,
                        subject='all_train',
                        fold='noFold')
# Out:
# using gpu: 0
# epoch 1, loss=0.7343 acc=0.5555 f1=0.6090
# epoch 1, val, loss=0.7120 acc=0.4983 f1=0.5348
# ETA:32s/27m SUB:all_train FOLD:noFold
# epoch 2, loss=0.6761 acc=0.5997 f1=0.6422
# epoch 2, val, loss=0.7015 acc=0.5413 f1=0.6422
# ETA:57s/24m SUB:all_train FOLD:noFold
# epoch 3, loss=0.6533 acc=0.6285 f1=0.6653
# epoch 3, val, loss=0.6906 acc=0.5683 f1=0.7020
# ETA:1m/23m SUB:all_train FOLD:noFold
# epoch 4, loss=0.6422 acc=0.6290 f1=0.6653
# epoch 4, val, loss=0.7085 acc=0.5921 f1=0.7366
# ETA:2m/23m SUB:all_train FOLD:noFold
# epoch 5, loss=0.6154 acc=0.6683 f1=0.6945
# epoch 5, val, loss=0.8386 acc=0.6088 f1=0.7564
# ETA:2m/22m SUB:all_train FOLD:noFold
# epoch 6, loss=0.6045 acc=0.6853 f1=0.7113
# epoch 6, val, loss=0.6918 acc=0.5975 f1=0.7049
# ETA:3m/22m SUB:all_train FOLD:noFold
# epoch 7, loss=0.5703 acc=0.7181 f1=0.7406
# epoch 7, val, loss=0.7852 acc=0.6104 f1=0.7395
# ETA:3m/22m SUB:all_train FOLD:noFold
# epoch 8, loss=0.5334 acc=0.7555 f1=0.7734
# epoch 8, val, loss=0.7890 acc=0.5913 f1=0.7295
# ETA:4m/22m SUB:all_train FOLD:noFold
# epoch 9, loss=0.4957 acc=0.7921 f1=0.8061
# epoch 9, val, loss=0.8500 acc=0.6012 f1=0.7409
# ETA:4m/22m SUB:all_train FOLD:noFold
# epoch 10, loss=0.4364 acc=0.8458 f1=0.8556
# epoch 10, val, loss=0.9676 acc=0.5825 f1=0.7005
# ETA:4m/22m SUB:all_train FOLD:noFold
# epoch 11, loss=0.3952 acc=0.8776 f1=0.8860
# epoch 11, val, loss=1.0749 acc=0.5946 f1=0.7061
# ETA:5m/22m SUB:all_train FOLD:noFold
# epoch 12, loss=0.3708 acc=0.8935 f1=0.9005
# epoch 12, val, loss=1.0465 acc=0.5950 f1=0.6941
# early stopping

# %%
from utils import *

def test(args, data, label, reproduce, subject, fold, path=None):
    set_up(args)
    seed_all(args.random_seed)
    test_loader = get_dataloader(data, label, args.batch_size)

    model = get_model(args)
    if CUDA:
        model = model.cuda()
    loss_fn = nn.CrossEntropyLoss()
    print('myTest')

    if reproduce:
        if path is None:
            model_name_reproduce = 'sub' + str(subject) + '.pth'
            data_type = 'model_{}_{}'.format(args.data_format, args.label_type)
            experiment_setting = 'T_{}_pool_{}'.format(args.T, args.pool)
            load_path_final = os.path.join(args.save_path, experiment_setting, data_type, model_name_reproduce)
            model.load_state_dict(torch.load(load_path_final))
        else:
            model.load_state_dict(torch.load(path))
    else:
        model.load_state_dict(torch.load(args.load_path_final))
    loss, pred, act = predict(
        data_loader=test_loader, net=model, loss_fn=loss_fn
    )
    acc, f1, cm = get_metrics(y_pred=pred, y_true=act)
    print('>>> Test:  loss={:.4f} acc={:.4f} f1={:.4f}'.format(loss, acc, f1))
    return acc, pred, act

# %%
label_test.float().mean()
# Out:
# tensor(0.5500)

# %%
path = '/content/drive/MyDrive/11777-Project-xs/LGG/save/candidate.pth'
acc_test, pred, act = test(args=args, data=data_test, label=label_test,
                                               reproduce=args.reproduce,
                                               subject='all_train', fold='noFold', path=path)
# Out:
# using gpu: 0
# myTest
# >>> Test:  loss=0.6939 acc=0.4800 f1=0.6486

# %% [markdown]
# # train user-model

# %%
import os
data_save_folder = '/content/drive/MyDrive/11777-Project-xs/data_face_seg_mean'
face_embed_file_list = os.listdir(data_save_folder)
# print(len(face_embed_file_list))
face_embed_file_list = [e for e in face_embed_file_list if 'embed' in e]
sub_trial_list = {}
for file in face_embed_file_list:
    # print(file)
    sub, trial, _, _, _ = file.split('_')
    sub, trial = int(sub[1:]), int(trial[5:])
    if sub in sub_trial_list.keys():
        sub_trial_list[sub].append(trial)
    else:
        sub_trial_list[sub] = [trial]

for sub in range(1,23):
    print('sub {}, {} trials with facial video'.format(sub, len(sub_trial_list[sub])))
# Out:
# sub 1, 40 trials with facial video
# sub 2, 40 trials with facial video
# sub 3, 39 trials with facial video
# sub 4, 40 trials with facial video
# sub 5, 39 trials with facial video
# sub 6, 40 trials with facial video
# sub 7, 40 trials with facial video
# sub 8, 40 trials with facial video
# sub 9, 40 trials with facial video
# sub 10, 40 trials with facial video
# sub 11, 37 trials with facial video
# sub 12, 40 trials with facial video
# sub 13, 40 trials with facial video
# sub 14, 39 trials with facial video
# sub 15, 40 trials with facial video
# sub 16, 40 trials with facial video
# sub 17, 40 trials with facial video
# sub 18, 40 trials with facial video
# sub 19, 40 trials with facial video
# sub 20, 40 trials with facial video
# sub 21, 40 trials with facial video
# sub 22, 40 trials with facial video

# %%
CUDA = torch.cuda.is_available()
fold = 'noFold'

for sub in range(22):
    print('='*48)
    cv = CrossValidation(args)
    data, label = cv.load_per_subject(sub)
    trial_to_remove = [i-1 for i in range(1,41) if i not in sub_trial_list[sub+1]]

    if len(trial_to_remove) > 0:
        mask = np.ones(data.shape[0], dtype=bool)
        mask[trial_to_remove] = False
        data = data[mask]
        label = label[mask]
    print(sub+1, trial_to_remove, data.shape[0])
    trial_id = np.arange(data.shape[0])
    trial_id_train, trial_id_test = train_test_split(trial_id, test_size=0.2, random_state=42)
    trial_id_tra, trial_id_val = train_test_split(trial_id_train, test_size=0.2, random_state=42)
    print(trial_id_tra.shape[0], trial_id_val.shape[0], trial_id_test.shape[0])

    data_train, data_val, label_train, label_val = \
        data[trial_id_tra], data[trial_id_val], label[trial_id_tra], label[trial_id_val]
    data_train, data_val, label_train, label_val = \
        np.concatenate(data_train, axis=0), np.concatenate(data_val, axis=0), np.concatenate(label_train, axis=0), np.concatenate(label_val, axis=0)
    print(data_train.shape, data_val.shape, label_train.shape, label_val.shape)

    data_test, label_test = \
        data[trial_id_test], label[trial_id_test]
    data_test, label_test = \
        np.concatenate(data_test, axis=0), np.concatenate(label_test, axis=0)
    print(data_test.shape, label_test.shape)

    data_train = torch.from_numpy(data_train).float()
    label_train = torch.from_numpy(label_train).long()
    data_val = torch.from_numpy(data_val).float()
    label_val = torch.from_numpy(label_val).long()
    data_test = torch.from_numpy(data_test).float()
    label_test = torch.from_numpy(label_test).long()

    acc_val, F1_val = train(args=args,
                        data_train=data_train,
                        label_train=label_train,
                        data_val=data_val,
                        label_val=label_val,
                        subject = str(sub+1),
                        fold='noFold')
    model = get_model(args)
    if CUDA:
        model = model.cuda()
    model.load_state_dict(torch.load(os.path.join(args.save_path, 'candidate.pth')))

    model_name_reproduce = 'sub' + str(sub+1) + '.pth'
    data_type = 'model_{}_{}'.format(args.data_format, args.label_type)
    experiment_setting = 'T_{}_pool_{}'.format(args.T, args.pool)
    save_path = os.path.join(args.save_path, experiment_setting, data_type)
    ensure_path(save_path)
    model_name_reproduce = os.path.join(save_path, model_name_reproduce)
    print(model_name_reproduce)
    torch.save(model.state_dict(), model_name_reproduce)

    model.load_state_dict(torch.load(model_name_reproduce))
    acc_test, pred, act = test(args=args, data=data_test, label=label_test,
                                               reproduce=args.reproduce,
                                               subject=str(sub+1), fold='noFold')
# Out:
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 1 [] 40
# 25 7 8
# (375, 1, 32, 512) (105, 1, 32, 512) (375,) (105,)
# (120, 1, 32, 512) (120,)
# using gpu: 0
# epoch 1, loss=1.0065 acc=0.5200 f1=0.5082
# epoch 1, val, loss=0.7366 acc=0.4286 f1=0.6000
# ETA:1s/1m SUB:1 FOLD:noFold
# epoch 2, loss=0.7018 acc=0.5947 f1=0.5682
# epoch 2, val, loss=0.7751 acc=0.4286 f1=0.6000
# ETA:2s/1m SUB:1 FOLD:noFold
# epoch 3, loss=0.6111 acc=0.7040 f1=0.7056
# epoch 3, val, loss=0.7745 acc=0.4286 f1=0.6000
# ETA:3s/1m SUB:1 FOLD:noFold
# epoch 4, loss=0.5380 acc=0.7413 f1=0.7087
# epoch 4, val, loss=0.7858 acc=0.4286 f1=0.6000
# ETA:5s/1m SUB:1 FOLD:noFold
# epoch 5, loss=0.4757 acc=0.8320 f1=0.8364
# epoch 5, val, loss=0.8239 acc=0.4286 f1=0.6000
# ETA:6s/1m SUB:1 FOLD:noFold
# epoch 6, loss=0.3758 acc=0.8987 f1=0.8920
# epoch 6, val, loss=0.8817 acc=0.4286 f1=0.6000
# ETA:7s/1m SUB:1 FOLD:noFold
# epoch 7, loss=0.2719 acc=0.9760 f1=0.9749
# epoch 7, val, loss=0.8855 acc=0.4286 f1=0.6000
# ETA:8s/1m SUB:1 FOLD:noFold
# epoch 8, loss=0.2349 acc=0.9973 f1=0.9972
# epoch 8, val, loss=0.8888 acc=0.4286 f1=0.6000
# ETA:9s/1m SUB:1 FOLD:noFold
# epoch 9, loss=0.2335 acc=0.9973 f1=0.9972
# epoch 9, val, loss=0.9149 acc=0.4286 f1=0.6000
# ETA:11s/1m SUB:1 FOLD:noFold
# epoch 10, loss=0.2335 acc=0.9973 f1=0.9972
# epoch 10, val, loss=0.8618 acc=0.4286 f1=0.6000
# ETA:12s/1m SUB:1 FOLD:noFold
# epoch 11, loss=0.2256 acc=1.0000 f1=1.0000
# epoch 11, val, loss=0.8746 acc=0.4476 f1=0.6081
# ETA:13s/1m SUB:1 FOLD:noFold
# epoch 12, loss=0.2176 acc=1.0000 f1=1.0000
# epoch 12, val, loss=0.8334 acc=0.4762 f1=0.6154
# ETA:15s/1m SUB:1 FOLD:noFold
# epoch 13, loss=0.2189 acc=1.0000 f1=1.0000
# epoch 13, val, loss=0.8218 acc=0.4762 f1=0.5985
# ETA:16s/1m SUB:1 FOLD:noFold
# epoch 14, loss=0.2169 acc=1.0000 f1=1.0000
# epoch 14, val, loss=0.7764 acc=0.4762 f1=0.5528
# ETA:17s/1m SUB:1 FOLD:noFold
# epoch 15, loss=0.2175 acc=1.0000 f1=1.0000
# epoch 15, val, loss=0.8143 acc=0.4857 f1=0.5714
# ETA:18s/1m SUB:1 FOLD:noFold
# epoch 16, loss=0.2146 acc=1.0000 f1=1.0000
# epoch 16, val, loss=0.7647 acc=0.5524 f1=0.5524
# ETA:20s/1m SUB:1 FOLD:noFold
# epoch 17, loss=0.2173 acc=1.0000 f1=1.0000
# epoch 17, val, loss=0.8391 acc=0.4857 f1=0.5179
# ETA:21s/1m SUB:1 FOLD:noFold
# epoch 18, loss=0.2158 acc=1.0000 f1=1.0000
# epoch 18, val, loss=0.8056 acc=0.5429 f1=0.5385
# ETA:22s/1m SUB:1 FOLD:noFold
# epoch 19, loss=0.2134 acc=1.0000 f1=1.0000
# epoch 19, val, loss=0.8115 acc=0.5524 f1=0.5437
# ETA:23s/1m SUB:1 FOLD:noFold
# epoch 20, loss=0.2144 acc=1.0000 f1=1.0000
# epoch 20, val, loss=0.8194 acc=0.5238 f1=0.5370
# ETA:24s/1m SUB:1 FOLD:noFold
# epoch 21, loss=0.2128 acc=1.0000 f1=1.0000
# epoch 21, val, loss=0.8344 acc=0.5048 f1=0.5273
# ETA:26s/1m SUB:1 FOLD:noFold
# epoch 22, loss=0.2123 acc=1.0000 f1=1.0000
# epoch 22, val, loss=0.8165 acc=0.5143 f1=0.5321
# ETA:27s/1m SUB:1 FOLD:noFold
# epoch 23, loss=0.2134 acc=1.0000 f1=1.0000
# epoch 23, val, loss=0.8038 acc=0.5143 f1=0.5234
# ETA:28s/1m SUB:1 FOLD:noFold
# epoch 24, loss=0.2136 acc=1.0000 f1=1.0000
# epoch 24, val, loss=0.8159 acc=0.5333 f1=0.5243
# early stopping
# /content/drive/MyDrive/11777-Project-xs/LGG/save/T_64_pool_16/model_eeg_V/sub1.pth
# using gpu: 0
# myTest
# >>> Test:  loss=0.8104 acc=0.5000 f1=0.5522
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 2 [] 40
# 25 7 8
# (375, 1, 32, 512) (105, 1, 32, 512) (375,) (105,)
# (120, 1, 32, 512) (120,)
# using gpu: 0
# epoch 1, loss=1.0752 acc=0.4907 f1=0.4879
# epoch 1, val, loss=0.6503 acc=0.7143 f1=0.8333
# ETA:1s/1m SUB:2 FOLD:noFold
# epoch 2, loss=0.8298 acc=0.5360 f1=0.5272
# epoch 2, val, loss=0.6328 acc=0.7143 f1=0.8333
# ETA:2s/1m SUB:2 FOLD:noFold
# epoch 3, loss=0.6767 acc=0.6320 f1=0.5941
# epoch 3, val, loss=0.6396 acc=0.7143 f1=0.8333
# ETA:3s/1m SUB:2 FOLD:noFold
# epoch 4, loss=0.7179 acc=0.5387 f1=0.5260
# epoch 4, val, loss=0.6290 acc=0.7143 f1=0.8333
# ETA:5s/1m SUB:2 FOLD:noFold
# epoch 5, loss=0.6230 acc=0.6800 f1=0.6571
# epoch 5, val, loss=0.6285 acc=0.7143 f1=0.8333
# ETA:6s/1m SUB:2 FOLD:noFold
# epoch 6, loss=0.6491 acc=0.6293 f1=0.6150
# epoch 6, val, loss=0.6271 acc=0.7143 f1=0.8333
# ETA:7s/1m SUB:2 FOLD:noFold
# epoch 7, loss=0.6186 acc=0.6427 f1=0.6193
# epoch 7, val, loss=0.6228 acc=0.7143 f1=0.8333
# ETA:8s/1m SUB:2 FOLD:noFold
# epoch 8, loss=0.5747 acc=0.7280 f1=0.7213
# epoch 8, val, loss=0.6043 acc=0.7143 f1=0.8333
# ETA:10s/1m SUB:2 FOLD:noFold
# epoch 9, loss=0.4949 acc=0.8080 f1=0.8095
# epoch 9, val, loss=0.6203 acc=0.7143 f1=0.8333
# ETA:11s/1m SUB:2 FOLD:noFold
# epoch 10, loss=0.3887 acc=0.8987 f1=0.8920
# epoch 10, val, loss=0.6274 acc=0.7143 f1=0.8333
# ETA:12s/1m SUB:2 FOLD:noFold
# epoch 11, loss=0.3419 acc=0.9200 f1=0.9185
# epoch 11, val, loss=0.6094 acc=0.7143 f1=0.8333
# ETA:13s/1m SUB:2 FOLD:noFold
# epoch 12, loss=0.2815 acc=0.9787 f1=0.9775
# epoch 12, val, loss=0.6250 acc=0.7048 f1=0.8249
# ETA:15s/1m SUB:2 FOLD:noFold
# epoch 13, loss=0.2598 acc=0.9893 f1=0.9888
# epoch 13, val, loss=0.6172 acc=0.7048 f1=0.8268
# ETA:16s/1m SUB:2 FOLD:noFold
# epoch 14, loss=0.2341 acc=0.9973 f1=0.9972
# epoch 14, val, loss=0.6009 acc=0.6667 f1=0.7879
# ETA:17s/1m SUB:2 FOLD:noFold
# epoch 15, loss=0.2361 acc=0.9947 f1=0.9945
# epoch 15, val, loss=0.6852 acc=0.6000 f1=0.7123
# ETA:18s/1m SUB:2 FOLD:noFold
# epoch 16, loss=0.2294 acc=1.0000 f1=1.0000
# epoch 16, val, loss=0.6928 acc=0.6857 f1=0.7843
# early stopping
# /content/drive/MyDrive/11777-Project-xs/LGG/save/T_64_pool_16/model_eeg_V/sub2.pth
# using gpu: 0
# myTest
# >>> Test:  loss=0.6954 acc=0.6250 f1=0.7692
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 3 [39] 39
# 24 7 8
# (360, 1, 32, 512) (105, 1, 32, 512) (360,) (105,)
# (120, 1, 32, 512) (120,)
# using gpu: 0
# epoch 1, loss=1.0944 acc=0.5167 f1=0.5372
# epoch 1, val, loss=0.7489 acc=0.4286 f1=0.6000
# ETA:1s/59s SUB:3 FOLD:noFold
# epoch 2, loss=0.7856 acc=0.5778 f1=0.6667
# epoch 2, val, loss=0.7369 acc=0.4286 f1=0.6000
# ETA:2s/59s SUB:3 FOLD:noFold
# epoch 3, loss=0.7261 acc=0.5556 f1=0.5062
# epoch 3, val, loss=0.7409 acc=0.4286 f1=0.6000
# ETA:3s/59s SUB:3 FOLD:noFold
# epoch 4, loss=0.6910 acc=0.5750 f1=0.6592
# epoch 4, val, loss=0.7697 acc=0.4286 f1=0.6000
# ETA:4s/59s SUB:3 FOLD:noFold
# epoch 5, loss=0.6607 acc=0.6028 f1=0.6682
# epoch 5, val, loss=0.7457 acc=0.4286 f1=0.6000
# ETA:5s/59s SUB:3 FOLD:noFold
# epoch 6, loss=0.6449 acc=0.6889 f1=0.6854
# epoch 6, val, loss=0.7509 acc=0.4286 f1=0.6000
# ETA:7s/59s SUB:3 FOLD:noFold
# epoch 7, loss=0.6111 acc=0.6917 f1=0.7259
# epoch 7, val, loss=0.7359 acc=0.4286 f1=0.6000
# ETA:8s/1m SUB:3 FOLD:noFold
# epoch 8, loss=0.5434 acc=0.7889 f1=0.8173
# epoch 8, val, loss=0.7348 acc=0.4286 f1=0.6000
# ETA:9s/59s SUB:3 FOLD:noFold
# epoch 9, loss=0.5025 acc=0.8472 f1=0.8579
# epoch 9, val, loss=0.7763 acc=0.4286 f1=0.6000
# ETA:10s/59s SUB:3 FOLD:noFold
# epoch 10, loss=0.3590 acc=0.9417 f1=0.9474
# epoch 10, val, loss=0.7698 acc=0.4286 f1=0.6000
# ETA:11s/59s SUB:3 FOLD:noFold
# epoch 11, loss=0.2782 acc=0.9778 f1=0.9795
# epoch 11, val, loss=0.7624 acc=0.4286 f1=0.6000
# ETA:13s/59s SUB:3 FOLD:noFold
# epoch 12, loss=0.2354 acc=0.9944 f1=0.9949
# epoch 12, val, loss=0.7687 acc=0.4286 f1=0.6000
# ETA:14s/59s SUB:3 FOLD:noFold
# epoch 13, loss=0.2333 acc=0.9944 f1=0.9948
# epoch 13, val, loss=0.7959 acc=0.4476 f1=0.6081
# ETA:15s/59s SUB:3 FOLD:noFold
# epoch 14, loss=0.2264 acc=1.0000 f1=1.0000
# epoch 14, val, loss=0.7557 acc=0.5524 f1=0.6412
# ETA:16s/59s SUB:3 FOLD:noFold
# epoch 15, loss=0.2275 acc=0.9972 f1=0.9974
# epoch 15, val, loss=0.7536 acc=0.5524 f1=0.6240
# ETA:17s/59s SUB:3 FOLD:noFold
# epoch 16, loss=0.2210 acc=1.0000 f1=1.0000
# epoch 16, val, loss=0.7743 acc=0.5714 f1=0.6281
# ETA:19s/59s SUB:3 FOLD:noFold
# epoch 17, loss=0.2192 acc=1.0000 f1=1.0000
# epoch 17, val, loss=0.7665 acc=0.5810 f1=0.6071
# ETA:20s/59s SUB:3 FOLD:noFold
# epoch 18, loss=0.2236 acc=1.0000 f1=1.0000
# epoch 18, val, loss=0.8493 acc=0.5524 f1=0.6299
# ETA:21s/59s SUB:3 FOLD:noFold
# epoch 19, loss=0.2178 acc=1.0000 f1=1.0000
# epoch 19, val, loss=0.7697 acc=0.6000 f1=0.6379
# ETA:22s/59s SUB:3 FOLD:noFold
# epoch 20, loss=0.2188 acc=1.0000 f1=1.0000
# epoch 20, val, loss=0.7694 acc=0.5619 f1=0.6230
# ETA:23s/59s SUB:3 FOLD:noFold
# epoch 21, loss=0.2204 acc=1.0000 f1=1.0000
# epoch 21, val, loss=0.6866 acc=0.6095 f1=0.6168
# ETA:25s/59s SUB:3 FOLD:noFold
# epoch 22, loss=0.2182 acc=1.0000 f1=1.0000
# epoch 22, val, loss=0.7287 acc=0.6095 f1=0.6435
# ETA:26s/59s SUB:3 FOLD:noFold
# epoch 23, loss=0.2161 acc=1.0000 f1=1.0000
# epoch 23, val, loss=0.7493 acc=0.5619 f1=0.6102
# ETA:27s/59s SUB:3 FOLD:noFold
# epoch 24, loss=0.2164 acc=1.0000 f1=1.0000
# epoch 24, val, loss=0.7282 acc=0.6000 f1=0.6182
# ETA:28s/59s SUB:3 FOLD:noFold
# epoch 25, loss=0.2149 acc=1.0000 f1=1.0000
# epoch 25, val, loss=0.7567 acc=0.6000 f1=0.6379
# ETA:29s/59s SUB:3 FOLD:noFold
# epoch 26, loss=0.2137 acc=1.0000 f1=1.0000
# epoch 26, val, loss=0.7945 acc=0.6000 f1=0.6500
# ETA:30s/59s SUB:3 FOLD:noFold
# epoch 27, loss=0.2122 acc=1.0000 f1=1.0000
# epoch 27, val, loss=0.6849 acc=0.6095 f1=0.6239
# ETA:32s/59s SUB:3 FOLD:noFold
# epoch 28, loss=0.2122 acc=1.0000 f1=1.0000
# epoch 28, val, loss=0.7465 acc=0.5905 f1=0.5981
# ETA:33s/59s SUB:3 FOLD:noFold
# epoch 29, loss=0.2103 acc=1.0000 f1=1.0000
# epoch 29, val, loss=0.7555 acc=0.5810 f1=0.6207
# ETA:34s/59s SUB:3 FOLD:noFold
# epoch 30, loss=0.2136 acc=1.0000 f1=1.0000
# epoch 30, val, loss=0.7126 acc=0.6000 f1=0.6182
# ETA:35s/59s SUB:3 FOLD:noFold
# epoch 31, loss=0.2125 acc=1.0000 f1=1.0000
# epoch 31, val, loss=0.7494 acc=0.6095 f1=0.6435
# ETA:36s/59s SUB:3 FOLD:noFold
# epoch 32, loss=0.2109 acc=1.0000 f1=1.0000
# epoch 32, val, loss=0.7832 acc=0.5810 f1=0.6393
# ETA:38s/59s SUB:3 FOLD:noFold
# epoch 33, loss=0.2104 acc=1.0000 f1=1.0000
# epoch 33, val, loss=0.7284 acc=0.5619 f1=0.5741
# ETA:39s/59s SUB:3 FOLD:noFold
# epoch 34, loss=0.2126 acc=1.0000 f1=1.0000
# epoch 34, val, loss=0.7153 acc=0.5810 f1=0.5849
# ETA:40s/59s SUB:3 FOLD:noFold
# epoch 35, loss=0.2113 acc=1.0000 f1=1.0000
# epoch 35, val, loss=0.7754 acc=0.5810 f1=0.6452
# ETA:41s/59s SUB:3 FOLD:noFold
# epoch 36, loss=0.2126 acc=1.0000 f1=1.0000
# epoch 36, val, loss=0.6815 acc=0.6000 f1=0.5882
# early stopping
# /content/drive/MyDrive/11777-Project-xs/LGG/save/T_64_pool_16/model_eeg_V/sub3.pth
# using gpu: 0
# myTest
# >>> Test:  loss=0.7335 acc=0.5667 f1=0.6623
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 4 [] 40
# 25 7 8
# (375, 1, 32, 512) (105, 1, 32, 512) (375,) (105,)
# (120, 1, 32, 512) (120,)
# using gpu: 0
# epoch 1, loss=1.0425 acc=0.5733 f1=0.4245
# epoch 1, val, loss=0.6820 acc=0.5714 f1=0.7273
# ETA:1s/1m SUB:4 FOLD:noFold
# epoch 2, loss=0.7736 acc=0.6240 f1=0.4000
# epoch 2, val, loss=0.6863 acc=0.5714 f1=0.7273
# ETA:2s/1m SUB:4 FOLD:noFold
# epoch 3, loss=0.6612 acc=0.6693 f1=0.5267
# epoch 3, val, loss=0.6853 acc=0.5714 f1=0.7273
# ETA:3s/1m SUB:4 FOLD:noFold
# epoch 4, loss=0.6756 acc=0.6587 f1=0.4019
# epoch 4, val, loss=0.6871 acc=0.5714 f1=0.7273
# ETA:4s/1m SUB:4 FOLD:noFold
# epoch 5, loss=0.5846 acc=0.7120 f1=0.5345
# epoch 5, val, loss=0.6854 acc=0.5714 f1=0.7273
# ETA:6s/1m SUB:4 FOLD:noFold
# epoch 6, loss=0.5946 acc=0.7227 f1=0.6061
# epoch 6, val, loss=0.6842 acc=0.5714 f1=0.7273
# ETA:7s/1m SUB:4 FOLD:noFold
# epoch 7, loss=0.5354 acc=0.7440 f1=0.5862
# epoch 7, val, loss=0.6828 acc=0.5714 f1=0.7273
# ETA:8s/1m SUB:4 FOLD:noFold
# epoch 8, loss=0.5126 acc=0.7893 f1=0.6950
# epoch 8, val, loss=0.6788 acc=0.5714 f1=0.7273
# ETA:9s/1m SUB:4 FOLD:noFold
# epoch 9, loss=0.4391 acc=0.8453 f1=0.7769
# epoch 9, val, loss=0.6835 acc=0.5714 f1=0.7273
# ETA:11s/1m SUB:4 FOLD:noFold
# epoch 10, loss=0.3647 acc=0.9093 f1=0.8692
# epoch 10, val, loss=0.6785 acc=0.5810 f1=0.7317
# ETA:12s/1m SUB:4 FOLD:noFold
# epoch 11, loss=0.2977 acc=0.9653 f1=0.9509
# epoch 11, val, loss=0.6907 acc=0.5714 f1=0.7239
# ETA:13s/1m SUB:4 FOLD:noFold
# epoch 12, loss=0.2477 acc=0.9893 f1=0.9853
# epoch 12, val, loss=0.6823 acc=0.5333 f1=0.6573
# ETA:14s/1m SUB:4 FOLD:noFold
# epoch 13, loss=0.2332 acc=0.9973 f1=0.9963
# epoch 13, val, loss=0.6980 acc=0.5429 f1=0.6667
# ETA:16s/1m SUB:4 FOLD:noFold
# epoch 14, loss=0.2360 acc=1.0000 f1=1.0000
# epoch 14, val, loss=0.7514 acc=0.4952 f1=0.5310
# ETA:17s/1m SUB:4 FOLD:noFold
# epoch 15, loss=0.2320 acc=0.9973 f1=0.9963
# epoch 15, val, loss=0.7715 acc=0.5619 f1=0.5490
# early stopping
# /content/drive/MyDrive/11777-Project-xs/LGG/save/T_64_pool_16/model_eeg_V/sub4.pth
# using gpu: 0
# myTest
# >>> Test:  loss=0.7259 acc=0.4000 f1=0.5556
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 5 [39] 39
# 24 7 8
# (360, 1, 32, 512) (105, 1, 32, 512) (360,) (105,)
# (120, 1, 32, 512) (120,)
# using gpu: 0
# epoch 1, loss=1.3261 acc=0.4583 f1=0.4214
# epoch 1, val, loss=0.6203 acc=0.7143 f1=0.8333
# ETA:1s/1m SUB:5 FOLD:noFold
# epoch 2, loss=0.8204 acc=0.5306 f1=0.6600
# epoch 2, val, loss=0.6252 acc=0.7143 f1=0.8333
# ETA:2s/1m SUB:5 FOLD:noFold
# epoch 3, loss=0.7224 acc=0.5333 f1=0.5200
# epoch 3, val, loss=0.6247 acc=0.7143 f1=0.8333
# ETA:3s/1m SUB:5 FOLD:noFold
# epoch 4, loss=0.6942 acc=0.6111 f1=0.6354
# epoch 4, val, loss=0.6143 acc=0.7143 f1=0.8333
# ETA:4s/1m SUB:5 FOLD:noFold
# epoch 5, loss=0.6922 acc=0.5639 f1=0.6580
# epoch 5, val, loss=0.6065 acc=0.7143 f1=0.8333
# ETA:6s/1m SUB:5 FOLD:noFold
# epoch 6, loss=0.6561 acc=0.6222 f1=0.6284
# epoch 6, val, loss=0.6214 acc=0.7143 f1=0.8333
# ETA:7s/1m SUB:5 FOLD:noFold
# epoch 7, loss=0.6144 acc=0.6722 f1=0.6927
# epoch 7, val, loss=0.6240 acc=0.7143 f1=0.8333
# ETA:8s/1m SUB:5 FOLD:noFold
# epoch 8, loss=0.5924 acc=0.6917 f1=0.7400
# epoch 8, val, loss=0.6238 acc=0.7143 f1=0.8333
# ETA:9s/1m SUB:5 FOLD:noFold
# epoch 9, loss=0.5382 acc=0.7583 f1=0.7797
# epoch 9, val, loss=0.6379 acc=0.7143 f1=0.8333
# ETA:10s/1m SUB:5 FOLD:noFold
# epoch 10, loss=0.5093 acc=0.8306 f1=0.8479
# epoch 10, val, loss=0.6347 acc=0.7143 f1=0.8333
# ETA:12s/1m SUB:5 FOLD:noFold
# epoch 11, loss=0.4167 acc=0.8889 f1=0.8958
# epoch 11, val, loss=0.6246 acc=0.7143 f1=0.8333
# ETA:13s/1m SUB:5 FOLD:noFold
# epoch 12, loss=0.3554 acc=0.9278 f1=0.9353
# epoch 12, val, loss=0.6253 acc=0.7143 f1=0.8333
# ETA:14s/1m SUB:5 FOLD:noFold
# epoch 13, loss=0.2876 acc=0.9694 f1=0.9716
# epoch 13, val, loss=0.6063 acc=0.7048 f1=0.8268
# ETA:15s/1m SUB:5 FOLD:noFold
# epoch 14, loss=0.2479 acc=0.9944 f1=0.9949
# epoch 14, val, loss=0.5981 acc=0.6857 f1=0.8070
# ETA:16s/1m SUB:5 FOLD:noFold
# epoch 15, loss=0.2443 acc=0.9917 f1=0.9924
# epoch 15, val, loss=0.6658 acc=0.6571 f1=0.7882
# ETA:17s/59s SUB:5 FOLD:noFold
# epoch 16, loss=0.2366 acc=0.9944 f1=0.9949
# epoch 16, val, loss=0.7155 acc=0.6095 f1=0.7211
# ETA:19s/59s SUB:5 FOLD:noFold
# epoch 17, loss=0.2327 acc=1.0000 f1=1.0000
# epoch 17, val, loss=0.6795 acc=0.6286 f1=0.7194
# early stopping
# /content/drive/MyDrive/11777-Project-xs/LGG/save/T_64_pool_16/model_eeg_V/sub5.pth
# using gpu: 0
# myTest
# >>> Test:  loss=0.6821 acc=0.6250 f1=0.7692
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 6 [] 40
# 25 7 8
# (375, 1, 32, 512) (105, 1, 32, 512) (375,) (105,)
# (120, 1, 32, 512) (120,)
# using gpu: 0
# epoch 1, loss=1.3388 acc=0.6587 f1=0.7785
# epoch 1, val, loss=0.6668 acc=0.7143 f1=0.8333
# ETA:1s/1m SUB:6 FOLD:noFold
# epoch 2, loss=0.7693 acc=0.5867 f1=0.6869
# epoch 2, val, loss=0.6287 acc=0.7143 f1=0.8333
# ETA:2s/1m SUB:6 FOLD:noFold
# epoch 3, loss=0.7151 acc=0.7200 f1=0.8357
# epoch 3, val, loss=0.6498 acc=0.7143 f1=0.8333
# ETA:3s/1m SUB:6 FOLD:noFold
# epoch 4, loss=0.6206 acc=0.6560 f1=0.7757
# epoch 4, val, loss=0.6783 acc=0.7143 f1=0.8333
# ETA:4s/1m SUB:6 FOLD:noFold
# epoch 5, loss=0.6226 acc=0.6800 f1=0.7849
# epoch 5, val, loss=0.6558 acc=0.7143 f1=0.8333
# ETA:6s/1m SUB:6 FOLD:noFold
# epoch 6, loss=0.5987 acc=0.7307 f1=0.8389
# epoch 6, val, loss=0.6668 acc=0.7143 f1=0.8333
# ETA:7s/1m SUB:6 FOLD:noFold
# epoch 7, loss=0.5587 acc=0.7227 f1=0.8249
# epoch 7, val, loss=0.6838 acc=0.6952 f1=0.8161
# ETA:8s/1m SUB:6 FOLD:noFold
# epoch 8, loss=0.5204 acc=0.7680 f1=0.8497
# epoch 8, val, loss=0.6806 acc=0.7048 f1=0.8229
# ETA:9s/1m SUB:6 FOLD:noFold
# epoch 9, loss=0.4769 acc=0.8107 f1=0.8807
# epoch 9, val, loss=0.6915 acc=0.4952 f1=0.5225
# ETA:11s/1m SUB:6 FOLD:noFold
# epoch 10, loss=0.4147 acc=0.8773 f1=0.9181
# epoch 10, val, loss=0.6929 acc=0.4857 f1=0.5000
# ETA:12s/1m SUB:6 FOLD:noFold
# epoch 11, loss=0.3536 acc=0.9280 f1=0.9514
# epoch 11, val, loss=0.6907 acc=0.4952 f1=0.5470
# early stopping
# /content/drive/MyDrive/11777-Project-xs/LGG/save/T_64_pool_16/model_eeg_V/sub6.pth
# using gpu: 0
# myTest
# >>> Test:  loss=0.6416 acc=0.8750 f1=0.9333
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 7 [] 40
# 25 7 8
# (375, 1, 32, 512) (105, 1, 32, 512) (375,) (105,)
# (120, 1, 32, 512) (120,)
# using gpu: 0
# epoch 1, loss=1.6818 acc=0.6293 f1=0.7599
# epoch 1, val, loss=0.6521 acc=0.7143 f1=0.8333
# ETA:1s/1m SUB:7 FOLD:noFold
# epoch 2, loss=0.7514 acc=0.5200 f1=0.5714
# epoch 2, val, loss=0.6641 acc=0.7143 f1=0.8333
# ETA:2s/1m SUB:7 FOLD:noFold
# epoch 3, loss=0.6136 acc=0.6933 f1=0.8021
# epoch 3, val, loss=0.6580 acc=0.7143 f1=0.8333
# ETA:3s/1m SUB:7 FOLD:noFold
# epoch 4, loss=0.6201 acc=0.6853 f1=0.8007
# epoch 4, val, loss=0.6860 acc=0.6095 f1=0.7515
# ETA:4s/1m SUB:7 FOLD:noFold
# epoch 5, loss=0.5988 acc=0.6613 f1=0.7534
# epoch 5, val, loss=0.7164 acc=0.3048 f1=0.0519
# ETA:6s/1m SUB:7 FOLD:noFold
# epoch 6, loss=0.5612 acc=0.7040 f1=0.7902
# epoch 6, val, loss=0.6924 acc=0.4286 f1=0.4340
# ETA:7s/1m SUB:7 FOLD:noFold
# epoch 7, loss=0.5471 acc=0.7493 f1=0.8345
# epoch 7, val, loss=0.6939 acc=0.4286 f1=0.4340
# ETA:8s/1m SUB:7 FOLD:noFold
# epoch 8, loss=0.5065 acc=0.8000 f1=0.8582
# epoch 8, val, loss=0.7063 acc=0.4476 f1=0.3958
# early stopping
# /content/drive/MyDrive/11777-Project-xs/LGG/save/T_64_pool_16/model_eeg_V/sub7.pth
# using gpu: 0
# myTest
# >>> Test:  loss=0.6461 acc=0.7500 f1=0.8571
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 8 [] 40
# 25 7 8
# (375, 1, 32, 512) (105, 1, 32, 512) (375,) (105,)
# (120, 1, 32, 512) (120,)
# using gpu: 0
# epoch 1, loss=0.8903 acc=0.5307 f1=0.5644
# epoch 1, val, loss=0.6806 acc=0.5714 f1=0.7273
# ETA:1s/1m SUB:8 FOLD:noFold
# epoch 2, loss=0.7472 acc=0.6213 f1=0.6979
# epoch 2, val, loss=0.6904 acc=0.5714 f1=0.7273
# ETA:2s/1m SUB:8 FOLD:noFold
# epoch 3, loss=0.6875 acc=0.6427 f1=0.6474
# epoch 3, val, loss=0.6992 acc=0.5714 f1=0.7273
# ETA:3s/1m SUB:8 FOLD:noFold
# epoch 4, loss=0.6351 acc=0.6747 f1=0.7520
# epoch 4, val, loss=0.6988 acc=0.5714 f1=0.7273
# ETA:4s/1m SUB:8 FOLD:noFold
# epoch 5, loss=0.5890 acc=0.7120 f1=0.7188
# epoch 5, val, loss=0.7314 acc=0.5714 f1=0.7273
# ETA:6s/1m SUB:8 FOLD:noFold
# epoch 6, loss=0.5142 acc=0.7653 f1=0.8112
# epoch 6, val, loss=0.7663 acc=0.5714 f1=0.7273
# ETA:7s/1m SUB:8 FOLD:noFold
# epoch 7, loss=0.4477 acc=0.8507 f1=0.8667
# epoch 7, val, loss=0.7830 acc=0.5714 f1=0.7273
# ETA:8s/1m SUB:8 FOLD:noFold
# epoch 8, loss=0.3944 acc=0.8880 f1=0.9032
# epoch 8, val, loss=0.7728 acc=0.5714 f1=0.7273
# ETA:9s/1m SUB:8 FOLD:noFold
# epoch 9, loss=0.3005 acc=0.9600 f1=0.9642
# epoch 9, val, loss=0.8052 acc=0.5714 f1=0.7273
# ETA:11s/1m SUB:8 FOLD:noFold
# epoch 10, loss=0.2564 acc=0.9787 f1=0.9810
# epoch 10, val, loss=0.8014 acc=0.5714 f1=0.7273
# ETA:12s/1m SUB:8 FOLD:noFold
# epoch 11, loss=0.2295 acc=1.0000 f1=1.0000
# epoch 11, val, loss=0.7732 acc=0.5714 f1=0.7273
# ETA:13s/1m SUB:8 FOLD:noFold
# epoch 12, loss=0.2361 acc=0.9920 f1=0.9929
# epoch 12, val, loss=0.7335 acc=0.5714 f1=0.7273
# ETA:14s/1m SUB:8 FOLD:noFold
# epoch 13, loss=0.2316 acc=1.0000 f1=1.0000
# epoch 13, val, loss=0.7463 acc=0.5905 f1=0.7362
# ETA:16s/1m SUB:8 FOLD:noFold
# epoch 14, loss=0.2206 acc=1.0000 f1=1.0000
# epoch 14, val, loss=0.6189 acc=0.6286 f1=0.7417
# ETA:17s/1m SUB:8 FOLD:noFold
# epoch 15, loss=0.2306 acc=0.9973 f1=0.9976
# epoch 15, val, loss=0.6533 acc=0.6381 f1=0.7564
# ETA:18s/1m SUB:8 FOLD:noFold
# epoch 16, loss=0.2224 acc=1.0000 f1=1.0000
# epoch 16, val, loss=0.6060 acc=0.6762 f1=0.7500
# ETA:19s/1m SUB:8 FOLD:noFold
# epoch 17, loss=0.2207 acc=1.0000 f1=1.0000
# epoch 17, val, loss=0.6178 acc=0.6762 f1=0.7571
# ETA:21s/1m SUB:8 FOLD:noFold
# epoch 18, loss=0.2196 acc=1.0000 f1=1.0000
# epoch 18, val, loss=0.6182 acc=0.7048 f1=0.7634
# ETA:22s/1m SUB:8 FOLD:noFold
# epoch 19, loss=0.2174 acc=1.0000 f1=1.0000
# epoch 19, val, loss=0.6221 acc=0.6952 f1=0.7538
# ETA:23s/1m SUB:8 FOLD:noFold
# epoch 20, loss=0.2140 acc=1.0000 f1=1.0000
# epoch 20, val, loss=0.6866 acc=0.6381 f1=0.7467
# ETA:24s/1m SUB:8 FOLD:noFold
# epoch 21, loss=0.2161 acc=1.0000 f1=1.0000
# epoch 21, val, loss=0.6286 acc=0.6667 f1=0.7154
# ETA:26s/1m SUB:8 FOLD:noFold
# epoch 22, loss=0.2156 acc=1.0000 f1=1.0000
# epoch 22, val, loss=0.6863 acc=0.6190 f1=0.7333
# ETA:27s/1m SUB:8 FOLD:noFold
# epoch 23, loss=0.2139 acc=0.9973 f1=0.9976
# epoch 23, val, loss=0.6162 acc=0.6667 f1=0.6957
# early stopping
# /content/drive/MyDrive/11777-Project-xs/LGG/save/T_64_pool_16/model_eeg_V/sub8.pth
# using gpu: 0
# myTest
# >>> Test:  loss=1.0099 acc=0.3500 f1=0.2642
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 9 [] 40
# 25 7 8
# (375, 1, 32, 512) (105, 1, 32, 512) (375,) (105,)
# (120, 1, 32, 512) (120,)
# using gpu: 0
# epoch 1, loss=1.0265 acc=0.4987 f1=0.4749
# epoch 1, val, loss=0.6821 acc=0.5714 f1=0.7273
# ETA:1s/1m SUB:9 FOLD:noFold
# epoch 2, loss=0.6810 acc=0.6027 f1=0.5630
# epoch 2, val, loss=0.6972 acc=0.5714 f1=0.7273
# ETA:2s/1m SUB:9 FOLD:noFold
# epoch 3, loss=0.6237 acc=0.6800 f1=0.6552
# epoch 3, val, loss=0.6997 acc=0.5714 f1=0.7273
# ETA:3s/1m SUB:9 FOLD:noFold
# epoch 4, loss=0.6206 acc=0.6853 f1=0.6722
# epoch 4, val, loss=0.7203 acc=0.5714 f1=0.7273
# ETA:4s/1m SUB:9 FOLD:noFold
# epoch 5, loss=0.6088 acc=0.7040 f1=0.6585
# epoch 5, val, loss=0.7131 acc=0.5714 f1=0.7273
# ETA:6s/1m SUB:9 FOLD:noFold
# epoch 6, loss=0.5661 acc=0.7360 f1=0.7332
# epoch 6, val, loss=0.7223 acc=0.5714 f1=0.7273
# ETA:7s/1m SUB:9 FOLD:noFold
# epoch 7, loss=0.4705 acc=0.8267 f1=0.8071
# epoch 7, val, loss=0.7280 acc=0.5714 f1=0.7273
# ETA:8s/1m SUB:9 FOLD:noFold
# epoch 8, loss=0.4400 acc=0.8533 f1=0.8485
# epoch 8, val, loss=0.7286 acc=0.5714 f1=0.7273
# ETA:9s/1m SUB:9 FOLD:noFold
# epoch 9, loss=0.3748 acc=0.8960 f1=0.8889
# epoch 9, val, loss=0.7756 acc=0.5714 f1=0.7273
# ETA:11s/1m SUB:9 FOLD:noFold
# epoch 10, loss=0.3287 acc=0.9360 f1=0.9326
# epoch 10, val, loss=0.8006 acc=0.5714 f1=0.7273
# ETA:12s/1m SUB:9 FOLD:noFold
# epoch 11, loss=0.3040 acc=0.9467 f1=0.9459
# epoch 11, val, loss=0.6701 acc=0.5714 f1=0.7239
# ETA:13s/1m SUB:9 FOLD:noFold
# epoch 12, loss=0.2886 acc=0.9653 f1=0.9638
# epoch 12, val, loss=0.6826 acc=0.5714 f1=0.7239
# ETA:14s/1m SUB:9 FOLD:noFold
# epoch 13, loss=0.2565 acc=0.9920 f1=0.9916
# epoch 13, val, loss=0.6769 acc=0.6000 f1=0.7375
# ETA:16s/1m SUB:9 FOLD:noFold
# epoch 14, loss=0.2411 acc=0.9920 f1=0.9917
# epoch 14, val, loss=0.5691 acc=0.7429 f1=0.8112
# ETA:17s/1m SUB:9 FOLD:noFold
# epoch 15, loss=0.2336 acc=1.0000 f1=1.0000
# epoch 15, val, loss=0.5893 acc=0.7429 f1=0.8058
# ETA:18s/1m SUB:9 FOLD:noFold
# epoch 16, loss=0.2298 acc=1.0000 f1=1.0000
# epoch 16, val, loss=0.5365 acc=0.8000 f1=0.8372
# ETA:19s/1m SUB:9 FOLD:noFold
# epoch 17, loss=0.2199 acc=1.0000 f1=1.0000
# epoch 17, val, loss=0.5359 acc=0.7429 f1=0.7692
# ETA:21s/1m SUB:9 FOLD:noFold
# epoch 18, loss=0.2208 acc=0.9973 f1=0.9972
# epoch 18, val, loss=0.5833 acc=0.7619 f1=0.8000
# ETA:22s/1m SUB:9 FOLD:noFold
# epoch 19, loss=0.2200 acc=1.0000 f1=1.0000
# epoch 19, val, loss=0.5745 acc=0.7429 f1=0.7652
# ETA:23s/1m SUB:9 FOLD:noFold
# epoch 20, loss=0.2213 acc=1.0000 f1=1.0000
# epoch 20, val, loss=0.5550 acc=0.7238 f1=0.7603
# ETA:24s/1m SUB:9 FOLD:noFold
# epoch 21, loss=0.2185 acc=1.0000 f1=1.0000
# epoch 21, val, loss=0.5669 acc=0.7238 f1=0.7563
# early stopping
# /content/drive/MyDrive/11777-Project-xs/LGG/save/T_64_pool_16/model_eeg_V/sub9.pth
# using gpu: 0
# myTest
# >>> Test:  loss=0.6851 acc=0.6917 f1=0.7582
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 10 [] 40
# 25 7 8
# (375, 1, 32, 512) (105, 1, 32, 512) (375,) (105,)
# (120, 1, 32, 512) (120,)
# using gpu: 0
# epoch 1, loss=1.0380 acc=0.5653 f1=0.6110
# epoch 1, val, loss=0.6789 acc=0.5714 f1=0.7273
# ETA:1s/1m SUB:10 FOLD:noFold
# epoch 2, loss=0.6863 acc=0.6613 f1=0.6163
# epoch 2, val, loss=0.6961 acc=0.5714 f1=0.7273
# ETA:2s/1m SUB:10 FOLD:noFold
# epoch 3, loss=0.5948 acc=0.6560 f1=0.6783
# epoch 3, val, loss=0.6883 acc=0.5714 f1=0.7273
# ETA:3s/1m SUB:10 FOLD:noFold
# epoch 4, loss=0.5341 acc=0.7520 f1=0.7533
# epoch 4, val, loss=0.6941 acc=0.5714 f1=0.7273
# ETA:5s/1m SUB:10 FOLD:noFold
# epoch 5, loss=0.4901 acc=0.8133 f1=0.8098
# epoch 5, val, loss=0.7013 acc=0.5714 f1=0.7273
# ETA:6s/1m SUB:10 FOLD:noFold
# epoch 6, loss=0.4794 acc=0.8053 f1=0.8104
# epoch 6, val, loss=0.6985 acc=0.5714 f1=0.7273
# ETA:7s/1m SUB:10 FOLD:noFold
# epoch 7, loss=0.4312 acc=0.8480 f1=0.8480
# epoch 7, val, loss=0.6967 acc=0.5714 f1=0.7273
# ETA:8s/1m SUB:10 FOLD:noFold
# epoch 8, loss=0.3985 acc=0.9013 f1=0.9044
# epoch 8, val, loss=0.6724 acc=0.5714 f1=0.7273
# ETA:10s/1m SUB:10 FOLD:noFold
# epoch 9, loss=0.3568 acc=0.9253 f1=0.9275
# epoch 9, val, loss=0.6751 acc=0.5714 f1=0.7273
# ETA:11s/1m SUB:10 FOLD:noFold
# epoch 10, loss=0.3054 acc=0.9360 f1=0.9365
# epoch 10, val, loss=0.6941 acc=0.5714 f1=0.7273
# ETA:12s/1m SUB:10 FOLD:noFold
# epoch 11, loss=0.2776 acc=0.9680 f1=0.9698
# epoch 11, val, loss=0.6319 acc=0.5810 f1=0.7317
# ETA:13s/1m SUB:10 FOLD:noFold
# epoch 12, loss=0.2547 acc=0.9840 f1=0.9847
# epoch 12, val, loss=0.6434 acc=0.5714 f1=0.7273
# ETA:14s/1m SUB:10 FOLD:noFold
# epoch 13, loss=0.2368 acc=0.9973 f1=0.9974
# epoch 13, val, loss=0.6392 acc=0.5905 f1=0.7329
# ETA:16s/1m SUB:10 FOLD:noFold
# epoch 14, loss=0.2345 acc=0.9973 f1=0.9974
# epoch 14, val, loss=0.6104 acc=0.6952 f1=0.7037
# ETA:17s/1m SUB:10 FOLD:noFold
# epoch 15, loss=0.2259 acc=1.0000 f1=1.0000
# epoch 15, val, loss=0.6031 acc=0.6762 f1=0.7018
# ETA:18s/1m SUB:10 FOLD:noFold
# epoch 16, loss=0.2276 acc=0.9973 f1=0.9974
# epoch 16, val, loss=0.6448 acc=0.6952 f1=0.6667
# ETA:19s/1m SUB:10 FOLD:noFold
# epoch 17, loss=0.2215 acc=0.9973 f1=0.9974
# epoch 17, val, loss=0.6621 acc=0.7048 f1=0.6804
# ETA:21s/1m SUB:10 FOLD:noFold
# epoch 18, loss=0.2252 acc=1.0000 f1=1.0000
# epoch 18, val, loss=0.6552 acc=0.7048 f1=0.6804
# ETA:22s/1m SUB:10 FOLD:noFold
# epoch 19, loss=0.2231 acc=1.0000 f1=1.0000
# epoch 19, val, loss=0.7395 acc=0.6857 f1=0.6374
# ETA:23s/1m SUB:10 FOLD:noFold
# epoch 20, loss=0.2194 acc=1.0000 f1=1.0000
# epoch 20, val, loss=0.7153 acc=0.6857 f1=0.6598
# ETA:24s/1m SUB:10 FOLD:noFold
# epoch 21, loss=0.2190 acc=1.0000 f1=1.0000
# epoch 21, val, loss=0.7885 acc=0.6857 f1=0.6374
# ETA:26s/1m SUB:10 FOLD:noFold
# epoch 22, loss=0.2201 acc=1.0000 f1=1.0000
# epoch 22, val, loss=0.7150 acc=0.6857 f1=0.6667
# ETA:27s/1m SUB:10 FOLD:noFold
# epoch 23, loss=0.2132 acc=1.0000 f1=1.0000
# epoch 23, val, loss=0.7057 acc=0.6762 f1=0.6600
# early stopping
# /content/drive/MyDrive/11777-Project-xs/LGG/save/T_64_pool_16/model_eeg_V/sub10.pth
# using gpu: 0
# myTest
# >>> Test:  loss=0.6142 acc=0.7000 f1=0.5610
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 11 [37, 38, 39] 37
# 23 6 8
# (345, 1, 32, 512) (90, 1, 32, 512) (345,) (90,)
# (120, 1, 32, 512) (120,)
# using gpu: 0
# epoch 1, loss=0.9546 acc=0.5768 f1=0.6404
# epoch 1, val, loss=0.5510 acc=0.8333 f1=0.9091
# ETA:1s/56s SUB:11 FOLD:noFold
# epoch 2, loss=0.6520 acc=0.6261 f1=0.7021
# epoch 2, val, loss=0.5364 acc=0.8333 f1=0.9091
# ETA:2s/56s SUB:11 FOLD:noFold
# epoch 3, loss=0.6748 acc=0.6232 f1=0.7111
# epoch 3, val, loss=0.5390 acc=0.8333 f1=0.9091
# ETA:3s/56s SUB:11 FOLD:noFold
# epoch 4, loss=0.6146 acc=0.6754 f1=0.7489
# epoch 4, val, loss=0.5554 acc=0.8333 f1=0.9091
# ETA:4s/56s SUB:11 FOLD:noFold
# epoch 5, loss=0.6436 acc=0.6870 f1=0.7545
# epoch 5, val, loss=0.5390 acc=0.8333 f1=0.9091
# ETA:5s/57s SUB:11 FOLD:noFold
# epoch 6, loss=0.5990 acc=0.6899 f1=0.7409
# epoch 6, val, loss=0.5190 acc=0.8333 f1=0.9091
# ETA:6s/57s SUB:11 FOLD:noFold
# epoch 7, loss=0.5139 acc=0.7797 f1=0.8326
# epoch 7, val, loss=0.5067 acc=0.8333 f1=0.9091
# ETA:7s/57s SUB:11 FOLD:noFold
# epoch 8, loss=0.4674 acc=0.8348 f1=0.8652
# epoch 8, val, loss=0.4990 acc=0.8333 f1=0.9091
# ETA:9s/57s SUB:11 FOLD:noFold
# epoch 9, loss=0.4163 acc=0.8812 f1=0.9044
# epoch 9, val, loss=0.5705 acc=0.8333 f1=0.9091
# ETA:10s/57s SUB:11 FOLD:noFold
# epoch 10, loss=0.3406 acc=0.9188 f1=0.9346
# epoch 10, val, loss=0.5028 acc=0.8333 f1=0.9091
# ETA:11s/57s SUB:11 FOLD:noFold
# epoch 11, loss=0.2646 acc=0.9855 f1=0.9882
# epoch 11, val, loss=0.4969 acc=0.8333 f1=0.9091
# ETA:12s/57s SUB:11 FOLD:noFold
# epoch 12, loss=0.2477 acc=0.9913 f1=0.9928
# epoch 12, val, loss=0.5040 acc=0.8333 f1=0.9091
# ETA:13s/57s SUB:11 FOLD:noFold
# epoch 13, loss=0.2414 acc=0.9971 f1=0.9976
# epoch 13, val, loss=0.5421 acc=0.8111 f1=0.8957
# ETA:14s/57s SUB:11 FOLD:noFold
# epoch 14, loss=0.2379 acc=0.9942 f1=0.9952
# epoch 14, val, loss=0.6556 acc=0.7444 f1=0.8535
# ETA:15s/56s SUB:11 FOLD:noFold
# epoch 15, loss=0.2301 acc=0.9971 f1=0.9976
# epoch 15, val, loss=0.6558 acc=0.7778 f1=0.8750
# ETA:17s/56s SUB:11 FOLD:noFold
# epoch 16, loss=0.2285 acc=1.0000 f1=1.0000
# epoch 16, val, loss=0.7480 acc=0.6111 f1=0.7518
# ETA:18s/56s SUB:11 FOLD:noFold
# epoch 17, loss=0.2237 acc=1.0000 f1=1.0000
# epoch 17, val, loss=0.8516 acc=0.5889 f1=0.7338
# early stopping
# /content/drive/MyDrive/11777-Project-xs/LGG/save/T_64_pool_16/model_eeg_V/sub11.pth
# using gpu: 0
# myTest
# >>> Test:  loss=0.8346 acc=0.6250 f1=0.7692
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 12 [] 40
# 25 7 8
# (375, 1, 32, 512) (105, 1, 32, 512) (375,) (105,)
# (120, 1, 32, 512) (120,)
# using gpu: 0
# epoch 1, loss=1.1444 acc=0.5600 f1=0.4954
# epoch 1, val, loss=0.6894 acc=0.5714 f1=0.7273
# ETA:1s/1m SUB:12 FOLD:noFold
# epoch 2, loss=0.7231 acc=0.6000 f1=0.6560
# epoch 2, val, loss=0.7063 acc=0.5714 f1=0.7273
# ETA:2s/1m SUB:12 FOLD:noFold
# epoch 3, loss=0.6947 acc=0.6107 f1=0.4427
# epoch 3, val, loss=0.7320 acc=0.5714 f1=0.7273
# ETA:3s/1m SUB:12 FOLD:noFold
# epoch 4, loss=0.6301 acc=0.6533 f1=0.6798
# epoch 4, val, loss=0.7794 acc=0.5714 f1=0.7273
# ETA:5s/1m SUB:12 FOLD:noFold
# epoch 5, loss=0.5929 acc=0.6827 f1=0.6510
# epoch 5, val, loss=0.7650 acc=0.5714 f1=0.7273
# ETA:6s/1m SUB:12 FOLD:noFold
# epoch 6, loss=0.5524 acc=0.7307 f1=0.6967
# epoch 6, val, loss=0.8148 acc=0.5714 f1=0.7273
# ETA:7s/1m SUB:12 FOLD:noFold
# epoch 7, loss=0.4813 acc=0.8080 f1=0.8011
# epoch 7, val, loss=0.8071 acc=0.5714 f1=0.7273
# ETA:8s/1m SUB:12 FOLD:noFold
# epoch 8, loss=0.3873 acc=0.8960 f1=0.8850
# epoch 8, val, loss=0.7995 acc=0.5714 f1=0.7273
# ETA:9s/1m SUB:12 FOLD:noFold
# epoch 9, loss=0.3135 acc=0.9680 f1=0.9670
# epoch 9, val, loss=0.8094 acc=0.5714 f1=0.7273
# ETA:11s/1m SUB:12 FOLD:noFold
# epoch 10, loss=0.2655 acc=0.9840 f1=0.9832
# epoch 10, val, loss=0.8155 acc=0.5714 f1=0.7273
# ETA:12s/1m SUB:12 FOLD:noFold
# epoch 11, loss=0.2438 acc=0.9947 f1=0.9944
# epoch 11, val, loss=0.8001 acc=0.5714 f1=0.7273
# ETA:13s/1m SUB:12 FOLD:noFold
# epoch 12, loss=0.2270 acc=0.9973 f1=0.9972
# epoch 12, val, loss=0.7271 acc=0.5619 f1=0.7195
# ETA:14s/1m SUB:12 FOLD:noFold
# epoch 13, loss=0.2285 acc=1.0000 f1=1.0000
# epoch 13, val, loss=0.7469 acc=0.5714 f1=0.7205
# ETA:16s/1m SUB:12 FOLD:noFold
# epoch 14, loss=0.2298 acc=1.0000 f1=1.0000
# epoch 14, val, loss=0.6983 acc=0.5429 f1=0.6000
# ETA:17s/1m SUB:12 FOLD:noFold
# epoch 15, loss=0.2299 acc=0.9947 f1=0.9944
# epoch 15, val, loss=0.7289 acc=0.6190 f1=0.7222
# ETA:18s/1m SUB:12 FOLD:noFold
# epoch 16, loss=0.2297 acc=1.0000 f1=1.0000
# epoch 16, val, loss=0.7480 acc=0.5619 f1=0.6034
# ETA:19s/1m SUB:12 FOLD:noFold
# epoch 17, loss=0.2211 acc=1.0000 f1=1.0000
# epoch 17, val, loss=0.7615 acc=0.5810 f1=0.6615
# ETA:21s/1m SUB:12 FOLD:noFold
# epoch 18, loss=0.2191 acc=1.0000 f1=1.0000
# epoch 18, val, loss=0.7903 acc=0.6000 f1=0.6613
# ETA:22s/1m SUB:12 FOLD:noFold
# epoch 19, loss=0.2147 acc=1.0000 f1=1.0000
# epoch 19, val, loss=0.7950 acc=0.5429 f1=0.5862
# ETA:23s/1m SUB:12 FOLD:noFold
# epoch 20, loss=0.2143 acc=1.0000 f1=1.0000
# epoch 20, val, loss=0.7813 acc=0.5905 f1=0.6504
# early stopping
# /content/drive/MyDrive/11777-Project-xs/LGG/save/T_64_pool_16/model_eeg_V/sub12.pth
# using gpu: 0
# myTest
# >>> Test:  loss=0.5891 acc=0.6750 f1=0.7797
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 13 [] 40
# 25 7 8
# (375, 1, 32, 512) (105, 1, 32, 512) (375,) (105,)
# (120, 1, 32, 512) (120,)
# using gpu: 0
# epoch 1, loss=0.9960 acc=0.5973 f1=0.4259
# epoch 1, val, loss=0.7516 acc=0.4286 f1=0.6000
# ETA:1s/1m SUB:13 FOLD:noFold
# epoch 2, loss=0.5893 acc=0.7653 f1=0.4824
# epoch 2, val, loss=0.8054 acc=0.4286 f1=0.6000
# ETA:2s/1m SUB:13 FOLD:noFold
# epoch 3, loss=0.5353 acc=0.7627 f1=0.6367
# epoch 3, val, loss=0.8421 acc=0.4286 f1=0.6000
# ETA:3s/1m SUB:13 FOLD:noFold
# epoch 4, loss=0.4728 acc=0.8293 f1=0.7143
# epoch 4, val, loss=0.8120 acc=0.4286 f1=0.6000
# ETA:4s/1m SUB:13 FOLD:noFold
# epoch 5, loss=0.4486 acc=0.8480 f1=0.6984
# epoch 5, val, loss=0.8831 acc=0.4286 f1=0.6000
# ETA:6s/1m SUB:13 FOLD:noFold
# epoch 6, loss=0.4378 acc=0.8587 f1=0.7782
# epoch 6, val, loss=0.9199 acc=0.4286 f1=0.6000
# ETA:7s/1m SUB:13 FOLD:noFold
# epoch 7, loss=0.3771 acc=0.9013 f1=0.8279
# epoch 7, val, loss=0.8698 acc=0.4286 f1=0.6000
# ETA:8s/1m SUB:13 FOLD:noFold
# epoch 8, loss=0.3309 acc=0.9253 f1=0.8739
# epoch 8, val, loss=0.8763 acc=0.4286 f1=0.6000
# ETA:9s/1m SUB:13 FOLD:noFold
# epoch 9, loss=0.3118 acc=0.9333 f1=0.8927
# epoch 9, val, loss=0.8824 acc=0.4286 f1=0.6000
# ETA:11s/1m SUB:13 FOLD:noFold
# epoch 10, loss=0.2640 acc=0.9840 f1=0.9746
# epoch 10, val, loss=0.8948 acc=0.4286 f1=0.6000
# ETA:12s/1m SUB:13 FOLD:noFold
# epoch 11, loss=0.2391 acc=0.9920 f1=0.9877
# epoch 11, val, loss=0.8281 acc=0.4286 f1=0.6000
# ETA:13s/1m SUB:13 FOLD:noFold
# epoch 12, loss=0.2338 acc=0.9973 f1=0.9958
# epoch 12, val, loss=0.7198 acc=0.4286 f1=0.6000
# ETA:14s/1m SUB:13 FOLD:noFold
# epoch 13, loss=0.2275 acc=1.0000 f1=1.0000
# epoch 13, val, loss=0.6706 acc=0.5048 f1=0.6338
# ETA:16s/1m SUB:13 FOLD:noFold
# epoch 14, loss=0.2243 acc=1.0000 f1=1.0000
# epoch 14, val, loss=0.4348 acc=0.8857 f1=0.8750
# ETA:17s/1m SUB:13 FOLD:noFold
# epoch 15, loss=0.2236 acc=0.9973 f1=0.9958
# epoch 15, val, loss=0.4508 acc=0.8571 f1=0.8544
# ETA:18s/1m SUB:13 FOLD:noFold
# epoch 16, loss=0.2160 acc=1.0000 f1=1.0000
# epoch 16, val, loss=0.3789 acc=0.9333 f1=0.9195
# ETA:19s/1m SUB:13 FOLD:noFold
# epoch 17, loss=0.2164 acc=1.0000 f1=1.0000
# epoch 17, val, loss=0.3626 acc=0.9143 f1=0.9011
# ETA:21s/1m SUB:13 FOLD:noFold
# epoch 18, loss=0.2161 acc=0.9973 f1=0.9959
# epoch 18, val, loss=0.3491 acc=0.9238 f1=0.9070
# ETA:22s/1m SUB:13 FOLD:noFold
# epoch 19, loss=0.2144 acc=1.0000 f1=1.0000
# epoch 19, val, loss=0.3422 acc=0.9238 f1=0.9070
# ETA:23s/1m SUB:13 FOLD:noFold
# epoch 20, loss=0.2128 acc=1.0000 f1=1.0000
# epoch 20, val, loss=0.3265 acc=0.9143 f1=0.8941
# ETA:24s/1m SUB:13 FOLD:noFold
# epoch 21, loss=0.2133 acc=1.0000 f1=1.0000
# epoch 21, val, loss=0.3293 acc=0.9429 f1=0.9333
# ETA:26s/1m SUB:13 FOLD:noFold
# epoch 22, loss=0.2116 acc=1.0000 f1=1.0000
# epoch 22, val, loss=0.3505 acc=0.9429 f1=0.9333
# ETA:27s/1m SUB:13 FOLD:noFold
# epoch 23, loss=0.2113 acc=1.0000 f1=1.0000
# epoch 23, val, loss=0.3409 acc=0.9429 f1=0.9333
# ETA:28s/1m SUB:13 FOLD:noFold
# epoch 24, loss=0.2126 acc=1.0000 f1=1.0000
# epoch 24, val, loss=0.3437 acc=0.9429 f1=0.9333
# ETA:29s/1m SUB:13 FOLD:noFold
# epoch 25, loss=0.2105 acc=1.0000 f1=1.0000
# epoch 25, val, loss=0.3416 acc=0.9143 f1=0.8966
# ETA:31s/1m SUB:13 FOLD:noFold
# epoch 26, loss=0.2102 acc=1.0000 f1=1.0000
# epoch 26, val, loss=0.3362 acc=0.9429 f1=0.9333
# ETA:32s/1m SUB:13 FOLD:noFold
# epoch 27, loss=0.2102 acc=1.0000 f1=1.0000
# epoch 27, val, loss=0.3342 acc=0.9143 f1=0.8966
# ETA:33s/1m SUB:13 FOLD:noFold
# epoch 28, loss=0.2109 acc=1.0000 f1=1.0000
# epoch 28, val, loss=0.3498 acc=0.9143 f1=0.8966
# ETA:34s/1m SUB:13 FOLD:noFold
# epoch 29, loss=0.2115 acc=1.0000 f1=1.0000
# epoch 29, val, loss=0.3353 acc=0.9143 f1=0.8966
# ETA:35s/1m SUB:13 FOLD:noFold
# epoch 30, loss=0.2104 acc=1.0000 f1=1.0000
# epoch 30, val, loss=0.3400 acc=0.9333 f1=0.9231
# ETA:37s/1m SUB:13 FOLD:noFold
# epoch 31, loss=0.2087 acc=1.0000 f1=1.0000
# epoch 31, val, loss=0.3469 acc=0.9238 f1=0.9091
# early stopping
# /content/drive/MyDrive/11777-Project-xs/LGG/save/T_64_pool_16/model_eeg_V/sub13.pth
# using gpu: 0
# myTest
# >>> Test:  loss=1.2647 acc=0.4500 f1=0.4407
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 14 [39] 39
# 24 7 8
# (360, 1, 32, 512) (105, 1, 32, 512) (360,) (105,)
# (120, 1, 32, 512) (120,)
# using gpu: 0
# epoch 1, loss=1.3308 acc=0.4806 f1=0.4672
# epoch 1, val, loss=0.7567 acc=0.4286 f1=0.6000
# ETA:1s/59s SUB:14 FOLD:noFold
# epoch 2, loss=0.7659 acc=0.6028 f1=0.6977
# epoch 2, val, loss=0.7526 acc=0.4286 f1=0.6000
# ETA:2s/59s SUB:14 FOLD:noFold
# epoch 3, loss=0.6915 acc=0.5972 f1=0.5619
# epoch 3, val, loss=0.7591 acc=0.4286 f1=0.6000
# ETA:3s/59s SUB:14 FOLD:noFold
# epoch 4, loss=0.6509 acc=0.5972 f1=0.6292
# epoch 4, val, loss=0.8147 acc=0.4286 f1=0.6000
# ETA:4s/59s SUB:14 FOLD:noFold
# epoch 5, loss=0.6345 acc=0.6361 f1=0.7002
# epoch 5, val, loss=0.7767 acc=0.4286 f1=0.6000
# ETA:5s/59s SUB:14 FOLD:noFold
# epoch 6, loss=0.5763 acc=0.7222 f1=0.7268
# epoch 6, val, loss=0.7841 acc=0.4286 f1=0.6000
# ETA:7s/1m SUB:14 FOLD:noFold
# epoch 7, loss=0.5574 acc=0.7333 f1=0.7460
# epoch 7, val, loss=0.8152 acc=0.4286 f1=0.6000
# ETA:8s/1m SUB:14 FOLD:noFold
# epoch 8, loss=0.5164 acc=0.7611 f1=0.7923
# epoch 8, val, loss=0.8063 acc=0.4286 f1=0.6000
# ETA:9s/1m SUB:14 FOLD:noFold
# epoch 9, loss=0.4951 acc=0.7861 f1=0.7843
# epoch 9, val, loss=0.8308 acc=0.4286 f1=0.6000
# ETA:10s/59s SUB:14 FOLD:noFold
# epoch 10, loss=0.4452 acc=0.8444 f1=0.8600
# epoch 10, val, loss=0.7991 acc=0.4286 f1=0.6000
# ETA:11s/59s SUB:14 FOLD:noFold
# epoch 11, loss=0.3863 acc=0.9000 f1=0.9053
# epoch 11, val, loss=0.7924 acc=0.4286 f1=0.6000
# ETA:13s/59s SUB:14 FOLD:noFold
# epoch 12, loss=0.3359 acc=0.9333 f1=0.9391
# epoch 12, val, loss=0.7597 acc=0.4286 f1=0.6000
# ETA:14s/59s SUB:14 FOLD:noFold
# epoch 13, loss=0.2659 acc=0.9917 f1=0.9923
# epoch 13, val, loss=0.7109 acc=0.4857 f1=0.6087
# ETA:15s/59s SUB:14 FOLD:noFold
# epoch 14, loss=0.2466 acc=0.9917 f1=0.9923
# epoch 14, val, loss=0.7202 acc=0.4857 f1=0.6029
# ETA:16s/59s SUB:14 FOLD:noFold
# epoch 15, loss=0.2357 acc=1.0000 f1=1.0000
# epoch 15, val, loss=0.6268 acc=0.6762 f1=0.6458
# ETA:17s/59s SUB:14 FOLD:noFold
# epoch 16, loss=0.2331 acc=1.0000 f1=1.0000
# epoch 16, val, loss=0.6497 acc=0.6857 f1=0.5926
# ETA:19s/1m SUB:14 FOLD:noFold
# epoch 17, loss=0.2350 acc=0.9972 f1=0.9974
# epoch 17, val, loss=0.7062 acc=0.6286 f1=0.6139
# ETA:20s/59s SUB:14 FOLD:noFold
# epoch 18, loss=0.2229 acc=1.0000 f1=1.0000
# epoch 18, val, loss=0.6852 acc=0.6762 f1=0.6667
# ETA:21s/59s SUB:14 FOLD:noFold
# epoch 19, loss=0.2247 acc=1.0000 f1=1.0000
# epoch 19, val, loss=0.7249 acc=0.6476 f1=0.5747
# ETA:22s/59s SUB:14 FOLD:noFold
# epoch 20, loss=0.2197 acc=1.0000 f1=1.0000
# epoch 20, val, loss=0.7432 acc=0.5810 f1=0.6140
# ETA:23s/59s SUB:14 FOLD:noFold
# epoch 21, loss=0.2211 acc=1.0000 f1=1.0000
# epoch 21, val, loss=0.7200 acc=0.6857 f1=0.6118
# ETA:25s/59s SUB:14 FOLD:noFold
# epoch 22, loss=0.2200 acc=1.0000 f1=1.0000
# epoch 22, val, loss=0.6638 acc=0.6952 f1=0.6364
# ETA:26s/59s SUB:14 FOLD:noFold
# epoch 23, loss=0.2163 acc=1.0000 f1=1.0000
# epoch 23, val, loss=0.7086 acc=0.6476 f1=0.5843
# ETA:27s/59s SUB:14 FOLD:noFold
# epoch 24, loss=0.2176 acc=1.0000 f1=1.0000
# epoch 24, val, loss=0.7239 acc=0.6571 f1=0.5263
# ETA:28s/59s SUB:14 FOLD:noFold
# epoch 25, loss=0.2159 acc=1.0000 f1=1.0000
# epoch 25, val, loss=0.7029 acc=0.6286 f1=0.6422
# ETA:29s/59s SUB:14 FOLD:noFold
# epoch 26, loss=0.2210 acc=1.0000 f1=1.0000
# epoch 26, val, loss=0.6585 acc=0.6857 f1=0.5926
# ETA:31s/59s SUB:14 FOLD:noFold
# epoch 27, loss=0.2150 acc=1.0000 f1=1.0000
# epoch 27, val, loss=0.6622 acc=0.6857 f1=0.6292
# early stopping
# /content/drive/MyDrive/11777-Project-xs/LGG/save/T_64_pool_16/model_eeg_V/sub14.pth
# using gpu: 0
# myTest
# >>> Test:  loss=0.7520 acc=0.5750 f1=0.4396
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 15 [] 40
# 25 7 8
# (375, 1, 32, 512) (105, 1, 32, 512) (375,) (105,)
# (120, 1, 32, 512) (120,)
# using gpu: 0
# epoch 1, loss=1.0887 acc=0.5413 f1=0.5000
# epoch 1, val, loss=0.6776 acc=0.5714 f1=0.7273
# ETA:1s/1m SUB:15 FOLD:noFold
# epoch 2, loss=0.6205 acc=0.7440 f1=0.6667
# epoch 2, val, loss=0.7019 acc=0.5714 f1=0.7273
# ETA:2s/1m SUB:15 FOLD:noFold
# epoch 3, loss=0.5472 acc=0.7467 f1=0.7324
# epoch 3, val, loss=0.6863 acc=0.5714 f1=0.7273
# ETA:3s/1m SUB:15 FOLD:noFold
# epoch 4, loss=0.5218 acc=0.7573 f1=0.7036
# epoch 4, val, loss=0.6947 acc=0.5714 f1=0.7273
# ETA:4s/1m SUB:15 FOLD:noFold
# epoch 5, loss=0.4594 acc=0.8213 f1=0.7873
# epoch 5, val, loss=0.6983 acc=0.5714 f1=0.7273
# ETA:6s/1m SUB:15 FOLD:noFold
# epoch 6, loss=0.4440 acc=0.8373 f1=0.8157
# epoch 6, val, loss=0.6941 acc=0.5714 f1=0.7273
# ETA:7s/1m SUB:15 FOLD:noFold
# epoch 7, loss=0.3974 acc=0.8720 f1=0.8491
# epoch 7, val, loss=0.6943 acc=0.5714 f1=0.7273
# ETA:8s/1m SUB:15 FOLD:noFold
# epoch 8, loss=0.3549 acc=0.9093 f1=0.8944
# epoch 8, val, loss=0.6730 acc=0.5714 f1=0.7273
# ETA:9s/1m SUB:15 FOLD:noFold
# epoch 9, loss=0.3066 acc=0.9627 f1=0.9576
# epoch 9, val, loss=0.6767 acc=0.5714 f1=0.7273
# ETA:11s/1m SUB:15 FOLD:noFold
# epoch 10, loss=0.2732 acc=0.9733 f1=0.9697
# epoch 10, val, loss=0.6654 acc=0.5714 f1=0.7273
# ETA:12s/1m SUB:15 FOLD:noFold
# epoch 11, loss=0.2441 acc=0.9893 f1=0.9877
# epoch 11, val, loss=0.6468 acc=0.5714 f1=0.7273
# ETA:13s/1m SUB:15 FOLD:noFold
# epoch 12, loss=0.2322 acc=0.9947 f1=0.9939
# epoch 12, val, loss=0.6106 acc=0.6000 f1=0.7342
# ETA:14s/1m SUB:15 FOLD:noFold
# epoch 13, loss=0.2228 acc=1.0000 f1=1.0000
# epoch 13, val, loss=0.5932 acc=0.7048 f1=0.7832
# ETA:16s/1m SUB:15 FOLD:noFold
# epoch 14, loss=0.2272 acc=0.9947 f1=0.9939
# epoch 14, val, loss=0.5696 acc=0.7238 f1=0.7339
# ETA:17s/1m SUB:15 FOLD:noFold
# epoch 15, loss=0.2212 acc=1.0000 f1=1.0000
# epoch 15, val, loss=0.5708 acc=0.7429 f1=0.7652
# ETA:18s/1m SUB:15 FOLD:noFold
# epoch 16, loss=0.2178 acc=1.0000 f1=1.0000
# epoch 16, val, loss=0.5867 acc=0.7048 f1=0.6931
# ETA:19s/1m SUB:15 FOLD:noFold
# epoch 17, loss=0.2182 acc=1.0000 f1=1.0000
# epoch 17, val, loss=0.5999 acc=0.7143 f1=0.7115
# ETA:21s/1m SUB:15 FOLD:noFold
# epoch 18, loss=0.2149 acc=1.0000 f1=1.0000
# epoch 18, val, loss=0.6850 acc=0.6857 f1=0.6598
# ETA:22s/1m SUB:15 FOLD:noFold
# epoch 19, loss=0.2194 acc=1.0000 f1=1.0000
# epoch 19, val, loss=0.6982 acc=0.6857 f1=0.6526
# ETA:23s/1m SUB:15 FOLD:noFold
# epoch 20, loss=0.2184 acc=1.0000 f1=1.0000
# epoch 20, val, loss=0.6330 acc=0.6762 f1=0.6531
# early stopping
# /content/drive/MyDrive/11777-Project-xs/LGG/save/T_64_pool_16/model_eeg_V/sub15.pth
# using gpu: 0
# myTest
# >>> Test:  loss=0.4763 acc=0.7833 f1=0.8333
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 16 [] 40
# 25 7 8
# (375, 1, 32, 512) (105, 1, 32, 512) (375,) (105,)
# (120, 1, 32, 512) (120,)
# using gpu: 0
# epoch 1, loss=1.2139 acc=0.6160 f1=0.4545
# epoch 1, val, loss=0.7010 acc=0.5714 f1=0.7273
# ETA:1s/1m SUB:16 FOLD:noFold
# epoch 2, loss=0.7726 acc=0.5867 f1=0.5932
# epoch 2, val, loss=0.7093 acc=0.5714 f1=0.7273
# ETA:2s/1m SUB:16 FOLD:noFold
# epoch 3, loss=0.7048 acc=0.6667 f1=0.3961
# epoch 3, val, loss=0.6937 acc=0.5714 f1=0.7273
# ETA:3s/1m SUB:16 FOLD:noFold
# epoch 4, loss=0.6354 acc=0.6720 f1=0.5020
# epoch 4, val, loss=0.7074 acc=0.5714 f1=0.7273
# ETA:5s/1m SUB:16 FOLD:noFold
# epoch 5, loss=0.6558 acc=0.6427 f1=0.5786
# epoch 5, val, loss=0.7260 acc=0.5714 f1=0.7273
# ETA:6s/1m SUB:16 FOLD:noFold
# epoch 6, loss=0.5879 acc=0.7280 f1=0.5952
# epoch 6, val, loss=0.7207 acc=0.5714 f1=0.7273
# ETA:7s/1m SUB:16 FOLD:noFold
# epoch 7, loss=0.5714 acc=0.7227 f1=0.5873
# epoch 7, val, loss=0.7397 acc=0.5714 f1=0.7273
# ETA:8s/1m SUB:16 FOLD:noFold
# epoch 8, loss=0.5147 acc=0.8107 f1=0.7473
# epoch 8, val, loss=0.7186 acc=0.5714 f1=0.7273
# ETA:10s/1m SUB:16 FOLD:noFold
# epoch 9, loss=0.4556 acc=0.8613 f1=0.8129
# epoch 9, val, loss=0.7248 acc=0.5714 f1=0.7273
# ETA:11s/1m SUB:16 FOLD:noFold
# epoch 10, loss=0.3808 acc=0.9147 f1=0.8881
# epoch 10, val, loss=0.7437 acc=0.5714 f1=0.7273
# ETA:12s/1m SUB:16 FOLD:noFold
# epoch 11, loss=0.2892 acc=0.9787 f1=0.9737
# epoch 11, val, loss=0.7641 acc=0.5714 f1=0.7273
# ETA:13s/1m SUB:16 FOLD:noFold
# epoch 12, loss=0.2431 acc=0.9973 f1=0.9967
# epoch 12, val, loss=0.7287 acc=0.5714 f1=0.7273
# ETA:14s/1m SUB:16 FOLD:noFold
# epoch 13, loss=0.2286 acc=1.0000 f1=1.0000
# epoch 13, val, loss=0.7306 acc=0.5810 f1=0.7067
# ETA:16s/1m SUB:16 FOLD:noFold
# epoch 14, loss=0.2245 acc=1.0000 f1=1.0000
# epoch 14, val, loss=0.7653 acc=0.5429 f1=0.6190
# ETA:17s/1m SUB:16 FOLD:noFold
# epoch 15, loss=0.2215 acc=1.0000 f1=1.0000
# epoch 15, val, loss=0.8406 acc=0.5143 f1=0.5321
# ETA:18s/1m SUB:16 FOLD:noFold
# epoch 16, loss=0.2225 acc=1.0000 f1=1.0000
# epoch 16, val, loss=0.9183 acc=0.5333 f1=0.5051
# ETA:19s/1m SUB:16 FOLD:noFold
# epoch 17, loss=0.2192 acc=0.9973 f1=0.9967
# epoch 17, val, loss=1.0028 acc=0.5143 f1=0.4396
# ETA:21s/1m SUB:16 FOLD:noFold
# epoch 18, loss=0.2180 acc=1.0000 f1=1.0000
# epoch 18, val, loss=1.0415 acc=0.5048 f1=0.4222
# early stopping
# /content/drive/MyDrive/11777-Project-xs/LGG/save/T_64_pool_16/model_eeg_V/sub16.pth
# using gpu: 0
# myTest
# >>> Test:  loss=1.0844 acc=0.2000 f1=0.2381
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 17 [] 40
# 25 7 8
# (375, 1, 32, 512) (105, 1, 32, 512) (375,) (105,)
# (120, 1, 32, 512) (120,)
# using gpu: 0
# epoch 1, loss=1.0953 acc=0.5707 f1=0.5660
# epoch 1, val, loss=0.5663 acc=0.8571 f1=0.9231
# ETA:1s/1m SUB:17 FOLD:noFold
# epoch 2, loss=0.7329 acc=0.5867 f1=0.5507
# epoch 2, val, loss=0.5048 acc=0.8571 f1=0.9231
# ETA:2s/1m SUB:17 FOLD:noFold
# epoch 3, loss=0.6533 acc=0.6187 f1=0.5806
# epoch 3, val, loss=0.4993 acc=0.8571 f1=0.9231
# ETA:3s/1m SUB:17 FOLD:noFold
# epoch 4, loss=0.6438 acc=0.6773 f1=0.6807
# epoch 4, val, loss=0.4994 acc=0.8571 f1=0.9231
# ETA:4s/1m SUB:17 FOLD:noFold
# epoch 5, loss=0.5930 acc=0.7253 f1=0.7099
# epoch 5, val, loss=0.4977 acc=0.8571 f1=0.9231
# ETA:6s/1m SUB:17 FOLD:noFold
# epoch 6, loss=0.5736 acc=0.7280 f1=0.6982
# epoch 6, val, loss=0.4825 acc=0.8571 f1=0.9231
# ETA:7s/1m SUB:17 FOLD:noFold
# epoch 7, loss=0.5062 acc=0.7840 f1=0.7828
# epoch 7, val, loss=0.4842 acc=0.8571 f1=0.9231
# ETA:8s/1m SUB:17 FOLD:noFold
# epoch 8, loss=0.4512 acc=0.8240 f1=0.8226
# epoch 8, val, loss=0.4646 acc=0.8571 f1=0.9231
# ETA:10s/1m SUB:17 FOLD:noFold
# epoch 9, loss=0.3858 acc=0.8933 f1=0.8876
# epoch 9, val, loss=0.4761 acc=0.8571 f1=0.9231
# ETA:11s/1m SUB:17 FOLD:noFold
# epoch 10, loss=0.3201 acc=0.9467 f1=0.9441
# epoch 10, val, loss=0.4949 acc=0.8571 f1=0.9231
# ETA:12s/1m SUB:17 FOLD:noFold
# epoch 11, loss=0.2718 acc=0.9787 f1=0.9781
# epoch 11, val, loss=0.5243 acc=0.8571 f1=0.9231
# ETA:13s/1m SUB:17 FOLD:noFold
# epoch 12, loss=0.2396 acc=0.9947 f1=0.9944
# epoch 12, val, loss=0.5355 acc=0.8571 f1=0.9231
# ETA:14s/1m SUB:17 FOLD:noFold
# epoch 13, loss=0.2318 acc=1.0000 f1=1.0000
# epoch 13, val, loss=0.5928 acc=0.8000 f1=0.8889
# ETA:16s/1m SUB:17 FOLD:noFold
# epoch 14, loss=0.2279 acc=0.9973 f1=0.9972
# epoch 14, val, loss=0.6307 acc=0.7619 f1=0.8649
# ETA:17s/1m SUB:17 FOLD:noFold
# epoch 15, loss=0.2229 acc=1.0000 f1=1.0000
# epoch 15, val, loss=0.7539 acc=0.6762 f1=0.8046
# ETA:18s/1m SUB:17 FOLD:noFold
# epoch 16, loss=0.2303 acc=0.9947 f1=0.9945
# epoch 16, val, loss=1.0345 acc=0.2952 f1=0.4394
# ETA:19s/1m SUB:17 FOLD:noFold
# epoch 17, loss=0.2186 acc=1.0000 f1=1.0000
# epoch 17, val, loss=0.8821 acc=0.5810 f1=0.7317
# early stopping
# /content/drive/MyDrive/11777-Project-xs/LGG/save/T_64_pool_16/model_eeg_V/sub17.pth
# using gpu: 0
# myTest
# >>> Test:  loss=0.8110 acc=0.4917 f1=0.6592
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 18 [] 40
# 25 7 8
# (375, 1, 32, 512) (105, 1, 32, 512) (375,) (105,)
# (120, 1, 32, 512) (120,)
# using gpu: 0
# epoch 1, loss=1.5018 acc=0.5733 f1=0.6117
# epoch 1, val, loss=0.6778 acc=0.5714 f1=0.7273
# ETA:1s/1m SUB:18 FOLD:noFold
# epoch 2, loss=0.7318 acc=0.6267 f1=0.6651
# epoch 2, val, loss=0.6902 acc=0.5714 f1=0.7273
# ETA:2s/1m SUB:18 FOLD:noFold
# epoch 3, loss=0.6737 acc=0.6347 f1=0.7243
# epoch 3, val, loss=0.6782 acc=0.5714 f1=0.7273
# ETA:3s/1m SUB:18 FOLD:noFold
# epoch 4, loss=0.6237 acc=0.6827 f1=0.6792
# epoch 4, val, loss=0.6790 acc=0.5714 f1=0.7273
# ETA:5s/1m SUB:18 FOLD:noFold
# epoch 5, loss=0.5617 acc=0.7520 f1=0.7919
# epoch 5, val, loss=0.6788 acc=0.5714 f1=0.7273
# ETA:6s/1m SUB:18 FOLD:noFold
# epoch 6, loss=0.5292 acc=0.7547 f1=0.7900
# epoch 6, val, loss=0.6733 acc=0.5714 f1=0.7273
# ETA:7s/1m SUB:18 FOLD:noFold
# epoch 7, loss=0.4802 acc=0.8133 f1=0.8241
# epoch 7, val, loss=0.6715 acc=0.5714 f1=0.7273
# ETA:8s/1m SUB:18 FOLD:noFold
# epoch 8, loss=0.4576 acc=0.8293 f1=0.8552
# epoch 8, val, loss=0.6492 acc=0.5714 f1=0.7273
# ETA:9s/1m SUB:18 FOLD:noFold
# epoch 9, loss=0.3992 acc=0.8640 f1=0.8741
# epoch 9, val, loss=0.6492 acc=0.5714 f1=0.7273
# ETA:11s/1m SUB:18 FOLD:noFold
# epoch 10, loss=0.3471 acc=0.9200 f1=0.9282
# epoch 10, val, loss=0.6306 acc=0.5714 f1=0.7273
# ETA:12s/1m SUB:18 FOLD:noFold
# epoch 11, loss=0.2905 acc=0.9653 f1=0.9690
# epoch 11, val, loss=0.6231 acc=0.5810 f1=0.7317
# ETA:13s/1m SUB:18 FOLD:noFold
# epoch 12, loss=0.2464 acc=0.9947 f1=0.9953
# epoch 12, val, loss=0.5979 acc=0.6095 f1=0.7421
# ETA:14s/1m SUB:18 FOLD:noFold
# epoch 13, loss=0.2367 acc=1.0000 f1=1.0000
# epoch 13, val, loss=0.5853 acc=0.6476 f1=0.7582
# ETA:16s/1m SUB:18 FOLD:noFold
# epoch 14, loss=0.2237 acc=1.0000 f1=1.0000
# epoch 14, val, loss=0.5191 acc=0.7143 f1=0.7727
# ETA:17s/1m SUB:18 FOLD:noFold
# epoch 15, loss=0.2260 acc=1.0000 f1=1.0000
# epoch 15, val, loss=0.5447 acc=0.7048 f1=0.7737
# ETA:18s/1m SUB:18 FOLD:noFold
# epoch 16, loss=0.2203 acc=1.0000 f1=1.0000
# epoch 16, val, loss=0.4912 acc=0.7714 f1=0.8033
# ETA:19s/1m SUB:18 FOLD:noFold
# epoch 17, loss=0.2199 acc=1.0000 f1=1.0000
# epoch 17, val, loss=0.5271 acc=0.7333 f1=0.7846
# ETA:21s/1m SUB:18 FOLD:noFold
# epoch 18, loss=0.2167 acc=1.0000 f1=1.0000
# epoch 18, val, loss=0.4985 acc=0.7619 f1=0.7934
# ETA:22s/1m SUB:18 FOLD:noFold
# epoch 19, loss=0.2170 acc=1.0000 f1=1.0000
# epoch 19, val, loss=0.5159 acc=0.7524 f1=0.7869
# ETA:23s/1m SUB:18 FOLD:noFold
# epoch 20, loss=0.2144 acc=1.0000 f1=1.0000
# epoch 20, val, loss=0.5364 acc=0.7714 f1=0.8065
# ETA:24s/1m SUB:18 FOLD:noFold
# epoch 21, loss=0.2144 acc=1.0000 f1=1.0000
# epoch 21, val, loss=0.5090 acc=0.7810 f1=0.8130
# ETA:26s/1m SUB:18 FOLD:noFold
# epoch 22, loss=0.2152 acc=1.0000 f1=1.0000
# epoch 22, val, loss=0.5099 acc=0.7810 f1=0.8130
# ETA:27s/1m SUB:18 FOLD:noFold
# epoch 23, loss=0.2131 acc=1.0000 f1=1.0000
# epoch 23, val, loss=0.4963 acc=0.7905 f1=0.8226
# ETA:28s/1m SUB:18 FOLD:noFold
# epoch 24, loss=0.2145 acc=1.0000 f1=1.0000
# epoch 24, val, loss=0.5074 acc=0.7619 f1=0.7899
# ETA:29s/1m SUB:18 FOLD:noFold
# epoch 25, loss=0.2111 acc=1.0000 f1=1.0000
# epoch 25, val, loss=0.5249 acc=0.7810 f1=0.8099
# ETA:31s/1m SUB:18 FOLD:noFold
# epoch 26, loss=0.2124 acc=1.0000 f1=1.0000
# epoch 26, val, loss=0.5514 acc=0.7714 f1=0.8065
# ETA:32s/1m SUB:18 FOLD:noFold
# epoch 27, loss=0.2106 acc=1.0000 f1=1.0000
# epoch 27, val, loss=0.5149 acc=0.7714 f1=0.8000
# ETA:33s/1m SUB:18 FOLD:noFold
# epoch 28, loss=0.2129 acc=1.0000 f1=1.0000
# epoch 28, val, loss=0.5247 acc=0.7619 f1=0.7934
# early stopping
# /content/drive/MyDrive/11777-Project-xs/LGG/save/T_64_pool_16/model_eeg_V/sub18.pth
# using gpu: 0
# myTest
# >>> Test:  loss=0.5885 acc=0.6583 f1=0.7657
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 19 [] 40
# 25 7 8
# (375, 1, 32, 512) (105, 1, 32, 512) (375,) (105,)
# (120, 1, 32, 512) (120,)
# using gpu: 0
# epoch 1, loss=1.1758 acc=0.5253 f1=0.5340
# epoch 1, val, loss=0.6807 acc=0.5714 f1=0.7273
# ETA:1s/1m SUB:19 FOLD:noFold
# epoch 2, loss=0.7502 acc=0.6107 f1=0.7103
# epoch 2, val, loss=0.6846 acc=0.5714 f1=0.7273
# ETA:2s/1m SUB:19 FOLD:noFold
# epoch 3, loss=0.7061 acc=0.6027 f1=0.5895
# epoch 3, val, loss=0.6806 acc=0.5714 f1=0.7273
# ETA:3s/1m SUB:19 FOLD:noFold
# epoch 4, loss=0.6645 acc=0.6347 f1=0.7041
# epoch 4, val, loss=0.6849 acc=0.5714 f1=0.7273
# ETA:4s/1m SUB:19 FOLD:noFold
# epoch 5, loss=0.6228 acc=0.6640 f1=0.7083
# epoch 5, val, loss=0.6843 acc=0.5714 f1=0.7273
# ETA:6s/1m SUB:19 FOLD:noFold
# epoch 6, loss=0.6028 acc=0.6880 f1=0.7097
# epoch 6, val, loss=0.6843 acc=0.5714 f1=0.7273
# ETA:7s/1m SUB:19 FOLD:noFold
# epoch 7, loss=0.5445 acc=0.7387 f1=0.7841
# epoch 7, val, loss=0.6827 acc=0.5714 f1=0.7273
# ETA:8s/1m SUB:19 FOLD:noFold
# epoch 8, loss=0.4821 acc=0.8160 f1=0.8244
# epoch 8, val, loss=0.6756 acc=0.5714 f1=0.7273
# ETA:9s/1m SUB:19 FOLD:noFold
# epoch 9, loss=0.3908 acc=0.9067 f1=0.9195
# epoch 9, val, loss=0.6752 acc=0.5714 f1=0.7273
# ETA:11s/1m SUB:19 FOLD:noFold
# epoch 10, loss=0.3366 acc=0.9547 f1=0.9586
# epoch 10, val, loss=0.6719 acc=0.5810 f1=0.7317
# ETA:12s/1m SUB:19 FOLD:noFold
# epoch 11, loss=0.2687 acc=0.9787 f1=0.9810
# epoch 11, val, loss=0.6725 acc=0.5810 f1=0.7317
# ETA:13s/1m SUB:19 FOLD:noFold
# epoch 12, loss=0.2407 acc=0.9947 f1=0.9952
# epoch 12, val, loss=0.6592 acc=0.6190 f1=0.7143
# ETA:14s/1m SUB:19 FOLD:noFold
# epoch 13, loss=0.2320 acc=1.0000 f1=1.0000
# epoch 13, val, loss=0.6690 acc=0.6476 f1=0.7413
# ETA:16s/1m SUB:19 FOLD:noFold
# epoch 14, loss=0.2266 acc=0.9947 f1=0.9952
# epoch 14, val, loss=0.6677 acc=0.6000 f1=0.6379
# ETA:17s/1m SUB:19 FOLD:noFold
# epoch 15, loss=0.2230 acc=1.0000 f1=1.0000
# epoch 15, val, loss=0.6708 acc=0.6095 f1=0.6435
# ETA:18s/1m SUB:19 FOLD:noFold
# epoch 16, loss=0.2244 acc=1.0000 f1=1.0000
# epoch 16, val, loss=0.7088 acc=0.6000 f1=0.5962
# ETA:19s/1m SUB:19 FOLD:noFold
# epoch 17, loss=0.2169 acc=1.0000 f1=1.0000
# epoch 17, val, loss=0.7280 acc=0.6286 f1=0.6355
# ETA:21s/1m SUB:19 FOLD:noFold
# epoch 18, loss=0.2218 acc=1.0000 f1=1.0000
# epoch 18, val, loss=0.7440 acc=0.6381 f1=0.6607
# early stopping
# /content/drive/MyDrive/11777-Project-xs/LGG/save/T_64_pool_16/model_eeg_V/sub19.pth
# using gpu: 0
# myTest
# >>> Test:  loss=0.5983 acc=0.7500 f1=0.8276
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 20 [] 40
# 25 7 8
# (375, 1, 32, 512) (105, 1, 32, 512) (375,) (105,)
# (120, 1, 32, 512) (120,)
# using gpu: 0
# epoch 1, loss=1.1044 acc=0.5440 f1=0.5581
# epoch 1, val, loss=0.6808 acc=0.5714 f1=0.7273
# ETA:1s/1m SUB:20 FOLD:noFold
# epoch 2, loss=0.6957 acc=0.6773 f1=0.6059
# epoch 2, val, loss=0.7149 acc=0.5714 f1=0.7273
# ETA:2s/1m SUB:20 FOLD:noFold
# epoch 3, loss=0.5916 acc=0.7253 f1=0.7366
# epoch 3, val, loss=0.7209 acc=0.5714 f1=0.7273
# ETA:3s/1m SUB:20 FOLD:noFold
# epoch 4, loss=0.5364 acc=0.7867 f1=0.7605
# epoch 4, val, loss=0.7722 acc=0.5714 f1=0.7273
# ETA:4s/1m SUB:20 FOLD:noFold
# epoch 5, loss=0.4790 acc=0.8133 f1=0.7929
# epoch 5, val, loss=0.8393 acc=0.5714 f1=0.7273
# ETA:6s/1m SUB:20 FOLD:noFold
# epoch 6, loss=0.4422 acc=0.8320 f1=0.8245
# epoch 6, val, loss=0.8914 acc=0.5714 f1=0.7273
# ETA:7s/1m SUB:20 FOLD:noFold
# epoch 7, loss=0.4201 acc=0.8720 f1=0.8636
# epoch 7, val, loss=0.9413 acc=0.5714 f1=0.7273
# ETA:8s/1m SUB:20 FOLD:noFold
# epoch 8, loss=0.3525 acc=0.9067 f1=0.9036
# epoch 8, val, loss=0.9154 acc=0.5714 f1=0.7273
# ETA:9s/1m SUB:20 FOLD:noFold
# epoch 9, loss=0.2957 acc=0.9440 f1=0.9421
# epoch 9, val, loss=0.9567 acc=0.5714 f1=0.7273
# ETA:11s/1m SUB:20 FOLD:noFold
# epoch 10, loss=0.2615 acc=0.9760 f1=0.9748
# epoch 10, val, loss=0.9568 acc=0.5714 f1=0.7273
# ETA:12s/1m SUB:20 FOLD:noFold
# epoch 11, loss=0.2366 acc=0.9947 f1=0.9945
# epoch 11, val, loss=0.8513 acc=0.5714 f1=0.7273
# ETA:13s/1m SUB:20 FOLD:noFold
# epoch 12, loss=0.2254 acc=1.0000 f1=1.0000
# epoch 12, val, loss=0.8289 acc=0.5905 f1=0.7362
# ETA:14s/1m SUB:20 FOLD:noFold
# epoch 13, loss=0.2216 acc=1.0000 f1=1.0000
# epoch 13, val, loss=0.7263 acc=0.6381 f1=0.7532
# ETA:16s/1m SUB:20 FOLD:noFold
# epoch 14, loss=0.2264 acc=0.9947 f1=0.9945
# epoch 14, val, loss=0.6523 acc=0.6571 f1=0.7500
# ETA:17s/1m SUB:20 FOLD:noFold
# epoch 15, loss=0.2195 acc=1.0000 f1=1.0000
# epoch 15, val, loss=0.6506 acc=0.6476 f1=0.6992
# ETA:18s/1m SUB:20 FOLD:noFold
# epoch 16, loss=0.2185 acc=1.0000 f1=1.0000
# epoch 16, val, loss=0.6582 acc=0.6762 f1=0.7500
# ETA:19s/1m SUB:20 FOLD:noFold
# epoch 17, loss=0.2191 acc=1.0000 f1=1.0000
# epoch 17, val, loss=0.6647 acc=0.6286 f1=0.6667
# ETA:21s/1m SUB:20 FOLD:noFold
# epoch 18, loss=0.2177 acc=0.9973 f1=0.9972
# epoch 18, val, loss=0.6958 acc=0.6000 f1=0.6769
# ETA:22s/1m SUB:20 FOLD:noFold
# epoch 19, loss=0.2164 acc=1.0000 f1=1.0000
# epoch 19, val, loss=0.6954 acc=0.6190 f1=0.6429
# ETA:23s/1m SUB:20 FOLD:noFold
# epoch 20, loss=0.2158 acc=1.0000 f1=1.0000
# epoch 20, val, loss=0.6769 acc=0.6286 f1=0.6486
# ETA:24s/1m SUB:20 FOLD:noFold
# epoch 21, loss=0.2152 acc=1.0000 f1=1.0000
# epoch 21, val, loss=0.7081 acc=0.6286 f1=0.6355
# early stopping
# /content/drive/MyDrive/11777-Project-xs/LGG/save/T_64_pool_16/model_eeg_V/sub20.pth
# using gpu: 0
# myTest
# >>> Test:  loss=0.5985 acc=0.6500 f1=0.7742
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 21 [] 40
# 25 7 8
# (375, 1, 32, 512) (105, 1, 32, 512) (375,) (105,)
# (120, 1, 32, 512) (120,)
# using gpu: 0
# epoch 1, loss=1.0242 acc=0.5387 f1=0.6181
# epoch 1, val, loss=0.7689 acc=0.4286 f1=0.6000
# ETA:1s/1m SUB:21 FOLD:noFold
# epoch 2, loss=0.7822 acc=0.5760 f1=0.6801
# epoch 2, val, loss=0.7657 acc=0.4286 f1=0.6000
# ETA:2s/1m SUB:21 FOLD:noFold
# epoch 3, loss=0.6913 acc=0.5813 f1=0.6235
# epoch 3, val, loss=0.8087 acc=0.4286 f1=0.6000
# ETA:3s/1m SUB:21 FOLD:noFold
# epoch 4, loss=0.6992 acc=0.6373 f1=0.7463
# epoch 4, val, loss=0.8154 acc=0.4286 f1=0.6000
# ETA:5s/1m SUB:21 FOLD:noFold
# epoch 5, loss=0.7154 acc=0.5547 f1=0.5751
# epoch 5, val, loss=0.8042 acc=0.4286 f1=0.6000
# ETA:6s/1m SUB:21 FOLD:noFold
# epoch 6, loss=0.6564 acc=0.6640 f1=0.7558
# epoch 6, val, loss=0.8463 acc=0.4286 f1=0.6000
# ETA:7s/1m SUB:21 FOLD:noFold
# epoch 7, loss=0.5717 acc=0.7280 f1=0.7802
# epoch 7, val, loss=0.8169 acc=0.4286 f1=0.6000
# ETA:8s/1m SUB:21 FOLD:noFold
# epoch 8, loss=0.5259 acc=0.7760 f1=0.8228
# epoch 8, val, loss=0.8171 acc=0.4286 f1=0.6000
# ETA:9s/1m SUB:21 FOLD:noFold
# epoch 9, loss=0.3902 acc=0.9013 f1=0.9187
# epoch 9, val, loss=0.8089 acc=0.4286 f1=0.6000
# ETA:11s/1m SUB:21 FOLD:noFold
# epoch 10, loss=0.3217 acc=0.9387 f1=0.9492
# epoch 10, val, loss=0.7986 acc=0.4286 f1=0.6000
# ETA:12s/1m SUB:21 FOLD:noFold
# epoch 11, loss=0.2514 acc=0.9920 f1=0.9933
# epoch 11, val, loss=0.7836 acc=0.4286 f1=0.6000
# ETA:13s/1m SUB:21 FOLD:noFold
# epoch 12, loss=0.2415 acc=0.9973 f1=0.9978
# epoch 12, val, loss=0.7424 acc=0.4762 f1=0.6154
# ETA:14s/1m SUB:21 FOLD:noFold
# epoch 13, loss=0.2356 acc=0.9973 f1=0.9978
# epoch 13, val, loss=0.8647 acc=0.4571 f1=0.6122
# ETA:16s/1m SUB:21 FOLD:noFold
# epoch 14, loss=0.2306 acc=1.0000 f1=1.0000
# epoch 14, val, loss=0.7633 acc=0.5714 f1=0.5872
# ETA:17s/1m SUB:21 FOLD:noFold
# epoch 15, loss=0.2320 acc=0.9973 f1=0.9978
# epoch 15, val, loss=1.0232 acc=0.4286 f1=0.5946
# ETA:18s/1m SUB:21 FOLD:noFold
# epoch 16, loss=0.2259 acc=1.0000 f1=1.0000
# epoch 16, val, loss=0.8600 acc=0.4857 f1=0.5714
# ETA:19s/1m SUB:21 FOLD:noFold
# epoch 17, loss=0.2229 acc=0.9973 f1=0.9978
# epoch 17, val, loss=1.0297 acc=0.4476 f1=0.5857
# ETA:21s/1m SUB:21 FOLD:noFold
# epoch 18, loss=0.2213 acc=1.0000 f1=1.0000
# epoch 18, val, loss=0.8853 acc=0.5524 f1=0.6116
# ETA:22s/1m SUB:21 FOLD:noFold
# epoch 19, loss=0.2230 acc=0.9973 f1=0.9978
# epoch 19, val, loss=0.9527 acc=0.5333 f1=0.6080
# early stopping
# /content/drive/MyDrive/11777-Project-xs/LGG/save/T_64_pool_16/model_eeg_V/sub21.pth
# using gpu: 0
# myTest
# >>> Test:  loss=0.7957 acc=0.3833 f1=0.3273
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 22 [] 40
# 25 7 8
# (375, 1, 32, 512) (105, 1, 32, 512) (375,) (105,)
# (120, 1, 32, 512) (120,)
# using gpu: 0
# epoch 1, loss=0.7573 acc=0.6507 f1=0.4903
# epoch 1, val, loss=0.7191 acc=0.4286 f1=0.6000
# ETA:1s/1m SUB:22 FOLD:noFold
# epoch 2, loss=0.5955 acc=0.7200 f1=0.6290
# epoch 2, val, loss=0.7249 acc=0.4286 f1=0.6000
# ETA:2s/1m SUB:22 FOLD:noFold
# epoch 3, loss=0.5339 acc=0.7760 f1=0.6316
# epoch 3, val, loss=0.7300 acc=0.4286 f1=0.6000
# ETA:3s/1m SUB:22 FOLD:noFold
# epoch 4, loss=0.4869 acc=0.8027 f1=0.7431
# epoch 4, val, loss=0.7431 acc=0.4286 f1=0.6000
# ETA:5s/1m SUB:22 FOLD:noFold
# epoch 5, loss=0.4317 acc=0.8533 f1=0.7660
# epoch 5, val, loss=0.7909 acc=0.4286 f1=0.6000
# ETA:6s/1m SUB:22 FOLD:noFold
# epoch 6, loss=0.3876 acc=0.8907 f1=0.8571
# epoch 6, val, loss=0.8255 acc=0.4286 f1=0.6000
# ETA:7s/1m SUB:22 FOLD:noFold
# epoch 7, loss=0.3484 acc=0.9200 f1=0.8837
# epoch 7, val, loss=0.8733 acc=0.4286 f1=0.6000
# ETA:8s/1m SUB:22 FOLD:noFold
# epoch 8, loss=0.3117 acc=0.9520 f1=0.9333
# epoch 8, val, loss=0.8399 acc=0.4286 f1=0.6000
# ETA:9s/1m SUB:22 FOLD:noFold
# epoch 9, loss=0.2570 acc=0.9813 f1=0.9740
# epoch 9, val, loss=0.8553 acc=0.4286 f1=0.6000
# ETA:11s/1m SUB:22 FOLD:noFold
# epoch 10, loss=0.2559 acc=0.9867 f1=0.9815
# epoch 10, val, loss=0.8334 acc=0.4286 f1=0.6000
# ETA:12s/1m SUB:22 FOLD:noFold
# epoch 11, loss=0.2379 acc=1.0000 f1=1.0000
# epoch 11, val, loss=0.7478 acc=0.4571 f1=0.5210
# ETA:13s/1m SUB:22 FOLD:noFold
# epoch 12, loss=0.2345 acc=0.9973 f1=0.9963
# epoch 12, val, loss=0.7657 acc=0.4571 f1=0.5289
# ETA:14s/1m SUB:22 FOLD:noFold
# epoch 13, loss=0.2256 acc=0.9973 f1=0.9963
# epoch 13, val, loss=0.7556 acc=0.5524 f1=0.4835
# ETA:16s/1m SUB:22 FOLD:noFold
# epoch 14, loss=0.2273 acc=1.0000 f1=1.0000
# epoch 14, val, loss=0.8615 acc=0.5429 f1=0.2500
# ETA:17s/1m SUB:22 FOLD:noFold
# epoch 15, loss=0.2318 acc=1.0000 f1=1.0000
# epoch 15, val, loss=0.8760 acc=0.5429 f1=0.3514
# ETA:18s/1m SUB:22 FOLD:noFold
# epoch 16, loss=0.2274 acc=1.0000 f1=1.0000
# epoch 16, val, loss=1.1745 acc=0.5714 f1=0.1509
# ETA:19s/1m SUB:22 FOLD:noFold
# epoch 17, loss=0.2244 acc=1.0000 f1=1.0000
# epoch 17, val, loss=0.9047 acc=0.5524 f1=0.2985
# ETA:21s/1m SUB:22 FOLD:noFold
# epoch 18, loss=0.2196 acc=0.9973 f1=0.9963
# epoch 18, val, loss=1.0811 acc=0.5333 f1=0.1967
# ETA:22s/1m SUB:22 FOLD:noFold
# epoch 19, loss=0.2167 acc=1.0000 f1=1.0000
# epoch 19, val, loss=1.0788 acc=0.5429 f1=0.2000
# ETA:23s/1m SUB:22 FOLD:noFold
# epoch 20, loss=0.2133 acc=1.0000 f1=1.0000
# epoch 20, val, loss=0.9893 acc=0.5333 f1=0.2222
# ETA:24s/1m SUB:22 FOLD:noFold
# epoch 21, loss=0.2159 acc=1.0000 f1=1.0000
# epoch 21, val, loss=1.2220 acc=0.5333 f1=0.1091
# early stopping
# /content/drive/MyDrive/11777-Project-xs/LGG/save/T_64_pool_16/model_eeg_V/sub22.pth
# using gpu: 0
# myTest
# >>> Test:  loss=1.3770 acc=0.3417 f1=0.2178

# %%
type(data_test)
# Out:
# numpy.ndarray

# %%
path = '/content/drive/MyDrive/11777-Project-xs/LGG/save/candidate.pth'
