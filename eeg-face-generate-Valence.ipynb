# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import scipy as sp
from tqdm import auto, tqdm
import torch
from sklearn.model_selection import train_test_split

import sys
sys.path.append('/content/drive/MyDrive/11777-Project-xs/LGG/')
sys.path.append('/content/drive/MyDrive/11777-Project-xs/MLP/')
from prepare_data_DEAP import PrepareData
from cross_validation import CrossValidation
from train_model import *
from mlp_networks import SimpleMLP, ComplexMLP
from mlp_train_model import train_simpleMLP, test_simpleMLP, train_complexMLP, test_complexMLP

CUDA = torch.cuda.is_available()

# %%
# Define default parameters
default_args = {
    'dataset': 'DEAP',
    'data_path': './data_preprocessed_python/',
    'subjects': 22,
    'num_class': 2,
    'label_type': 'V',
    'segment': 4,
    'overlap': 0,
    'sampling_rate': 128,
    'scale_coefficient': 1,
    'input_shape': (1, 32, 512),
    'data_format': 'eeg',
    'random_seed': 2021,
    'max_epoch': 50, #200
    'patient': 5, #20,
    'patient_cmb': 8,
    'max_epoch_cmb': 20,
    'batch_size': 64,
    'learning_rate': 1e-3,
    'step_size': 5,
    'dropout': 0.5,
    'LS': True,
    'LS_rate': 0.1,
    'save_path': '/content/drive/MyDrive/11777-Project-xs/LGG/save/',
    'load_path': '/content/drive/MyDrive/11777-Project-xs/LGG/save/max-acc.pth',
    'load_path_final': '/content/drive/MyDrive/11777-Project-xs/LGG/save/final_model.pth',
    'mlp_save_path': '/content/drive/MyDrive/11777-Project-xs/MLP/save/',
    'mlp_load_path': '/content/drive/MyDrive/11777-Project-xs/MLP/save/max-acc.pth',
    'mlp_load_path_final': '/content/drive/MyDrive/11777-Project-xs/MLP/save/final_model.pth',
    'gpu': '0',
    'save_model': True,
    'model': 'LGGNet',
    'pool': 16,
    'pool_step_rate': 0.25,
    'T': 64,
    'graph_type': 'hem',
    'hidden': 32
}

# %%
######## Reproduce the result using the saved model ######
# parser.add_argument('--reproduce', action='store_true')
# args = parser.parse_args()
class Args:
    def __init__(self, param_dict):
        for key, value in param_dict.items():
            setattr(self, key, value)

default_args['data_path'] = '/content/drive/MyDrive/11777-Project-xs/data_preprocessed_python/'
default_args['reproduce'] = 'store_true'
# Create an Args object with default parameters
args = Args(default_args)

# %%
# only need to run once
sub_to_run = np.arange(args.subjects)
prepdt = PrepareData(args)
prepdt.run(sub_to_run, split=True, expand=True)
# Out:
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------

# %%
participant_ids = list(range(1, 23))
data_save_folder = '/content/drive/MyDrive/11777-Project-xs/data_face_seg_mean'

def delete_file(path):
    '''
    used to remove temporal file generated
    '''
    if os.path.exists(path):
        os.remove(path)

# # only need to run once
# for participant_id in auto.tqdm(participant_ids):
#     participant_id = '{:02d}'.format(participant_id)
#     for trial_id in auto.tqdm(range(1, 41)):
#         file_name = 's{0}_trial{1}_mean_frames.npy'.format(participant_id, trial_id)
#         if not os.path.exists(os.path.join(data_save_folder, file_name)):
#             print('No face data found for s{0}_trial{1}'.format(participant_id, trial_id))
#             continue

#         file_name2 = 's{0}_trial{1}_mean_frames_embed.npy'.format(participant_id, trial_id)
#         if os.path.exists(os.path.join(data_save_folder, file_name2)):
#             continue
#         participant_trial_seg = np.load(os.path.join(data_save_folder, file_name))
#         participant_trial_embed = []
#         for image in participant_trial_seg:
#             delete_file('curr_face_image.png')
#             plt.imsave('curr_face_image.png', np.uint8(participant_trial_seg[0]),
#                        cmap=plt.cm.Spectral)
#             embedding_objs = DeepFace.represent(img_path = 'curr_face_image.png', enforce_detection = False)
#             embedding = embedding_objs[0]['embedding']
#             assert isinstance(embedding, list)
#             assert len(embedding) == 2622
#             participant_trial_embed.append(np.array(embedding))

#         participant_trial_embed = np.stack(participant_trial_embed, axis=0)
#         np.save(os.path.join(data_save_folder, file_name2), participant_trial_embed)

# %%
import os
data_save_folder = '/content/drive/MyDrive/11777-Project-xs/data_face_seg_mean'
face_embed_file_list = os.listdir(data_save_folder)
# print(len(face_embed_file_list))
face_embed_file_list = [e for e in face_embed_file_list if 'embed.npy' in e]
sub_trial_list = {}
for file in face_embed_file_list:
    # print(file)
    sub, trial, _, _, _ = file.split('_')
    sub, trial = int(sub[1:]), int(trial[5:])
    if sub in sub_trial_list.keys():
        sub_trial_list[sub].append(trial)
    else:
        sub_trial_list[sub] = [trial]

for sub in range(1,23):
    print('sub {}, {} trials with facial video'.format(sub, len(sub_trial_list[sub])))
# Out:
# sub 1, 40 trials with facial video
# sub 2, 40 trials with facial video
# sub 3, 39 trials with facial video
# sub 4, 40 trials with facial video
# sub 5, 39 trials with facial video
# sub 6, 40 trials with facial video
# sub 7, 40 trials with facial video
# sub 8, 40 trials with facial video
# sub 9, 40 trials with facial video
# sub 10, 40 trials with facial video
# sub 11, 37 trials with facial video
# sub 12, 40 trials with facial video
# sub 13, 40 trials with facial video
# sub 14, 39 trials with facial video
# sub 15, 40 trials with facial video
# sub 16, 40 trials with facial video
# sub 17, 40 trials with facial video
# sub 18, 40 trials with facial video
# sub 19, 40 trials with facial video
# sub 20, 40 trials with facial video
# sub 21, 40 trials with facial video
# sub 22, 40 trials with facial video

# %%
def load_mean_frames_embed(sub, data_save_folder):
    '''
    sub starting index from 1 (not 0)
    '''
    face_embed_file_list = os.listdir(data_save_folder)
    sub_face_embed_file_list = [e for e in face_embed_file_list if 'embed' in e and sub==int(e[1:3])]
    sorted(sub_face_embed_file_list)
    # print(sub_face_embed_file_list)
    sub_frame_embed = []
    for file in auto.tqdm(sub_face_embed_file_list):
        embed = np.load(os.path.join(data_save_folder, file))
        sub_frame_embed.append(embed)
    sub_frame_embed = np.stack(sub_frame_embed, axis=0)
    print(sub_frame_embed.shape)
    return sub_frame_embed

# 's01_trial1_mean_frames_embed.npy'

data_save_folder = '/content/drive/MyDrive/11777-Project-xs/data_face_seg_mean'
all_sub_frame_embed = []
for sub in auto.tqdm(range(1,23)):
    sub_frame_embed = load_mean_frames_embed(sub, data_save_folder)
    all_sub_frame_embed.append(sub_frame_embed)
# Out:
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/39 [00:00<?, ?it/s]
# (39, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/39 [00:00<?, ?it/s]
# (39, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/37 [00:00<?, ?it/s]
# (37, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/39 [00:00<?, ?it/s]
# (39, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)

# %%
import pickle
file_name = 'all_sub_frame_embed.pkl'
# with open(os.path.join(data_save_folder, file_name), 'wb') as file:
#     pickle.dump(all_sub_frame_embed, file)

with open(os.path.join(data_save_folder, file_name), 'rb') as file:
    all_sub_frame_embed = pickle.load(file)

# %%
def generate_eeg_embed(eeg_data, LGG, CUDA=True):
    LGG.eval()
    eeg_embed = []
    # eeg_data = np.concatenate(eeg_data, axis=0)
    for eeg_data_trial in eeg_data:
        eeg_data_trial = torch.from_numpy(eeg_data_trial).float()
        if CUDA:
            eeg_data_trial = eeg_data_trial.cuda()
            LGG = LGG.cuda()
        with torch.no_grad():
            eeg_embed_trial = LGG.get_embed(eeg_data_trial)
        eeg_embed_trial = eeg_embed_trial.to('cpu')
        eeg_embed_trial = eeg_embed_trial.numpy()
        eeg_embed.append(eeg_embed_trial)
    eeg_embed = np.stack(eeg_embed, axis=0)
    return eeg_embed

# %%
def get_model_embed(args):
    if args.model == 'LGGNet':
        idx_local_graph = list(np.array(h5py.File('num_chan_local_graph_{}.hdf'.format(args.graph_type), 'r')['data']))
        channels = sum(idx_local_graph)
        input_size = (args.input_shape[0], channels, args.input_shape[2])
        model = LGGNet2(
            num_classes=args.num_class, input_size=input_size,
            sampling_rate=int(args.sampling_rate*args.scale_coefficient),
            num_T=args.T, out_graph=args.hidden,
            dropout_rate=args.dropout,
            pool=args.pool, pool_step_rate=args.pool_step_rate,
            idx_graph=idx_local_graph)

    return model

def transfer_weight(LGG, LGG_embed):
    for i, (pre_trained_layer, custom_layer) in enumerate(zip(LGG.children(), LGG_embed.children())):
        custom_layer.load_state_dict(pre_trained_layer.state_dict())
    return LGG_embed

# %%
# from utils import *

# def train_one_epoch_cmlp(data_loader, net, loss_fn, loss_2, alpha, optimizer):
#     net.train()
#     tl, tl_mse, tl_total = Averager(), Averager(), Averager()

#     pred_train = []
#     act_train = []
#     for i, (x_batch, y_batch) in enumerate(data_loader):
#         if CUDA:
#             x_batch, y_batch = x_batch.cuda(), y_batch.cuda()

#         out, face_embed_pred, face_embed_low = net(x_batch)
#         loss1 = loss_fn(out, y_batch)
#         loss2 = loss_2(face_embed_pred, face_embed_low)
#         loss_total = loss1 + alpha * loss2
#         _, pred = torch.max(out, 1)
#         pred_train.extend(pred.data.tolist())
#         act_train.extend(y_batch.data.tolist())
#         optimizer.zero_grad()
#         loss_total.backward()
#         optimizer.step()
#         tl.add(loss1.item())
#         tl_mse.add(loss_total.item())
#         tl_total.add(loss2.item())
#     return tl.item(), tl_mse.item(), tl_total.item(), pred_train, act_train


# def predict_cmlp(data_loader, net, loss_fn, loss_2, alpha, ):
#     net.eval()
#     pred_val = []
#     act_val = []
#     vl, vl_mse, vl_total = Averager(), Averager(), Averager()
#     with torch.no_grad():
#         for i, (x_batch, y_batch) in enumerate(data_loader):
#             if CUDA:
#                 x_batch, y_batch = x_batch.cuda(), y_batch.cuda()

#             out, face_embed_pred, face_embed_low = net(x_batch)
#             loss1 = loss_fn(out, y_batch)
#             loss2 = loss_2(face_embed_pred, face_embed_low)
#             loss_total = loss1 + alpha * loss2
#             _, pred = torch.max(out, 1)
#             vl.add(loss1.item())
#             vl_mse.add(loss2.item())
#             vl_total.add(loss_total.item())
#             pred_val.extend(pred.data.tolist())
#             act_val.extend(y_batch.data.tolist())
#     return vl.item(), vl_mse.item(), vl_total.item(), pred_val, act_val

# def mlp_set_up(args):
#     set_gpu(args.gpu)
#     ensure_path(args.mlp_save_path)
#     torch.manual_seed(args.random_seed)
#     torch.backends.cudnn.deterministic = True

# %%
# def train_complexMLP(model, args, data_train, label_train, data_val, label_val, subject, alpha=1):
#     '''
#     alpha: trade of between two loss terms --> loss = loss_fn + alpha * loss_2
#     '''
#     seed_all(args.random_seed)
#     save_name = '_sub' + str(subject) + '_mlp'
#     mlp_set_up(args)

#     train_loader = get_dataloader(data_train, label_train, args.batch_size)

#     val_loader = get_dataloader(data_val, label_val, args.batch_size)

#     # model = get_model(args)
#     if CUDA:
#         model = model.cuda()

#     optimizer = torch.optim.Adam(model.parameters(), lr=args.learning_rate)

#     ### binary classification prediction loss
#     if args.LS:
#         loss_fn = LabelSmoothing(args.LS_rate)
#     else:
#         loss_fn = nn.CrossEntropyLoss()
#     ### facial embedding prediction loss
#     loss_2 = nn.MSELoss()


#     def save_model(name):
#         previous_model = osp.join(args.mlp_save_path, '{}_cmlp.pth'.format(name))
#         if os.path.exists(previous_model):
#             os.remove(previous_model)
#         torch.save(model.state_dict(), osp.join(args.mlp_save_path, '{}_cmlp.pth'.format(name)))

#     trlog = {}
#     trlog['args'] = vars(args)
#     trlog['train_loss'] = []
#     trlog['val_loss'] = []
#     trlog['train_acc'] = []
#     trlog['val_acc'] = []
#     trlog['max_acc'] = 0.0
#     trlog['F1'] = 0.0

#     timer = Timer()
#     patient = args.patient
#     counter = 0

#     for epoch in range(1, args.max_epoch + 1):

#         loss_bi_train, loss_mse_train, loss_total_train, pred_train, act_train = train_one_epoch_cmlp(
#             data_loader=train_loader, net=model, loss_fn=loss_fn, loss_2=loss_2, alpha=alpha, optimizer=optimizer)

#         acc_train, f1_train, _ = get_metrics(y_pred=pred_train, y_true=act_train)
#         print('epoch {}, loss_bi={:.4f} loss_mse={:.4f} loss_total={:.4f} acc={:.4f} f1={:.4f}'
#               .format(epoch, loss_bi_train, loss_mse_train, loss_total_train, acc_train, f1_train))

#         loss_bi_val, loss_mse_val, loss_total_val, pred_val, act_val = predict_cmlp(
#             data_loader=val_loader, net=model, loss_fn=loss_fn, loss_2=loss_2, alpha=alpha
#         )
#         acc_val, f1_val, _ = get_metrics(y_pred=pred_val, y_true=act_val)
#         print('epoch {}, val, loss_bi={:.4f} loss_mse={:.4f} loss_total={:.4f} acc={:.4f} f1={:.4f}'.
#               format(epoch, loss_bi_val, loss_mse_val, loss_total_val, acc_val, f1_val))

#         if acc_val >= trlog['max_acc']:
#             trlog['max_acc'] = acc_val
#             trlog['F1'] = f1_val
#             save_model('candidate')
#             counter = 0
#         else:
#             counter += 1
#             if counter >= patient:
#                 print('early stopping')
#                 break

#         trlog['train_loss'].append(loss_total_train)
#         trlog['train_acc'].append(acc_train)
#         trlog['val_loss'].append(loss_total_val)
#         trlog['val_acc'].append(acc_val)

#         print('ETA:{}/{} SUB:{}'.format(timer.measure(), timer.measure(epoch / args.max_epoch),
#                                                  subject))
#     # save the training log file
#     save_name = 'trlog' + save_name
#     experiment_setting = 'T_{}_pool_{}'.format(args.T, args.pool)
#     save_path = osp.join(args.mlp_save_path, experiment_setting, 'log_train')
#     ensure_path(save_path)
#     torch.save(trlog, osp.join(save_path, save_name))

#     return trlog['max_acc'], trlog['F1']

# %%
# def test_complexMLP(model, args, data, label, reproduce, subject, alpha=1):
#     mlp_set_up(args)
#     seed_all(args.random_seed)
#     test_loader = get_dataloader(data, label, args.batch_size)

#     # model = get_model(args)
#     if CUDA:
#         model = model.cuda()
#     ### binary classification prediction loss
#     loss_fn = nn.CrossEntropyLoss()
#     ### facial embedding prediction loss
#     loss_2 = nn.MSELoss()

#     if reproduce:
#         model_name_reproduce = 'sub' + str(subject) + '_cmlp' + '.pth'
#         data_type = 'model_{}_{}'.format(args.data_format, args.label_type)
#         experiment_setting = 'T_{}_pool_{}'.format(args.T, args.pool)
#         load_path_final = osp.join(args.mlp_save_path, experiment_setting, data_type, model_name_reproduce)
#         model.load_state_dict(torch.load(load_path_final))
#     else:
#         model.load_state_dict(torch.load(args.mlp_load_path_final))
#     loss_bi, loss_mse, loss_total, pred, act = predict_cmlp(
#         data_loader=test_loader, net=model, loss_fn=loss_fn, loss_2=loss_2, alpha=alpha
#     )
#     acc, f1, cm = get_metrics(y_pred=pred, y_true=act)
#     print('>>> Test:  loss_bi={:.4f} loss_mse={:.4f} loss_total={:.4f} acc={:.4f} f1={:.4f}'\
#               .format(loss_bi, loss_mse, loss_total, acc, f1))
#     return acc, pred, act

# %%
CUDA = torch.cuda.is_available()
fold = 'noFold'

with open(os.path.join(data_save_folder, file_name), 'rb') as file:
    all_sub_frame_embed = pickle.load(file)

for sub in range(22):

    print('='*48)
    cv = CrossValidation(args)
    eeg_data, label = cv.load_per_subject(sub)
    trial_to_remove = [i-1 for i in range(1,41) if i not in sub_trial_list[sub+1]]
    ### face embeddings
    sub_frame_embed = all_sub_frame_embed[sub]

    if len(trial_to_remove) > 0:
        mask = np.ones(eeg_data.shape[0], dtype=bool)
        mask[trial_to_remove] = False
        eeg_data = eeg_data[mask]
        label = label[mask]

    ### Load pre-trained LGG model weights
    ### and generate the EEG embeddings
    lgg_model = get_model(args)
    lgg_model_embed = get_model_embed(args)
    if CUDA:
        lgg_model = lgg_model.cuda()
    model_name_reproduce = 'sub' + str(sub+1) + '.pth'
    data_type = 'model_{}_{}'.format(args.data_format, args.label_type)
    experiment_setting = 'T_{}_pool_{}'.format(args.T, args.pool)
    save_path = os.path.join(args.save_path, experiment_setting, data_type)
    ensure_path(save_path)
    model_name_reproduce = os.path.join(save_path, model_name_reproduce)
    lgg_model.load_state_dict(torch.load(model_name_reproduce))
    lgg_model_embed = transfer_weight(lgg_model, lgg_model_embed)
    eeg_embed = generate_eeg_embed(eeg_data, lgg_model_embed, CUDA)

    ### concat eeg + face embedding
    eeg_face_embed = np.concatenate([eeg_embed, sub_frame_embed], axis=2)
    eeg_embed_dim, face_embed_dim = eeg_embed.shape[2], sub_frame_embed.shape[2]

    print(sub+1, trial_to_remove, sub_frame_embed.shape[0])
    trial_id = np.arange(eeg_data.shape[0])
    trial_id_train, trial_id_test = train_test_split(trial_id, test_size=0.2, random_state=42)
    trial_id_tra, trial_id_val = train_test_split(trial_id_train, test_size=0.2, random_state=42)
    print(trial_id_tra.shape[0], trial_id_val.shape[0], trial_id_test.shape[0])

    data_train, data_val, label_train, label_val = \
        eeg_face_embed[trial_id_tra], eeg_face_embed[trial_id_val], label[trial_id_tra], label[trial_id_val]
    data_train, data_val, label_train, label_val = \
        np.concatenate(data_train, axis=0), np.concatenate(data_val, axis=0), np.concatenate(label_train, axis=0), np.concatenate(label_val, axis=0)
    print(data_train.shape, data_val.shape, label_train.shape, label_val.shape)

    data_test, label_test = \
        eeg_face_embed[trial_id_test], label[trial_id_test]
    data_test, label_test = \
        np.concatenate(data_test, axis=0), np.concatenate(label_test, axis=0)
    print(data_test.shape, label_test.shape)

    data_train = torch.from_numpy(data_train).float()
    label_train = torch.from_numpy(label_train).long()
    data_val = torch.from_numpy(data_val).float()
    label_val = torch.from_numpy(label_val).long()
    data_test = torch.from_numpy(data_test).float()
    label_test = torch.from_numpy(label_test).long()


    ### define a complex MLP as the predictor
    predictor = ComplexMLP(eeg_embed_dim, face_embed_dim, 2)

    acc_val, F1_val = train_complexMLP(model=predictor, args=args,
                                      data_train=data_train,
                                      label_train=label_train,
                                      data_val=data_val,
                                      label_val=label_val,
                                      subject = str(sub+1))

    if CUDA:
        predictor = predictor.cuda()
    predictor.load_state_dict(torch.load(os.path.join(args.mlp_save_path, 'candidate_cmlp.pth')))

    model_name_reproduce = 'sub' + str(sub+1) + '_cmlp.pth'
    data_type = 'model_{}_{}'.format(args.data_format, args.label_type)
    experiment_setting = 'T_{}_pool_{}'.format(args.T, args.pool)
    save_path = os.path.join(args.mlp_save_path, experiment_setting, data_type)
    ensure_path(save_path)
    model_name_reproduce = os.path.join(save_path, model_name_reproduce)
    print(model_name_reproduce)
    torch.save(predictor.state_dict(), model_name_reproduce)

    acc_test, pred, act = test_complexMLP(model=predictor, args=args, data=data_test, label=label_test,
                                               reproduce=args.reproduce,
                                               subject=str(sub+1))
# Out:
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 1 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss_bi=0.7003 loss_mse=0.7136 loss_total=0.0132 acc=0.5253 f1=0.4702
# epoch 1, val, loss_bi=0.6913 loss_mse=0.0007 loss_total=0.6920 acc=0.5429 f1=0.2000
# ETA:0s/11s SUB:1
# epoch 2, loss_bi=0.6957 loss_mse=0.6966 loss_total=0.0009 acc=0.5280 f1=0.4554
# epoch 2, val, loss_bi=0.6887 loss_mse=0.0003 loss_total=0.6889 acc=0.5333 f1=0.3636
# ETA:0s/6s SUB:1
# epoch 3, loss_bi=0.6372 loss_mse=0.6376 loss_total=0.0004 acc=0.6160 f1=0.6170
# epoch 3, val, loss_bi=0.6975 loss_mse=0.0001 loss_total=0.6976 acc=0.5333 f1=0.2899
# ETA:0s/5s SUB:1
# epoch 4, loss_bi=0.5874 loss_mse=0.5876 loss_total=0.0002 acc=0.7120 f1=0.6966
# epoch 4, val, loss_bi=0.7666 loss_mse=0.0001 loss_total=0.7668 acc=0.5429 f1=0.1724
# ETA:0s/5s SUB:1
# epoch 5, loss_bi=0.5739 loss_mse=0.5743 loss_total=0.0004 acc=0.7093 f1=0.6877
# epoch 5, val, loss_bi=0.7871 loss_mse=0.0001 loss_total=0.7871 acc=0.5524 f1=0.2540
# ETA:0s/5s SUB:1
# epoch 6, loss_bi=0.5388 loss_mse=0.5391 loss_total=0.0003 acc=0.7547 f1=0.7430
# epoch 6, val, loss_bi=0.8003 loss_mse=0.0004 loss_total=0.8007 acc=0.5333 f1=0.2899
# ETA:0s/5s SUB:1
# epoch 7, loss_bi=0.5108 loss_mse=0.5112 loss_total=0.0004 acc=0.7813 f1=0.7657
# epoch 7, val, loss_bi=0.8153 loss_mse=0.0002 loss_total=0.8155 acc=0.5238 f1=0.3421
# ETA:0s/4s SUB:1
# epoch 8, loss_bi=0.4523 loss_mse=0.4526 loss_total=0.0003 acc=0.8347 f1=0.8208
# epoch 8, val, loss_bi=0.8478 loss_mse=0.0001 loss_total=0.8479 acc=0.4762 f1=0.4330
# ETA:0s/4s SUB:1
# epoch 9, loss_bi=0.4109 loss_mse=0.4111 loss_total=0.0002 acc=0.8640 f1=0.8563
# epoch 9, val, loss_bi=0.8948 loss_mse=0.0001 loss_total=0.8949 acc=0.4952 f1=0.4045
# ETA:0s/4s SUB:1
# epoch 10, loss_bi=0.4178 loss_mse=0.4180 loss_total=0.0002 acc=0.8480 f1=0.8394
# epoch 10, val, loss_bi=0.9242 loss_mse=0.0000 loss_total=0.9243 acc=0.5333 f1=0.3636
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_V/sub1_cmlp.pth
# using gpu: 0
# >>> Test:  loss_bi=0.8534 loss_mse=0.0001 loss_total=0.8535 acc=0.5083 f1=0.2532
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 2 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss_bi=0.7115 loss_mse=0.7139 loss_total=0.0024 acc=0.4933 f1=0.4780
# epoch 1, val, loss_bi=0.7366 loss_mse=0.0004 loss_total=0.7370 acc=0.2857 f1=0.0000
# ETA:0s/8s SUB:2
# epoch 2, loss_bi=0.6994 loss_mse=0.6999 loss_total=0.0005 acc=0.5280 f1=0.0829
# epoch 2, val, loss_bi=0.7136 loss_mse=0.0002 loss_total=0.7137 acc=0.2857 f1=0.0000
# ETA:0s/8s SUB:2
# epoch 3, loss_bi=0.6861 loss_mse=0.6863 loss_total=0.0002 acc=0.5600 f1=0.5553
# epoch 3, val, loss_bi=0.6813 loss_mse=0.0000 loss_total=0.6813 acc=0.7143 f1=0.8333
# ETA:0s/8s SUB:2
# epoch 4, loss_bi=0.6969 loss_mse=0.6969 loss_total=0.0001 acc=0.5147 f1=0.4417
# epoch 4, val, loss_bi=0.7378 loss_mse=0.0000 loss_total=0.7378 acc=0.2857 f1=0.0000
# ETA:0s/7s SUB:2
# epoch 5, loss_bi=0.6951 loss_mse=0.6951 loss_total=0.0001 acc=0.5093 f1=0.2520
# epoch 5, val, loss_bi=0.6930 loss_mse=0.0000 loss_total=0.6930 acc=0.5048 f1=0.6232
# ETA:0s/6s SUB:2
# epoch 6, loss_bi=0.6864 loss_mse=0.6864 loss_total=0.0000 acc=0.5600 f1=0.5455
# epoch 6, val, loss_bi=0.7279 loss_mse=0.0000 loss_total=0.7279 acc=0.2857 f1=0.0000
# ETA:0s/5s SUB:2
# epoch 7, loss_bi=0.6828 loss_mse=0.6829 loss_total=0.0001 acc=0.5680 f1=0.4255
# epoch 7, val, loss_bi=0.7002 loss_mse=0.0000 loss_total=0.7002 acc=0.4381 f1=0.5042
# ETA:0s/5s SUB:2
# epoch 8, loss_bi=0.6849 loss_mse=0.6849 loss_total=0.0001 acc=0.5440 f1=0.4673
# epoch 8, val, loss_bi=0.6941 loss_mse=0.0000 loss_total=0.6942 acc=0.5333 f1=0.6475
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_V/sub2_cmlp.pth
# using gpu: 0
# >>> Test:  loss_bi=0.6831 loss_mse=0.0000 loss_total=0.6832 acc=0.6250 f1=0.7692
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 3 [39] 39
# 24 7 8
# (360, 3166) (105, 3166) (360,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss_bi=0.8313 loss_mse=0.8618 loss_total=0.0305 acc=0.4944 f1=0.4615
# epoch 1, val, loss_bi=0.8129 loss_mse=0.0015 loss_total=0.8145 acc=0.4286 f1=0.6000
# ETA:0s/6s SUB:3
# epoch 2, loss_bi=0.7332 loss_mse=0.7345 loss_total=0.0013 acc=0.5556 f1=0.6491
# epoch 2, val, loss_bi=0.6893 loss_mse=0.0005 loss_total=0.6898 acc=0.5619 f1=0.0000
# ETA:0s/6s SUB:3
# epoch 3, loss_bi=0.6839 loss_mse=0.6843 loss_total=0.0004 acc=0.5306 f1=0.6115
# epoch 3, val, loss_bi=0.7138 loss_mse=0.0001 loss_total=0.7138 acc=0.4286 f1=0.6000
# ETA:0s/5s SUB:3
# epoch 4, loss_bi=0.6796 loss_mse=0.6797 loss_total=0.0001 acc=0.5722 f1=0.6562
# epoch 4, val, loss_bi=0.6965 loss_mse=0.0000 loss_total=0.6966 acc=0.5143 f1=0.5854
# ETA:0s/4s SUB:3
# epoch 5, loss_bi=0.6777 loss_mse=0.6778 loss_total=0.0001 acc=0.5694 f1=0.6015
# epoch 5, val, loss_bi=0.7335 loss_mse=0.0000 loss_total=0.7335 acc=0.4286 f1=0.6000
# ETA:0s/4s SUB:3
# epoch 6, loss_bi=0.6523 loss_mse=0.6524 loss_total=0.0001 acc=0.6472 f1=0.7040
# epoch 6, val, loss_bi=0.7090 loss_mse=0.0000 loss_total=0.7091 acc=0.4667 f1=0.5882
# ETA:0s/3s SUB:3
# epoch 7, loss_bi=0.6113 loss_mse=0.6113 loss_total=0.0000 acc=0.7167 f1=0.7583
# epoch 7, val, loss_bi=0.7281 loss_mse=0.0000 loss_total=0.7281 acc=0.4952 f1=0.6015
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_V/sub3_cmlp.pth
# using gpu: 0
# >>> Test:  loss_bi=0.7031 loss_mse=0.0005 loss_total=0.7035 acc=0.3667 f1=0.0000
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 4 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss_bi=0.6756 loss_mse=0.6782 loss_total=0.0025 acc=0.6373 f1=0.0000
# epoch 1, val, loss_bi=0.7211 loss_mse=0.0003 loss_total=0.7214 acc=0.4286 f1=0.0000
# ETA:0s/6s SUB:4
# epoch 2, loss_bi=0.6662 loss_mse=0.6667 loss_total=0.0004 acc=0.6373 f1=0.0000
# epoch 2, val, loss_bi=0.7719 loss_mse=0.0001 loss_total=0.7720 acc=0.4286 f1=0.0000
# ETA:0s/6s SUB:4
# epoch 3, loss_bi=0.6646 loss_mse=0.6647 loss_total=0.0001 acc=0.6347 f1=0.0000
# epoch 3, val, loss_bi=0.7347 loss_mse=0.0000 loss_total=0.7347 acc=0.4286 f1=0.0000
# ETA:0s/6s SUB:4
# epoch 4, loss_bi=0.6660 loss_mse=0.6661 loss_total=0.0001 acc=0.6373 f1=0.0145
# epoch 4, val, loss_bi=0.7536 loss_mse=0.0000 loss_total=0.7537 acc=0.4286 f1=0.0000
# ETA:0s/6s SUB:4
# epoch 5, loss_bi=0.6530 loss_mse=0.6531 loss_total=0.0001 acc=0.6373 f1=0.0000
# epoch 5, val, loss_bi=0.7521 loss_mse=0.0000 loss_total=0.7521 acc=0.4286 f1=0.0000
# ETA:0s/6s SUB:4
# epoch 6, loss_bi=0.6538 loss_mse=0.6539 loss_total=0.0001 acc=0.6400 f1=0.0000
# epoch 6, val, loss_bi=0.7493 loss_mse=0.0001 loss_total=0.7494 acc=0.4286 f1=0.0000
# ETA:0s/6s SUB:4
# epoch 7, loss_bi=0.6516 loss_mse=0.6518 loss_total=0.0002 acc=0.6400 f1=0.0000
# epoch 7, val, loss_bi=0.7871 loss_mse=0.0001 loss_total=0.7872 acc=0.4286 f1=0.0000
# ETA:0s/6s SUB:4
# epoch 8, loss_bi=0.6620 loss_mse=0.6627 loss_total=0.0006 acc=0.6453 f1=0.0292
# epoch 8, val, loss_bi=0.7015 loss_mse=0.0009 loss_total=0.7024 acc=0.4286 f1=0.0000
# ETA:1s/6s SUB:4
# epoch 9, loss_bi=0.6648 loss_mse=0.6656 loss_total=0.0009 acc=0.6320 f1=0.1375
# epoch 9, val, loss_bi=0.8151 loss_mse=0.0002 loss_total=0.8153 acc=0.4286 f1=0.0000
# ETA:1s/6s SUB:4
# epoch 10, loss_bi=0.6536 loss_mse=0.6539 loss_total=0.0003 acc=0.6400 f1=0.0000
# epoch 10, val, loss_bi=0.7270 loss_mse=0.0001 loss_total=0.7271 acc=0.4286 f1=0.0000
# ETA:1s/6s SUB:4
# epoch 11, loss_bi=0.6502 loss_mse=0.6504 loss_total=0.0001 acc=0.6427 f1=0.0147
# epoch 11, val, loss_bi=0.7795 loss_mse=0.0001 loss_total=0.7796 acc=0.4286 f1=0.0000
# ETA:1s/6s SUB:4
# epoch 12, loss_bi=0.6446 loss_mse=0.6447 loss_total=0.0002 acc=0.6400 f1=0.0000
# epoch 12, val, loss_bi=0.7364 loss_mse=0.0001 loss_total=0.7364 acc=0.4286 f1=0.0000
# ETA:1s/6s SUB:4
# epoch 13, loss_bi=0.6329 loss_mse=0.6330 loss_total=0.0001 acc=0.6400 f1=0.0000
# epoch 13, val, loss_bi=0.7533 loss_mse=0.0000 loss_total=0.7533 acc=0.4286 f1=0.0000
# ETA:1s/6s SUB:4
# epoch 14, loss_bi=0.6279 loss_mse=0.6280 loss_total=0.0001 acc=0.6587 f1=0.1233
# epoch 14, val, loss_bi=0.6999 loss_mse=0.0001 loss_total=0.6999 acc=0.4857 f1=0.2895
# ETA:1s/6s SUB:4
# epoch 15, loss_bi=0.6003 loss_mse=0.6006 loss_total=0.0003 acc=0.6933 f1=0.2767
# epoch 15, val, loss_bi=0.7454 loss_mse=0.0003 loss_total=0.7457 acc=0.4286 f1=0.0625
# ETA:1s/6s SUB:4
# epoch 16, loss_bi=0.5902 loss_mse=0.5912 loss_total=0.0009 acc=0.6960 f1=0.3667
# epoch 16, val, loss_bi=0.6864 loss_mse=0.0001 loss_total=0.6865 acc=0.5333 f1=0.6016
# ETA:1s/6s SUB:4
# epoch 17, loss_bi=0.5695 loss_mse=0.5698 loss_total=0.0003 acc=0.7360 f1=0.5600
# epoch 17, val, loss_bi=0.7026 loss_mse=0.0004 loss_total=0.7030 acc=0.5333 f1=0.5505
# ETA:2s/6s SUB:4
# epoch 18, loss_bi=0.5573 loss_mse=0.5577 loss_total=0.0004 acc=0.7520 f1=0.6173
# epoch 18, val, loss_bi=0.8429 loss_mse=0.0002 loss_total=0.8430 acc=0.4571 f1=0.1739
# ETA:2s/5s SUB:4
# epoch 19, loss_bi=0.5620 loss_mse=0.5623 loss_total=0.0002 acc=0.7360 f1=0.5520
# epoch 19, val, loss_bi=0.9022 loss_mse=0.0001 loss_total=0.9023 acc=0.4381 f1=0.1194
# ETA:2s/5s SUB:4
# epoch 20, loss_bi=0.5779 loss_mse=0.5781 loss_total=0.0002 acc=0.6853 f1=0.5042
# epoch 20, val, loss_bi=0.8127 loss_mse=0.0001 loss_total=0.8128 acc=0.4952 f1=0.2740
# ETA:2s/5s SUB:4
# epoch 21, loss_bi=0.5391 loss_mse=0.5393 loss_total=0.0002 acc=0.7573 f1=0.6592
# epoch 21, val, loss_bi=1.0240 loss_mse=0.0001 loss_total=1.0240 acc=0.4190 f1=0.0000
# ETA:2s/5s SUB:4
# epoch 22, loss_bi=0.5580 loss_mse=0.5582 loss_total=0.0001 acc=0.7493 f1=0.6083
# epoch 22, val, loss_bi=0.7655 loss_mse=0.0000 loss_total=0.7655 acc=0.5524 f1=0.4471
# ETA:2s/5s SUB:4
# epoch 23, loss_bi=0.5193 loss_mse=0.5194 loss_total=0.0001 acc=0.7600 f1=0.6018
# epoch 23, val, loss_bi=0.7587 loss_mse=0.0000 loss_total=0.7587 acc=0.5524 f1=0.5155
# ETA:2s/5s SUB:4
# epoch 24, loss_bi=0.5028 loss_mse=0.5030 loss_total=0.0002 acc=0.7840 f1=0.6873
# epoch 24, val, loss_bi=0.7929 loss_mse=0.0000 loss_total=0.7930 acc=0.5524 f1=0.4719
# ETA:2s/5s SUB:4
# epoch 25, loss_bi=0.5011 loss_mse=0.5012 loss_total=0.0002 acc=0.7920 f1=0.6880
# epoch 25, val, loss_bi=0.7557 loss_mse=0.0000 loss_total=0.7557 acc=0.5619 f1=0.5660
# ETA:2s/5s SUB:4
# epoch 26, loss_bi=0.5150 loss_mse=0.5152 loss_total=0.0002 acc=0.7920 f1=0.6905
# epoch 26, val, loss_bi=0.7332 loss_mse=0.0000 loss_total=0.7332 acc=0.5524 f1=0.6299
# ETA:2s/5s SUB:4
# epoch 27, loss_bi=0.5157 loss_mse=0.5158 loss_total=0.0001 acc=0.7547 f1=0.6593
# epoch 27, val, loss_bi=0.7478 loss_mse=0.0000 loss_total=0.7478 acc=0.5429 f1=0.5636
# ETA:2s/5s SUB:4
# epoch 28, loss_bi=0.4761 loss_mse=0.4762 loss_total=0.0001 acc=0.8107 f1=0.7341
# epoch 28, val, loss_bi=0.7804 loss_mse=0.0001 loss_total=0.7804 acc=0.5905 f1=0.5657
# ETA:3s/5s SUB:4
# epoch 29, loss_bi=0.4629 loss_mse=0.4630 loss_total=0.0001 acc=0.8320 f1=0.7529
# epoch 29, val, loss_bi=0.7265 loss_mse=0.0000 loss_total=0.7265 acc=0.5238 f1=0.6032
# ETA:3s/5s SUB:4
# epoch 30, loss_bi=0.4702 loss_mse=0.4703 loss_total=0.0001 acc=0.8160 f1=0.7336
# epoch 30, val, loss_bi=0.7730 loss_mse=0.0000 loss_total=0.7730 acc=0.5714 f1=0.5794
# ETA:3s/5s SUB:4
# epoch 31, loss_bi=0.4998 loss_mse=0.4999 loss_total=0.0001 acc=0.7733 f1=0.6840
# epoch 31, val, loss_bi=0.9576 loss_mse=0.0000 loss_total=0.9576 acc=0.4952 f1=0.3117
# ETA:3s/5s SUB:4
# epoch 32, loss_bi=0.5375 loss_mse=0.5375 loss_total=0.0001 acc=0.7547 f1=0.6541
# epoch 32, val, loss_bi=1.1261 loss_mse=0.0000 loss_total=1.1262 acc=0.4476 f1=0.1471
# ETA:3s/5s SUB:4
# epoch 33, loss_bi=0.5207 loss_mse=0.5208 loss_total=0.0001 acc=0.7627 f1=0.6564
# epoch 33, val, loss_bi=0.7644 loss_mse=0.0000 loss_total=0.7644 acc=0.5905 f1=0.5743
# ETA:3s/5s SUB:4
# epoch 34, loss_bi=0.4592 loss_mse=0.4593 loss_total=0.0001 acc=0.8240 f1=0.7273
# epoch 34, val, loss_bi=0.7237 loss_mse=0.0000 loss_total=0.7237 acc=0.5238 f1=0.5902
# ETA:3s/5s SUB:4
# epoch 35, loss_bi=0.4491 loss_mse=0.4493 loss_total=0.0001 acc=0.8240 f1=0.7402
# epoch 35, val, loss_bi=0.7374 loss_mse=0.0000 loss_total=0.7374 acc=0.5524 f1=0.6466
# ETA:3s/4s SUB:4
# epoch 36, loss_bi=0.4533 loss_mse=0.4535 loss_total=0.0002 acc=0.8080 f1=0.7165
# epoch 36, val, loss_bi=0.7583 loss_mse=0.0000 loss_total=0.7583 acc=0.5619 f1=0.6714
# ETA:3s/4s SUB:4
# epoch 37, loss_bi=0.4863 loss_mse=0.4864 loss_total=0.0001 acc=0.7973 f1=0.7077
# epoch 37, val, loss_bi=0.7526 loss_mse=0.0001 loss_total=0.7527 acc=0.5619 f1=0.6667
# ETA:3s/4s SUB:4
# epoch 38, loss_bi=0.5050 loss_mse=0.5052 loss_total=0.0001 acc=0.7760 f1=0.6744
# epoch 38, val, loss_bi=0.7804 loss_mse=0.0001 loss_total=0.7805 acc=0.5714 f1=0.6809
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_V/sub4_cmlp.pth
# using gpu: 0
# >>> Test:  loss_bi=0.5855 loss_mse=0.0000 loss_total=0.5856 acc=0.6917 f1=0.6186
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 5 [39] 39
# 24 7 8
# (360, 3166) (105, 3166) (360,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss_bi=0.7020 loss_mse=0.7043 loss_total=0.0022 acc=0.5194 f1=0.5871
# epoch 1, val, loss_bi=0.6840 loss_mse=0.0002 loss_total=0.6843 acc=0.7143 f1=0.8333
# ETA:0s/6s SUB:5
# epoch 2, loss_bi=0.6960 loss_mse=0.6964 loss_total=0.0004 acc=0.5333 f1=0.6719
# epoch 2, val, loss_bi=0.6817 loss_mse=0.0001 loss_total=0.6818 acc=0.7143 f1=0.8333
# ETA:0s/6s SUB:5
# epoch 3, loss_bi=0.6881 loss_mse=0.6883 loss_total=0.0002 acc=0.5611 f1=0.5353
# epoch 3, val, loss_bi=0.6654 loss_mse=0.0002 loss_total=0.6656 acc=0.7143 f1=0.8333
# ETA:0s/6s SUB:5
# epoch 4, loss_bi=0.6903 loss_mse=0.6907 loss_total=0.0004 acc=0.5389 f1=0.6937
# epoch 4, val, loss_bi=0.6744 loss_mse=0.0002 loss_total=0.6746 acc=0.6667 f1=0.8000
# ETA:0s/5s SUB:5
# epoch 5, loss_bi=0.6799 loss_mse=0.6803 loss_total=0.0004 acc=0.5861 f1=0.6427
# epoch 5, val, loss_bi=0.6796 loss_mse=0.0001 loss_total=0.6797 acc=0.6095 f1=0.7453
# ETA:0s/5s SUB:5
# epoch 6, loss_bi=0.6716 loss_mse=0.6719 loss_total=0.0003 acc=0.6361 f1=0.6843
# epoch 6, val, loss_bi=0.6689 loss_mse=0.0001 loss_total=0.6690 acc=0.6381 f1=0.7683
# ETA:0s/4s SUB:5
# epoch 7, loss_bi=0.6467 loss_mse=0.6470 loss_total=0.0003 acc=0.6889 f1=0.7489
# epoch 7, val, loss_bi=0.6865 loss_mse=0.0001 loss_total=0.6867 acc=0.5524 f1=0.6667
# ETA:0s/4s SUB:5
# epoch 8, loss_bi=0.6056 loss_mse=0.6062 loss_total=0.0006 acc=0.7528 f1=0.7781
# epoch 8, val, loss_bi=0.6462 loss_mse=0.0005 loss_total=0.6467 acc=0.6667 f1=0.7953
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_V/sub5_cmlp.pth
# using gpu: 0
# >>> Test:  loss_bi=0.6741 loss_mse=0.0002 loss_total=0.6743 acc=0.6250 f1=0.7692
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 6 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss_bi=0.6442 loss_mse=0.6464 loss_total=0.0022 acc=0.6667 f1=0.7849
# epoch 1, val, loss_bi=0.6211 loss_mse=0.0003 loss_total=0.6214 acc=0.7143 f1=0.8333
# ETA:0s/6s SUB:6
# epoch 2, loss_bi=0.6258 loss_mse=0.6263 loss_total=0.0005 acc=0.7200 f1=0.8372
# epoch 2, val, loss_bi=0.6209 loss_mse=0.0001 loss_total=0.6211 acc=0.7143 f1=0.8333
# ETA:0s/6s SUB:6
# epoch 3, loss_bi=0.6257 loss_mse=0.6259 loss_total=0.0002 acc=0.7200 f1=0.8372
# epoch 3, val, loss_bi=0.6231 loss_mse=0.0000 loss_total=0.6232 acc=0.7143 f1=0.8333
# ETA:0s/6s SUB:6
# epoch 4, loss_bi=0.6124 loss_mse=0.6125 loss_total=0.0001 acc=0.7200 f1=0.8372
# epoch 4, val, loss_bi=0.6171 loss_mse=0.0000 loss_total=0.6172 acc=0.7143 f1=0.8333
# ETA:0s/6s SUB:6
# epoch 5, loss_bi=0.6179 loss_mse=0.6180 loss_total=0.0001 acc=0.7200 f1=0.8372
# epoch 5, val, loss_bi=0.6145 loss_mse=0.0000 loss_total=0.6145 acc=0.7143 f1=0.8333
# ETA:0s/6s SUB:6
# epoch 6, loss_bi=0.6194 loss_mse=0.6195 loss_total=0.0001 acc=0.7200 f1=0.8372
# epoch 6, val, loss_bi=0.6046 loss_mse=0.0000 loss_total=0.6046 acc=0.7143 f1=0.8333
# ETA:0s/6s SUB:6
# epoch 7, loss_bi=0.6159 loss_mse=0.6160 loss_total=0.0001 acc=0.7200 f1=0.8372
# epoch 7, val, loss_bi=0.6186 loss_mse=0.0000 loss_total=0.6187 acc=0.7143 f1=0.8333
# ETA:0s/6s SUB:6
# epoch 8, loss_bi=0.6204 loss_mse=0.6205 loss_total=0.0001 acc=0.7200 f1=0.8372
# epoch 8, val, loss_bi=0.6214 loss_mse=0.0000 loss_total=0.6215 acc=0.7143 f1=0.8333
# ETA:0s/6s SUB:6
# epoch 9, loss_bi=0.6215 loss_mse=0.6216 loss_total=0.0001 acc=0.7200 f1=0.8372
# epoch 9, val, loss_bi=0.6203 loss_mse=0.0000 loss_total=0.6203 acc=0.7143 f1=0.8333
# ETA:1s/6s SUB:6
# epoch 10, loss_bi=0.6207 loss_mse=0.6209 loss_total=0.0001 acc=0.7200 f1=0.8372
# epoch 10, val, loss_bi=0.6234 loss_mse=0.0000 loss_total=0.6234 acc=0.7143 f1=0.8333
# ETA:1s/6s SUB:6
# epoch 11, loss_bi=0.6239 loss_mse=0.6240 loss_total=0.0001 acc=0.7200 f1=0.8372
# epoch 11, val, loss_bi=0.6161 loss_mse=0.0000 loss_total=0.6161 acc=0.7143 f1=0.8333
# ETA:1s/6s SUB:6
# epoch 12, loss_bi=0.6185 loss_mse=0.6186 loss_total=0.0001 acc=0.7200 f1=0.8372
# epoch 12, val, loss_bi=0.6230 loss_mse=0.0000 loss_total=0.6230 acc=0.7143 f1=0.8333
# ETA:1s/6s SUB:6
# epoch 13, loss_bi=0.6235 loss_mse=0.6236 loss_total=0.0001 acc=0.7200 f1=0.8372
# epoch 13, val, loss_bi=0.6145 loss_mse=0.0000 loss_total=0.6145 acc=0.7143 f1=0.8333
# ETA:1s/6s SUB:6
# epoch 14, loss_bi=0.6165 loss_mse=0.6165 loss_total=0.0001 acc=0.7200 f1=0.8372
# epoch 14, val, loss_bi=0.6258 loss_mse=0.0000 loss_total=0.6259 acc=0.7143 f1=0.8333
# ETA:1s/6s SUB:6
# epoch 15, loss_bi=0.6211 loss_mse=0.6211 loss_total=0.0000 acc=0.7200 f1=0.8372
# epoch 15, val, loss_bi=0.6052 loss_mse=0.0000 loss_total=0.6053 acc=0.7143 f1=0.8333
# ETA:1s/6s SUB:6
# epoch 16, loss_bi=0.6210 loss_mse=0.6211 loss_total=0.0000 acc=0.7200 f1=0.8372
# epoch 16, val, loss_bi=0.6295 loss_mse=0.0000 loss_total=0.6295 acc=0.7143 f1=0.8333
# ETA:1s/6s SUB:6
# epoch 17, loss_bi=0.6135 loss_mse=0.6135 loss_total=0.0000 acc=0.7200 f1=0.8372
# epoch 17, val, loss_bi=0.6255 loss_mse=0.0000 loss_total=0.6255 acc=0.7143 f1=0.8333
# ETA:2s/6s SUB:6
# epoch 18, loss_bi=0.6229 loss_mse=0.6229 loss_total=0.0000 acc=0.7200 f1=0.8372
# epoch 18, val, loss_bi=0.6242 loss_mse=0.0000 loss_total=0.6242 acc=0.7143 f1=0.8333
# ETA:2s/6s SUB:6
# epoch 19, loss_bi=0.6156 loss_mse=0.6156 loss_total=0.0000 acc=0.7200 f1=0.8372
# epoch 19, val, loss_bi=0.6182 loss_mse=0.0000 loss_total=0.6182 acc=0.7143 f1=0.8333
# ETA:2s/6s SUB:6
# epoch 20, loss_bi=0.6147 loss_mse=0.6147 loss_total=0.0000 acc=0.7200 f1=0.8372
# epoch 20, val, loss_bi=0.6216 loss_mse=0.0000 loss_total=0.6216 acc=0.7143 f1=0.8333
# ETA:2s/6s SUB:6
# epoch 21, loss_bi=0.6171 loss_mse=0.6171 loss_total=0.0000 acc=0.7200 f1=0.8372
# epoch 21, val, loss_bi=0.6213 loss_mse=0.0000 loss_total=0.6213 acc=0.7143 f1=0.8333
# ETA:2s/6s SUB:6
# epoch 22, loss_bi=0.6172 loss_mse=0.6172 loss_total=0.0000 acc=0.7200 f1=0.8372
# epoch 22, val, loss_bi=0.6239 loss_mse=0.0000 loss_total=0.6239 acc=0.7143 f1=0.8333
# ETA:2s/6s SUB:6
# epoch 23, loss_bi=0.6149 loss_mse=0.6149 loss_total=0.0000 acc=0.7200 f1=0.8372
# epoch 23, val, loss_bi=0.6292 loss_mse=0.0000 loss_total=0.6292 acc=0.7143 f1=0.8333
# ETA:2s/6s SUB:6
# epoch 24, loss_bi=0.6160 loss_mse=0.6160 loss_total=0.0000 acc=0.7200 f1=0.8372
# epoch 24, val, loss_bi=0.6189 loss_mse=0.0000 loss_total=0.6189 acc=0.7143 f1=0.8333
# ETA:3s/6s SUB:6
# epoch 25, loss_bi=0.6157 loss_mse=0.6157 loss_total=0.0000 acc=0.7200 f1=0.8372
# epoch 25, val, loss_bi=0.6209 loss_mse=0.0000 loss_total=0.6209 acc=0.7143 f1=0.8333
# ETA:3s/6s SUB:6
# epoch 26, loss_bi=0.6163 loss_mse=0.6163 loss_total=0.0000 acc=0.7200 f1=0.8372
# epoch 26, val, loss_bi=0.6087 loss_mse=0.0000 loss_total=0.6087 acc=0.7143 f1=0.8333
# ETA:3s/6s SUB:6
# epoch 27, loss_bi=0.6193 loss_mse=0.6194 loss_total=0.0000 acc=0.7200 f1=0.8372
# epoch 27, val, loss_bi=0.6245 loss_mse=0.0000 loss_total=0.6245 acc=0.7143 f1=0.8333
# ETA:3s/6s SUB:6
# epoch 28, loss_bi=0.6147 loss_mse=0.6147 loss_total=0.0000 acc=0.7200 f1=0.8372
# epoch 28, val, loss_bi=0.6208 loss_mse=0.0000 loss_total=0.6208 acc=0.7143 f1=0.8333
# ETA:3s/6s SUB:6
# epoch 29, loss_bi=0.6133 loss_mse=0.6133 loss_total=0.0000 acc=0.7200 f1=0.8372
# epoch 29, val, loss_bi=0.6206 loss_mse=0.0000 loss_total=0.6206 acc=0.7143 f1=0.8333
# ETA:3s/6s SUB:6
# epoch 30, loss_bi=0.6153 loss_mse=0.6153 loss_total=0.0000 acc=0.7200 f1=0.8372
# epoch 30, val, loss_bi=0.5955 loss_mse=0.0000 loss_total=0.5955 acc=0.7143 f1=0.8333
# ETA:3s/6s SUB:6
# epoch 31, loss_bi=0.6129 loss_mse=0.6129 loss_total=0.0000 acc=0.7200 f1=0.8372
# epoch 31, val, loss_bi=0.6179 loss_mse=0.0000 loss_total=0.6179 acc=0.7143 f1=0.8333
# ETA:4s/6s SUB:6
# epoch 32, loss_bi=0.6123 loss_mse=0.6123 loss_total=0.0000 acc=0.7200 f1=0.8372
# epoch 32, val, loss_bi=0.6149 loss_mse=0.0000 loss_total=0.6149 acc=0.7143 f1=0.8333
# ETA:4s/6s SUB:6
# epoch 33, loss_bi=0.6173 loss_mse=0.6173 loss_total=0.0000 acc=0.7200 f1=0.8372
# epoch 33, val, loss_bi=0.6209 loss_mse=0.0000 loss_total=0.6209 acc=0.7143 f1=0.8333
# ETA:4s/6s SUB:6
# epoch 34, loss_bi=0.6168 loss_mse=0.6168 loss_total=0.0000 acc=0.7200 f1=0.8372
# epoch 34, val, loss_bi=0.6177 loss_mse=0.0000 loss_total=0.6177 acc=0.7143 f1=0.8333
# ETA:4s/6s SUB:6
# epoch 35, loss_bi=0.6182 loss_mse=0.6182 loss_total=0.0000 acc=0.7200 f1=0.8372
# epoch 35, val, loss_bi=0.6269 loss_mse=0.0000 loss_total=0.6269 acc=0.7143 f1=0.8333
# ETA:4s/6s SUB:6
# epoch 36, loss_bi=0.6114 loss_mse=0.6114 loss_total=0.0000 acc=0.7200 f1=0.8372
# epoch 36, val, loss_bi=0.6044 loss_mse=0.0000 loss_total=0.6044 acc=0.7143 f1=0.8333
# ETA:5s/6s SUB:6
# epoch 37, loss_bi=0.6133 loss_mse=0.6133 loss_total=0.0000 acc=0.7200 f1=0.8372
# epoch 37, val, loss_bi=0.6149 loss_mse=0.0000 loss_total=0.6149 acc=0.7143 f1=0.8333
# ETA:5s/7s SUB:6
# epoch 38, loss_bi=0.6193 loss_mse=0.6193 loss_total=0.0000 acc=0.7200 f1=0.8372
# epoch 38, val, loss_bi=0.6202 loss_mse=0.0000 loss_total=0.6202 acc=0.7143 f1=0.8333
# ETA:5s/7s SUB:6
# epoch 39, loss_bi=0.6109 loss_mse=0.6109 loss_total=0.0000 acc=0.7200 f1=0.8372
# epoch 39, val, loss_bi=0.6288 loss_mse=0.0000 loss_total=0.6288 acc=0.7143 f1=0.8333
# ETA:5s/7s SUB:6
# epoch 40, loss_bi=0.6232 loss_mse=0.6232 loss_total=0.0000 acc=0.7200 f1=0.8372
# epoch 40, val, loss_bi=0.6124 loss_mse=0.0000 loss_total=0.6124 acc=0.7143 f1=0.8333
# ETA:5s/7s SUB:6
# epoch 41, loss_bi=0.6220 loss_mse=0.6220 loss_total=0.0000 acc=0.7200 f1=0.8372
# epoch 41, val, loss_bi=0.6274 loss_mse=0.0000 loss_total=0.6274 acc=0.7143 f1=0.8333
# ETA:5s/7s SUB:6
# epoch 42, loss_bi=0.6136 loss_mse=0.6136 loss_total=0.0000 acc=0.7200 f1=0.8372
# epoch 42, val, loss_bi=0.6291 loss_mse=0.0000 loss_total=0.6291 acc=0.7143 f1=0.8333
# ETA:6s/7s SUB:6
# epoch 43, loss_bi=0.6166 loss_mse=0.6166 loss_total=0.0000 acc=0.7200 f1=0.8372
# epoch 43, val, loss_bi=0.6179 loss_mse=0.0000 loss_total=0.6179 acc=0.7143 f1=0.8333
# ETA:6s/7s SUB:6
# epoch 44, loss_bi=0.6126 loss_mse=0.6126 loss_total=0.0000 acc=0.7200 f1=0.8372
# epoch 44, val, loss_bi=0.6178 loss_mse=0.0000 loss_total=0.6178 acc=0.7143 f1=0.8333
# ETA:6s/7s SUB:6
# epoch 45, loss_bi=0.6119 loss_mse=0.6119 loss_total=0.0000 acc=0.7200 f1=0.8372
# epoch 45, val, loss_bi=0.6145 loss_mse=0.0000 loss_total=0.6145 acc=0.7143 f1=0.8333
# ETA:6s/7s SUB:6
# epoch 46, loss_bi=0.6174 loss_mse=0.6174 loss_total=0.0000 acc=0.7200 f1=0.8372
# epoch 46, val, loss_bi=0.6148 loss_mse=0.0000 loss_total=0.6148 acc=0.7143 f1=0.8333
# ETA:7s/7s SUB:6
# epoch 47, loss_bi=0.6162 loss_mse=0.6162 loss_total=0.0000 acc=0.7200 f1=0.8372
# epoch 47, val, loss_bi=0.6239 loss_mse=0.0000 loss_total=0.6239 acc=0.7143 f1=0.8333
# ETA:7s/8s SUB:6
# epoch 48, loss_bi=0.6187 loss_mse=0.6187 loss_total=0.0000 acc=0.7200 f1=0.8372
# epoch 48, val, loss_bi=0.6208 loss_mse=0.0000 loss_total=0.6208 acc=0.7143 f1=0.8333
# ETA:7s/8s SUB:6
# epoch 49, loss_bi=0.6144 loss_mse=0.6144 loss_total=0.0000 acc=0.7200 f1=0.8372
# epoch 49, val, loss_bi=0.6208 loss_mse=0.0000 loss_total=0.6208 acc=0.7143 f1=0.8333
# ETA:7s/8s SUB:6
# epoch 50, loss_bi=0.6149 loss_mse=0.6149 loss_total=0.0000 acc=0.7200 f1=0.8372
# epoch 50, val, loss_bi=0.6238 loss_mse=0.0000 loss_total=0.6238 acc=0.7143 f1=0.8333
# ETA:8s/8s SUB:6
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_V/sub6_cmlp.pth
# using gpu: 0
# >>> Test:  loss_bi=0.4462 loss_mse=0.0000 loss_total=0.4462 acc=0.8750 f1=0.9333
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 7 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss_bi=0.6623 loss_mse=0.6645 loss_total=0.0022 acc=0.6000 f1=0.7350
# epoch 1, val, loss_bi=0.6215 loss_mse=0.0003 loss_total=0.6218 acc=0.7143 f1=0.8333
# ETA:0s/6s SUB:7
# epoch 2, loss_bi=0.6475 loss_mse=0.6480 loss_total=0.0005 acc=0.6720 f1=0.8032
# epoch 2, val, loss_bi=0.6193 loss_mse=0.0001 loss_total=0.6194 acc=0.7143 f1=0.8333
# ETA:0s/6s SUB:7
# epoch 3, loss_bi=0.6487 loss_mse=0.6489 loss_total=0.0002 acc=0.6773 f1=0.8076
# epoch 3, val, loss_bi=0.6215 loss_mse=0.0001 loss_total=0.6216 acc=0.7143 f1=0.8333
# ETA:0s/6s SUB:7
# epoch 4, loss_bi=0.6513 loss_mse=0.6514 loss_total=0.0001 acc=0.6773 f1=0.8064
# epoch 4, val, loss_bi=0.6101 loss_mse=0.0000 loss_total=0.6102 acc=0.7143 f1=0.8333
# ETA:0s/6s SUB:7
# epoch 5, loss_bi=0.6459 loss_mse=0.6460 loss_total=0.0001 acc=0.6800 f1=0.8095
# epoch 5, val, loss_bi=0.6292 loss_mse=0.0000 loss_total=0.6292 acc=0.7143 f1=0.8333
# ETA:0s/6s SUB:7
# epoch 6, loss_bi=0.6393 loss_mse=0.6394 loss_total=0.0001 acc=0.6800 f1=0.8095
# epoch 6, val, loss_bi=0.6167 loss_mse=0.0000 loss_total=0.6167 acc=0.7143 f1=0.8333
# ETA:0s/6s SUB:7
# epoch 7, loss_bi=0.6440 loss_mse=0.6441 loss_total=0.0001 acc=0.6800 f1=0.8095
# epoch 7, val, loss_bi=0.6316 loss_mse=0.0000 loss_total=0.6316 acc=0.7143 f1=0.8333
# ETA:0s/6s SUB:7
# epoch 8, loss_bi=0.6392 loss_mse=0.6393 loss_total=0.0001 acc=0.6800 f1=0.8095
# epoch 8, val, loss_bi=0.6241 loss_mse=0.0000 loss_total=0.6241 acc=0.7143 f1=0.8333
# ETA:1s/6s SUB:7
# epoch 9, loss_bi=0.6484 loss_mse=0.6485 loss_total=0.0001 acc=0.6800 f1=0.8095
# epoch 9, val, loss_bi=0.6114 loss_mse=0.0001 loss_total=0.6115 acc=0.7143 f1=0.8333
# ETA:1s/6s SUB:7
# epoch 10, loss_bi=0.6448 loss_mse=0.6450 loss_total=0.0002 acc=0.6800 f1=0.8095
# epoch 10, val, loss_bi=0.6246 loss_mse=0.0000 loss_total=0.6246 acc=0.7143 f1=0.8333
# ETA:1s/6s SUB:7
# epoch 11, loss_bi=0.6457 loss_mse=0.6458 loss_total=0.0001 acc=0.6800 f1=0.8095
# epoch 11, val, loss_bi=0.6302 loss_mse=0.0001 loss_total=0.6303 acc=0.7143 f1=0.8333
# ETA:1s/6s SUB:7
# epoch 12, loss_bi=0.6447 loss_mse=0.6448 loss_total=0.0001 acc=0.6800 f1=0.8095
# epoch 12, val, loss_bi=0.6199 loss_mse=0.0000 loss_total=0.6199 acc=0.7143 f1=0.8333
# ETA:1s/6s SUB:7
# epoch 13, loss_bi=0.6438 loss_mse=0.6439 loss_total=0.0001 acc=0.6800 f1=0.8095
# epoch 13, val, loss_bi=0.6238 loss_mse=0.0000 loss_total=0.6239 acc=0.7143 f1=0.8333
# ETA:1s/6s SUB:7
# epoch 14, loss_bi=0.6417 loss_mse=0.6417 loss_total=0.0000 acc=0.6800 f1=0.8095
# epoch 14, val, loss_bi=0.6175 loss_mse=0.0000 loss_total=0.6175 acc=0.7143 f1=0.8333
# ETA:1s/6s SUB:7
# epoch 15, loss_bi=0.6408 loss_mse=0.6408 loss_total=0.0000 acc=0.6800 f1=0.8095
# epoch 15, val, loss_bi=0.6299 loss_mse=0.0000 loss_total=0.6299 acc=0.7143 f1=0.8333
# ETA:1s/6s SUB:7
# epoch 16, loss_bi=0.6467 loss_mse=0.6468 loss_total=0.0000 acc=0.6800 f1=0.8095
# epoch 16, val, loss_bi=0.6117 loss_mse=0.0000 loss_total=0.6117 acc=0.7143 f1=0.8333
# ETA:2s/6s SUB:7
# epoch 17, loss_bi=0.6459 loss_mse=0.6460 loss_total=0.0000 acc=0.6800 f1=0.8095
# epoch 17, val, loss_bi=0.6324 loss_mse=0.0000 loss_total=0.6324 acc=0.7143 f1=0.8333
# ETA:2s/6s SUB:7
# epoch 18, loss_bi=0.6488 loss_mse=0.6489 loss_total=0.0000 acc=0.6800 f1=0.8095
# epoch 18, val, loss_bi=0.6141 loss_mse=0.0000 loss_total=0.6141 acc=0.7143 f1=0.8333
# ETA:2s/6s SUB:7
# epoch 19, loss_bi=0.6466 loss_mse=0.6466 loss_total=0.0000 acc=0.6800 f1=0.8095
# epoch 19, val, loss_bi=0.6100 loss_mse=0.0000 loss_total=0.6100 acc=0.7143 f1=0.8333
# ETA:2s/6s SUB:7
# epoch 20, loss_bi=0.6413 loss_mse=0.6413 loss_total=0.0000 acc=0.6800 f1=0.8095
# epoch 20, val, loss_bi=0.6182 loss_mse=0.0000 loss_total=0.6182 acc=0.7143 f1=0.8333
# ETA:2s/6s SUB:7
# epoch 21, loss_bi=0.6387 loss_mse=0.6387 loss_total=0.0000 acc=0.6800 f1=0.8095
# epoch 21, val, loss_bi=0.6174 loss_mse=0.0000 loss_total=0.6174 acc=0.7143 f1=0.8333
# ETA:2s/6s SUB:7
# epoch 22, loss_bi=0.6440 loss_mse=0.6441 loss_total=0.0000 acc=0.6800 f1=0.8095
# epoch 22, val, loss_bi=0.6233 loss_mse=0.0000 loss_total=0.6233 acc=0.7143 f1=0.8333
# ETA:2s/6s SUB:7
# epoch 23, loss_bi=0.6446 loss_mse=0.6446 loss_total=0.0000 acc=0.6800 f1=0.8095
# epoch 23, val, loss_bi=0.6131 loss_mse=0.0000 loss_total=0.6132 acc=0.7143 f1=0.8333
# ETA:3s/6s SUB:7
# epoch 24, loss_bi=0.6467 loss_mse=0.6467 loss_total=0.0000 acc=0.6800 f1=0.8095
# epoch 24, val, loss_bi=0.6172 loss_mse=0.0000 loss_total=0.6172 acc=0.7143 f1=0.8333
# ETA:3s/6s SUB:7
# epoch 25, loss_bi=0.6391 loss_mse=0.6392 loss_total=0.0000 acc=0.6800 f1=0.8095
# epoch 25, val, loss_bi=0.6205 loss_mse=0.0000 loss_total=0.6205 acc=0.7143 f1=0.8333
# ETA:3s/6s SUB:7
# epoch 26, loss_bi=0.6439 loss_mse=0.6439 loss_total=0.0000 acc=0.6800 f1=0.8095
# epoch 26, val, loss_bi=0.6230 loss_mse=0.0000 loss_total=0.6231 acc=0.7143 f1=0.8333
# ETA:3s/6s SUB:7
# epoch 27, loss_bi=0.6454 loss_mse=0.6455 loss_total=0.0000 acc=0.6800 f1=0.8095
# epoch 27, val, loss_bi=0.6158 loss_mse=0.0000 loss_total=0.6158 acc=0.7143 f1=0.8333
# ETA:3s/6s SUB:7
# epoch 28, loss_bi=0.6337 loss_mse=0.6337 loss_total=0.0000 acc=0.6800 f1=0.8095
# epoch 28, val, loss_bi=0.6068 loss_mse=0.0000 loss_total=0.6068 acc=0.7143 f1=0.8333
# ETA:3s/6s SUB:7
# epoch 29, loss_bi=0.6381 loss_mse=0.6381 loss_total=0.0000 acc=0.6800 f1=0.8095
# epoch 29, val, loss_bi=0.6173 loss_mse=0.0000 loss_total=0.6173 acc=0.7143 f1=0.8333
# ETA:3s/6s SUB:7
# epoch 30, loss_bi=0.6403 loss_mse=0.6403 loss_total=0.0000 acc=0.6800 f1=0.8095
# epoch 30, val, loss_bi=0.6268 loss_mse=0.0000 loss_total=0.6268 acc=0.7143 f1=0.8333
# ETA:3s/6s SUB:7
# epoch 31, loss_bi=0.6448 loss_mse=0.6448 loss_total=0.0000 acc=0.6800 f1=0.8095
# epoch 31, val, loss_bi=0.6218 loss_mse=0.0000 loss_total=0.6218 acc=0.7143 f1=0.8333
# ETA:4s/6s SUB:7
# epoch 32, loss_bi=0.6437 loss_mse=0.6437 loss_total=0.0000 acc=0.6800 f1=0.8095
# epoch 32, val, loss_bi=0.6233 loss_mse=0.0000 loss_total=0.6233 acc=0.7143 f1=0.8333
# ETA:4s/6s SUB:7
# epoch 33, loss_bi=0.6395 loss_mse=0.6395 loss_total=0.0000 acc=0.6800 f1=0.8095
# epoch 33, val, loss_bi=0.6237 loss_mse=0.0000 loss_total=0.6237 acc=0.7143 f1=0.8333
# ETA:4s/6s SUB:7
# epoch 34, loss_bi=0.6392 loss_mse=0.6392 loss_total=0.0000 acc=0.6800 f1=0.8095
# epoch 34, val, loss_bi=0.6140 loss_mse=0.0000 loss_total=0.6140 acc=0.7143 f1=0.8333
# ETA:4s/6s SUB:7
# epoch 35, loss_bi=0.6408 loss_mse=0.6408 loss_total=0.0000 acc=0.6800 f1=0.8095
# epoch 35, val, loss_bi=0.6212 loss_mse=0.0000 loss_total=0.6212 acc=0.7143 f1=0.8333
# ETA:4s/6s SUB:7
# epoch 36, loss_bi=0.6412 loss_mse=0.6412 loss_total=0.0000 acc=0.6800 f1=0.8095
# epoch 36, val, loss_bi=0.6206 loss_mse=0.0000 loss_total=0.6206 acc=0.7143 f1=0.8333
# ETA:4s/6s SUB:7
# epoch 37, loss_bi=0.6428 loss_mse=0.6428 loss_total=0.0000 acc=0.6800 f1=0.8095
# epoch 37, val, loss_bi=0.6169 loss_mse=0.0000 loss_total=0.6169 acc=0.7143 f1=0.8333
# ETA:4s/6s SUB:7
# epoch 38, loss_bi=0.6366 loss_mse=0.6366 loss_total=0.0000 acc=0.6800 f1=0.8095
# epoch 38, val, loss_bi=0.6198 loss_mse=0.0000 loss_total=0.6198 acc=0.7143 f1=0.8333
# ETA:5s/6s SUB:7
# epoch 39, loss_bi=0.6431 loss_mse=0.6431 loss_total=0.0000 acc=0.6800 f1=0.8095
# epoch 39, val, loss_bi=0.6093 loss_mse=0.0000 loss_total=0.6093 acc=0.7143 f1=0.8333
# ETA:5s/6s SUB:7
# epoch 40, loss_bi=0.6396 loss_mse=0.6396 loss_total=0.0000 acc=0.6800 f1=0.8095
# epoch 40, val, loss_bi=0.6266 loss_mse=0.0000 loss_total=0.6266 acc=0.7143 f1=0.8333
# ETA:5s/6s SUB:7
# epoch 41, loss_bi=0.6433 loss_mse=0.6433 loss_total=0.0000 acc=0.6800 f1=0.8095
# epoch 41, val, loss_bi=0.6179 loss_mse=0.0000 loss_total=0.6179 acc=0.7143 f1=0.8333
# ETA:5s/6s SUB:7
# epoch 42, loss_bi=0.6417 loss_mse=0.6417 loss_total=0.0000 acc=0.6800 f1=0.8095
# epoch 42, val, loss_bi=0.6048 loss_mse=0.0000 loss_total=0.6048 acc=0.7143 f1=0.8333
# ETA:5s/6s SUB:7
# epoch 43, loss_bi=0.6378 loss_mse=0.6378 loss_total=0.0000 acc=0.6800 f1=0.8095
# epoch 43, val, loss_bi=0.6181 loss_mse=0.0000 loss_total=0.6181 acc=0.7143 f1=0.8333
# ETA:5s/6s SUB:7
# epoch 44, loss_bi=0.6405 loss_mse=0.6405 loss_total=0.0000 acc=0.6800 f1=0.8095
# epoch 44, val, loss_bi=0.6156 loss_mse=0.0000 loss_total=0.6156 acc=0.7143 f1=0.8333
# ETA:5s/6s SUB:7
# epoch 45, loss_bi=0.6421 loss_mse=0.6421 loss_total=0.0000 acc=0.6800 f1=0.8095
# epoch 45, val, loss_bi=0.6287 loss_mse=0.0000 loss_total=0.6287 acc=0.7143 f1=0.8333
# ETA:6s/6s SUB:7
# epoch 46, loss_bi=0.6351 loss_mse=0.6351 loss_total=0.0000 acc=0.6800 f1=0.8095
# epoch 46, val, loss_bi=0.6248 loss_mse=0.0000 loss_total=0.6248 acc=0.7143 f1=0.8333
# ETA:6s/6s SUB:7
# epoch 47, loss_bi=0.6421 loss_mse=0.6421 loss_total=0.0000 acc=0.6800 f1=0.8095
# epoch 47, val, loss_bi=0.6220 loss_mse=0.0000 loss_total=0.6220 acc=0.7143 f1=0.8333
# ETA:6s/6s SUB:7
# epoch 48, loss_bi=0.6369 loss_mse=0.6369 loss_total=0.0000 acc=0.6800 f1=0.8095
# epoch 48, val, loss_bi=0.6099 loss_mse=0.0000 loss_total=0.6099 acc=0.7143 f1=0.8333
# ETA:6s/6s SUB:7
# epoch 49, loss_bi=0.6345 loss_mse=0.6345 loss_total=0.0000 acc=0.6800 f1=0.8095
# epoch 49, val, loss_bi=0.6231 loss_mse=0.0000 loss_total=0.6231 acc=0.7143 f1=0.8333
# ETA:6s/6s SUB:7
# epoch 50, loss_bi=0.6359 loss_mse=0.6359 loss_total=0.0000 acc=0.6800 f1=0.8095
# epoch 50, val, loss_bi=0.6142 loss_mse=0.0000 loss_total=0.6142 acc=0.7143 f1=0.8333
# ETA:6s/6s SUB:7
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_V/sub7_cmlp.pth
# using gpu: 0
# >>> Test:  loss_bi=0.5858 loss_mse=0.0000 loss_total=0.5858 acc=0.7500 f1=0.8571
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 8 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss_bi=0.7420 loss_mse=0.7577 loss_total=0.0157 acc=0.5067 f1=0.4904
# epoch 1, val, loss_bi=0.6817 loss_mse=0.0014 loss_total=0.6831 acc=0.6286 f1=0.7111
# ETA:0s/6s SUB:8
# epoch 2, loss_bi=0.6645 loss_mse=0.6661 loss_total=0.0016 acc=0.6080 f1=0.7263
# epoch 2, val, loss_bi=0.6685 loss_mse=0.0004 loss_total=0.6689 acc=0.5810 f1=0.7143
# ETA:0s/4s SUB:8
# epoch 3, loss_bi=0.6406 loss_mse=0.6411 loss_total=0.0004 acc=0.6720 f1=0.7261
# epoch 3, val, loss_bi=0.6630 loss_mse=0.0001 loss_total=0.6631 acc=0.6095 f1=0.7285
# ETA:0s/3s SUB:8
# epoch 4, loss_bi=0.5702 loss_mse=0.5707 loss_total=0.0005 acc=0.7520 f1=0.7947
# epoch 4, val, loss_bi=0.6415 loss_mse=0.0003 loss_total=0.6418 acc=0.6762 f1=0.7302
# ETA:0s/4s SUB:8
# epoch 5, loss_bi=0.5169 loss_mse=0.5178 loss_total=0.0009 acc=0.7813 f1=0.8111
# epoch 5, val, loss_bi=0.6584 loss_mse=0.0005 loss_total=0.6588 acc=0.6857 f1=0.7591
# ETA:0s/4s SUB:8
# epoch 6, loss_bi=0.4756 loss_mse=0.4766 loss_total=0.0011 acc=0.8000 f1=0.8337
# epoch 6, val, loss_bi=0.7699 loss_mse=0.0004 loss_total=0.7703 acc=0.5810 f1=0.5111
# ETA:0s/4s SUB:8
# epoch 7, loss_bi=0.4516 loss_mse=0.4523 loss_total=0.0006 acc=0.8480 f1=0.8671
# epoch 7, val, loss_bi=0.7698 loss_mse=0.0006 loss_total=0.7704 acc=0.5619 f1=0.5106
# ETA:0s/4s SUB:8
# epoch 8, loss_bi=0.4061 loss_mse=0.4077 loss_total=0.0017 acc=0.8533 f1=0.8706
# epoch 8, val, loss_bi=0.7367 loss_mse=0.0031 loss_total=0.7398 acc=0.5905 f1=0.5567
# ETA:0s/3s SUB:8
# epoch 9, loss_bi=0.3867 loss_mse=0.3888 loss_total=0.0021 acc=0.8987 f1=0.9082
# epoch 9, val, loss_bi=0.6649 loss_mse=0.0004 loss_total=0.6653 acc=0.6286 f1=0.6486
# ETA:0s/3s SUB:8
# epoch 10, loss_bi=0.3722 loss_mse=0.3729 loss_total=0.0007 acc=0.8933 f1=0.9038
# epoch 10, val, loss_bi=0.6831 loss_mse=0.0004 loss_total=0.6835 acc=0.6095 f1=0.6306
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_V/sub8_cmlp.pth
# using gpu: 0
# >>> Test:  loss_bi=0.8579 loss_mse=0.0005 loss_total=0.8585 acc=0.5250 f1=0.5581
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 9 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss_bi=0.7039 loss_mse=0.7128 loss_total=0.0089 acc=0.5200 f1=0.4410
# epoch 1, val, loss_bi=0.7007 loss_mse=0.0008 loss_total=0.7015 acc=0.4857 f1=0.2286
# ETA:0s/6s SUB:9
# epoch 2, loss_bi=0.6853 loss_mse=0.6866 loss_total=0.0013 acc=0.5547 f1=0.5187
# epoch 2, val, loss_bi=0.6806 loss_mse=0.0004 loss_total=0.6810 acc=0.6000 f1=0.6667
# ETA:0s/6s SUB:9
# epoch 3, loss_bi=0.6253 loss_mse=0.6261 loss_total=0.0008 acc=0.6747 f1=0.6369
# epoch 3, val, loss_bi=0.6925 loss_mse=0.0005 loss_total=0.6930 acc=0.5238 f1=0.4186
# ETA:0s/5s SUB:9
# epoch 4, loss_bi=0.5630 loss_mse=0.5657 loss_total=0.0027 acc=0.7493 f1=0.7283
# epoch 4, val, loss_bi=0.6948 loss_mse=0.0011 loss_total=0.6959 acc=0.5238 f1=0.4681
# ETA:0s/4s SUB:9
# epoch 5, loss_bi=0.5374 loss_mse=0.5395 loss_total=0.0021 acc=0.7387 f1=0.7216
# epoch 5, val, loss_bi=0.6987 loss_mse=0.0008 loss_total=0.6995 acc=0.5714 f1=0.5545
# ETA:0s/4s SUB:9
# epoch 6, loss_bi=0.4788 loss_mse=0.4806 loss_total=0.0018 acc=0.8293 f1=0.8171
# epoch 6, val, loss_bi=0.7998 loss_mse=0.0005 loss_total=0.8002 acc=0.5619 f1=0.4773
# ETA:0s/3s SUB:9
# epoch 7, loss_bi=0.4424 loss_mse=0.4443 loss_total=0.0019 acc=0.8453 f1=0.8371
# epoch 7, val, loss_bi=0.8384 loss_mse=0.0008 loss_total=0.8392 acc=0.5810 f1=0.5111
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_V/sub9_cmlp.pth
# using gpu: 0
# >>> Test:  loss_bi=0.6804 loss_mse=0.0004 loss_total=0.6808 acc=0.5500 f1=0.5846
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 10 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss_bi=0.7833 loss_mse=0.8250 loss_total=0.0417 acc=0.5440 f1=0.5015
# epoch 1, val, loss_bi=0.6731 loss_mse=0.0019 loss_total=0.6750 acc=0.5810 f1=0.7105
# ETA:0s/8s SUB:10
# epoch 2, loss_bi=0.6667 loss_mse=0.6687 loss_total=0.0020 acc=0.5600 f1=0.6207
# epoch 2, val, loss_bi=0.6586 loss_mse=0.0006 loss_total=0.6592 acc=0.6381 f1=0.6984
# ETA:0s/8s SUB:10
# epoch 3, loss_bi=0.6175 loss_mse=0.6180 loss_total=0.0005 acc=0.6693 f1=0.7019
# epoch 3, val, loss_bi=0.7224 loss_mse=0.0002 loss_total=0.7226 acc=0.5810 f1=0.4634
# ETA:0s/6s SUB:10
# epoch 4, loss_bi=0.5915 loss_mse=0.5918 loss_total=0.0003 acc=0.6987 f1=0.7018
# epoch 4, val, loss_bi=0.7482 loss_mse=0.0002 loss_total=0.7484 acc=0.5905 f1=0.4819
# ETA:0s/5s SUB:10
# epoch 5, loss_bi=0.5679 loss_mse=0.5681 loss_total=0.0002 acc=0.7147 f1=0.7147
# epoch 5, val, loss_bi=0.6519 loss_mse=0.0001 loss_total=0.6520 acc=0.6190 f1=0.6296
# ETA:0s/5s SUB:10
# epoch 6, loss_bi=0.5313 loss_mse=0.5313 loss_total=0.0001 acc=0.7520 f1=0.7452
# epoch 6, val, loss_bi=0.6277 loss_mse=0.0000 loss_total=0.6278 acc=0.6476 f1=0.6838
# ETA:0s/5s SUB:10
# epoch 7, loss_bi=0.4834 loss_mse=0.4834 loss_total=0.0000 acc=0.8053 f1=0.8032
# epoch 7, val, loss_bi=0.6410 loss_mse=0.0000 loss_total=0.6410 acc=0.6476 f1=0.6783
# ETA:0s/6s SUB:10
# epoch 8, loss_bi=0.5103 loss_mse=0.5103 loss_total=0.0000 acc=0.7787 f1=0.7981
# epoch 8, val, loss_bi=0.6544 loss_mse=0.0000 loss_total=0.6544 acc=0.6095 f1=0.5941
# ETA:0s/5s SUB:10
# epoch 9, loss_bi=0.4602 loss_mse=0.4602 loss_total=0.0000 acc=0.8240 f1=0.8177
# epoch 9, val, loss_bi=0.6377 loss_mse=0.0000 loss_total=0.6377 acc=0.6952 f1=0.7419
# ETA:1s/6s SUB:10
# epoch 10, loss_bi=0.4244 loss_mse=0.4245 loss_total=0.0000 acc=0.8560 f1=0.8594
# epoch 10, val, loss_bi=0.6568 loss_mse=0.0000 loss_total=0.6568 acc=0.6857 f1=0.7179
# ETA:1s/5s SUB:10
# epoch 11, loss_bi=0.4095 loss_mse=0.4096 loss_total=0.0000 acc=0.8720 f1=0.8794
# epoch 11, val, loss_bi=0.7441 loss_mse=0.0000 loss_total=0.7441 acc=0.5905 f1=0.5474
# ETA:1s/5s SUB:10
# epoch 12, loss_bi=0.3864 loss_mse=0.3865 loss_total=0.0000 acc=0.8987 f1=0.9005
# epoch 12, val, loss_bi=0.7618 loss_mse=0.0000 loss_total=0.7618 acc=0.6190 f1=0.6078
# ETA:1s/5s SUB:10
# epoch 13, loss_bi=0.3709 loss_mse=0.3710 loss_total=0.0000 acc=0.9093 f1=0.9119
# epoch 13, val, loss_bi=0.7728 loss_mse=0.0001 loss_total=0.7729 acc=0.6000 f1=0.5714
# ETA:1s/5s SUB:10
# epoch 14, loss_bi=0.3508 loss_mse=0.3512 loss_total=0.0004 acc=0.9200 f1=0.9227
# epoch 14, val, loss_bi=0.8924 loss_mse=0.0001 loss_total=0.8924 acc=0.5810 f1=0.5217
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_V/sub10_cmlp.pth
# using gpu: 0
# >>> Test:  loss_bi=0.7431 loss_mse=0.0000 loss_total=0.7431 acc=0.5583 f1=0.5620
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 11 [37, 38, 39] 37
# 23 6 8
# (345, 3166) (90, 3166) (345,) (90,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss_bi=0.6891 loss_mse=0.6922 loss_total=0.0031 acc=0.5507 f1=0.6830
# epoch 1, val, loss_bi=0.6004 loss_mse=0.0003 loss_total=0.6007 acc=0.8333 f1=0.9091
# ETA:0s/6s SUB:11
# epoch 2, loss_bi=0.6551 loss_mse=0.6557 loss_total=0.0006 acc=0.6116 f1=0.7352
# epoch 2, val, loss_bi=0.5724 loss_mse=0.0002 loss_total=0.5726 acc=0.8333 f1=0.9091
# ETA:0s/6s SUB:11
# epoch 3, loss_bi=0.6224 loss_mse=0.6234 loss_total=0.0010 acc=0.6667 f1=0.7639
# epoch 3, val, loss_bi=0.5458 loss_mse=0.0011 loss_total=0.5469 acc=0.8333 f1=0.9091
# ETA:0s/6s SUB:11
# epoch 4, loss_bi=0.5893 loss_mse=0.5909 loss_total=0.0016 acc=0.7014 f1=0.7894
# epoch 4, val, loss_bi=0.6692 loss_mse=0.0006 loss_total=0.6699 acc=0.5222 f1=0.6767
# ETA:0s/5s SUB:11
# epoch 5, loss_bi=0.5192 loss_mse=0.5219 loss_total=0.0027 acc=0.8000 f1=0.8503
# epoch 5, val, loss_bi=0.8516 loss_mse=0.0016 loss_total=0.8531 acc=0.4444 f1=0.5690
# ETA:0s/4s SUB:11
# epoch 6, loss_bi=0.5046 loss_mse=0.5088 loss_total=0.0042 acc=0.8000 f1=0.8399
# epoch 6, val, loss_bi=1.3073 loss_mse=0.0023 loss_total=1.3095 acc=0.2556 f1=0.2796
# ETA:0s/4s SUB:11
# epoch 7, loss_bi=0.5554 loss_mse=0.5581 loss_total=0.0028 acc=0.7217 f1=0.7767
# epoch 7, val, loss_bi=0.8748 loss_mse=0.0008 loss_total=0.8757 acc=0.4222 f1=0.5439
# ETA:0s/4s SUB:11
# epoch 8, loss_bi=0.4924 loss_mse=0.4943 loss_total=0.0019 acc=0.8029 f1=0.8182
# epoch 8, val, loss_bi=0.6221 loss_mse=0.0008 loss_total=0.6229 acc=0.8000 f1=0.8889
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_V/sub11_cmlp.pth
# using gpu: 0
# >>> Test:  loss_bi=0.7151 loss_mse=0.0012 loss_total=0.7164 acc=0.6250 f1=0.7692
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 12 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss_bi=0.6614 loss_mse=0.6692 loss_total=0.0077 acc=0.5893 f1=0.5032
# epoch 1, val, loss_bi=0.6788 loss_mse=0.0007 loss_total=0.6795 acc=0.5524 f1=0.6569
# ETA:0s/6s SUB:12
# epoch 2, loss_bi=0.5524 loss_mse=0.5536 loss_total=0.0012 acc=0.7627 f1=0.7588
# epoch 2, val, loss_bi=0.7227 loss_mse=0.0005 loss_total=0.7232 acc=0.5333 f1=0.6142
# ETA:0s/4s SUB:12
# epoch 3, loss_bi=0.4574 loss_mse=0.4586 loss_total=0.0012 acc=0.8507 f1=0.8453
# epoch 3, val, loss_bi=0.8826 loss_mse=0.0004 loss_total=0.8829 acc=0.5333 f1=0.5149
# ETA:0s/3s SUB:12
# epoch 4, loss_bi=0.4199 loss_mse=0.4215 loss_total=0.0016 acc=0.8587 f1=0.8548
# epoch 4, val, loss_bi=0.9917 loss_mse=0.0004 loss_total=0.9921 acc=0.5333 f1=0.4948
# ETA:0s/3s SUB:12
# epoch 5, loss_bi=0.4195 loss_mse=0.4205 loss_total=0.0009 acc=0.8507 f1=0.8409
# epoch 5, val, loss_bi=0.8993 loss_mse=0.0003 loss_total=0.8996 acc=0.5714 f1=0.6512
# ETA:0s/4s SUB:12
# epoch 6, loss_bi=0.3336 loss_mse=0.3343 loss_total=0.0007 acc=0.9333 f1=0.9311
# epoch 6, val, loss_bi=0.9061 loss_mse=0.0003 loss_total=0.9064 acc=0.5810 f1=0.6271
# ETA:0s/4s SUB:12
# epoch 7, loss_bi=0.3236 loss_mse=0.3244 loss_total=0.0008 acc=0.9333 f1=0.9311
# epoch 7, val, loss_bi=0.9613 loss_mse=0.0003 loss_total=0.9616 acc=0.5905 f1=0.6261
# ETA:0s/4s SUB:12
# epoch 8, loss_bi=0.3079 loss_mse=0.3088 loss_total=0.0009 acc=0.9493 f1=0.9479
# epoch 8, val, loss_bi=1.0137 loss_mse=0.0003 loss_total=1.0140 acc=0.5905 f1=0.6261
# ETA:0s/4s SUB:12
# epoch 9, loss_bi=0.2905 loss_mse=0.2914 loss_total=0.0009 acc=0.9547 f1=0.9529
# epoch 9, val, loss_bi=0.9658 loss_mse=0.0003 loss_total=0.9661 acc=0.5619 f1=0.6167
# ETA:0s/4s SUB:12
# epoch 10, loss_bi=0.2760 loss_mse=0.2771 loss_total=0.0010 acc=0.9653 f1=0.9646
# epoch 10, val, loss_bi=1.0750 loss_mse=0.0010 loss_total=1.0760 acc=0.5714 f1=0.5631
# ETA:0s/4s SUB:12
# epoch 11, loss_bi=0.2837 loss_mse=0.2849 loss_total=0.0013 acc=0.9680 f1=0.9670
# epoch 11, val, loss_bi=1.0000 loss_mse=0.0003 loss_total=1.0003 acc=0.5714 f1=0.5714
# ETA:0s/4s SUB:12
# epoch 12, loss_bi=0.2661 loss_mse=0.2670 loss_total=0.0009 acc=0.9787 f1=0.9781
# epoch 12, val, loss_bi=1.0289 loss_mse=0.0003 loss_total=1.0292 acc=0.5810 f1=0.5849
# ETA:0s/4s SUB:12
# epoch 13, loss_bi=0.2598 loss_mse=0.2607 loss_total=0.0009 acc=0.9813 f1=0.9807
# epoch 13, val, loss_bi=1.0146 loss_mse=0.0003 loss_total=1.0149 acc=0.5810 f1=0.6000
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_V/sub12_cmlp.pth
# using gpu: 0
# >>> Test:  loss_bi=0.7497 loss_mse=0.0003 loss_total=0.7500 acc=0.6333 f1=0.7027
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 13 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss_bi=0.6682 loss_mse=0.6882 loss_total=0.0200 acc=0.6747 f1=0.2989
# epoch 1, val, loss_bi=0.6181 loss_mse=0.0016 loss_total=0.6197 acc=0.6381 f1=0.2692
# ETA:0s/6s SUB:13
# epoch 2, loss_bi=0.4808 loss_mse=0.4827 loss_total=0.0019 acc=0.8187 f1=0.6092
# epoch 2, val, loss_bi=0.4723 loss_mse=0.0006 loss_total=0.4730 acc=0.8000 f1=0.7200
# ETA:0s/6s SUB:13
# epoch 3, loss_bi=0.3772 loss_mse=0.3787 loss_total=0.0015 acc=0.8827 f1=0.8036
# epoch 3, val, loss_bi=0.4915 loss_mse=0.0004 loss_total=0.4919 acc=0.8095 f1=0.7368
# ETA:0s/6s SUB:13
# epoch 4, loss_bi=0.3563 loss_mse=0.3570 loss_total=0.0007 acc=0.8987 f1=0.8304
# epoch 4, val, loss_bi=0.4325 loss_mse=0.0004 loss_total=0.4328 acc=0.8381 f1=0.7848
# ETA:0s/6s SUB:13
# epoch 5, loss_bi=0.3192 loss_mse=0.3200 loss_total=0.0008 acc=0.9253 f1=0.8772
# epoch 5, val, loss_bi=0.4220 loss_mse=0.0002 loss_total=0.4223 acc=0.8571 f1=0.8193
# ETA:0s/6s SUB:13
# epoch 6, loss_bi=0.3139 loss_mse=0.3157 loss_total=0.0018 acc=0.9413 f1=0.9068
# epoch 6, val, loss_bi=0.3887 loss_mse=0.0007 loss_total=0.3894 acc=0.8762 f1=0.8539
# ETA:0s/6s SUB:13
# epoch 7, loss_bi=0.3116 loss_mse=0.3125 loss_total=0.0009 acc=0.9440 f1=0.9067
# epoch 7, val, loss_bi=0.4611 loss_mse=0.0005 loss_total=0.4616 acc=0.7905 f1=0.7963
# ETA:0s/5s SUB:13
# epoch 8, loss_bi=0.3064 loss_mse=0.3072 loss_total=0.0008 acc=0.9387 f1=0.9013
# epoch 8, val, loss_bi=0.4059 loss_mse=0.0003 loss_total=0.4062 acc=0.8381 f1=0.8000
# ETA:0s/5s SUB:13
# epoch 9, loss_bi=0.2642 loss_mse=0.2647 loss_total=0.0005 acc=0.9787 f1=0.9664
# epoch 9, val, loss_bi=0.4070 loss_mse=0.0003 loss_total=0.4072 acc=0.8381 f1=0.8000
# ETA:0s/5s SUB:13
# epoch 10, loss_bi=0.2474 loss_mse=0.2478 loss_total=0.0004 acc=0.9893 f1=0.9831
# epoch 10, val, loss_bi=0.4152 loss_mse=0.0002 loss_total=0.4154 acc=0.8667 f1=0.8542
# ETA:0s/4s SUB:13
# epoch 11, loss_bi=0.2468 loss_mse=0.2472 loss_total=0.0004 acc=0.9893 f1=0.9832
# epoch 11, val, loss_bi=0.3983 loss_mse=0.0001 loss_total=0.3984 acc=0.8667 f1=0.8409
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_V/sub13_cmlp.pth
# using gpu: 0
# >>> Test:  loss_bi=1.3488 loss_mse=0.0005 loss_total=1.3494 acc=0.3917 f1=0.3866
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 14 [39] 39
# 24 7 8
# (360, 3166) (105, 3166) (360,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss_bi=0.7014 loss_mse=0.7110 loss_total=0.0096 acc=0.5528 f1=0.5589
# epoch 1, val, loss_bi=0.8375 loss_mse=0.0008 loss_total=0.8383 acc=0.4286 f1=0.6000
# ETA:0s/6s SUB:14
# epoch 2, loss_bi=0.6554 loss_mse=0.6567 loss_total=0.0013 acc=0.6083 f1=0.6484
# epoch 2, val, loss_bi=0.6622 loss_mse=0.0004 loss_total=0.6626 acc=0.5905 f1=0.5567
# ETA:0s/6s SUB:14
# epoch 3, loss_bi=0.5744 loss_mse=0.5752 loss_total=0.0008 acc=0.7111 f1=0.7581
# epoch 3, val, loss_bi=0.6658 loss_mse=0.0003 loss_total=0.6661 acc=0.6286 f1=0.4179
# ETA:0s/6s SUB:14
# epoch 4, loss_bi=0.5281 loss_mse=0.5286 loss_total=0.0005 acc=0.7694 f1=0.7899
# epoch 4, val, loss_bi=0.6245 loss_mse=0.0001 loss_total=0.6246 acc=0.6476 f1=0.4932
# ETA:0s/6s SUB:14
# epoch 5, loss_bi=0.4834 loss_mse=0.4839 loss_total=0.0005 acc=0.7944 f1=0.8122
# epoch 5, val, loss_bi=0.6858 loss_mse=0.0002 loss_total=0.6860 acc=0.6190 f1=0.4444
# ETA:0s/5s SUB:14
# ...
# epoch 6, val, loss_bi=0.9179 loss_mse=0.0011 loss_total=0.9189 acc=0.5810 f1=0.4884
# ETA:0s/7s SUB:15
# epoch 7, loss_bi=0.4181 loss_mse=0.4195 loss_total=0.0014 acc=0.8693 f1=0.8474
# epoch 7, val, loss_bi=0.7102 loss_mse=0.0004 loss_total=0.7106 acc=0.6667 f1=0.6729
# ETA:1s/7s SUB:15
# epoch 8, loss_bi=0.3934 loss_mse=0.3944 loss_total=0.0010 acc=0.8773 f1=0.8631
# epoch 8, val, loss_bi=0.7607 loss_mse=0.0003 loss_total=0.7611 acc=0.5905 f1=0.5275
# ETA:1s/7s SUB:15
# epoch 9, loss_bi=0.3779 loss_mse=0.3790 loss_total=0.0011 acc=0.8933 f1=0.8780
# epoch 9, val, loss_bi=0.8648 loss_mse=0.0004 loss_total=0.8652 acc=0.5714 f1=0.4706
# ETA:1s/6s SUB:15
# epoch 10, loss_bi=0.3914 loss_mse=0.3927 loss_total=0.0013 acc=0.8747 f1=0.8630
# epoch 10, val, loss_bi=1.1565 loss_mse=0.0003 loss_total=1.1568 acc=0.4857 f1=0.2286
# ETA:1s/6s SUB:15
# epoch 11, loss_bi=0.4383 loss_mse=0.4391 loss_total=0.0007 acc=0.8453 f1=0.8221
# epoch 11, val, loss_bi=0.8131 loss_mse=0.0004 loss_total=0.8135 acc=0.5714 f1=0.4828
# ETA:1s/5s SUB:15
# epoch 12, loss_bi=0.4057 loss_mse=0.4065 loss_total=0.0009 acc=0.8747 f1=0.8498
# epoch 12, val, loss_bi=0.6866 loss_mse=0.0002 loss_total=0.6867 acc=0.6857 f1=0.7481
# ETA:1s/6s SUB:15
# epoch 13, loss_bi=0.3529 loss_mse=0.3536 loss_total=0.0007 acc=0.8907 f1=0.8791
# epoch 13, val, loss_bi=0.8734 loss_mse=0.0003 loss_total=0.8738 acc=0.5619 f1=0.4651
# ETA:1s/5s SUB:15
# epoch 14, loss_bi=0.3333 loss_mse=0.3342 loss_total=0.0009 acc=0.9253 f1=0.9157
# epoch 14, val, loss_bi=0.9445 loss_mse=0.0009 loss_total=0.9453 acc=0.5810 f1=0.4884
# ETA:1s/5s SUB:15
# epoch 15, loss_bi=0.3339 loss_mse=0.3353 loss_total=0.0015 acc=0.9227 f1=0.9129
# epoch 15, val, loss_bi=0.8292 loss_mse=0.0004 loss_total=0.8296 acc=0.6000 f1=0.5532
# ETA:1s/5s SUB:15
# epoch 16, loss_bi=0.3128 loss_mse=0.3137 loss_total=0.0009 acc=0.9333 f1=0.9221
# epoch 16, val, loss_bi=0.8079 loss_mse=0.0003 loss_total=0.8083 acc=0.6286 f1=0.6139
# ETA:1s/5s SUB:15
# epoch 17, loss_bi=0.3008 loss_mse=0.3018 loss_total=0.0010 acc=0.9467 f1=0.9390
# epoch 17, val, loss_bi=0.7431 loss_mse=0.0004 loss_total=0.7436 acc=0.6667 f1=0.7200
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_V/sub15_cmlp.pth
# using gpu: 0
# >>> Test:  loss_bi=0.5361 loss_mse=0.0001 loss_total=0.5362 acc=0.7333 f1=0.8000
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 16 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss_bi=0.7470 loss_mse=0.7573 loss_total=0.0103 acc=0.5040 f1=0.3673
# epoch 1, val, loss_bi=0.7830 loss_mse=0.0012 loss_total=0.7843 acc=0.4286 f1=0.0000
# ETA:0s/6s SUB:16
# epoch 2, loss_bi=0.6862 loss_mse=0.6874 loss_total=0.0012 acc=0.6107 f1=0.1310
# epoch 2, val, loss_bi=0.7030 loss_mse=0.0003 loss_total=0.7033 acc=0.4381 f1=0.0328
# ETA:0s/6s SUB:16
# epoch 3, loss_bi=0.6640 loss_mse=0.6644 loss_total=0.0003 acc=0.6240 f1=0.2618
# epoch 3, val, loss_bi=0.7556 loss_mse=0.0001 loss_total=0.7557 acc=0.4286 f1=0.0000
# ETA:0s/5s SUB:16
# epoch 4, loss_bi=0.6469 loss_mse=0.6475 loss_total=0.0005 acc=0.6560 f1=0.2951
# epoch 4, val, loss_bi=0.7528 loss_mse=0.0001 loss_total=0.7529 acc=0.4381 f1=0.0328
# ETA:0s/5s SUB:16
# epoch 5, loss_bi=0.6308 loss_mse=0.6311 loss_total=0.0003 acc=0.6587 f1=0.3043
# epoch 5, val, loss_bi=0.6773 loss_mse=0.0002 loss_total=0.6775 acc=0.5048 f1=0.3158
# ETA:0s/5s SUB:16
# epoch 6, loss_bi=0.6069 loss_mse=0.6076 loss_total=0.0007 acc=0.6773 f1=0.4622
# epoch 6, val, loss_bi=0.7008 loss_mse=0.0004 loss_total=0.7012 acc=0.4952 f1=0.2740
# ETA:0s/5s SUB:16
# epoch 7, loss_bi=0.5751 loss_mse=0.5764 loss_total=0.0013 acc=0.7093 f1=0.5551
# epoch 7, val, loss_bi=0.8346 loss_mse=0.0005 loss_total=0.8352 acc=0.4571 f1=0.1231
# ETA:0s/4s SUB:16
# epoch 8, loss_bi=0.6047 loss_mse=0.6055 loss_total=0.0008 acc=0.6933 f1=0.5188
# epoch 8, val, loss_bi=0.6728 loss_mse=0.0003 loss_total=0.6732 acc=0.6476 f1=0.6263
# ETA:0s/5s SUB:16
# epoch 9, loss_bi=0.5600 loss_mse=0.5609 loss_total=0.0009 acc=0.7493 f1=0.6736
# epoch 9, val, loss_bi=0.8036 loss_mse=0.0005 loss_total=0.8041 acc=0.4667 f1=0.1765
# ETA:0s/4s SUB:16
# epoch 10, loss_bi=0.5638 loss_mse=0.5649 loss_total=0.0011 acc=0.7147 f1=0.5633
# epoch 10, val, loss_bi=0.7520 loss_mse=0.0002 loss_total=0.7522 acc=0.5143 f1=0.3200
# ETA:0s/4s SUB:16
# epoch 11, loss_bi=0.5410 loss_mse=0.5413 loss_total=0.0004 acc=0.7493 f1=0.6544
# epoch 11, val, loss_bi=0.7764 loss_mse=0.0002 loss_total=0.7766 acc=0.4952 f1=0.2740
# ETA:0s/4s SUB:16
# epoch 12, loss_bi=0.5152 loss_mse=0.5159 loss_total=0.0007 acc=0.7787 f1=0.7088
# epoch 12, val, loss_bi=0.7479 loss_mse=0.0003 loss_total=0.7482 acc=0.5238 f1=0.3750
# ETA:1s/4s SUB:16
# epoch 13, loss_bi=0.5311 loss_mse=0.5316 loss_total=0.0005 acc=0.7600 f1=0.6763
# epoch 13, val, loss_bi=0.8667 loss_mse=0.0001 loss_total=0.8669 acc=0.4857 f1=0.2286
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_V/sub16_cmlp.pth
# using gpu: 0
# >>> Test:  loss_bi=0.5357 loss_mse=0.0003 loss_total=0.5360 acc=0.8167 f1=0.4762
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 17 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss_bi=0.7036 loss_mse=0.7066 loss_total=0.0031 acc=0.4960 f1=0.2470
# epoch 1, val, loss_bi=0.6966 loss_mse=0.0003 loss_total=0.6969 acc=0.2571 f1=0.3906
# ETA:0s/6s SUB:17
# epoch 2, loss_bi=0.6957 loss_mse=0.6960 loss_total=0.0004 acc=0.5120 f1=0.5172
# epoch 2, val, loss_bi=0.7270 loss_mse=0.0001 loss_total=0.7271 acc=0.1429 f1=0.0000
# ETA:0s/4s SUB:17
# epoch 3, loss_bi=0.6924 loss_mse=0.6926 loss_total=0.0002 acc=0.5360 f1=0.5029
# epoch 3, val, loss_bi=0.7270 loss_mse=0.0001 loss_total=0.7270 acc=0.1333 f1=0.0000
# ETA:0s/3s SUB:17
# epoch 4, loss_bi=0.6900 loss_mse=0.6902 loss_total=0.0002 acc=0.5120 f1=0.2078
# epoch 4, val, loss_bi=0.7270 loss_mse=0.0001 loss_total=0.7271 acc=0.1524 f1=0.0825
# ETA:0s/3s SUB:17
# epoch 5, loss_bi=0.6809 loss_mse=0.6813 loss_total=0.0003 acc=0.5547 f1=0.5815
# epoch 5, val, loss_bi=0.7510 loss_mse=0.0005 loss_total=0.7515 acc=0.1238 f1=0.0000
# ETA:0s/3s SUB:17
# epoch 6, loss_bi=0.6687 loss_mse=0.6692 loss_total=0.0005 acc=0.6293 f1=0.5851
# epoch 6, val, loss_bi=0.7801 loss_mse=0.0001 loss_total=0.7802 acc=0.1429 f1=0.0625
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_V/sub17_cmlp.pth
# using gpu: 0
# >>> Test:  loss_bi=0.6919 loss_mse=0.0003 loss_total=0.6922 acc=0.5917 f1=0.5149
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 18 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss_bi=0.6817 loss_mse=0.6905 loss_total=0.0088 acc=0.5520 f1=0.6216
# epoch 1, val, loss_bi=0.6498 loss_mse=0.0009 loss_total=0.6506 acc=0.6476 f1=0.7517
# ETA:0s/6s SUB:18
# epoch 2, loss_bi=0.5886 loss_mse=0.5900 loss_total=0.0013 acc=0.7093 f1=0.7636
# epoch 2, val, loss_bi=0.6249 loss_mse=0.0007 loss_total=0.6256 acc=0.6762 f1=0.7639
# ETA:0s/6s SUB:18
# epoch 3, loss_bi=0.4700 loss_mse=0.4714 loss_total=0.0014 acc=0.8347 f1=0.8545
# epoch 3, val, loss_bi=0.6875 loss_mse=0.0015 loss_total=0.6890 acc=0.6857 f1=0.6796
# ETA:0s/6s SUB:18
# epoch 4, loss_bi=0.3937 loss_mse=0.3960 loss_total=0.0023 acc=0.8827 f1=0.8937
# epoch 4, val, loss_bi=0.7136 loss_mse=0.0010 loss_total=0.7147 acc=0.7143 f1=0.7170
# ETA:0s/6s SUB:18
# epoch 5, loss_bi=0.3391 loss_mse=0.3413 loss_total=0.0023 acc=0.9173 f1=0.9264
# epoch 5, val, loss_bi=0.7272 loss_mse=0.0011 loss_total=0.7283 acc=0.7143 f1=0.7321
# ETA:0s/6s SUB:18
# epoch 6, loss_bi=0.3174 loss_mse=0.3195 loss_total=0.0022 acc=0.9333 f1=0.9400
# epoch 6, val, loss_bi=0.7632 loss_mse=0.0011 loss_total=0.7643 acc=0.7143 f1=0.7368
# ETA:0s/6s SUB:18
# epoch 7, loss_bi=0.2903 loss_mse=0.2922 loss_total=0.0019 acc=0.9547 f1=0.9600
# epoch 7, val, loss_bi=0.7868 loss_mse=0.0012 loss_total=0.7881 acc=0.7143 f1=0.7222
# ETA:0s/6s SUB:18
# epoch 8, loss_bi=0.2847 loss_mse=0.2864 loss_total=0.0017 acc=0.9600 f1=0.9640
# epoch 8, val, loss_bi=0.7413 loss_mse=0.0008 loss_total=0.7421 acc=0.7048 f1=0.7257
# ETA:0s/5s SUB:18
# epoch 9, loss_bi=0.2666 loss_mse=0.2681 loss_total=0.0015 acc=0.9787 f1=0.9810
# epoch 9, val, loss_bi=0.7502 loss_mse=0.0008 loss_total=0.7510 acc=0.6952 f1=0.7143
# ETA:1s/5s SUB:18
# epoch 10, loss_bi=0.2609 loss_mse=0.2626 loss_total=0.0017 acc=0.9707 f1=0.9739
# epoch 10, val, loss_bi=0.7469 loss_mse=0.0008 loss_total=0.7478 acc=0.6762 f1=0.7018
# ETA:1s/5s SUB:18
# epoch 11, loss_bi=0.2857 loss_mse=0.2871 loss_total=0.0015 acc=0.9627 f1=0.9665
# epoch 11, val, loss_bi=0.8176 loss_mse=0.0007 loss_total=0.8183 acc=0.6476 f1=0.7259
# ETA:1s/4s SUB:18
# epoch 12, loss_bi=0.2595 loss_mse=0.2606 loss_total=0.0011 acc=0.9733 f1=0.9764
# epoch 12, val, loss_bi=0.7461 loss_mse=0.0006 loss_total=0.7467 acc=0.6762 f1=0.7344
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_V/sub18_cmlp.pth
# using gpu: 0
# >>> Test:  loss_bi=0.8861 loss_mse=0.0010 loss_total=0.8870 acc=0.5833 f1=0.6667
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 19 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss_bi=0.6839 loss_mse=0.6871 loss_total=0.0032 acc=0.5493 f1=0.6334
# epoch 1, val, loss_bi=0.6694 loss_mse=0.0004 loss_total=0.6698 acc=0.6000 f1=0.7375
# ETA:0s/6s SUB:19
# epoch 2, loss_bi=0.6631 loss_mse=0.6640 loss_total=0.0009 acc=0.5813 f1=0.6695
# epoch 2, val, loss_bi=0.6576 loss_mse=0.0003 loss_total=0.6579 acc=0.6762 f1=0.7639
# ETA:0s/6s SUB:19
# epoch 3, loss_bi=0.6532 loss_mse=0.6543 loss_total=0.0011 acc=0.6293 f1=0.6698
# epoch 3, val, loss_bi=0.6920 loss_mse=0.0003 loss_total=0.6923 acc=0.6190 f1=0.7436
# ETA:0s/5s SUB:19
# epoch 4, loss_bi=0.6148 loss_mse=0.6156 loss_total=0.0008 acc=0.6907 f1=0.7143
# epoch 4, val, loss_bi=0.6620 loss_mse=0.0004 loss_total=0.6624 acc=0.6381 f1=0.6833
# ETA:0s/4s SUB:19
# epoch 5, loss_bi=0.5870 loss_mse=0.5880 loss_total=0.0010 acc=0.7227 f1=0.7759
# epoch 5, val, loss_bi=0.6920 loss_mse=0.0008 loss_total=0.6928 acc=0.5619 f1=0.5208
# ETA:0s/4s SUB:19
# epoch 6, loss_bi=0.5811 loss_mse=0.5824 loss_total=0.0013 acc=0.7173 f1=0.7500
# epoch 6, val, loss_bi=0.6445 loss_mse=0.0004 loss_total=0.6450 acc=0.6476 f1=0.7040
# ETA:0s/3s SUB:19
# epoch 7, loss_bi=0.5253 loss_mse=0.5263 loss_total=0.0011 acc=0.7840 f1=0.8112
# epoch 7, val, loss_bi=0.7004 loss_mse=0.0006 loss_total=0.7010 acc=0.6095 f1=0.6019
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_V/sub19_cmlp.pth
# using gpu: 0
# >>> Test:  loss_bi=0.6244 loss_mse=0.0003 loss_total=0.6247 acc=0.6500 f1=0.7640
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 20 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss_bi=0.6941 loss_mse=0.7140 loss_total=0.0199 acc=0.5600 f1=0.4330
# epoch 1, val, loss_bi=0.6862 loss_mse=0.0013 loss_total=0.6875 acc=0.5714 f1=0.7273
# ETA:0s/6s SUB:20
# epoch 2, loss_bi=0.6747 loss_mse=0.6763 loss_total=0.0015 acc=0.5680 f1=0.5318
# epoch 2, val, loss_bi=0.6627 loss_mse=0.0005 loss_total=0.6632 acc=0.6095 f1=0.7421
# ETA:0s/6s SUB:20
# epoch 3, loss_bi=0.5830 loss_mse=0.5838 loss_total=0.0009 acc=0.7387 f1=0.7487
# epoch 3, val, loss_bi=0.6997 loss_mse=0.0002 loss_total=0.6999 acc=0.5619 f1=0.4390
# ETA:0s/5s SUB:20
# epoch 4, loss_bi=0.4942 loss_mse=0.4953 loss_total=0.0011 acc=0.8373 f1=0.8232
# epoch 4, val, loss_bi=0.7731 loss_mse=0.0012 loss_total=0.7743 acc=0.5714 f1=0.4706
# ETA:0s/4s SUB:20
# epoch 5, loss_bi=0.4650 loss_mse=0.4663 loss_total=0.0014 acc=0.8267 f1=0.8127
# epoch 5, val, loss_bi=0.7792 loss_mse=0.0006 loss_total=0.7798 acc=0.5810 f1=0.5111
# ETA:0s/4s SUB:20
# epoch 6, loss_bi=0.3989 loss_mse=0.4001 loss_total=0.0011 acc=0.8853 f1=0.8802
# epoch 6, val, loss_bi=0.8741 loss_mse=0.0003 loss_total=0.8744 acc=0.5619 f1=0.5000
# ETA:0s/4s SUB:20
# epoch 7, loss_bi=0.4068 loss_mse=0.4075 loss_total=0.0007 acc=0.8853 f1=0.8761
# epoch 7, val, loss_bi=0.8144 loss_mse=0.0002 loss_total=0.8147 acc=0.5905 f1=0.6126
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_V/sub20_cmlp.pth
# using gpu: 0
# >>> Test:  loss_bi=0.5826 loss_mse=0.0005 loss_total=0.5830 acc=0.8000 f1=0.8879
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 21 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss_bi=0.6896 loss_mse=0.6960 loss_total=0.0064 acc=0.5680 f1=0.6873
# epoch 1, val, loss_bi=0.7185 loss_mse=0.0005 loss_total=0.7189 acc=0.4286 f1=0.6000
# ETA:0s/6s SUB:21
# epoch 2, loss_bi=0.6845 loss_mse=0.6853 loss_total=0.0008 acc=0.5680 f1=0.7055
# epoch 2, val, loss_bi=0.7886 loss_mse=0.0002 loss_total=0.7888 acc=0.4286 f1=0.6000
# ETA:0s/6s SUB:21
# epoch 3, loss_bi=0.6576 loss_mse=0.6580 loss_total=0.0004 acc=0.6213 f1=0.7380
# epoch 3, val, loss_bi=0.8132 loss_mse=0.0002 loss_total=0.8134 acc=0.4286 f1=0.6000
# ETA:0s/6s SUB:21
# epoch 4, loss_bi=0.6249 loss_mse=0.6254 loss_total=0.0005 acc=0.6667 f1=0.7637
# epoch 4, val, loss_bi=0.8531 loss_mse=0.0003 loss_total=0.8534 acc=0.4286 f1=0.6000
# ETA:0s/6s SUB:21
# epoch 5, loss_bi=0.6025 loss_mse=0.6042 loss_total=0.0017 acc=0.6773 f1=0.7515
# epoch 5, val, loss_bi=0.9678 loss_mse=0.0008 loss_total=0.9686 acc=0.4381 f1=0.5986
# ETA:0s/6s SUB:21
# epoch 6, loss_bi=0.5583 loss_mse=0.5599 loss_total=0.0016 acc=0.7307 f1=0.8008
# epoch 6, val, loss_bi=0.9108 loss_mse=0.0006 loss_total=0.9114 acc=0.4571 f1=0.4356
# ETA:0s/6s SUB:21
# epoch 7, loss_bi=0.5400 loss_mse=0.5424 loss_total=0.0024 acc=0.7760 f1=0.8166
# epoch 7, val, loss_bi=1.0523 loss_mse=0.0009 loss_total=1.0533 acc=0.4000 f1=0.5532
# ETA:0s/6s SUB:21
# epoch 8, loss_bi=0.5259 loss_mse=0.5282 loss_total=0.0023 acc=0.7600 f1=0.8133
# epoch 8, val, loss_bi=0.9344 loss_mse=0.0006 loss_total=0.9350 acc=0.4286 f1=0.2105
# ETA:0s/5s SUB:21
# epoch 9, loss_bi=0.5210 loss_mse=0.5223 loss_total=0.0013 acc=0.7600 f1=0.8018
# epoch 9, val, loss_bi=0.9417 loss_mse=0.0004 loss_total=0.9421 acc=0.4190 f1=0.3297
# ETA:0s/5s SUB:21
# epoch 10, loss_bi=0.4830 loss_mse=0.4839 loss_total=0.0008 acc=0.8160 f1=0.8510
# epoch 10, val, loss_bi=0.9525 loss_mse=0.0003 loss_total=0.9528 acc=0.4286 f1=0.3878
# ETA:1s/5s SUB:21
# epoch 11, loss_bi=0.4362 loss_mse=0.4370 loss_total=0.0007 acc=0.8640 f1=0.8903
# epoch 11, val, loss_bi=1.0027 loss_mse=0.0004 loss_total=1.0031 acc=0.3905 f1=0.2889
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_V/sub21_cmlp.pth
# using gpu: 0
# >>> Test:  loss_bi=0.8084 loss_mse=0.0006 loss_total=0.8090 acc=0.4500 f1=0.3889
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 22 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss_bi=0.5934 loss_mse=0.5977 loss_total=0.0043 acc=0.6933 f1=0.2857
# epoch 1, val, loss_bi=0.8191 loss_mse=0.0005 loss_total=0.8196 acc=0.5429 f1=0.0769
# ETA:0s/5s SUB:22
# epoch 2, loss_bi=0.4106 loss_mse=0.4124 loss_total=0.0019 acc=0.8987 f1=0.8516
# epoch 2, val, loss_bi=1.1611 loss_mse=0.0007 loss_total=1.1618 acc=0.5048 f1=0.2121
# ETA:0s/4s SUB:22
# epoch 3, loss_bi=0.3142 loss_mse=0.3165 loss_total=0.0023 acc=0.9387 f1=0.9125
# epoch 3, val, loss_bi=1.2837 loss_mse=0.0006 loss_total=1.2843 acc=0.4762 f1=0.2466
# ETA:0s/3s SUB:22
# epoch 4, loss_bi=0.2757 loss_mse=0.2775 loss_total=0.0019 acc=0.9680 f1=0.9556
# epoch 4, val, loss_bi=1.4392 loss_mse=0.0008 loss_total=1.4400 acc=0.5048 f1=0.1613
# ETA:0s/3s SUB:22
# epoch 5, loss_bi=0.2591 loss_mse=0.2608 loss_total=0.0016 acc=0.9787 f1=0.9706
# epoch 5, val, loss_bi=1.3294 loss_mse=0.0006 loss_total=1.3300 acc=0.5143 f1=0.1905
# ETA:0s/3s SUB:22
# epoch 6, loss_bi=0.2496 loss_mse=0.2511 loss_total=0.0016 acc=0.9867 f1=0.9813
# epoch 6, val, loss_bi=1.3172 loss_mse=0.0004 loss_total=1.3177 acc=0.4667 f1=0.2000
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_V/sub22_cmlp.pth
# using gpu: 0
# >>> Test:  loss_bi=1.0172 loss_mse=0.0006 loss_total=1.0177 acc=0.3083 f1=0.1942
