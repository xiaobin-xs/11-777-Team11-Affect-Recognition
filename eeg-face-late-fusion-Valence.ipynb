# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import scipy as sp
from tqdm import auto, tqdm
import torch
from sklearn.model_selection import train_test_split

import sys
sys.path.append('/content/drive/MyDrive/11777-Project-xs/LGG/')
from prepare_data_DEAP import PrepareData
from cross_validation import CrossValidation
from train_model import *

# %%
original_order = ['Fp1', 'AF3', 'F3', 'F7', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'P3', 'P7', 'PO3', 'O1', 'Oz',
                  'Pz', 'Fp2', 'AF4', 'Fz', 'F4', 'F8', 'FC6', 'FC2', 'Cz', 'C4', 'T8', 'CP6', 'CP2', 'P4', 'P8',
                  'PO4', 'O2']

# Define proper channel orders for the local-global graphs in LGGNet. Please refer to three graph definitions (general, frontal, hemesphere).
graph_general_DEAP = [['Fp1', 'Fp2'], ['AF3', 'AF4'], ['F3', 'F7', 'Fz', 'F4', 'F8'],
                     ['FC5', 'FC1', 'FC6', 'FC2'], ['C3', 'Cz', 'C4'], ['CP5', 'CP1', 'CP2', 'CP6'],
                     ['P7', 'P3', 'Pz', 'P4', 'P8'], ['PO3', 'PO4'], ['O1', 'Oz', 'O2'],
                     ['T7'], ['T8']]

graph_idx = graph_general_DEAP   # The general graph definition for DEAP is used as an example.
idx = []
num_chan_local_graph = []
for i in range(len(graph_idx)):
    num_chan_local_graph.append(len(graph_idx[i]))
    for chan in graph_idx[i]:
        idx.append(original_order.index(chan))

LGG = LGGNet(
    num_classes=2,
    input_size=(1, 32, 512),
    sampling_rate=128,
    num_T=64,  # num_T controls the number of temporal filters
    out_graph=32,
    pool=16,
    pool_step_rate=0.25,
    idx_graph=num_chan_local_graph,
    dropout_rate=0.5
)

LGG

# %%
# Define default parameters
default_args = {
    'dataset': 'DEAP',
    'data_path': './data_preprocessed_python/',
    'subjects': 22,
    'num_class': 2,
    'label_type': 'V',
    'segment': 4,
    'overlap': 0,
    'sampling_rate': 128,
    'scale_coefficient': 1,
    'input_shape': (1, 32, 512),
    'data_format': 'eeg',
    'random_seed': 2021,
    'max_epoch': 50, #200
    'patient': 5, #20,
    'patient_cmb': 8,
    'max_epoch_cmb': 20,
    'batch_size': 64,
    'learning_rate': 1e-3,
    'step_size': 5,
    'dropout': 0.5,
    'LS': True,
    'LS_rate': 0.1,
    'save_path': '/content/drive/MyDrive/11777-Project-xs/LGG/save/',
    'load_path': '/content/drive/MyDrive/11777-Project-xs/LGG/save/max-acc.pth',
    'load_path_final': '/content/drive/MyDrive/11777-Project-xs/LGG/save/final_model.pth',
    'mlp_save_path': '/content/drive/MyDrive/11777-Project-xs/MLP/save/',
    'mlp_load_path': '/content/drive/MyDrive/11777-Project-xs/MLP/save/max-acc.pth',
    'mlp_load_path_final': '/content/drive/MyDrive/11777-Project-xs/MLP/save/final_model.pth',
    'gpu': '0',
    'save_model': True,
    'model': 'LGGNet',
    'pool': 16,
    'pool_step_rate': 0.25,
    'T': 64,
    'graph_type': 'hem',
    'hidden': 32
}

# %%
######## Reproduce the result using the saved model ######
# parser.add_argument('--reproduce', action='store_true')
# args = parser.parse_args()
class Args:
    def __init__(self, param_dict):
        for key, value in param_dict.items():
            setattr(self, key, value)

default_args['data_path'] = '/content/drive/MyDrive/11777-Project-xs/data_preprocessed_python/'
default_args['reproduce'] = 'store_true'
# Create an Args object with default parameters
args = Args(default_args)

# %%
# only need to run once
sub_to_run = np.arange(args.subjects)
prepdt = PrepareData(args)
prepdt.run(sub_to_run, split=True, expand=True)
# Out:
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------

# %%
participant_ids = list(range(1, 23))
data_save_folder = '/content/drive/MyDrive/11777-Project-xs/data_face_seg_mean'

def delete_file(path):
    '''
    used to remove temporal file generated
    '''
    if os.path.exists(path):
        os.remove(path)

# # only need to run once
# for participant_id in auto.tqdm(participant_ids):
#     participant_id = '{:02d}'.format(participant_id)
#     for trial_id in auto.tqdm(range(1, 41)):
#         file_name = 's{0}_trial{1}_mean_frames.npy'.format(participant_id, trial_id)
#         if not os.path.exists(os.path.join(data_save_folder, file_name)):
#             print('No face data found for s{0}_trial{1}'.format(participant_id, trial_id))
#             continue

#         file_name2 = 's{0}_trial{1}_mean_frames_embed.npy'.format(participant_id, trial_id)
#         if os.path.exists(os.path.join(data_save_folder, file_name2)):
#             continue
#         participant_trial_seg = np.load(os.path.join(data_save_folder, file_name))
#         participant_trial_embed = []
#         for image in participant_trial_seg:
#             delete_file('curr_face_image.png')
#             plt.imsave('curr_face_image.png', np.uint8(participant_trial_seg[0]),
#                        cmap=plt.cm.Spectral)
#             embedding_objs = DeepFace.represent(img_path = 'curr_face_image.png', enforce_detection = False)
#             embedding = embedding_objs[0]['embedding']
#             assert isinstance(embedding, list)
#             assert len(embedding) == 2622
#             participant_trial_embed.append(np.array(embedding))

#         participant_trial_embed = np.stack(participant_trial_embed, axis=0)
#         np.save(os.path.join(data_save_folder, file_name2), participant_trial_embed)

# %%
import os
data_save_folder = '/content/drive/MyDrive/11777-Project-xs/data_face_seg_mean'
face_embed_file_list = os.listdir(data_save_folder)
# print(len(face_embed_file_list))
face_embed_file_list = [e for e in face_embed_file_list if 'embed.npy' in e]
sub_trial_list = {}
for file in face_embed_file_list:
    # print(file)
    sub, trial, _, _, _ = file.split('_')
    sub, trial = int(sub[1:]), int(trial[5:])
    if sub in sub_trial_list.keys():
        sub_trial_list[sub].append(trial)
    else:
        sub_trial_list[sub] = [trial]

for sub in range(1,23):
    print('sub {}, {} trials with facial video'.format(sub, len(sub_trial_list[sub])))
# Out:
# sub 1, 40 trials with facial video
# sub 2, 40 trials with facial video
# sub 3, 39 trials with facial video
# sub 4, 40 trials with facial video
# sub 5, 39 trials with facial video
# sub 6, 40 trials with facial video
# sub 7, 40 trials with facial video
# sub 8, 40 trials with facial video
# sub 9, 40 trials with facial video
# sub 10, 40 trials with facial video
# sub 11, 37 trials with facial video
# sub 12, 40 trials with facial video
# sub 13, 40 trials with facial video
# sub 14, 39 trials with facial video
# sub 15, 40 trials with facial video
# sub 16, 40 trials with facial video
# sub 17, 40 trials with facial video
# sub 18, 40 trials with facial video
# sub 19, 40 trials with facial video
# sub 20, 40 trials with facial video
# sub 21, 40 trials with facial video
# sub 22, 40 trials with facial video

# %%
def load_mean_frames_embed(sub, data_save_folder):
    '''
    sub starting index from 1 (not 0)
    '''
    face_embed_file_list = os.listdir(data_save_folder)
    sub_face_embed_file_list = [e for e in face_embed_file_list if 'embed' in e and sub==int(e[1:3])]
    sorted(sub_face_embed_file_list)
    # print(sub_face_embed_file_list)
    sub_frame_embed = []
    for file in auto.tqdm(sub_face_embed_file_list):
        embed = np.load(os.path.join(data_save_folder, file))
        sub_frame_embed.append(embed)
    sub_frame_embed = np.stack(sub_frame_embed, axis=0)
    print(sub_frame_embed.shape)
    return sub_frame_embed

# 's01_trial1_mean_frames_embed.npy'

data_save_folder = '/content/drive/MyDrive/11777-Project-xs/data_face_seg_mean'
all_sub_frame_embed = []
for sub in auto.tqdm(range(1,23)):
    sub_frame_embed = load_mean_frames_embed(sub, data_save_folder)
    all_sub_frame_embed.append(sub_frame_embed)
# Out:
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/39 [00:00<?, ?it/s]
# (39, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/39 [00:00<?, ?it/s]
# (39, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/37 [00:00<?, ?it/s]
# (37, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/39 [00:00<?, ?it/s]
# (39, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)

# %%
import pickle
file_name = 'all_sub_frame_embed.pkl'
# with open(os.path.join(data_save_folder, file_name), 'wb') as file:
#     pickle.dump(all_sub_frame_embed, file)

with open(os.path.join(data_save_folder, file_name), 'rb') as file:
    all_sub_frame_embed = pickle.load(file)

# %%
def generate_eeg_embed(eeg_data, LGG, CUDA=True):
    LGG.eval()
    eeg_embed = []
    # eeg_data = np.concatenate(eeg_data, axis=0)
    for eeg_data_trial in eeg_data:
        eeg_data_trial = torch.from_numpy(eeg_data_trial).float()
        if CUDA:
            eeg_data_trial = eeg_data_trial.cuda()
            LGG = LGG.cuda()
        with torch.no_grad():
            eeg_embed_trial = LGG.get_embed(eeg_data_trial)
        eeg_embed_trial = eeg_embed_trial.to('cpu')
        eeg_embed_trial = eeg_embed_trial.numpy()
        eeg_embed.append(eeg_embed_trial)
    eeg_embed = np.stack(eeg_embed, axis=0)
    return eeg_embed

# %%
def get_model_embed(args):
    if args.model == 'LGGNet':
        idx_local_graph = list(np.array(h5py.File('num_chan_local_graph_{}.hdf'.format(args.graph_type), 'r')['data']))
        channels = sum(idx_local_graph)
        input_size = (args.input_shape[0], channels, args.input_shape[2])
        model = LGGNet2(
            num_classes=args.num_class, input_size=input_size,
            sampling_rate=int(args.sampling_rate*args.scale_coefficient),
            num_T=args.T, out_graph=args.hidden,
            dropout_rate=args.dropout,
            pool=args.pool, pool_step_rate=args.pool_step_rate,
            idx_graph=idx_local_graph)

    return model

def transfer_weight(LGG, LGG_embed):
    for i, (pre_trained_layer, custom_layer) in enumerate(zip(LGG.children(), LGG_embed.children())):
        custom_layer.load_state_dict(pre_trained_layer.state_dict())
    return LGG_embed

# %%
all_sub_frame_embed[sub].shape
# Out:
# (40, 15, 2622)

# %%
import torch
import torch.nn as nn

class SimpleMLP(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, dropout_prob=0.5):
        super(SimpleMLP, self).__init__()
        # Input layer
        self.input_layer = nn.Linear(input_dim, hidden_dim)
        # Hidden layer
        self.hidden_layer = nn.Linear(hidden_dim, hidden_dim)
        # Output layer
        self.output_layer = nn.Linear(hidden_dim, output_dim)
        # Dropout layer
        self.dropout = nn.Dropout(p=dropout_prob)

    def forward(self, x):
        # Input layer
        x = self.input_layer(x)
        x = torch.relu(x)

        # Hidden layer with dropout
        x = self.hidden_layer(x)
        x = torch.relu(x)
        x = self.dropout(x)

        # Output layer
        x = self.output_layer(x)
        return x

# %%
from utils import *
import torch.nn as nn

CUDA = torch.cuda.is_available()

def mlp_set_up(args):
    set_gpu(args.gpu)
    ensure_path(args.mlp_save_path)
    torch.manual_seed(args.random_seed)
    torch.backends.cudnn.deterministic = True

def train_simpleMLP(model, args, data_train, label_train, data_val, label_val, subject):
    seed_all(args.random_seed)
    save_name = '_sub' + str(subject) + '_mlp'
    mlp_set_up(args)

    train_loader = get_dataloader(data_train, label_train, args.batch_size)

    val_loader = get_dataloader(data_val, label_val, args.batch_size)

    # model = get_model(args)
    if CUDA:
        model = model.cuda()

    optimizer = torch.optim.Adam(model.parameters(), lr=args.learning_rate)

    if args.LS:
        loss_fn = LabelSmoothing(args.LS_rate)
    else:
        loss_fn = nn.CrossEntropyLoss()


    def save_model(name):
        previous_model = osp.join(args.mlp_save_path, '{}.pth'.format(name))
        if os.path.exists(previous_model):
            os.remove(previous_model)
        torch.save(model.state_dict(), osp.join(args.mlp_save_path, '{}.pth'.format(name)))

    trlog = {}
    trlog['args'] = vars(args)
    trlog['train_loss'] = []
    trlog['val_loss'] = []
    trlog['train_acc'] = []
    trlog['val_acc'] = []
    trlog['max_acc'] = 0.0
    trlog['F1'] = 0.0

    timer = Timer()
    patient = args.patient
    counter = 0

    for epoch in range(1, args.max_epoch + 1):

        loss_train, pred_train, act_train = train_one_epoch(
            data_loader=train_loader, net=model, loss_fn=loss_fn, optimizer=optimizer)

        acc_train, f1_train, _ = get_metrics(y_pred=pred_train, y_true=act_train)
        print('epoch {}, loss={:.4f} acc={:.4f} f1={:.4f}'
              .format(epoch, loss_train, acc_train, f1_train))

        loss_val, pred_val, act_val = predict(
            data_loader=val_loader, net=model, loss_fn=loss_fn
        )
        acc_val, f1_val, _ = get_metrics(y_pred=pred_val, y_true=act_val)
        print('epoch {}, val, loss={:.4f} acc={:.4f} f1={:.4f}'.
              format(epoch, loss_val, acc_val, f1_val))

        if acc_val >= trlog['max_acc']:
            trlog['max_acc'] = acc_val
            trlog['F1'] = f1_val
            save_model('candidate')
            counter = 0
        else:
            counter += 1
            if counter >= patient:
                print('early stopping')
                break

        trlog['train_loss'].append(loss_train)
        trlog['train_acc'].append(acc_train)
        trlog['val_loss'].append(loss_val)
        trlog['val_acc'].append(acc_val)

        print('ETA:{}/{} SUB:{}'.format(timer.measure(), timer.measure(epoch / args.max_epoch),
                                                 subject))
    # save the training log file
    save_name = 'trlog' + save_name
    experiment_setting = 'T_{}_pool_{}'.format(args.T, args.pool)
    save_path = osp.join(args.mlp_save_path, experiment_setting, 'log_train')
    ensure_path(save_path)
    torch.save(trlog, osp.join(save_path, save_name))

    return trlog['max_acc'], trlog['F1']

# %%
def test_simpleMLP(model, args, data, label, reproduce, subject):
    set_up(args)
    seed_all(args.random_seed)
    test_loader = get_dataloader(data, label, args.batch_size)

    # model = get_model(args)
    if CUDA:
        model = model.cuda()
    loss_fn = nn.CrossEntropyLoss()

    if reproduce:
        model_name_reproduce = 'sub' + str(subject) + '_mlp' + '.pth'
        data_type = 'model_{}_{}'.format(args.data_format, args.label_type)
        experiment_setting = 'T_{}_pool_{}'.format(args.T, args.pool)
        load_path_final = osp.join(args.mlp_save_path, experiment_setting, data_type, model_name_reproduce)
        model.load_state_dict(torch.load(load_path_final))
    else:
        model.load_state_dict(torch.load(args.mlp_load_path_final))
    loss, pred, act = predict(
        data_loader=test_loader, net=model, loss_fn=loss_fn
    )
    acc, f1, cm = get_metrics(y_pred=pred, y_true=act)
    print('>>> Test:  loss={:.4f} acc={:.4f} f1={:.4f}'.format(loss, acc, f1))
    return acc, pred, act

# %%
CUDA = torch.cuda.is_available()
fold = 'noFold'

with open(os.path.join(data_save_folder, file_name), 'rb') as file:
    all_sub_frame_embed = pickle.load(file)

for sub in range(22):

    print('='*48)
    cv = CrossValidation(args)
    eeg_data, label = cv.load_per_subject(sub)
    trial_to_remove = [i-1 for i in range(1,41) if i not in sub_trial_list[sub+1]]
    ### face embeddings
    sub_frame_embed = all_sub_frame_embed[sub]

    if len(trial_to_remove) > 0:
        mask = np.ones(eeg_data.shape[0], dtype=bool)
        mask[trial_to_remove] = False
        eeg_data = eeg_data[mask]
        label = label[mask]

    ### Load pre-trained LGG model weights
    ### and generate the EEG embeddings
    lgg_model = get_model(args)
    lgg_model_embed = get_model_embed(args)
    if CUDA:
        lgg_model = lgg_model.cuda()
    model_name_reproduce = 'sub' + str(sub+1) + '.pth'
    data_type = 'model_{}_{}'.format(args.data_format, args.label_type)
    experiment_setting = 'T_{}_pool_{}'.format(args.T, args.pool)
    save_path = os.path.join(args.save_path, experiment_setting, data_type)
    ensure_path(save_path)
    model_name_reproduce = os.path.join(save_path, model_name_reproduce)
    lgg_model.load_state_dict(torch.load(model_name_reproduce))
    lgg_model_embed = transfer_weight(lgg_model, lgg_model_embed)
    eeg_embed = generate_eeg_embed(eeg_data, lgg_model_embed, CUDA)

    ### concat eeg + face embedding
    eeg_face_embed = np.concatenate([eeg_embed, sub_frame_embed], axis=2)

    print(sub+1, trial_to_remove, sub_frame_embed.shape[0])
    trial_id = np.arange(eeg_data.shape[0])
    trial_id_train, trial_id_test = train_test_split(trial_id, test_size=0.2, random_state=42)
    trial_id_tra, trial_id_val = train_test_split(trial_id_train, test_size=0.2, random_state=42)
    print(trial_id_tra.shape[0], trial_id_val.shape[0], trial_id_test.shape[0])

    data_train, data_val, label_train, label_val = \
        eeg_face_embed[trial_id_tra], eeg_face_embed[trial_id_val], label[trial_id_tra], label[trial_id_val]
    data_train, data_val, label_train, label_val = \
        np.concatenate(data_train, axis=0), np.concatenate(data_val, axis=0), np.concatenate(label_train, axis=0), np.concatenate(label_val, axis=0)
    print(data_train.shape, data_val.shape, label_train.shape, label_val.shape)

    data_test, label_test = \
        eeg_face_embed[trial_id_test], label[trial_id_test]
    data_test, label_test = \
        np.concatenate(data_test, axis=0), np.concatenate(label_test, axis=0)
    print(data_test.shape, label_test.shape)

    data_train = torch.from_numpy(data_train).float()
    label_train = torch.from_numpy(label_train).long()
    data_val = torch.from_numpy(data_val).float()
    label_val = torch.from_numpy(label_val).long()
    data_test = torch.from_numpy(data_test).float()
    label_test = torch.from_numpy(label_test).long()


    ### define a simple MLP as the predictor
    predictor = SimpleMLP(data_train.shape[1], data_train.shape[1] // 4, 2)

    acc_val, F1_val = train_simpleMLP(model=predictor, args=args,
                                      data_train=data_train,
                                      label_train=label_train,
                                      data_val=data_val,
                                      label_val=label_val,
                                      subject = str(sub+1))

    if CUDA:
        predictor = predictor.cuda()
    predictor.load_state_dict(torch.load(os.path.join(args.mlp_save_path, 'candidate.pth')))

    model_name_reproduce = 'sub' + str(sub+1) + '_mlp.pth'
    data_type = 'model_{}_{}'.format(args.data_format, args.label_type)
    experiment_setting = 'T_{}_pool_{}'.format(args.T, args.pool)
    save_path = os.path.join(args.mlp_save_path, experiment_setting, data_type)
    ensure_path(save_path)
    model_name_reproduce = os.path.join(save_path, model_name_reproduce)
    print(model_name_reproduce)
    torch.save(predictor.state_dict(), model_name_reproduce)

    acc_test, pred, act = test_simpleMLP(model=predictor, args=args, data=data_test, label=label_test,
                                               reproduce=args.reproduce,
                                               subject=str(sub+1))
# Out:
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 1 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss=0.7542 acc=0.5147 f1=0.3636
# epoch 1, val, loss=0.7085 acc=0.4286 f1=0.6000
# ETA:0s/4s SUB:1
# epoch 2, loss=0.7127 acc=0.4960 f1=0.4960
# epoch 2, val, loss=0.6825 acc=0.5714 f1=0.0000
# ETA:0s/4s SUB:1
# epoch 3, loss=0.6682 acc=0.6293 f1=0.6128
# epoch 3, val, loss=0.6876 acc=0.5714 f1=0.2623
# ETA:0s/4s SUB:1
# epoch 4, loss=0.6423 acc=0.6667 f1=0.6313
# epoch 4, val, loss=0.7070 acc=0.5714 f1=0.1509
# ETA:0s/4s SUB:1
# epoch 5, loss=0.6018 acc=0.7013 f1=0.6706
# epoch 5, val, loss=0.7587 acc=0.5619 f1=0.0800
# ETA:0s/4s SUB:1
# epoch 6, loss=0.5499 acc=0.7573 f1=0.7284
# epoch 6, val, loss=0.7576 acc=0.4762 f1=0.2667
# ETA:0s/3s SUB:1
# epoch 7, loss=0.5163 acc=0.7733 f1=0.7522
# epoch 7, val, loss=0.9109 acc=0.4667 f1=0.5484
# ETA:0s/3s SUB:1
# epoch 8, loss=0.5150 acc=0.7573 f1=0.7560
# epoch 8, val, loss=0.8936 acc=0.4952 f1=0.5138
# ETA:0s/3s SUB:1
# epoch 9, loss=0.4810 acc=0.7893 f1=0.7775
# epoch 9, val, loss=0.8547 acc=0.4857 f1=0.3864
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_V/sub1_mlp.pth
# using gpu: 0
# >>> Test:  loss=0.7308 acc=0.4917 f1=0.1644
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 2 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss=0.7104 acc=0.4987 f1=0.4689
# epoch 1, val, loss=0.8170 acc=0.2857 f1=0.0000
# ETA:0s/3s SUB:2
# epoch 2, loss=0.6964 acc=0.5387 f1=0.3843
# epoch 2, val, loss=0.6738 acc=0.7143 f1=0.8333
# ETA:0s/3s SUB:2
# epoch 3, loss=0.6874 acc=0.5547 f1=0.5499
# epoch 3, val, loss=0.7113 acc=0.2857 f1=0.0000
# ETA:0s/3s SUB:2
# epoch 4, loss=0.7017 acc=0.4800 f1=0.3390
# epoch 4, val, loss=0.7097 acc=0.2857 f1=0.0000
# ETA:0s/2s SUB:2
# epoch 5, loss=0.6866 acc=0.5573 f1=0.3852
# epoch 5, val, loss=0.7085 acc=0.2857 f1=0.0000
# ETA:0s/2s SUB:2
# epoch 6, loss=0.6859 acc=0.5547 f1=0.4525
# epoch 6, val, loss=0.7235 acc=0.2857 f1=0.0000
# ETA:0s/2s SUB:2
# epoch 7, loss=0.6795 acc=0.5707 f1=0.5076
# epoch 7, val, loss=0.6989 acc=0.4952 f1=0.5225
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_V/sub2_mlp.pth
# using gpu: 0
# >>> Test:  loss=0.6798 acc=0.6250 f1=0.7692
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 3 [39] 39
# 24 7 8
# (360, 3166) (105, 3166) (360,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss=0.7875 acc=0.5500 f1=0.6068
# epoch 1, val, loss=0.6791 acc=0.5714 f1=0.0000
# ETA:0s/3s SUB:3
# epoch 2, loss=0.7030 acc=0.5389 f1=0.5871
# epoch 2, val, loss=0.7323 acc=0.4286 f1=0.6000
# ETA:0s/2s SUB:3
# epoch 3, loss=0.6646 acc=0.6278 f1=0.6546
# epoch 3, val, loss=0.7531 acc=0.4286 f1=0.6000
# ETA:0s/2s SUB:3
# epoch 4, loss=0.6618 acc=0.6000 f1=0.6651
# epoch 4, val, loss=0.6984 acc=0.5714 f1=0.5714
# ETA:0s/2s SUB:3
# epoch 5, loss=0.5985 acc=0.7028 f1=0.7517
# epoch 5, val, loss=0.6933 acc=0.5619 f1=0.3611
# ETA:0s/2s SUB:3
# epoch 6, loss=0.5674 acc=0.7194 f1=0.7377
# epoch 6, val, loss=0.7032 acc=0.6000 f1=0.4474
# ETA:0s/2s SUB:3
# epoch 7, loss=0.4946 acc=0.7972 f1=0.8094
# epoch 7, val, loss=0.8167 acc=0.5619 f1=0.6290
# ETA:0s/2s SUB:3
# epoch 8, loss=0.4377 acc=0.8611 f1=0.8724
# epoch 8, val, loss=1.1862 acc=0.4667 f1=0.6111
# ETA:0s/2s SUB:3
# epoch 9, loss=0.4556 acc=0.8278 f1=0.8434
# epoch 9, val, loss=0.7883 acc=0.6190 f1=0.6000
# ETA:0s/2s SUB:3
# epoch 10, loss=0.3661 acc=0.8917 f1=0.8992
# epoch 10, val, loss=1.0451 acc=0.5238 f1=0.6269
# ETA:0s/2s SUB:3
# epoch 11, loss=0.3712 acc=0.8944 f1=0.9036
# epoch 11, val, loss=0.9323 acc=0.5429 f1=0.6000
# ETA:0s/2s SUB:3
# epoch 12, loss=0.3328 acc=0.9222 f1=0.9286
# epoch 12, val, loss=0.8661 acc=0.5714 f1=0.5794
# ETA:0s/2s SUB:3
# epoch 13, loss=0.3393 acc=0.9167 f1=0.9242
# epoch 13, val, loss=0.8204 acc=0.6381 f1=0.5476
# ETA:0s/2s SUB:3
# epoch 14, loss=0.3688 acc=0.8778 f1=0.8842
# epoch 14, val, loss=0.8426 acc=0.6000 f1=0.5882
# ETA:0s/2s SUB:3
# epoch 15, loss=0.3409 acc=0.9222 f1=0.9282
# epoch 15, val, loss=1.1059 acc=0.5048 f1=0.6176
# ETA:0s/2s SUB:3
# epoch 16, loss=0.3344 acc=0.9194 f1=0.9270
# epoch 16, val, loss=1.0658 acc=0.5238 f1=0.6269
# ETA:0s/2s SUB:3
# epoch 17, loss=0.3367 acc=0.8972 f1=0.9077
# epoch 17, val, loss=0.8296 acc=0.5905 f1=0.5567
# ETA:0s/2s SUB:3
# epoch 18, loss=0.2891 acc=0.9583 f1=0.9612
# epoch 18, val, loss=0.8658 acc=0.6000 f1=0.5882
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_V/sub3_mlp.pth
# using gpu: 0
# >>> Test:  loss=1.2450 acc=0.4833 f1=0.4464
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 4 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss=0.6824 acc=0.6293 f1=0.0544
# epoch 1, val, loss=0.7335 acc=0.4286 f1=0.0000
# ETA:0s/3s SUB:4
# epoch 2, loss=0.6609 acc=0.6400 f1=0.0000
# epoch 2, val, loss=0.7626 acc=0.4286 f1=0.0000
# ETA:0s/3s SUB:4
# epoch 3, loss=0.6663 acc=0.6293 f1=0.0280
# epoch 3, val, loss=0.7261 acc=0.4286 f1=0.0000
# ETA:0s/3s SUB:4
# epoch 4, loss=0.6570 acc=0.6453 f1=0.0292
# epoch 4, val, loss=0.7571 acc=0.4286 f1=0.0000
# ETA:0s/3s SUB:4
# epoch 5, loss=0.6548 acc=0.6400 f1=0.0000
# epoch 5, val, loss=0.7455 acc=0.4286 f1=0.0000
# ETA:0s/3s SUB:4
# epoch 6, loss=0.6422 acc=0.6480 f1=0.0435
# epoch 6, val, loss=0.7395 acc=0.4286 f1=0.0000
# ETA:0s/3s SUB:4
# epoch 7, loss=0.6214 acc=0.6720 f1=0.1633
# epoch 7, val, loss=0.8123 acc=0.4286 f1=0.0000
# ETA:0s/3s SUB:4
# epoch 8, loss=0.6309 acc=0.6667 f1=0.4589
# epoch 8, val, loss=0.7104 acc=0.4286 f1=0.3478
# ETA:0s/3s SUB:4
# epoch 9, loss=0.5863 acc=0.6933 f1=0.2581
# epoch 9, val, loss=0.6903 acc=0.5714 f1=0.7059
# ETA:0s/3s SUB:4
# epoch 10, loss=0.5682 acc=0.7520 f1=0.5327
# epoch 10, val, loss=0.6903 acc=0.5810 f1=0.6765
# ETA:0s/3s SUB:4
# epoch 11, loss=0.5269 acc=0.7840 f1=0.6233
# epoch 11, val, loss=0.7189 acc=0.5905 f1=0.7114
# ETA:0s/3s SUB:4
# epoch 12, loss=0.4880 acc=0.8027 f1=0.6810
# epoch 12, val, loss=0.7580 acc=0.5714 f1=0.7020
# ETA:0s/3s SUB:4
# epoch 13, loss=0.4798 acc=0.8080 f1=0.7209
# epoch 13, val, loss=0.7711 acc=0.5810 f1=0.6508
# ETA:0s/3s SUB:4
# epoch 14, loss=0.5566 acc=0.7600 f1=0.6691
# epoch 14, val, loss=0.7483 acc=0.5429 f1=0.5714
# ETA:0s/3s SUB:4
# epoch 15, loss=0.4767 acc=0.8080 f1=0.7049
# epoch 15, val, loss=0.7660 acc=0.5810 f1=0.6615
# ETA:0s/3s SUB:4
# epoch 16, loss=0.4248 acc=0.8507 f1=0.7500
# epoch 16, val, loss=0.7585 acc=0.6000 f1=0.7200
# ETA:1s/3s SUB:4
# epoch 17, loss=0.4011 acc=0.8827 f1=0.8211
# epoch 17, val, loss=0.7765 acc=0.6381 f1=0.7500
# ETA:1s/3s SUB:4
# epoch 18, loss=0.4077 acc=0.8533 f1=0.7843
# epoch 18, val, loss=0.7951 acc=0.6000 f1=0.7042
# ETA:1s/3s SUB:4
# epoch 19, loss=0.3657 acc=0.8960 f1=0.8494
# epoch 19, val, loss=0.7949 acc=0.5905 f1=0.6325
# ETA:1s/3s SUB:4
# epoch 20, loss=0.3785 acc=0.8667 f1=0.8016
# epoch 20, val, loss=0.8093 acc=0.6000 f1=0.7042
# ETA:1s/3s SUB:4
# epoch 21, loss=0.3354 acc=0.9307 f1=0.9044
# epoch 21, val, loss=0.8031 acc=0.6000 f1=0.6866
# ETA:1s/3s SUB:4
# epoch 22, loss=0.3366 acc=0.9120 f1=0.8745
# epoch 22, val, loss=0.8725 acc=0.6476 f1=0.7582
# ETA:1s/3s SUB:4
# epoch 23, loss=0.3554 acc=0.9067 f1=0.8718
# epoch 23, val, loss=0.7690 acc=0.6286 f1=0.7068
# ETA:1s/3s SUB:4
# epoch 24, loss=0.3286 acc=0.9200 f1=0.8864
# epoch 24, val, loss=0.8139 acc=0.6000 f1=0.6111
# ETA:1s/3s SUB:4
# epoch 25, loss=0.3410 acc=0.9120 f1=0.8696
# epoch 25, val, loss=0.7570 acc=0.6476 f1=0.7259
# ETA:1s/3s SUB:4
# epoch 26, loss=0.3471 acc=0.9120 f1=0.8736
# epoch 26, val, loss=0.8578 acc=0.6286 f1=0.7484
# ETA:1s/3s SUB:4
# epoch 27, loss=0.3261 acc=0.9253 f1=0.8947
# epoch 27, val, loss=0.7971 acc=0.6571 f1=0.7600
# ETA:1s/3s SUB:4
# epoch 28, loss=0.3273 acc=0.9173 f1=0.8881
# epoch 28, val, loss=0.7460 acc=0.6571 f1=0.7143
# ETA:1s/3s SUB:4
# epoch 29, loss=0.2873 acc=0.9493 f1=0.9283
# epoch 29, val, loss=0.7450 acc=0.6667 f1=0.7328
# ETA:1s/3s SUB:4
# epoch 30, loss=0.2901 acc=0.9547 f1=0.9368
# epoch 30, val, loss=0.7624 acc=0.6286 f1=0.6422
# ETA:1s/3s SUB:4
# epoch 31, loss=0.2881 acc=0.9600 f1=0.9442
# epoch 31, val, loss=0.7614 acc=0.6190 f1=0.6226
# ETA:1s/3s SUB:4
# epoch 32, loss=0.2999 acc=0.9440 f1=0.9202
# epoch 32, val, loss=0.8409 acc=0.5810 f1=0.5686
# ETA:1s/3s SUB:4
# epoch 33, loss=0.3242 acc=0.9253 f1=0.8947
# epoch 33, val, loss=0.7332 acc=0.6381 f1=0.6885
# ETA:2s/3s SUB:4
# epoch 34, loss=0.2966 acc=0.9387 f1=0.9112
# epoch 34, val, loss=0.7556 acc=0.6762 f1=0.7536
# ETA:2s/3s SUB:4
# epoch 35, loss=0.2968 acc=0.9413 f1=0.9185
# epoch 35, val, loss=0.8282 acc=0.6667 f1=0.7651
# ETA:2s/3s SUB:4
# epoch 36, loss=0.2818 acc=0.9547 f1=0.9373
# epoch 36, val, loss=0.8571 acc=0.6667 f1=0.7651
# ETA:2s/3s SUB:4
# epoch 37, loss=0.2787 acc=0.9600 f1=0.9430
# epoch 37, val, loss=0.8429 acc=0.6571 f1=0.7568
# ETA:2s/2s SUB:4
# epoch 38, loss=0.2962 acc=0.9360 f1=0.9104
# epoch 38, val, loss=1.0797 acc=0.6286 f1=0.7516
# ETA:2s/2s SUB:4
# epoch 39, loss=0.3673 acc=0.8960 f1=0.8528
# epoch 39, val, loss=0.9038 acc=0.6286 f1=0.7484
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_V/sub4_mlp.pth
# using gpu: 0
# >>> Test:  loss=0.8043 acc=0.5333 f1=0.4717
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 5 [39] 39
# 24 7 8
# (360, 3166) (105, 3166) (360,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss=0.7184 acc=0.4972 f1=0.5299
# epoch 1, val, loss=0.6938 acc=0.5238 f1=0.5000
# ETA:0s/5s SUB:5
# epoch 2, loss=0.6927 acc=0.5361 f1=0.6782
# epoch 2, val, loss=0.6562 acc=0.7143 f1=0.8333
# ETA:0s/4s SUB:5
# epoch 3, loss=0.6847 acc=0.5611 f1=0.5611
# epoch 3, val, loss=0.6551 acc=0.6952 f1=0.8161
# ETA:0s/4s SUB:5
# epoch 4, loss=0.6733 acc=0.5583 f1=0.7061
# epoch 4, val, loss=0.6589 acc=0.6000 f1=0.6500
# ETA:0s/3s SUB:5
# epoch 5, loss=0.6486 acc=0.6528 f1=0.6612
# epoch 5, val, loss=0.6484 acc=0.5429 f1=0.5789
# ETA:0s/3s SUB:5
# epoch 6, loss=0.6255 acc=0.6722 f1=0.6974
# epoch 6, val, loss=0.6537 acc=0.5524 f1=0.5841
# ETA:0s/3s SUB:5
# epoch 7, loss=0.6011 acc=0.6722 f1=0.6758
# epoch 7, val, loss=0.6880 acc=0.5619 f1=0.5893
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_V/sub5_mlp.pth
# using gpu: 0
# >>> Test:  loss=0.6665 acc=0.6250 f1=0.7692
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 6 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss=0.6362 acc=0.6987 f1=0.8126
# epoch 1, val, loss=0.6244 acc=0.7143 f1=0.8333
# ETA:0s/3s SUB:6
# epoch 2, loss=0.6217 acc=0.7200 f1=0.8372
# epoch 2, val, loss=0.6241 acc=0.7143 f1=0.8333
# ETA:0s/3s SUB:6
# epoch 3, loss=0.6174 acc=0.7200 f1=0.8372
# epoch 3, val, loss=0.6247 acc=0.7143 f1=0.8333
# ETA:0s/3s SUB:6
# epoch 4, loss=0.6065 acc=0.7200 f1=0.8372
# epoch 4, val, loss=0.6199 acc=0.7143 f1=0.8333
# ETA:0s/4s SUB:6
# epoch 5, loss=0.6006 acc=0.7200 f1=0.8372
# epoch 5, val, loss=0.6229 acc=0.7143 f1=0.8333
# ETA:0s/4s SUB:6
# epoch 6, loss=0.6084 acc=0.7200 f1=0.8372
# epoch 6, val, loss=0.6179 acc=0.7143 f1=0.8333
# ETA:0s/4s SUB:6
# epoch 7, loss=0.5871 acc=0.7200 f1=0.8372
# epoch 7, val, loss=0.6373 acc=0.7143 f1=0.8333
# ETA:0s/4s SUB:6
# epoch 8, loss=0.5791 acc=0.7200 f1=0.8372
# epoch 8, val, loss=0.6533 acc=0.7143 f1=0.8333
# ETA:0s/4s SUB:6
# epoch 9, loss=0.5597 acc=0.7200 f1=0.8372
# epoch 9, val, loss=0.6700 acc=0.7143 f1=0.8333
# ETA:0s/4s SUB:6
# epoch 10, loss=0.5357 acc=0.7200 f1=0.8372
# epoch 10, val, loss=0.7390 acc=0.7143 f1=0.8333
# ETA:0s/4s SUB:6
# epoch 11, loss=0.5225 acc=0.7627 f1=0.8576
# epoch 11, val, loss=0.7526 acc=0.7143 f1=0.8333
# ETA:0s/4s SUB:6
# epoch 12, loss=0.4867 acc=0.8400 f1=0.8990
# epoch 12, val, loss=0.8326 acc=0.6952 f1=0.8202
# ETA:0s/3s SUB:6
# epoch 13, loss=0.4886 acc=0.8213 f1=0.8831
# epoch 13, val, loss=0.8830 acc=0.3429 f1=0.5106
# ETA:0s/3s SUB:6
# epoch 14, loss=0.4559 acc=0.8613 f1=0.9091
# epoch 14, val, loss=0.9775 acc=0.2857 f1=0.4444
# ETA:0s/3s SUB:6
# epoch 15, loss=0.4446 acc=0.8560 f1=0.9039
# epoch 15, val, loss=1.0253 acc=0.2857 f1=0.4444
# ETA:1s/3s SUB:6
# epoch 16, loss=0.4559 acc=0.8480 f1=0.8973
# epoch 16, val, loss=1.0281 acc=0.7143 f1=0.8333
# ETA:1s/3s SUB:6
# epoch 17, loss=0.4640 acc=0.8053 f1=0.8708
# epoch 17, val, loss=0.9398 acc=0.7143 f1=0.8333
# ETA:1s/3s SUB:6
# epoch 18, loss=0.4366 acc=0.8453 f1=0.8957
# epoch 18, val, loss=0.9261 acc=0.7143 f1=0.8333
# ETA:1s/3s SUB:6
# epoch 19, loss=0.4842 acc=0.7893 f1=0.8577
# epoch 19, val, loss=0.9389 acc=0.7143 f1=0.8333
# ETA:1s/3s SUB:6
# epoch 20, loss=0.4395 acc=0.8133 f1=0.8713
# epoch 20, val, loss=0.8747 acc=0.7143 f1=0.8333
# ETA:1s/3s SUB:6
# epoch 21, loss=0.4501 acc=0.8480 f1=0.8995
# epoch 21, val, loss=0.8640 acc=0.7048 f1=0.8268
# ETA:1s/3s SUB:6
# epoch 22, loss=0.4253 acc=0.8560 f1=0.9022
# epoch 22, val, loss=0.9265 acc=0.7143 f1=0.8333
# ETA:1s/3s SUB:6
# epoch 23, loss=0.4241 acc=0.8693 f1=0.9133
# epoch 23, val, loss=0.9468 acc=0.6762 f1=0.8068
# ETA:1s/3s SUB:6
# epoch 24, loss=0.3900 acc=0.8987 f1=0.9331
# epoch 24, val, loss=0.9541 acc=0.5905 f1=0.7425
# ETA:1s/3s SUB:6
# epoch 25, loss=0.3721 acc=0.9013 f1=0.9336
# epoch 25, val, loss=1.0003 acc=0.7143 f1=0.8333
# ETA:1s/3s SUB:6
# epoch 26, loss=0.4110 acc=0.8747 f1=0.9147
# epoch 26, val, loss=0.9441 acc=0.7143 f1=0.8333
# ETA:1s/3s SUB:6
# epoch 27, loss=0.3909 acc=0.8747 f1=0.9153
# epoch 27, val, loss=0.9570 acc=0.6762 f1=0.8068
# ETA:1s/3s SUB:6
# epoch 28, loss=0.3762 acc=0.9040 f1=0.9362
# epoch 28, val, loss=0.9618 acc=0.7143 f1=0.8333
# ETA:1s/3s SUB:6
# epoch 29, loss=0.3716 acc=0.9040 f1=0.9359
# epoch 29, val, loss=1.0380 acc=0.5048 f1=0.6709
# ETA:1s/3s SUB:6
# epoch 30, loss=0.3619 acc=0.8933 f1=0.9288
# epoch 30, val, loss=1.0132 acc=0.5619 f1=0.7195
# ETA:1s/3s SUB:6
# epoch 31, loss=0.3822 acc=0.8720 f1=0.9140
# epoch 31, val, loss=1.1042 acc=0.3905 f1=0.5616
# ETA:1s/3s SUB:6
# epoch 32, loss=0.3522 acc=0.8960 f1=0.9305
# epoch 32, val, loss=1.2716 acc=0.2857 f1=0.4444
# ETA:2s/3s SUB:6
# epoch 33, loss=0.3244 acc=0.9440 f1=0.9620
# epoch 33, val, loss=1.2838 acc=0.2857 f1=0.4444
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_V/sub6_mlp.pth
# using gpu: 0
# >>> Test:  loss=0.2645 acc=0.8750 f1=0.9333
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 7 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss=0.6610 acc=0.6213 f1=0.7568
# epoch 1, val, loss=0.6128 acc=0.7143 f1=0.8333
# ETA:0s/3s SUB:7
# epoch 2, loss=0.6456 acc=0.6827 f1=0.8108
# epoch 2, val, loss=0.6192 acc=0.7143 f1=0.8333
# ETA:0s/3s SUB:7
# epoch 3, loss=0.6452 acc=0.6827 f1=0.8108
# epoch 3, val, loss=0.6189 acc=0.7143 f1=0.8333
# ETA:0s/3s SUB:7
# epoch 4, loss=0.6402 acc=0.6827 f1=0.8108
# epoch 4, val, loss=0.6064 acc=0.7143 f1=0.8333
# ETA:0s/3s SUB:7
# epoch 5, loss=0.6295 acc=0.6800 f1=0.8095
# epoch 5, val, loss=0.6242 acc=0.7143 f1=0.8333
# ETA:0s/3s SUB:7
# epoch 6, loss=0.6192 acc=0.6800 f1=0.8095
# epoch 6, val, loss=0.6182 acc=0.7143 f1=0.8333
# ETA:0s/3s SUB:7
# epoch 7, loss=0.5981 acc=0.6800 f1=0.8095
# epoch 7, val, loss=0.6208 acc=0.7143 f1=0.8333
# ETA:0s/3s SUB:7
# epoch 8, loss=0.6007 acc=0.7173 f1=0.8245
# epoch 8, val, loss=0.6589 acc=0.7143 f1=0.8333
# ETA:0s/3s SUB:7
# epoch 9, loss=0.5850 acc=0.7440 f1=0.8356
# epoch 9, val, loss=0.6033 acc=0.7143 f1=0.8333
# ETA:0s/3s SUB:7
# epoch 10, loss=0.5684 acc=0.7413 f1=0.8381
# epoch 10, val, loss=0.6719 acc=0.5714 f1=0.6667
# ETA:0s/3s SUB:7
# epoch 11, loss=0.5821 acc=0.7440 f1=0.8273
# epoch 11, val, loss=0.6108 acc=0.7143 f1=0.8333
# ETA:0s/3s SUB:7
# epoch 12, loss=0.5413 acc=0.7760 f1=0.8433
# epoch 12, val, loss=0.6588 acc=0.7143 f1=0.8333
# ETA:0s/3s SUB:7
# epoch 13, loss=0.5174 acc=0.7813 f1=0.8498
# epoch 13, val, loss=0.6046 acc=0.7143 f1=0.8333
# ETA:0s/3s SUB:7
# epoch 14, loss=0.4740 acc=0.8187 f1=0.8773
# epoch 14, val, loss=0.6025 acc=0.8571 f1=0.9091
# ETA:1s/3s SUB:7
# epoch 15, loss=0.4686 acc=0.8187 f1=0.8697
# epoch 15, val, loss=0.6132 acc=0.8571 f1=0.9091
# ETA:1s/3s SUB:7
# epoch 16, loss=0.4389 acc=0.8427 f1=0.8880
# epoch 16, val, loss=0.6203 acc=0.6286 f1=0.7234
# ETA:1s/3s SUB:7
# epoch 17, loss=0.4496 acc=0.8427 f1=0.8880
# epoch 17, val, loss=0.6493 acc=0.5714 f1=0.6667
# ETA:1s/3s SUB:7
# epoch 18, loss=0.4369 acc=0.8373 f1=0.8834
# epoch 18, val, loss=0.5801 acc=0.8571 f1=0.9091
# ETA:1s/3s SUB:7
# epoch 19, loss=0.4278 acc=0.8400 f1=0.8828
# epoch 19, val, loss=0.6427 acc=0.7143 f1=0.8333
# ETA:1s/3s SUB:7
# epoch 20, loss=0.4126 acc=0.8400 f1=0.8859
# epoch 20, val, loss=0.6373 acc=0.7143 f1=0.8333
# ETA:1s/3s SUB:7
# epoch 21, loss=0.3888 acc=0.8907 f1=0.9228
# epoch 21, val, loss=0.5803 acc=0.8571 f1=0.9091
# ETA:1s/3s SUB:7
# epoch 22, loss=0.3778 acc=0.8667 f1=0.9016
# epoch 22, val, loss=0.5736 acc=0.8571 f1=0.9091
# ETA:1s/3s SUB:7
# epoch 23, loss=0.3541 acc=0.8987 f1=0.9252
# epoch 23, val, loss=0.5833 acc=0.8476 f1=0.9036
# ETA:1s/3s SUB:7
# epoch 24, loss=0.3964 acc=0.8427 f1=0.8850
# epoch 24, val, loss=0.5789 acc=0.7143 f1=0.8000
# ETA:1s/3s SUB:7
# epoch 25, loss=0.3538 acc=0.8960 f1=0.9225
# epoch 25, val, loss=0.6062 acc=0.8476 f1=0.9036
# ETA:1s/3s SUB:7
# epoch 26, loss=0.3393 acc=0.9147 f1=0.9365
# epoch 26, val, loss=0.6974 acc=0.7143 f1=0.8333
# ETA:1s/3s SUB:7
# epoch 27, loss=0.3238 acc=0.9120 f1=0.9347
# epoch 27, val, loss=0.5930 acc=0.8286 f1=0.8929
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_V/sub7_mlp.pth
# using gpu: 0
# >>> Test:  loss=0.3663 acc=0.7500 f1=0.8333
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 8 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss=0.7359 acc=0.4960 f1=0.5091
# epoch 1, val, loss=0.6863 acc=0.5714 f1=0.7273
# ETA:0s/3s SUB:8
# epoch 2, loss=0.6759 acc=0.5867 f1=0.6830
# epoch 2, val, loss=0.6713 acc=0.5905 f1=0.7261
# ETA:0s/3s SUB:8
# epoch 3, loss=0.5983 acc=0.7227 f1=0.7895
# epoch 3, val, loss=0.6739 acc=0.6667 f1=0.7287
# ETA:0s/3s SUB:8
# epoch 4, loss=0.5402 acc=0.7760 f1=0.8100
# epoch 4, val, loss=0.7081 acc=0.5619 f1=0.5490
# ETA:0s/3s SUB:8
# epoch 5, loss=0.4930 acc=0.8027 f1=0.8246
# epoch 5, val, loss=0.7030 acc=0.5810 f1=0.6393
# ETA:0s/2s SUB:8
# epoch 6, loss=0.4250 acc=0.8347 f1=0.8604
# epoch 6, val, loss=0.7703 acc=0.6000 f1=0.5962
# ETA:0s/2s SUB:8
# epoch 7, loss=0.4048 acc=0.8853 f1=0.8979
# epoch 7, val, loss=0.7739 acc=0.5905 f1=0.5905
# ETA:0s/2s SUB:8
# epoch 8, loss=0.3424 acc=0.9200 f1=0.9289
# epoch 8, val, loss=0.8022 acc=0.5810 f1=0.5769
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_V/sub8_mlp.pth
# using gpu: 0
# >>> Test:  loss=0.7442 acc=0.5083 f1=0.5042
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 9 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss=0.7738 acc=0.5520 f1=0.5821
# epoch 1, val, loss=0.7238 acc=0.4286 f1=0.0000
# ETA:0s/4s SUB:9
# epoch 2, loss=0.7015 acc=0.5173 f1=0.1502
# epoch 2, val, loss=0.6848 acc=0.5714 f1=0.7273
# ETA:0s/6s SUB:9
# epoch 3, loss=0.6791 acc=0.5493 f1=0.6706
# epoch 3, val, loss=0.6891 acc=0.4952 f1=0.4045
# ETA:0s/4s SUB:9
# epoch 4, loss=0.6545 acc=0.6480 f1=0.5111
# epoch 4, val, loss=0.6762 acc=0.6095 f1=0.6963
# ETA:0s/4s SUB:9
# epoch 5, loss=0.5997 acc=0.7627 f1=0.7479
# epoch 5, val, loss=0.6736 acc=0.5619 f1=0.6102
# ETA:0s/4s SUB:9
# epoch 6, loss=0.5222 acc=0.7733 f1=0.7522
# epoch 6, val, loss=0.6909 acc=0.6000 f1=0.7042
# ETA:0s/4s SUB:9
# epoch 7, loss=0.4684 acc=0.8187 f1=0.8142
# epoch 7, val, loss=0.8741 acc=0.5524 f1=0.4471
# ETA:0s/3s SUB:9
# epoch 8, loss=0.4389 acc=0.8507 f1=0.8436
# epoch 8, val, loss=0.8348 acc=0.5905 f1=0.5376
# ETA:0s/3s SUB:9
# epoch 9, loss=0.4089 acc=0.8533 f1=0.8433
# epoch 9, val, loss=0.7635 acc=0.5714 f1=0.6617
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_V/sub9_mlp.pth
# using gpu: 0
# >>> Test:  loss=0.6766 acc=0.6000 f1=0.6522
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 10 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss=0.8529 acc=0.5387 f1=0.5312
# epoch 1, val, loss=0.7986 acc=0.4286 f1=0.0000
# ETA:0s/3s SUB:10
# epoch 2, loss=0.6770 acc=0.5547 f1=0.6281
# epoch 2, val, loss=0.6696 acc=0.6000 f1=0.5882
# ETA:0s/3s SUB:10
# epoch 3, loss=0.6185 acc=0.6613 f1=0.6998
# epoch 3, val, loss=0.7747 acc=0.4762 f1=0.1538
# ETA:0s/3s SUB:10
# epoch 4, loss=0.6237 acc=0.6613 f1=0.6577
# epoch 4, val, loss=0.6470 acc=0.6000 f1=0.5800
# ETA:0s/3s SUB:10
# epoch 5, loss=0.5761 acc=0.7093 f1=0.6667
# epoch 5, val, loss=0.6539 acc=0.6667 f1=0.7518
# ETA:0s/3s SUB:10
# epoch 6, loss=0.5532 acc=0.7307 f1=0.7390
# epoch 6, val, loss=0.6480 acc=0.6286 f1=0.6061
# ETA:0s/3s SUB:10
# epoch 7, loss=0.5354 acc=0.7573 f1=0.7673
# epoch 7, val, loss=0.7754 acc=0.5429 f1=0.3846
# ETA:0s/2s SUB:10
# epoch 8, loss=0.4993 acc=0.7893 f1=0.7990
# epoch 8, val, loss=0.6763 acc=0.6286 f1=0.5618
# ETA:0s/2s SUB:10
# epoch 9, loss=0.4682 acc=0.8107 f1=0.8000
# epoch 9, val, loss=0.6260 acc=0.7238 f1=0.7820
# ETA:0s/2s SUB:10
# epoch 10, loss=0.4515 acc=0.8187 f1=0.8182
# epoch 10, val, loss=0.6298 acc=0.6857 f1=0.7273
# ETA:0s/2s SUB:10
# epoch 11, loss=0.4121 acc=0.8693 f1=0.8759
# epoch 11, val, loss=0.7032 acc=0.6095 f1=0.5684
# ETA:0s/2s SUB:10
# epoch 12, loss=0.3766 acc=0.8933 f1=0.8964
# epoch 12, val, loss=0.7229 acc=0.6000 f1=0.5882
# ETA:0s/2s SUB:10
# epoch 13, loss=0.3610 acc=0.9013 f1=0.9034
# epoch 13, val, loss=0.7273 acc=0.6000 f1=0.5714
# ETA:0s/2s SUB:10
# epoch 14, loss=0.3432 acc=0.9253 f1=0.9282
# epoch 14, val, loss=0.9623 acc=0.5810 f1=0.5000
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_V/sub10_mlp.pth
# using gpu: 0
# >>> Test:  loss=0.7765 acc=0.5417 f1=0.5669
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 11 [37, 38, 39] 37
# 23 6 8
# (345, 3166) (90, 3166) (345,) (90,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss=0.7068 acc=0.4957 f1=0.5953
# epoch 1, val, loss=0.5567 acc=0.8333 f1=0.9091
# ETA:0s/3s SUB:11
# epoch 2, loss=0.6417 acc=0.6261 f1=0.7633
# epoch 2, val, loss=0.5569 acc=0.8333 f1=0.9091
# ETA:0s/3s SUB:11
# epoch 3, loss=0.5950 acc=0.7333 f1=0.8122
# epoch 3, val, loss=0.4993 acc=0.7889 f1=0.8805
# ETA:0s/3s SUB:11
# epoch 4, loss=0.5142 acc=0.7855 f1=0.8405
# epoch 4, val, loss=0.6574 acc=0.6889 f1=0.7879
# ETA:0s/3s SUB:11
# epoch 5, loss=0.4432 acc=0.8406 f1=0.8747
# epoch 5, val, loss=0.7772 acc=0.6444 f1=0.7500
# ETA:0s/2s SUB:11
# epoch 6, loss=0.4331 acc=0.8493 f1=0.8779
# epoch 6, val, loss=1.4018 acc=0.3667 f1=0.4000
# ETA:0s/2s SUB:11
# epoch 7, loss=0.4974 acc=0.8000 f1=0.8345
# epoch 7, val, loss=0.7351 acc=0.6444 f1=0.7500
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_V/sub11_mlp.pth
# using gpu: 0
# >>> Test:  loss=0.6659 acc=0.6250 f1=0.7692
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 12 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss=0.7019 acc=0.5680 f1=0.5645
# epoch 1, val, loss=0.7085 acc=0.4857 f1=0.3250
# ETA:0s/3s SUB:12
# epoch 2, loss=0.5700 acc=0.7813 f1=0.7574
# epoch 2, val, loss=0.8019 acc=0.5048 f1=0.4583
# ETA:0s/3s SUB:12
# epoch 3, loss=0.4278 acc=0.8560 f1=0.8483
# epoch 3, val, loss=1.0507 acc=0.5143 f1=0.4632
# ETA:0s/3s SUB:12
# epoch 4, loss=0.3679 acc=0.8907 f1=0.8858
# epoch 4, val, loss=1.0893 acc=0.5143 f1=0.5143
# ETA:0s/3s SUB:12
# epoch 5, loss=0.3703 acc=0.8987 f1=0.8933
# epoch 5, val, loss=1.0433 acc=0.5238 f1=0.5283
# ETA:0s/3s SUB:12
# epoch 6, loss=0.3562 acc=0.9013 f1=0.8997
# epoch 6, val, loss=1.0218 acc=0.5333 f1=0.4731
# ETA:0s/3s SUB:12
# epoch 7, loss=0.3554 acc=0.9093 f1=0.9086
# epoch 7, val, loss=0.9901 acc=0.5238 f1=0.4681
# ETA:0s/3s SUB:12
# epoch 8, loss=0.3356 acc=0.9067 f1=0.9014
# epoch 8, val, loss=1.0049 acc=0.5905 f1=0.6767
# ETA:0s/3s SUB:12
# epoch 9, loss=0.3018 acc=0.9333 f1=0.9288
# epoch 9, val, loss=0.9820 acc=0.5810 f1=0.6615
# ETA:0s/3s SUB:12
# epoch 10, loss=0.2815 acc=0.9627 f1=0.9620
# epoch 10, val, loss=1.1456 acc=0.4952 f1=0.4301
# ETA:0s/3s SUB:12
# epoch 11, loss=0.3070 acc=0.9387 f1=0.9366
# epoch 11, val, loss=0.9656 acc=0.5619 f1=0.6167
# ETA:0s/3s SUB:12
# epoch 12, loss=0.2809 acc=0.9440 f1=0.9398
# epoch 12, val, loss=1.0384 acc=0.6000 f1=0.6912
# ETA:0s/3s SUB:12
# epoch 13, loss=0.2934 acc=0.9413 f1=0.9389
# epoch 13, val, loss=1.0019 acc=0.5810 f1=0.6000
# ETA:0s/3s SUB:12
# epoch 14, loss=0.2673 acc=0.9653 f1=0.9646
# epoch 14, val, loss=1.0357 acc=0.5524 f1=0.5437
# ETA:0s/2s SUB:12
# epoch 15, loss=0.2522 acc=0.9760 f1=0.9751
# epoch 15, val, loss=0.9752 acc=0.5714 f1=0.6154
# ETA:0s/2s SUB:12
# epoch 16, loss=0.2403 acc=0.9867 f1=0.9861
# epoch 16, val, loss=1.0271 acc=0.5810 f1=0.6393
# ETA:0s/2s SUB:12
# epoch 17, loss=0.2468 acc=0.9733 f1=0.9728
# epoch 17, val, loss=1.0810 acc=0.5524 f1=0.5437
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_V/sub12_mlp.pth
# using gpu: 0
# >>> Test:  loss=0.7854 acc=0.6667 f1=0.7590
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 13 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss=0.6980 acc=0.6347 f1=0.3251
# epoch 1, val, loss=0.6482 acc=0.6000 f1=0.1250
# ETA:0s/4s SUB:13
# epoch 2, loss=0.4692 acc=0.8347 f1=0.6556
# epoch 2, val, loss=0.4488 acc=0.8190 f1=0.7532
# ETA:0s/4s SUB:13
# epoch 3, loss=0.3533 acc=0.9147 f1=0.8584
# epoch 3, val, loss=0.4430 acc=0.8286 f1=0.7692
# ETA:0s/4s SUB:13
# epoch 4, loss=0.3525 acc=0.9093 f1=0.8522
# epoch 4, val, loss=0.4011 acc=0.8476 f1=0.8095
# ETA:0s/4s SUB:13
# epoch 5, loss=0.3012 acc=0.9547 f1=0.9270
# epoch 5, val, loss=0.4013 acc=0.8476 f1=0.8095
# ETA:0s/4s SUB:13
# epoch 6, loss=0.2860 acc=0.9547 f1=0.9289
# epoch 6, val, loss=0.3749 acc=0.8762 f1=0.8539
# ETA:0s/4s SUB:13
# epoch 7, loss=0.2788 acc=0.9653 f1=0.9442
# epoch 7, val, loss=0.3905 acc=0.8952 f1=0.8817
# ETA:0s/4s SUB:13
# epoch 8, loss=0.2675 acc=0.9707 f1=0.9540
# epoch 8, val, loss=0.3916 acc=0.8952 f1=0.8817
# ETA:0s/4s SUB:13
# epoch 9, loss=0.2537 acc=0.9787 f1=0.9664
# epoch 9, val, loss=0.4270 acc=0.8476 f1=0.8400
# ETA:0s/3s SUB:13
# epoch 10, loss=0.2622 acc=0.9760 f1=0.9614
# epoch 10, val, loss=0.4251 acc=0.8476 f1=0.8400
# ETA:0s/3s SUB:13
# epoch 11, loss=0.2495 acc=0.9893 f1=0.9832
# epoch 11, val, loss=0.3957 acc=0.8571 f1=0.8235
# ETA:0s/3s SUB:13
# epoch 12, loss=0.2429 acc=0.9840 f1=0.9748
# epoch 12, val, loss=0.4444 acc=0.8381 f1=0.7848
# ETA:0s/3s SUB:13
# epoch 13, loss=0.2268 acc=0.9947 f1=0.9916
# epoch 13, val, loss=0.3865 acc=0.8667 f1=0.8409
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_V/sub13_mlp.pth
# using gpu: 0
# >>> Test:  loss=1.3108 acc=0.4500 f1=0.4677
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 14 [39] 39
# 24 7 8
# (360, 3166) (105, 3166) (360,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss=0.7744 acc=0.5361 f1=0.5374
# epoch 1, val, loss=0.6738 acc=0.6190 f1=0.4444
# ETA:0s/4s SUB:14
# epoch 2, loss=0.6497 acc=0.6306 f1=0.7188
# epoch 2, val, loss=0.6636 acc=0.5810 f1=0.5111
# ETA:0s/2s SUB:14
# epoch 3, loss=0.5731 acc=0.7444 f1=0.7653
# epoch 3, val, loss=0.6548 acc=0.6000 f1=0.5000
# ETA:0s/2s SUB:14
# epoch 4, loss=0.5198 acc=0.7778 f1=0.7949
# epoch 4, val, loss=0.6335 acc=0.6286 f1=0.5618
# ETA:0s/2s SUB:14
# epoch 5, loss=0.4322 acc=0.8500 f1=0.8643
# epoch 5, val, loss=0.6669 acc=0.6381 f1=0.5581
# ETA:0s/2s SUB:14
# epoch 6, loss=0.3781 acc=0.8917 f1=0.8997
# epoch 6, val, loss=0.6912 acc=0.6286 f1=0.5301
# ETA:0s/2s SUB:14
# epoch 7, loss=0.3824 acc=0.8778 f1=0.8830
# epoch 7, val, loss=0.9246 acc=0.5619 f1=0.6230
# ETA:0s/2s SUB:14
# epoch 8, loss=0.3811 acc=0.8861 f1=0.8957
# epoch 8, val, loss=0.8617 acc=0.5810 f1=0.6207
# ETA:0s/2s SUB:14
# epoch 9, loss=0.3490 acc=0.9056 f1=0.9141
# epoch 9, val, loss=0.7605 acc=0.6476 f1=0.5432
# ETA:0s/2s SUB:14
# epoch 10, loss=0.3670 acc=0.9000 f1=0.9104
# epoch 10, val, loss=0.7520 acc=0.6667 f1=0.5205
# ETA:0s/2s SUB:14
# epoch 11, loss=0.3339 acc=0.9222 f1=0.9300
# epoch 11, val, loss=0.7981 acc=0.6571 f1=0.4545
# ETA:0s/2s SUB:14
# epoch 12, loss=0.3380 acc=0.9167 f1=0.9223
# epoch 12, val, loss=0.7639 acc=0.6286 f1=0.5063
# ETA:0s/2s SUB:14
# epoch 13, loss=0.3205 acc=0.9167 f1=0.9219
# epoch 13, val, loss=0.7988 acc=0.6381 f1=0.6275
# ETA:0s/2s SUB:14
# epoch 14, loss=0.2888 acc=0.9528 f1=0.9565
# epoch 14, val, loss=0.8439 acc=0.6667 f1=0.6465
# ETA:0s/2s SUB:14
# epoch 15, loss=0.2620 acc=0.9778 f1=0.9795
# epoch 15, val, loss=0.8513 acc=0.6286 f1=0.5895
# ETA:0s/2s SUB:14
# epoch 16, loss=0.2535 acc=0.9861 f1=0.9872
# epoch 16, val, loss=0.8414 acc=0.6095 f1=0.5591
# ETA:0s/2s SUB:14
# epoch 17, loss=0.2469 acc=0.9861 f1=0.9872
# epoch 17, val, loss=0.7954 acc=0.5905 f1=0.5057
# ETA:0s/2s SUB:14
# epoch 18, loss=0.2418 acc=0.9917 f1=0.9923
# epoch 18, val, loss=0.8710 acc=0.6095 f1=0.5393
# ETA:0s/2s SUB:14
# epoch 19, loss=0.2382 acc=0.9917 f1=0.9923
# epoch 19, val, loss=0.8811 acc=0.5905 f1=0.4941
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_V/sub14_mlp.pth
# using gpu: 0
# >>> Test:  loss=0.8268 acc=0.5917 f1=0.5333
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 15 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss=0.6970 acc=0.5547 f1=0.4057
# epoch 1, val, loss=0.6839 acc=0.5905 f1=0.5169
# ETA:0s/5s SUB:15
# epoch 2, loss=0.6612 acc=0.5840 f1=0.4868
# epoch 2, val, loss=0.6602 acc=0.6286 f1=0.6486
# ETA:0s/4s SUB:15
# epoch 3, loss=0.6012 acc=0.7067 f1=0.5985
# epoch 3, val, loss=0.6413 acc=0.6286 f1=0.6549
# ETA:0s/4s SUB:15
# epoch 4, loss=0.5282 acc=0.7787 f1=0.7365
# epoch 4, val, loss=0.6494 acc=0.6476 f1=0.6942
# ETA:0s/4s SUB:15
# epoch 5, loss=0.4552 acc=0.8293 f1=0.8037
# epoch 5, val, loss=0.6725 acc=0.6571 f1=0.6538
# ETA:0s/4s SUB:15
# epoch 6, loss=0.4113 acc=0.8693 f1=0.8492
# epoch 6, val, loss=0.7739 acc=0.6095 f1=0.5684
# ETA:0s/3s SUB:15
# epoch 7, loss=0.3744 acc=0.8907 f1=0.8723
# epoch 7, val, loss=0.6891 acc=0.7143 f1=0.7458
# ETA:0s/3s SUB:15
# epoch 8, loss=0.3837 acc=0.8880 f1=0.8757
# epoch 8, val, loss=0.6944 acc=0.6762 f1=0.6731
# ETA:0s/3s SUB:15
# epoch 9, loss=0.3442 acc=0.9227 f1=0.9119
# epoch 9, val, loss=0.7056 acc=0.6381 f1=0.6122
# ETA:0s/3s SUB:15
# epoch 10, loss=0.3646 acc=0.8827 f1=0.8683
# epoch 10, val, loss=0.8119 acc=0.5810 f1=0.4884
# ETA:0s/3s SUB:15
# epoch 11, loss=0.3479 acc=0.9067 f1=0.8896
# epoch 11, val, loss=0.7301 acc=0.6286 f1=0.5895
# ETA:0s/2s SUB:15
# epoch 12, loss=0.3355 acc=0.9093 f1=0.8957
# epoch 12, val, loss=0.6607 acc=0.7524 f1=0.7719
# ETA:0s/3s SUB:15
# epoch 13, loss=0.2923 acc=0.9467 f1=0.9390
# epoch 13, val, loss=0.6912 acc=0.7238 f1=0.7238
# ETA:0s/2s SUB:15
# epoch 14, loss=0.2721 acc=0.9680 f1=0.9634
# epoch 14, val, loss=0.6781 acc=0.7143 f1=0.7115
# ETA:0s/2s SUB:15
# epoch 15, loss=0.2568 acc=0.9707 f1=0.9664
# epoch 15, val, loss=0.6675 acc=0.7238 f1=0.7339
# ETA:0s/2s SUB:15
# epoch 16, loss=0.2517 acc=0.9867 f1=0.9846
# epoch 16, val, loss=0.6593 acc=0.7524 f1=0.7797
# ETA:0s/2s SUB:15
# epoch 17, loss=0.2725 acc=0.9680 f1=0.9636
# epoch 17, val, loss=0.6704 acc=0.6952 f1=0.7576
# ETA:0s/2s SUB:15
# epoch 18, loss=0.2791 acc=0.9600 f1=0.9544
# epoch 18, val, loss=0.6014 acc=0.7333 f1=0.7742
# ETA:0s/2s SUB:15
# epoch 19, loss=0.2502 acc=0.9787 f1=0.9760
# epoch 19, val, loss=0.6479 acc=0.7143 f1=0.7170
# ETA:1s/2s SUB:15
# epoch 20, loss=0.2285 acc=0.9947 f1=0.9939
# epoch 20, val, loss=0.6509 acc=0.7238 f1=0.7290
# ETA:1s/2s SUB:15
# epoch 21, loss=0.2251 acc=0.9973 f1=0.9970
# epoch 21, val, loss=0.7394 acc=0.7238 f1=0.7071
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_V/sub15_mlp.pth
# using gpu: 0
# >>> Test:  loss=0.6211 acc=0.6667 f1=0.7297
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 16 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss=0.7856 acc=0.5067 f1=0.4237
# epoch 1, val, loss=0.7721 acc=0.4286 f1=0.0000
# ETA:0s/3s SUB:16
# epoch 2, loss=0.6837 acc=0.6027 f1=0.0132
# epoch 2, val, loss=0.7145 acc=0.4286 f1=0.0000
# ETA:0s/3s SUB:16
# epoch 3, loss=0.6670 acc=0.6293 f1=0.1775
# epoch 3, val, loss=0.7407 acc=0.4286 f1=0.0000
# ETA:0s/3s SUB:16
# epoch 4, loss=0.6526 acc=0.6267 f1=0.1250
# epoch 4, val, loss=0.7252 acc=0.4381 f1=0.0328
# ETA:0s/4s SUB:16
# epoch 5, loss=0.6317 acc=0.6613 f1=0.2825
# epoch 5, val, loss=0.6762 acc=0.5143 f1=0.3377
# ETA:0s/4s SUB:16
# epoch 6, loss=0.6038 acc=0.6987 f1=0.4933
# epoch 6, val, loss=0.6772 acc=0.5619 f1=0.4250
# ETA:0s/4s SUB:16
# epoch 7, loss=0.5765 acc=0.7200 f1=0.5882
# epoch 7, val, loss=0.9121 acc=0.4476 f1=0.0645
# ETA:0s/4s SUB:16
# epoch 8, loss=0.5853 acc=0.7067 f1=0.5492
# epoch 8, val, loss=0.6645 acc=0.6476 f1=0.6186
# ETA:0s/4s SUB:16
# epoch 9, loss=0.5356 acc=0.7600 f1=0.6831
# epoch 9, val, loss=0.7876 acc=0.4857 f1=0.2286
# ETA:0s/4s SUB:16
# epoch 10, loss=0.5180 acc=0.7627 f1=0.6510
# epoch 10, val, loss=0.7440 acc=0.5524 f1=0.4051
# ETA:0s/3s SUB:16
# epoch 11, loss=0.5099 acc=0.8107 f1=0.7437
# epoch 11, val, loss=0.6819 acc=0.6381 f1=0.5870
# ETA:0s/3s SUB:16
# epoch 12, loss=0.4831 acc=0.8133 f1=0.7569
# epoch 12, val, loss=0.7399 acc=0.6000 f1=0.5116
# ETA:0s/3s SUB:16
# epoch 13, loss=0.4893 acc=0.8080 f1=0.7465
# epoch 13, val, loss=0.9424 acc=0.4857 f1=0.2286
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_V/sub16_mlp.pth
# using gpu: 0
# >>> Test:  loss=0.5214 acc=0.8250 f1=0.5532
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 17 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss=0.7115 acc=0.4827 f1=0.3310
# epoch 1, val, loss=0.6176 acc=0.8571 f1=0.9231
# ETA:0s/3s SUB:17
# epoch 2, loss=0.7046 acc=0.5093 f1=0.4177
# epoch 2, val, loss=0.6878 acc=0.7429 f1=0.8525
# ETA:0s/2s SUB:17
# epoch 3, loss=0.6901 acc=0.5627 f1=0.6583
# epoch 3, val, loss=0.7449 acc=0.1429 f1=0.0000
# ETA:0s/2s SUB:17
# epoch 4, loss=0.6867 acc=0.5280 f1=0.1015
# epoch 4, val, loss=0.6883 acc=0.6095 f1=0.7574
# ETA:0s/2s SUB:17
# epoch 5, loss=0.6768 acc=0.5760 f1=0.6536
# epoch 5, val, loss=0.7814 acc=0.1429 f1=0.0000
# ETA:0s/2s SUB:17
# epoch 6, loss=0.6648 acc=0.6213 f1=0.5506
# epoch 6, val, loss=0.7732 acc=0.1810 f1=0.1400
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_V/sub17_mlp.pth
# using gpu: 0
# >>> Test:  loss=0.7001 acc=0.5000 f1=0.6667
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 18 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss=0.7257 acc=0.5387 f1=0.6231
# epoch 1, val, loss=0.6547 acc=0.5619 f1=0.7160
# ETA:0s/4s SUB:18
# epoch 2, loss=0.6000 acc=0.7253 f1=0.7841
# epoch 2, val, loss=0.6161 acc=0.7048 f1=0.7801
# ETA:0s/4s SUB:18
# epoch 3, loss=0.4959 acc=0.8107 f1=0.8360
# epoch 3, val, loss=0.7001 acc=0.6286 f1=0.5618
# ETA:0s/3s SUB:18
# epoch 4, loss=0.4229 acc=0.8640 f1=0.8765
# epoch 4, val, loss=0.6672 acc=0.7238 f1=0.7238
# ETA:0s/3s SUB:18
# epoch 5, loss=0.3374 acc=0.9227 f1=0.9305
# epoch 5, val, loss=0.6625 acc=0.7429 f1=0.7611
# ETA:0s/3s SUB:18
# epoch 6, loss=0.3061 acc=0.9413 f1=0.9474
# epoch 6, val, loss=0.6891 acc=0.7429 f1=0.7611
# ETA:0s/3s SUB:18
# epoch 7, loss=0.2814 acc=0.9573 f1=0.9619
# epoch 7, val, loss=0.6945 acc=0.7333 f1=0.7500
# ETA:0s/3s SUB:18
# epoch 8, loss=0.2772 acc=0.9653 f1=0.9690
# epoch 8, val, loss=0.6795 acc=0.7429 f1=0.7568
# ETA:0s/3s SUB:18
# epoch 9, loss=0.2653 acc=0.9680 f1=0.9716
# epoch 9, val, loss=0.6776 acc=0.7524 f1=0.7636
# ETA:0s/3s SUB:18
# epoch 10, loss=0.2559 acc=0.9760 f1=0.9784
# epoch 10, val, loss=0.6697 acc=0.7429 f1=0.7523
# ETA:0s/3s SUB:18
# epoch 11, loss=0.2623 acc=0.9653 f1=0.9690
# epoch 11, val, loss=0.6920 acc=0.7429 f1=0.7769
# ETA:0s/3s SUB:18
# epoch 12, loss=0.2427 acc=0.9867 f1=0.9880
# epoch 12, val, loss=0.6426 acc=0.7333 f1=0.7705
# ETA:0s/3s SUB:18
# epoch 13, loss=0.2311 acc=0.9973 f1=0.9976
# epoch 13, val, loss=0.6535 acc=0.7429 f1=0.7769
# ETA:0s/2s SUB:18
# epoch 14, loss=0.2268 acc=1.0000 f1=1.0000
# epoch 14, val, loss=0.6854 acc=0.7429 f1=0.7769
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_V/sub18_mlp.pth
# using gpu: 0
# >>> Test:  loss=0.9775 acc=0.5750 f1=0.6577
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 19 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss=0.6937 acc=0.5067 f1=0.6232
# epoch 1, val, loss=0.6709 acc=0.6190 f1=0.7468
# ETA:0s/4s SUB:19
# epoch 2, loss=0.6584 acc=0.6400 f1=0.7097
# epoch 2, val, loss=0.6594 acc=0.6667 f1=0.7619
# ETA:0s/4s SUB:19
# epoch 3, loss=0.6606 acc=0.5920 f1=0.6107
# epoch 3, val, loss=0.7274 acc=0.5810 f1=0.7284
# ETA:0s/3s SUB:19
# epoch 4, loss=0.6066 acc=0.7013 f1=0.7419
# epoch 4, val, loss=0.6656 acc=0.6000 f1=0.6379
# ETA:0s/3s SUB:19
# epoch 5, loss=0.5665 acc=0.7253 f1=0.7696
# epoch 5, val, loss=0.6705 acc=0.6190 f1=0.6552
# ETA:0s/2s SUB:19
# epoch 6, loss=0.5527 acc=0.7333 f1=0.7664
# epoch 6, val, loss=0.6513 acc=0.6762 f1=0.7302
# ETA:0s/2s SUB:19
# epoch 7, loss=0.5142 acc=0.7867 f1=0.8122
# epoch 7, val, loss=0.7175 acc=0.6190 f1=0.6000
# ETA:0s/2s SUB:19
# epoch 8, loss=0.5502 acc=0.7333 f1=0.7596
# epoch 8, val, loss=0.6904 acc=0.6095 f1=0.7092
# ETA:0s/2s SUB:19
# epoch 9, loss=0.5000 acc=0.8187 f1=0.8300
# epoch 9, val, loss=0.6825 acc=0.6190 f1=0.7101
# ETA:0s/2s SUB:19
# epoch 10, loss=0.4780 acc=0.8187 f1=0.8396
# epoch 10, val, loss=0.7122 acc=0.6381 f1=0.6415
# ETA:0s/2s SUB:19
# epoch 11, loss=0.4533 acc=0.8267 f1=0.8492
# epoch 11, val, loss=0.8332 acc=0.5143 f1=0.4000
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_V/sub19_mlp.pth
# using gpu: 0
# >>> Test:  loss=0.7533 acc=0.5583 f1=0.6443
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 20 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss=0.8067 acc=0.5173 f1=0.4396
# epoch 1, val, loss=0.7923 acc=0.4286 f1=0.0000
# ETA:0s/3s SUB:20
# epoch 2, loss=0.6745 acc=0.6187 f1=0.6266
# epoch 2, val, loss=0.6685 acc=0.7238 f1=0.8000
# ETA:0s/3s SUB:20
# epoch 3, loss=0.6262 acc=0.7067 f1=0.6707
# epoch 3, val, loss=0.6466 acc=0.6000 f1=0.5625
# ETA:0s/3s SUB:20
# epoch 4, loss=0.5441 acc=0.7947 f1=0.7794
# epoch 4, val, loss=0.6486 acc=0.6286 f1=0.5714
# ETA:0s/2s SUB:20
# epoch 5, loss=0.4756 acc=0.8400 f1=0.8276
# epoch 5, val, loss=0.7329 acc=0.5905 f1=0.4819
# ETA:0s/2s SUB:20
# epoch 6, loss=0.4005 acc=0.8747 f1=0.8683
# epoch 6, val, loss=0.8714 acc=0.5810 f1=0.4500
# ETA:0s/2s SUB:20
# epoch 7, loss=0.4030 acc=0.8827 f1=0.8743
# epoch 7, val, loss=0.7303 acc=0.6667 f1=0.6602
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_V/sub20_mlp.pth
# using gpu: 0
# >>> Test:  loss=0.6536 acc=0.7333 f1=0.8400
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 21 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss=0.6903 acc=0.5920 f1=0.7140
# epoch 1, val, loss=0.7191 acc=0.4286 f1=0.6000
# ETA:0s/4s SUB:21
# epoch 2, loss=0.6964 acc=0.5467 f1=0.6756
# epoch 2, val, loss=0.8122 acc=0.4286 f1=0.6000
# ETA:0s/4s SUB:21
# epoch 3, loss=0.6618 acc=0.6213 f1=0.7183
# epoch 3, val, loss=0.7751 acc=0.4286 f1=0.6000
# ETA:0s/4s SUB:21
# epoch 4, loss=0.6284 acc=0.6587 f1=0.7722
# epoch 4, val, loss=0.8473 acc=0.4381 f1=0.6040
# ETA:0s/4s SUB:21
# epoch 5, loss=0.5987 acc=0.6800 f1=0.7541
# epoch 5, val, loss=0.9646 acc=0.4381 f1=0.6040
# ETA:0s/5s SUB:21
# epoch 6, loss=0.5538 acc=0.7227 f1=0.7953
# epoch 6, val, loss=0.8927 acc=0.5143 f1=0.5487
# ETA:0s/5s SUB:21
# epoch 7, loss=0.5236 acc=0.7893 f1=0.8301
# epoch 7, val, loss=1.0142 acc=0.4762 f1=0.6154
# ETA:0s/4s SUB:21
# epoch 8, loss=0.4601 acc=0.8507 f1=0.8833
# epoch 8, val, loss=0.9314 acc=0.4667 f1=0.3778
# ETA:0s/4s SUB:21
# epoch 9, loss=0.4985 acc=0.7867 f1=0.8190
# epoch 9, val, loss=1.0747 acc=0.4952 f1=0.5891
# ETA:0s/3s SUB:21
# epoch 10, loss=0.4752 acc=0.7973 f1=0.8369
# epoch 10, val, loss=0.9707 acc=0.4762 f1=0.5299
# ETA:0s/3s SUB:21
# epoch 11, loss=0.4099 acc=0.8667 f1=0.8950
# epoch 11, val, loss=0.9164 acc=0.5048 f1=0.3659
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_V/sub21_mlp.pth
# using gpu: 0
# >>> Test:  loss=0.8220 acc=0.4417 f1=0.4463
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 22 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss=0.6195 acc=0.6533 f1=0.3564
# epoch 1, val, loss=0.7711 acc=0.5429 f1=0.0769
# ETA:0s/4s SUB:22
# epoch 2, loss=0.4250 acc=0.8800 f1=0.8249
# epoch 2, val, loss=1.1146 acc=0.5143 f1=0.2154
# ETA:0s/2s SUB:22
# epoch 3, loss=0.3055 acc=0.9467 f1=0.9248
# epoch 3, val, loss=1.2662 acc=0.4667 f1=0.2432
# ETA:0s/2s SUB:22
# epoch 4, loss=0.2741 acc=0.9787 f1=0.9706
# epoch 4, val, loss=1.3589 acc=0.4952 f1=0.1846
# ETA:0s/2s SUB:22
# epoch 5, loss=0.2511 acc=0.9893 f1=0.9852
# epoch 5, val, loss=1.2991 acc=0.5238 f1=0.1667
# ETA:0s/2s SUB:22
# epoch 6, loss=0.2432 acc=0.9920 f1=0.9889
# epoch 6, val, loss=1.2785 acc=0.4952 f1=0.2090
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_V/sub22_mlp.pth
# using gpu: 0
# >>> Test:  loss=0.9045 acc=0.3083 f1=0.1942
