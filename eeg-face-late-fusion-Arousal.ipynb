# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import scipy as sp
from tqdm import auto, tqdm
import torch
from sklearn.model_selection import train_test_split

import sys
sys.path.append('/content/drive/MyDrive/11777-Project-xs/LGG/')
sys.path.append('/content/drive/MyDrive/11777-Project-xs/MLP/')
from prepare_data_DEAP import PrepareData
from cross_validation import CrossValidation
from train_model import *

# %%
# Define default parameters
default_args = {
    'dataset': 'DEAP',
    'data_path': './data_preprocessed_python/',
    'subjects': 22,
    'num_class': 2,
    'label_type': 'A',
    'segment': 4,
    'overlap': 0,
    'sampling_rate': 128,
    'scale_coefficient': 1,
    'input_shape': (1, 32, 512),
    'data_format': 'eeg',
    'random_seed': 2021,
    'max_epoch': 50, #200
    'patient': 5, #20,
    'patient_cmb': 8,
    'max_epoch_cmb': 20,
    'batch_size': 64,
    'learning_rate': 1e-3,
    'step_size': 5,
    'dropout': 0.5,
    'LS': True,
    'LS_rate': 0.1,
    'save_path': '/content/drive/MyDrive/11777-Project-xs/LGG/save/',
    'load_path': '/content/drive/MyDrive/11777-Project-xs/LGG/save/max-acc.pth',
    'load_path_final': '/content/drive/MyDrive/11777-Project-xs/LGG/save/final_model.pth',
    'mlp_save_path': '/content/drive/MyDrive/11777-Project-xs/MLP/save/',
    'mlp_load_path': '/content/drive/MyDrive/11777-Project-xs/MLP/save/max-acc.pth',
    'mlp_load_path_final': '/content/drive/MyDrive/11777-Project-xs/MLP/save/final_model.pth',
    'gpu': '0',
    'save_model': True,
    'model': 'LGGNet',
    'pool': 16,
    'pool_step_rate': 0.25,
    'T': 64,
    'graph_type': 'hem',
    'hidden': 32
}

# %%
######## Reproduce the result using the saved model ######
# parser.add_argument('--reproduce', action='store_true')
# args = parser.parse_args()
class Args:
    def __init__(self, param_dict):
        for key, value in param_dict.items():
            setattr(self, key, value)

default_args['data_path'] = '/content/drive/MyDrive/11777-Project-xs/data_preprocessed_python/'
default_args['reproduce'] = 'store_true'
# Create an Args object with default parameters
args = Args(default_args)

# %%
# only need to run once
sub_to_run = np.arange(args.subjects)
prepdt = PrepareData(args)
prepdt.run(sub_to_run, split=True, expand=True)
# Out:
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------
# data:(40, 32, 7680) label:(40, 4)
# Binary label generated!
# The data and label are split: Data shape:(40, 15, 1, 32, 512) Label:(40, 15)
# Data and label prepared!
# data:(40, 15, 1, 32, 512) label:(40, 15)
# ----------------------

# %%
participant_ids = list(range(1, 23))
data_save_folder = '/content/drive/MyDrive/11777-Project-xs/data_face_seg_mean'

def delete_file(path):
    '''
    used to remove temporal file generated
    '''
    if os.path.exists(path):
        os.remove(path)

# # only need to run once
# for participant_id in auto.tqdm(participant_ids):
#     participant_id = '{:02d}'.format(participant_id)
#     for trial_id in auto.tqdm(range(1, 41)):
#         file_name = 's{0}_trial{1}_mean_frames.npy'.format(participant_id, trial_id)
#         if not os.path.exists(os.path.join(data_save_folder, file_name)):
#             print('No face data found for s{0}_trial{1}'.format(participant_id, trial_id))
#             continue

#         file_name2 = 's{0}_trial{1}_mean_frames_embed.npy'.format(participant_id, trial_id)
#         if os.path.exists(os.path.join(data_save_folder, file_name2)):
#             continue
#         participant_trial_seg = np.load(os.path.join(data_save_folder, file_name))
#         participant_trial_embed = []
#         for image in participant_trial_seg:
#             delete_file('curr_face_image.png')
#             plt.imsave('curr_face_image.png', np.uint8(participant_trial_seg[0]),
#                        cmap=plt.cm.Spectral)
#             embedding_objs = DeepFace.represent(img_path = 'curr_face_image.png', enforce_detection = False)
#             embedding = embedding_objs[0]['embedding']
#             assert isinstance(embedding, list)
#             assert len(embedding) == 2622
#             participant_trial_embed.append(np.array(embedding))

#         participant_trial_embed = np.stack(participant_trial_embed, axis=0)
#         np.save(os.path.join(data_save_folder, file_name2), participant_trial_embed)

# %%
import os
data_save_folder = '/content/drive/MyDrive/11777-Project-xs/data_face_seg_mean'
face_embed_file_list = os.listdir(data_save_folder)
# print(len(face_embed_file_list))
face_embed_file_list = [e for e in face_embed_file_list if 'embed.npy' in e]
sub_trial_list = {}
for file in face_embed_file_list:
    # print(file)
    sub, trial, _, _, _ = file.split('_')
    sub, trial = int(sub[1:]), int(trial[5:])
    if sub in sub_trial_list.keys():
        sub_trial_list[sub].append(trial)
    else:
        sub_trial_list[sub] = [trial]

for sub in range(1,23):
    print('sub {}, {} trials with facial video'.format(sub, len(sub_trial_list[sub])))
# Out:
# sub 1, 40 trials with facial video
# sub 2, 40 trials with facial video
# sub 3, 39 trials with facial video
# sub 4, 40 trials with facial video
# sub 5, 39 trials with facial video
# sub 6, 40 trials with facial video
# sub 7, 40 trials with facial video
# sub 8, 40 trials with facial video
# sub 9, 40 trials with facial video
# sub 10, 40 trials with facial video
# sub 11, 37 trials with facial video
# sub 12, 40 trials with facial video
# sub 13, 40 trials with facial video
# sub 14, 39 trials with facial video
# sub 15, 40 trials with facial video
# sub 16, 40 trials with facial video
# sub 17, 40 trials with facial video
# sub 18, 40 trials with facial video
# sub 19, 40 trials with facial video
# sub 20, 40 trials with facial video
# sub 21, 40 trials with facial video
# sub 22, 40 trials with facial video

# %%
def load_mean_frames_embed(sub, data_save_folder):
    '''
    sub starting index from 1 (not 0)
    '''
    face_embed_file_list = os.listdir(data_save_folder)
    sub_face_embed_file_list = [e for e in face_embed_file_list if 'embed' in e and sub==int(e[1:3])]
    sorted(sub_face_embed_file_list)
    # print(sub_face_embed_file_list)
    sub_frame_embed = []
    for file in auto.tqdm(sub_face_embed_file_list):
        embed = np.load(os.path.join(data_save_folder, file))
        sub_frame_embed.append(embed)
    sub_frame_embed = np.stack(sub_frame_embed, axis=0)
    print(sub_frame_embed.shape)
    return sub_frame_embed

# 's01_trial1_mean_frames_embed.npy'

data_save_folder = '/content/drive/MyDrive/11777-Project-xs/data_face_seg_mean'
all_sub_frame_embed = []
for sub in auto.tqdm(range(1,23)):
    sub_frame_embed = load_mean_frames_embed(sub, data_save_folder)
    all_sub_frame_embed.append(sub_frame_embed)
# Out:
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/39 [00:00<?, ?it/s]
# (39, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/39 [00:00<?, ?it/s]
# (39, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/37 [00:00<?, ?it/s]
# (37, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/39 [00:00<?, ?it/s]
# (39, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)
#   0%|          | 0/40 [00:00<?, ?it/s]
# (40, 15, 2622)

# %%
import pickle
file_name = 'all_sub_frame_embed.pkl'
# with open(os.path.join(data_save_folder, file_name), 'wb') as file:
#     pickle.dump(all_sub_frame_embed, file)

with open(os.path.join(data_save_folder, file_name), 'rb') as file:
    all_sub_frame_embed = pickle.load(file)

# %%
def generate_eeg_embed(eeg_data, LGG, CUDA=True):
    LGG.eval()
    eeg_embed = []
    # eeg_data = np.concatenate(eeg_data, axis=0)
    for eeg_data_trial in eeg_data:
        eeg_data_trial = torch.from_numpy(eeg_data_trial).float()
        if CUDA:
            eeg_data_trial = eeg_data_trial.cuda()
            LGG = LGG.cuda()
        with torch.no_grad():
            eeg_embed_trial = LGG.get_embed(eeg_data_trial)
        eeg_embed_trial = eeg_embed_trial.to('cpu')
        eeg_embed_trial = eeg_embed_trial.numpy()
        eeg_embed.append(eeg_embed_trial)
    eeg_embed = np.stack(eeg_embed, axis=0)
    return eeg_embed

# %%
def get_model_embed(args):
    if args.model == 'LGGNet':
        idx_local_graph = list(np.array(h5py.File('num_chan_local_graph_{}.hdf'.format(args.graph_type), 'r')['data']))
        channels = sum(idx_local_graph)
        input_size = (args.input_shape[0], channels, args.input_shape[2])
        model = LGGNet2(
            num_classes=args.num_class, input_size=input_size,
            sampling_rate=int(args.sampling_rate*args.scale_coefficient),
            num_T=args.T, out_graph=args.hidden,
            dropout_rate=args.dropout,
            pool=args.pool, pool_step_rate=args.pool_step_rate,
            idx_graph=idx_local_graph)

    return model

def transfer_weight(LGG, LGG_embed):
    for i, (pre_trained_layer, custom_layer) in enumerate(zip(LGG.children(), LGG_embed.children())):
        custom_layer.load_state_dict(pre_trained_layer.state_dict())
    return LGG_embed

# %%
from mlp_networks import SimpleMLP
from mlp_train_model import train_simpleMLP, test_simpleMLP

CUDA = torch.cuda.is_available()

# %%
CUDA = torch.cuda.is_available()
fold = 'noFold'

with open(os.path.join(data_save_folder, file_name), 'rb') as file:
    all_sub_frame_embed = pickle.load(file)

for sub in range(22):

    print('='*48)
    cv = CrossValidation(args)
    eeg_data, label = cv.load_per_subject(sub)
    trial_to_remove = [i-1 for i in range(1,41) if i not in sub_trial_list[sub+1]]
    ### face embeddings
    sub_frame_embed = all_sub_frame_embed[sub]

    if len(trial_to_remove) > 0:
        mask = np.ones(eeg_data.shape[0], dtype=bool)
        mask[trial_to_remove] = False
        eeg_data = eeg_data[mask]
        label = label[mask]

    ### Load pre-trained LGG model weights
    ### and generate the EEG embeddings
    lgg_model = get_model(args)
    lgg_model_embed = get_model_embed(args)
    if CUDA:
        lgg_model = lgg_model.cuda()
    model_name_reproduce = 'sub' + str(sub+1) + '.pth'
    data_type = 'model_{}_{}'.format(args.data_format, args.label_type)
    experiment_setting = 'T_{}_pool_{}'.format(args.T, args.pool)
    save_path = os.path.join(args.save_path, experiment_setting, data_type)
    ensure_path(save_path)
    model_name_reproduce = os.path.join(save_path, model_name_reproduce)
    lgg_model.load_state_dict(torch.load(model_name_reproduce))
    lgg_model_embed = transfer_weight(lgg_model, lgg_model_embed)
    eeg_embed = generate_eeg_embed(eeg_data, lgg_model_embed, CUDA)

    ### concat eeg + face embedding
    eeg_face_embed = np.concatenate([eeg_embed, sub_frame_embed], axis=2)

    print(sub+1, trial_to_remove, sub_frame_embed.shape[0])
    trial_id = np.arange(eeg_data.shape[0])
    trial_id_train, trial_id_test = train_test_split(trial_id, test_size=0.2, random_state=42)
    trial_id_tra, trial_id_val = train_test_split(trial_id_train, test_size=0.2, random_state=42)
    print(trial_id_tra.shape[0], trial_id_val.shape[0], trial_id_test.shape[0])

    data_train, data_val, label_train, label_val = \
        eeg_face_embed[trial_id_tra], eeg_face_embed[trial_id_val], label[trial_id_tra], label[trial_id_val]
    data_train, data_val, label_train, label_val = \
        np.concatenate(data_train, axis=0), np.concatenate(data_val, axis=0), np.concatenate(label_train, axis=0), np.concatenate(label_val, axis=0)
    print(data_train.shape, data_val.shape, label_train.shape, label_val.shape)

    data_test, label_test = \
        eeg_face_embed[trial_id_test], label[trial_id_test]
    data_test, label_test = \
        np.concatenate(data_test, axis=0), np.concatenate(label_test, axis=0)
    print(data_test.shape, label_test.shape)

    data_train = torch.from_numpy(data_train).float()
    label_train = torch.from_numpy(label_train).long()
    data_val = torch.from_numpy(data_val).float()
    label_val = torch.from_numpy(label_val).long()
    data_test = torch.from_numpy(data_test).float()
    label_test = torch.from_numpy(label_test).long()


    ### define a simple MLP as the predictor
    predictor = SimpleMLP(data_train.shape[1], data_train.shape[1] // 4, 2)

    acc_val, F1_val = train_simpleMLP(model=predictor, args=args,
                                      data_train=data_train,
                                      label_train=label_train,
                                      data_val=data_val,
                                      label_val=label_val,
                                      subject = str(sub+1))

    if CUDA:
        predictor = predictor.cuda()
    predictor.load_state_dict(torch.load(os.path.join(args.mlp_save_path, 'candidate.pth')))

    model_name_reproduce = 'sub' + str(sub+1) + '_mlp.pth'
    data_type = 'model_{}_{}'.format(args.data_format, args.label_type)
    experiment_setting = 'T_{}_pool_{}'.format(args.T, args.pool)
    save_path = os.path.join(args.mlp_save_path, experiment_setting, data_type)
    ensure_path(save_path)
    model_name_reproduce = os.path.join(save_path, model_name_reproduce)
    print(model_name_reproduce)
    torch.save(predictor.state_dict(), model_name_reproduce)

    acc_test, pred, act = test_simpleMLP(model=predictor, args=args, data=data_test, label=label_test,
                                               reproduce=args.reproduce,
                                               subject=str(sub+1))
# Out:
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 1 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss=0.6930 acc=0.5573 f1=0.6891
# epoch 1, val, loss=0.6879 acc=0.5714 f1=0.7273
# ETA:0s/7s SUB:1
# epoch 2, loss=0.6796 acc=0.6053 f1=0.7385
# epoch 2, val, loss=0.6883 acc=0.5714 f1=0.7273
# ETA:0s/5s SUB:1
# epoch 3, loss=0.6702 acc=0.6000 f1=0.7475
# epoch 3, val, loss=0.6862 acc=0.5714 f1=0.7273
# ETA:0s/4s SUB:1
# epoch 4, loss=0.6632 acc=0.5947 f1=0.7379
# epoch 4, val, loss=0.6893 acc=0.5714 f1=0.7273
# ETA:0s/4s SUB:1
# epoch 5, loss=0.6319 acc=0.6507 f1=0.7722
# epoch 5, val, loss=0.7047 acc=0.5619 f1=0.7195
# ETA:0s/3s SUB:1
# epoch 6, loss=0.5994 acc=0.7280 f1=0.8061
# epoch 6, val, loss=0.7784 acc=0.5619 f1=0.7195
# ETA:0s/3s SUB:1
# epoch 7, loss=0.6001 acc=0.6587 f1=0.7322
# epoch 7, val, loss=0.8919 acc=0.5619 f1=0.7195
# ETA:0s/3s SUB:1
# epoch 8, loss=0.5991 acc=0.6960 f1=0.7500
# epoch 8, val, loss=0.8274 acc=0.5714 f1=0.7239
# ETA:0s/3s SUB:1
# epoch 9, loss=0.5786 acc=0.6933 f1=0.7589
# epoch 9, val, loss=0.7318 acc=0.4476 f1=0.5246
# ETA:0s/3s SUB:1
# epoch 10, loss=0.5392 acc=0.7547 f1=0.8196
# epoch 10, val, loss=0.8060 acc=0.5238 f1=0.3902
# ETA:0s/2s SUB:1
# epoch 11, loss=0.5159 acc=0.7760 f1=0.8205
# epoch 11, val, loss=0.7795 acc=0.4762 f1=0.5865
# ETA:0s/2s SUB:1
# epoch 12, loss=0.4723 acc=0.8400 f1=0.8690
# epoch 12, val, loss=0.8526 acc=0.5238 f1=0.6377
# ETA:0s/2s SUB:1
# epoch 13, loss=0.4539 acc=0.8320 f1=0.8651
# epoch 13, val, loss=0.9346 acc=0.5524 f1=0.6759
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_A/sub1_mlp.pth
# using gpu: 0
# >>> Test:  loss=0.7223 acc=0.6167 f1=0.7629
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 2 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss=0.7029 acc=0.5200 f1=0.5775
# epoch 1, val, loss=0.5713 acc=0.8571 f1=0.9231
# ETA:0s/4s SUB:2
# epoch 2, loss=0.7028 acc=0.5333 f1=0.6667
# epoch 2, val, loss=0.6925 acc=0.4667 f1=0.5692
# ETA:0s/2s SUB:2
# epoch 3, loss=0.6889 acc=0.5520 f1=0.6500
# epoch 3, val, loss=0.5781 acc=0.8571 f1=0.9231
# ETA:0s/3s SUB:2
# epoch 4, loss=0.6877 acc=0.5547 f1=0.7126
# epoch 4, val, loss=0.6409 acc=0.8571 f1=0.9231
# ETA:0s/3s SUB:2
# epoch 5, loss=0.6799 acc=0.5680 f1=0.7207
# epoch 5, val, loss=0.6156 acc=0.8571 f1=0.9231
# ETA:0s/3s SUB:2
# epoch 6, loss=0.6731 acc=0.5573 f1=0.7057
# epoch 6, val, loss=0.6479 acc=0.7714 f1=0.8696
# ETA:0s/3s SUB:2
# epoch 7, loss=0.6576 acc=0.6373 f1=0.7434
# epoch 7, val, loss=0.5959 acc=0.8381 f1=0.9119
# ETA:0s/3s SUB:2
# epoch 8, loss=0.6405 acc=0.6560 f1=0.7296
# epoch 8, val, loss=0.5835 acc=0.8000 f1=0.8877
# ETA:0s/3s SUB:2
# epoch 9, loss=0.6123 acc=0.7120 f1=0.7600
# epoch 9, val, loss=0.6192 acc=0.6476 f1=0.7758
# ETA:0s/2s SUB:2
# epoch 10, loss=0.5857 acc=0.7440 f1=0.7818
# epoch 10, val, loss=0.8823 acc=0.3524 f1=0.4138
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_A/sub2_mlp.pth
# using gpu: 0
# >>> Test:  loss=0.7038 acc=0.5000 f1=0.6667
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 3 [39] 39
# 24 7 8
# (360, 3166) (105, 3166) (360,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss=0.8525 acc=0.6222 f1=0.2273
# epoch 1, val, loss=0.2567 acc=1.0000 f1=0.0000
# ETA:0s/4s SUB:3
# epoch 2, loss=0.6058 acc=0.7500 f1=0.0000
# epoch 2, val, loss=0.4055 acc=1.0000 f1=0.0000
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# ETA:0s/4s SUB:3
# epoch 3, loss=0.5840 acc=0.7528 f1=0.0220
# epoch 3, val, loss=0.3419 acc=1.0000 f1=0.0000
# ETA:0s/4s SUB:3
# epoch 4, loss=0.5894 acc=0.7500 f1=0.0000
# epoch 4, val, loss=0.3725 acc=1.0000 f1=0.0000
# ETA:0s/4s SUB:3
# epoch 5, loss=0.5929 acc=0.7500 f1=0.0000
# epoch 5, val, loss=0.3847 acc=1.0000 f1=0.0000
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# ETA:0s/3s SUB:3
# epoch 6, loss=0.5779 acc=0.7472 f1=0.0000
# epoch 6, val, loss=0.3273 acc=1.0000 f1=0.0000
# ETA:0s/3s SUB:3
# epoch 7, loss=0.5756 acc=0.7500 f1=0.0000
# epoch 7, val, loss=0.4161 acc=1.0000 f1=0.0000
# ETA:0s/3s SUB:3
# epoch 8, loss=0.5622 acc=0.7444 f1=0.0000
# epoch 8, val, loss=0.3045 acc=1.0000 f1=0.0000
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# ETA:0s/3s SUB:3
# epoch 9, loss=0.5676 acc=0.7500 f1=0.0000
# epoch 9, val, loss=0.4622 acc=1.0000 f1=0.0000
# ETA:0s/3s SUB:3
# epoch 10, loss=0.5576 acc=0.7500 f1=0.0000
# epoch 10, val, loss=0.3016 acc=1.0000 f1=0.0000
# ETA:0s/3s SUB:3
# epoch 11, loss=0.5446 acc=0.7500 f1=0.0000
# epoch 11, val, loss=0.3819 acc=1.0000 f1=0.0000
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# ETA:0s/3s SUB:3
# epoch 12, loss=0.5384 acc=0.7528 f1=0.0220
# epoch 12, val, loss=0.3595 acc=1.0000 f1=0.0000
# ETA:0s/3s SUB:3
# epoch 13, loss=0.5422 acc=0.7528 f1=0.0220
# epoch 13, val, loss=0.4310 acc=1.0000 f1=0.0000
# ETA:1s/3s SUB:3
# epoch 14, loss=0.5239 acc=0.7611 f1=0.0851
# epoch 14, val, loss=0.4757 acc=0.9714 f1=0.0000
# ETA:1s/3s SUB:3
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# epoch 15, loss=0.5017 acc=0.7861 f1=0.2667
# epoch 15, val, loss=0.5537 acc=0.7810 f1=0.0000
# ETA:1s/3s SUB:3
# epoch 16, loss=0.5405 acc=0.7917 f1=0.4526
# epoch 16, val, loss=0.3874 acc=1.0000 f1=0.0000
# ETA:1s/3s SUB:3
# epoch 17, loss=0.5009 acc=0.7917 f1=0.3363
# epoch 17, val, loss=0.5296 acc=0.8381 f1=0.0000
# ETA:1s/3s SUB:3
# epoch 18, loss=0.5025 acc=0.7750 f1=0.2957
# epoch 18, val, loss=0.6421 acc=0.6000 f1=0.0000
# ETA:1s/3s SUB:3
# epoch 19, loss=0.4807 acc=0.7944 f1=0.4789
# epoch 19, val, loss=0.3640 acc=0.9905 f1=0.0000
# ETA:1s/3s SUB:3
# epoch 20, loss=0.4670 acc=0.8194 f1=0.4961
# epoch 20, val, loss=0.5308 acc=0.7810 f1=0.0000
# ETA:1s/3s SUB:3
# epoch 21, loss=0.4490 acc=0.8556 f1=0.6623
# epoch 21, val, loss=0.5133 acc=0.7905 f1=0.0000
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_A/sub3_mlp.pth
# using gpu: 0
# >>> Test:  loss=0.5422 acc=0.7417 f1=0.0606
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 4 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss=0.6315 acc=0.7093 f1=0.0000
# epoch 1, val, loss=1.0128 acc=0.4286 f1=0.0000
# ETA:0s/3s SUB:4
# epoch 2, loss=0.6057 acc=0.7200 f1=0.0000
# epoch 2, val, loss=0.7638 acc=0.4286 f1=0.0000
# ETA:0s/3s SUB:4
# epoch 3, loss=0.5977 acc=0.7200 f1=0.0000
# epoch 3, val, loss=0.8067 acc=0.4286 f1=0.0000
# ETA:0s/3s SUB:4
# epoch 4, loss=0.5775 acc=0.7200 f1=0.0000
# epoch 4, val, loss=0.7996 acc=0.4286 f1=0.0000
# ETA:0s/3s SUB:4
# epoch 5, loss=0.5365 acc=0.7280 f1=0.0556
# epoch 5, val, loss=0.7984 acc=0.4476 f1=0.0645
# ETA:0s/3s SUB:4
# epoch 6, loss=0.4917 acc=0.8027 f1=0.4714
# epoch 6, val, loss=0.7516 acc=0.4952 f1=0.4646
# ETA:0s/3s SUB:4
# epoch 7, loss=0.4308 acc=0.8453 f1=0.6506
# epoch 7, val, loss=0.7952 acc=0.5048 f1=0.6061
# ETA:0s/3s SUB:4
# epoch 8, loss=0.3875 acc=0.8880 f1=0.7835
# epoch 8, val, loss=0.9325 acc=0.4952 f1=0.5760
# ETA:0s/3s SUB:4
# epoch 9, loss=0.3679 acc=0.8960 f1=0.8040
# epoch 9, val, loss=1.0695 acc=0.5524 f1=0.6713
# ETA:0s/3s SUB:4
# epoch 10, loss=0.3505 acc=0.9147 f1=0.8431
# epoch 10, val, loss=1.0205 acc=0.4952 f1=0.5760
# ETA:0s/3s SUB:4
# epoch 11, loss=0.3258 acc=0.9413 f1=0.8889
# epoch 11, val, loss=1.0101 acc=0.4952 f1=0.5760
# ETA:0s/3s SUB:4
# epoch 12, loss=0.3200 acc=0.9333 f1=0.8768
# epoch 12, val, loss=1.0049 acc=0.5143 f1=0.5920
# ETA:0s/2s SUB:4
# epoch 13, loss=0.3029 acc=0.9493 f1=0.9073
# epoch 13, val, loss=1.0671 acc=0.5143 f1=0.6047
# ETA:0s/2s SUB:4
# epoch 14, loss=0.2983 acc=0.9467 f1=0.9038
# epoch 14, val, loss=1.0855 acc=0.5619 f1=0.6849
# ETA:0s/2s SUB:4
# epoch 15, loss=0.2900 acc=0.9467 f1=0.9038
# epoch 15, val, loss=1.1802 acc=0.5524 f1=0.6619
# ETA:0s/2s SUB:4
# epoch 16, loss=0.2754 acc=0.9707 f1=0.9474
# epoch 16, val, loss=1.1152 acc=0.5619 f1=0.6618
# ETA:0s/2s SUB:4
# epoch 17, loss=0.3010 acc=0.9440 f1=0.8955
# epoch 17, val, loss=1.1818 acc=0.5619 f1=0.6974
# ETA:0s/2s SUB:4
# epoch 18, loss=0.2870 acc=0.9547 f1=0.9194
# epoch 18, val, loss=1.1343 acc=0.5429 f1=0.6522
# ETA:1s/2s SUB:4
# epoch 19, loss=0.2573 acc=0.9707 f1=0.9463
# epoch 19, val, loss=1.1395 acc=0.5714 f1=0.6667
# ETA:1s/2s SUB:4
# epoch 20, loss=0.2603 acc=0.9733 f1=0.9515
# epoch 20, val, loss=1.2049 acc=0.5429 f1=0.6522
# ETA:1s/2s SUB:4
# epoch 21, loss=0.2665 acc=0.9653 f1=0.9372
# epoch 21, val, loss=1.2587 acc=0.5238 f1=0.6479
# ETA:1s/2s SUB:4
# epoch 22, loss=0.2552 acc=0.9707 f1=0.9474
# epoch 22, val, loss=1.1539 acc=0.5333 f1=0.6525
# ETA:1s/2s SUB:4
# epoch 23, loss=0.2570 acc=0.9707 f1=0.9484
# epoch 23, val, loss=1.2362 acc=0.5714 f1=0.7059
# ETA:1s/2s SUB:4
# epoch 24, loss=0.2522 acc=0.9707 f1=0.9479
# epoch 24, val, loss=1.2286 acc=0.5714 f1=0.6715
# ETA:1s/2s SUB:4
# epoch 25, loss=0.2459 acc=0.9787 f1=0.9612
# epoch 25, val, loss=1.2310 acc=0.5524 f1=0.6619
# ETA:1s/2s SUB:4
# epoch 26, loss=0.2449 acc=0.9787 f1=0.9619
# epoch 26, val, loss=1.2447 acc=0.5429 f1=0.6667
# ETA:1s/2s SUB:4
# epoch 27, loss=0.2355 acc=0.9893 f1=0.9811
# epoch 27, val, loss=1.2642 acc=0.5333 f1=0.6711
# ETA:1s/2s SUB:4
# epoch 28, loss=0.2354 acc=0.9867 f1=0.9761
# epoch 28, val, loss=1.3545 acc=0.5524 f1=0.6887
# ETA:1s/2s SUB:4
# epoch 29, loss=0.2317 acc=0.9947 f1=0.9905
# epoch 29, val, loss=1.2629 acc=0.5619 f1=0.6714
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_A/sub4_mlp.pth
# using gpu: 0
# >>> Test:  loss=0.9561 acc=0.6083 f1=0.5766
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 5 [39] 39
# 24 7 8
# (360, 3166) (105, 3166) (360,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss=0.6759 acc=0.5861 f1=0.2871
# epoch 1, val, loss=0.9704 acc=0.2857 f1=0.0000
# ETA:0s/3s SUB:5
# epoch 2, loss=0.6479 acc=0.6417 f1=0.1103
# epoch 2, val, loss=0.9167 acc=0.2857 f1=0.0000
# ETA:0s/3s SUB:5
# epoch 3, loss=0.6131 acc=0.6528 f1=0.1497
# epoch 3, val, loss=0.7922 acc=0.3429 f1=0.2418
# ETA:0s/3s SUB:5
# epoch 4, loss=0.5556 acc=0.7528 f1=0.5822
# epoch 4, val, loss=0.8548 acc=0.4476 f1=0.4630
# ETA:0s/3s SUB:5
# epoch 5, loss=0.5050 acc=0.7944 f1=0.7040
# epoch 5, val, loss=0.8627 acc=0.4857 f1=0.5500
# ETA:0s/3s SUB:5
# epoch 6, loss=0.4620 acc=0.8389 f1=0.7820
# epoch 6, val, loss=1.3033 acc=0.3905 f1=0.3725
# ETA:0s/3s SUB:5
# epoch 7, loss=0.4171 acc=0.8778 f1=0.8382
# epoch 7, val, loss=1.2035 acc=0.4190 f1=0.4299
# ETA:0s/3s SUB:5
# epoch 8, loss=0.4476 acc=0.8417 f1=0.7799
# epoch 8, val, loss=1.0278 acc=0.4476 f1=0.5323
# ETA:0s/2s SUB:5
# epoch 9, loss=0.4324 acc=0.8333 f1=0.7761
# epoch 9, val, loss=0.9823 acc=0.4286 f1=0.5161
# ETA:0s/2s SUB:5
# epoch 10, loss=0.3719 acc=0.8861 f1=0.8487
# epoch 10, val, loss=1.4280 acc=0.3333 f1=0.2553
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_A/sub5_mlp.pth
# using gpu: 0
# >>> Test:  loss=0.8860 acc=0.4833 f1=0.4746
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 6 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss=0.6972 acc=0.5520 f1=0.2566
# epoch 1, val, loss=0.7955 acc=0.4286 f1=0.0000
# ETA:0s/4s SUB:6
# epoch 2, loss=0.6639 acc=0.6000 f1=0.3802
# epoch 2, val, loss=0.7014 acc=0.5429 f1=0.6190
# ETA:0s/4s SUB:6
# epoch 3, loss=0.6191 acc=0.6773 f1=0.4475
# epoch 3, val, loss=0.7567 acc=0.4000 f1=0.3636
# ETA:0s/3s SUB:6
# epoch 4, loss=0.5638 acc=0.7387 f1=0.6260
# epoch 4, val, loss=0.8503 acc=0.3905 f1=0.2889
# ETA:0s/3s SUB:6
# epoch 5, loss=0.5041 acc=0.7867 f1=0.7059
# epoch 5, val, loss=0.8466 acc=0.4476 f1=0.4630
# ETA:0s/3s SUB:6
# epoch 6, loss=0.4351 acc=0.8453 f1=0.8027
# epoch 6, val, loss=1.0631 acc=0.4190 f1=0.2469
# ETA:0s/3s SUB:6
# epoch 7, loss=0.4127 acc=0.8720 f1=0.8345
# epoch 7, val, loss=0.9212 acc=0.4762 f1=0.5455
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_A/sub6_mlp.pth
# using gpu: 0
# >>> Test:  loss=0.6924 acc=0.4667 f1=0.5152
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 7 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss=0.6637 acc=0.6773 f1=0.8000
# epoch 1, val, loss=1.0991 acc=0.2857 f1=0.4444
# ETA:0s/3s SUB:7
# epoch 2, loss=0.5863 acc=0.7600 f1=0.8636
# epoch 2, val, loss=0.9011 acc=0.2857 f1=0.4444
# ETA:0s/3s SUB:7
# epoch 3, loss=0.5819 acc=0.7600 f1=0.8636
# epoch 3, val, loss=1.0823 acc=0.2857 f1=0.4444
# ETA:0s/3s SUB:7
# epoch 4, loss=0.5748 acc=0.7600 f1=0.8636
# epoch 4, val, loss=1.0556 acc=0.2857 f1=0.4444
# ETA:0s/3s SUB:7
# epoch 5, loss=0.5678 acc=0.7600 f1=0.8636
# epoch 5, val, loss=0.8910 acc=0.2857 f1=0.4444
# ETA:0s/3s SUB:7
# epoch 6, loss=0.5363 acc=0.7600 f1=0.8636
# epoch 6, val, loss=1.0089 acc=0.2857 f1=0.4444
# ETA:0s/3s SUB:7
# epoch 7, loss=0.5141 acc=0.7627 f1=0.8649
# epoch 7, val, loss=1.1894 acc=0.2857 f1=0.4444
# ETA:0s/3s SUB:7
# epoch 8, loss=0.4716 acc=0.7707 f1=0.8669
# epoch 8, val, loss=1.0470 acc=0.3238 f1=0.4580
# ETA:0s/3s SUB:7
# epoch 9, loss=0.4425 acc=0.8267 f1=0.8936
# epoch 9, val, loss=1.2625 acc=0.3333 f1=0.4615
# ETA:0s/3s SUB:7
# epoch 10, loss=0.3996 acc=0.8773 f1=0.9228
# epoch 10, val, loss=0.8416 acc=0.5524 f1=0.4719
# ETA:0s/3s SUB:7
# epoch 11, loss=0.3824 acc=0.8853 f1=0.9247
# epoch 11, val, loss=0.9323 acc=0.4952 f1=0.4752
# ETA:0s/3s SUB:7
# epoch 12, loss=0.3652 acc=0.8907 f1=0.9279
# epoch 12, val, loss=1.6872 acc=0.3524 f1=0.4687
# ETA:0s/3s SUB:7
# epoch 13, loss=0.3271 acc=0.9333 f1=0.9564
# epoch 13, val, loss=1.5587 acc=0.3714 f1=0.4762
# ETA:0s/3s SUB:7
# epoch 14, loss=0.3020 acc=0.9413 f1=0.9611
# epoch 14, val, loss=1.5537 acc=0.3714 f1=0.4677
# ETA:0s/3s SUB:7
# epoch 15, loss=0.3059 acc=0.9333 f1=0.9561
# epoch 15, val, loss=1.5239 acc=0.3714 f1=0.4677
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_A/sub7_mlp.pth
# using gpu: 0
# >>> Test:  loss=1.0724 acc=0.4167 f1=0.5139
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 8 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss=0.7349 acc=0.5600 f1=0.6758
# epoch 1, val, loss=1.4124 acc=0.2857 f1=0.4444
# ETA:0s/3s SUB:8
# epoch 2, loss=0.6368 acc=0.7173 f1=0.8354
# epoch 2, val, loss=0.8178 acc=0.2857 f1=0.4444
# ETA:0s/3s SUB:8
# epoch 3, loss=0.5926 acc=0.7227 f1=0.8380
# epoch 3, val, loss=0.9861 acc=0.2857 f1=0.4444
# ETA:0s/3s SUB:8
# epoch 4, loss=0.5505 acc=0.7440 f1=0.8466
# epoch 4, val, loss=1.0983 acc=0.3429 f1=0.4651
# ETA:0s/3s SUB:8
# epoch 5, loss=0.5046 acc=0.7973 f1=0.8738
# epoch 5, val, loss=0.9308 acc=0.3905 f1=0.4386
# ETA:0s/3s SUB:8
# epoch 6, loss=0.4710 acc=0.8187 f1=0.8803
# epoch 6, val, loss=1.1520 acc=0.4000 f1=0.4425
# ETA:0s/3s SUB:8
# epoch 7, loss=0.4966 acc=0.8080 f1=0.8719
# epoch 7, val, loss=1.0097 acc=0.4095 f1=0.4259
# ETA:0s/3s SUB:8
# epoch 8, loss=0.4285 acc=0.8453 f1=0.8990
# epoch 8, val, loss=0.9157 acc=0.4476 f1=0.4200
# ETA:0s/3s SUB:8
# epoch 9, loss=0.3912 acc=0.8827 f1=0.9203
# epoch 9, val, loss=1.1239 acc=0.4000 f1=0.4112
# ETA:0s/3s SUB:8
# epoch 10, loss=0.3674 acc=0.8853 f1=0.9222
# epoch 10, val, loss=1.2353 acc=0.4190 f1=0.4078
# ETA:0s/3s SUB:8
# epoch 11, loss=0.3522 acc=0.9013 f1=0.9326
# epoch 11, val, loss=1.4446 acc=0.4095 f1=0.4364
# ETA:0s/3s SUB:8
# epoch 12, loss=0.3378 acc=0.9013 f1=0.9321
# epoch 12, val, loss=1.5243 acc=0.4000 f1=0.4425
# ETA:0s/3s SUB:8
# epoch 13, loss=0.3337 acc=0.9253 f1=0.9491
# epoch 13, val, loss=1.1758 acc=0.4286 f1=0.4000
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_A/sub8_mlp.pth
# using gpu: 0
# >>> Test:  loss=0.9830 acc=0.4500 f1=0.4762
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 9 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss=1.0071 acc=0.5467 f1=0.5874
# epoch 1, val, loss=0.7121 acc=0.5714 f1=0.7273
# ETA:0s/5s SUB:9
# epoch 2, loss=0.6947 acc=0.5893 f1=0.7127
# epoch 2, val, loss=0.6875 acc=0.5714 f1=0.7273
# ETA:0s/5s SUB:9
# epoch 3, loss=0.6947 acc=0.5920 f1=0.7253
# epoch 3, val, loss=0.6863 acc=0.5714 f1=0.7273
# ETA:0s/5s SUB:9
# epoch 4, loss=0.6879 acc=0.5467 f1=0.6171
# epoch 4, val, loss=0.7115 acc=0.5714 f1=0.7273
# ETA:0s/5s SUB:9
# epoch 5, loss=0.6936 acc=0.6027 f1=0.7504
# epoch 5, val, loss=0.6877 acc=0.5714 f1=0.7273
# ETA:0s/5s SUB:9
# epoch 6, loss=0.6656 acc=0.6133 f1=0.7513
# epoch 6, val, loss=0.6902 acc=0.5714 f1=0.7273
# ETA:0s/5s SUB:9
# epoch 7, loss=0.6560 acc=0.6133 f1=0.7563
# epoch 7, val, loss=0.6892 acc=0.5714 f1=0.7273
# ETA:0s/4s SUB:9
# epoch 8, loss=0.6425 acc=0.6480 f1=0.7626
# epoch 8, val, loss=0.7052 acc=0.5619 f1=0.7160
# ETA:0s/4s SUB:9
# epoch 9, loss=0.6063 acc=0.6880 f1=0.7771
# epoch 9, val, loss=0.7257 acc=0.5429 f1=0.6923
# ETA:0s/4s SUB:9
# epoch 10, loss=0.5666 acc=0.7307 f1=0.7926
# epoch 10, val, loss=0.7808 acc=0.5429 f1=0.6962
# ETA:0s/4s SUB:9
# epoch 11, loss=0.5721 acc=0.7280 f1=0.7935
# epoch 11, val, loss=0.7811 acc=0.5524 f1=0.6466
# ETA:0s/3s SUB:9
# epoch 12, loss=0.6039 acc=0.7120 f1=0.7712
# epoch 12, val, loss=0.8129 acc=0.5619 f1=0.6974
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_A/sub9_mlp.pth
# using gpu: 0
# >>> Test:  loss=0.6589 acc=0.6167 f1=0.7629
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 10 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss=1.0675 acc=0.5627 f1=0.6746
# epoch 1, val, loss=1.6276 acc=0.2857 f1=0.4444
# ETA:0s/3s SUB:10
# epoch 2, loss=0.7002 acc=0.6987 f1=0.8209
# epoch 2, val, loss=0.7421 acc=0.2857 f1=0.4444
# ETA:0s/3s SUB:10
# epoch 3, loss=0.6564 acc=0.6933 f1=0.8166
# epoch 3, val, loss=1.0563 acc=0.2857 f1=0.4444
# ETA:0s/3s SUB:10
# epoch 4, loss=0.6117 acc=0.7200 f1=0.8372
# epoch 4, val, loss=0.8953 acc=0.2857 f1=0.4444
# ETA:0s/3s SUB:10
# epoch 5, loss=0.6039 acc=0.7200 f1=0.8372
# epoch 5, val, loss=0.9836 acc=0.2857 f1=0.4444
# ETA:0s/3s SUB:10
# epoch 6, loss=0.5968 acc=0.7200 f1=0.8372
# epoch 6, val, loss=1.0034 acc=0.2857 f1=0.4444
# ETA:0s/3s SUB:10
# epoch 7, loss=0.5978 acc=0.7200 f1=0.8372
# epoch 7, val, loss=1.0102 acc=0.2857 f1=0.4444
# ETA:0s/3s SUB:10
# epoch 8, loss=0.5912 acc=0.7200 f1=0.8372
# epoch 8, val, loss=0.9488 acc=0.2857 f1=0.4444
# ETA:0s/3s SUB:10
# epoch 9, loss=0.5708 acc=0.7200 f1=0.8372
# epoch 9, val, loss=0.8744 acc=0.2857 f1=0.4444
# ETA:0s/3s SUB:10
# epoch 10, loss=0.5532 acc=0.7387 f1=0.8459
# epoch 10, val, loss=0.9973 acc=0.2857 f1=0.4444
# ETA:0s/3s SUB:10
# epoch 11, loss=0.5198 acc=0.7600 f1=0.8558
# epoch 11, val, loss=1.0135 acc=0.3048 f1=0.4252
# ETA:0s/3s SUB:10
# epoch 12, loss=0.4938 acc=0.8107 f1=0.8799
# epoch 12, val, loss=0.9013 acc=0.4190 f1=0.4696
# ETA:0s/3s SUB:10
# epoch 13, loss=0.5596 acc=0.7600 f1=0.8410
# epoch 13, val, loss=0.6765 acc=0.6381 f1=0.3871
# ETA:0s/3s SUB:10
# epoch 14, loss=0.6161 acc=0.6933 f1=0.7965
# epoch 14, val, loss=1.2740 acc=0.2857 f1=0.4444
# ETA:0s/3s SUB:10
# epoch 15, loss=0.5437 acc=0.7973 f1=0.8742
# epoch 15, val, loss=0.9060 acc=0.2762 f1=0.4328
# ETA:1s/3s SUB:10
# epoch 16, loss=0.5015 acc=0.7680 f1=0.8599
# epoch 16, val, loss=1.0960 acc=0.2857 f1=0.4275
# ETA:1s/3s SUB:10
# epoch 17, loss=0.4679 acc=0.8160 f1=0.8812
# epoch 17, val, loss=1.1193 acc=0.3429 f1=0.4390
# ETA:1s/3s SUB:10
# epoch 18, loss=0.4327 acc=0.8507 f1=0.9007
# epoch 18, val, loss=1.3070 acc=0.3429 f1=0.4390
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_A/sub10_mlp.pth
# using gpu: 0
# >>> Test:  loss=0.5959 acc=0.6750 f1=0.4000
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 11 [37, 38, 39] 37
# 23 6 8
# (345, 3166) (90, 3166) (345,) (90,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss=0.7051 acc=0.6319 f1=0.3060
# epoch 1, val, loss=0.7488 acc=0.6667 f1=0.0000
# ETA:0s/7s SUB:11
# epoch 2, loss=0.5328 acc=0.7507 f1=0.3175
# epoch 2, val, loss=0.6541 acc=0.6889 f1=0.2222
# ETA:0s/7s SUB:11
# epoch 3, loss=0.3634 acc=0.9246 f1=0.8602
# epoch 3, val, loss=0.7504 acc=0.5000 f1=0.3478
# ETA:0s/6s SUB:11
# epoch 4, loss=0.3462 acc=0.9304 f1=0.8899
# epoch 4, val, loss=1.0234 acc=0.6778 f1=0.2162
# ETA:0s/5s SUB:11
# epoch 5, loss=0.3296 acc=0.9362 f1=0.8900
# epoch 5, val, loss=0.9372 acc=0.5556 f1=0.4737
# ETA:0s/4s SUB:11
# epoch 6, loss=0.3524 acc=0.9275 f1=0.8815
# epoch 6, val, loss=0.8124 acc=0.6889 f1=0.2222
# ETA:0s/5s SUB:11
# epoch 7, loss=0.2907 acc=0.9449 f1=0.9156
# epoch 7, val, loss=0.7614 acc=0.6333 f1=0.2326
# ETA:0s/5s SUB:11
# epoch 8, loss=0.2570 acc=0.9855 f1=0.9756
# epoch 8, val, loss=0.8389 acc=0.6444 f1=0.3043
# ETA:0s/5s SUB:11
# epoch 9, loss=0.2450 acc=0.9768 f1=0.9626
# epoch 9, val, loss=0.8635 acc=0.6556 f1=0.2051
# ETA:1s/5s SUB:11
# epoch 10, loss=0.2398 acc=0.9913 f1=0.9855
# epoch 10, val, loss=0.8425 acc=0.6444 f1=0.3333
# ETA:1s/5s SUB:11
# epoch 11, loss=0.2314 acc=0.9884 f1=0.9808
# epoch 11, val, loss=0.8944 acc=0.6556 f1=0.2051
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_A/sub11_mlp.pth
# using gpu: 0
# >>> Test:  loss=1.1298 acc=0.4750 f1=0.2410
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 12 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss=0.5475 acc=0.7227 f1=0.8344
# epoch 1, val, loss=0.2483 acc=1.0000 f1=1.0000
# ETA:0s/4s SUB:12
# epoch 2, loss=0.4723 acc=0.8400 f1=0.9130
# epoch 2, val, loss=0.3512 acc=1.0000 f1=1.0000
# ETA:0s/4s SUB:12
# epoch 3, loss=0.4455 acc=0.8400 f1=0.9130
# epoch 3, val, loss=0.2544 acc=1.0000 f1=1.0000
# ETA:0s/4s SUB:12
# epoch 4, loss=0.3663 acc=0.8800 f1=0.9333
# epoch 4, val, loss=0.2219 acc=1.0000 f1=1.0000
# ETA:0s/4s SUB:12
# epoch 5, loss=0.3188 acc=0.9253 f1=0.9572
# epoch 5, val, loss=0.2676 acc=0.9429 f1=0.9706
# ETA:0s/4s SUB:12
# epoch 6, loss=0.2842 acc=0.9680 f1=0.9811
# epoch 6, val, loss=0.3508 acc=0.9333 f1=0.9655
# ETA:0s/3s SUB:12
# epoch 7, loss=0.2634 acc=0.9760 f1=0.9857
# epoch 7, val, loss=0.3134 acc=0.9333 f1=0.9655
# ETA:0s/3s SUB:12
# epoch 8, loss=0.2456 acc=0.9920 f1=0.9953
# epoch 8, val, loss=0.2797 acc=0.9429 f1=0.9706
# ETA:0s/3s SUB:12
# epoch 9, loss=0.2368 acc=0.9947 f1=0.9968
# epoch 9, val, loss=0.2668 acc=0.9429 f1=0.9706
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_A/sub12_mlp.pth
# using gpu: 0
# >>> Test:  loss=1.0335 acc=0.6250 f1=0.7692
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 13 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss=0.5571 acc=0.7440 f1=0.8509
# epoch 1, val, loss=0.4773 acc=0.8571 f1=0.9231
# ETA:0s/3s SUB:13
# epoch 2, loss=0.5001 acc=0.8400 f1=0.9130
# epoch 2, val, loss=0.4683 acc=0.8571 f1=0.9231
# ETA:0s/3s SUB:13
# epoch 3, loss=0.4975 acc=0.8400 f1=0.9130
# epoch 3, val, loss=0.4941 acc=0.8571 f1=0.9231
# ETA:0s/3s SUB:13
# epoch 4, loss=0.5030 acc=0.8400 f1=0.9130
# epoch 4, val, loss=0.4510 acc=0.8571 f1=0.9231
# ETA:0s/3s SUB:13
# epoch 5, loss=0.4923 acc=0.8400 f1=0.9130
# epoch 5, val, loss=0.4742 acc=0.8571 f1=0.9231
# ETA:0s/3s SUB:13
# epoch 6, loss=0.4867 acc=0.8400 f1=0.9130
# epoch 6, val, loss=0.4800 acc=0.8571 f1=0.9231
# ETA:0s/3s SUB:13
# epoch 7, loss=0.4887 acc=0.8400 f1=0.9130
# epoch 7, val, loss=0.4682 acc=0.8571 f1=0.9231
# ETA:0s/3s SUB:13
# epoch 8, loss=0.4891 acc=0.8400 f1=0.9130
# epoch 8, val, loss=0.4672 acc=0.8571 f1=0.9231
# ETA:0s/3s SUB:13
# epoch 9, loss=0.4797 acc=0.8400 f1=0.9130
# epoch 9, val, loss=0.4838 acc=0.8571 f1=0.9231
# ETA:0s/3s SUB:13
# epoch 10, loss=0.4758 acc=0.8400 f1=0.9130
# epoch 10, val, loss=0.4672 acc=0.8571 f1=0.9231
# ETA:0s/3s SUB:13
# epoch 11, loss=0.4732 acc=0.8400 f1=0.9130
# epoch 11, val, loss=0.4589 acc=0.8571 f1=0.9231
# ETA:0s/3s SUB:13
# epoch 12, loss=0.4647 acc=0.8400 f1=0.9130
# epoch 12, val, loss=0.4518 acc=0.8571 f1=0.9231
# ETA:0s/3s SUB:13
# epoch 13, loss=0.4613 acc=0.8400 f1=0.9130
# epoch 13, val, loss=0.4732 acc=0.8571 f1=0.9231
# ETA:0s/3s SUB:13
# epoch 14, loss=0.4368 acc=0.8400 f1=0.9130
# epoch 14, val, loss=0.4971 acc=0.8571 f1=0.9231
# ETA:1s/3s SUB:13
# epoch 15, loss=0.4437 acc=0.8400 f1=0.9130
# epoch 15, val, loss=0.4885 acc=0.8571 f1=0.9231
# ETA:1s/3s SUB:13
# epoch 16, loss=0.4217 acc=0.8400 f1=0.9130
# epoch 16, val, loss=0.4515 acc=0.8571 f1=0.9231
# ETA:1s/3s SUB:13
# epoch 17, loss=0.4477 acc=0.8400 f1=0.9130
# epoch 17, val, loss=0.4652 acc=0.8571 f1=0.9231
# ETA:1s/3s SUB:13
# epoch 18, loss=0.4012 acc=0.8400 f1=0.9130
# epoch 18, val, loss=0.4901 acc=0.8571 f1=0.9231
# ETA:1s/3s SUB:13
# epoch 19, loss=0.3853 acc=0.8400 f1=0.9130
# epoch 19, val, loss=0.4914 acc=0.8381 f1=0.9119
# ETA:1s/3s SUB:13
# epoch 20, loss=0.3847 acc=0.8613 f1=0.9235
# epoch 20, val, loss=0.5059 acc=0.7429 f1=0.8508
# ETA:1s/3s SUB:13
# epoch 21, loss=0.3615 acc=0.9120 f1=0.9496
# epoch 21, val, loss=0.5201 acc=0.7810 f1=0.8770
# ETA:1s/3s SUB:13
# epoch 22, loss=0.3397 acc=0.9067 f1=0.9462
# epoch 22, val, loss=0.5869 acc=0.7810 f1=0.8770
# ETA:1s/3s SUB:13
# epoch 23, loss=0.3518 acc=0.9253 f1=0.9571
# epoch 23, val, loss=0.5909 acc=0.8000 f1=0.8889
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_A/sub13_mlp.pth
# using gpu: 0
# >>> Test:  loss=0.4360 acc=0.8750 f1=0.9333
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 14 [39] 39
# 24 7 8
# (360, 3166) (105, 3166) (360,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss=0.8379 acc=0.5528 f1=0.6639
# epoch 1, val, loss=0.6084 acc=0.7143 f1=0.8333
# ETA:0s/3s SUB:14
# epoch 2, loss=0.6270 acc=0.6917 f1=0.8103
# epoch 2, val, loss=0.6217 acc=0.7143 f1=0.8333
# ETA:0s/3s SUB:14
# epoch 3, loss=0.6293 acc=0.6806 f1=0.8014
# epoch 3, val, loss=0.7276 acc=0.3333 f1=0.2222
# ETA:0s/2s SUB:14
# epoch 4, loss=0.6286 acc=0.6861 f1=0.7806
# epoch 4, val, loss=0.6222 acc=0.7048 f1=0.8249
# ETA:0s/2s SUB:14
# epoch 5, loss=0.5717 acc=0.7556 f1=0.8288
# epoch 5, val, loss=0.6314 acc=0.7048 f1=0.8229
# ETA:0s/2s SUB:14
# epoch 6, loss=0.5498 acc=0.7361 f1=0.8282
# epoch 6, val, loss=0.7001 acc=0.5905 f1=0.6950
# ETA:0s/2s SUB:14
# epoch 7, loss=0.4652 acc=0.8472 f1=0.8936
# epoch 7, val, loss=0.7805 acc=0.5905 f1=0.6815
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_A/sub14_mlp.pth
# using gpu: 0
# >>> Test:  loss=0.6855 acc=0.6250 f1=0.7692
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 15 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss=0.7084 acc=0.4800 f1=0.4715
# epoch 1, val, loss=0.6874 acc=0.5714 f1=0.7273
# ETA:0s/4s SUB:15
# epoch 2, loss=0.6891 acc=0.5173 f1=0.3823
# epoch 2, val, loss=0.6820 acc=0.5714 f1=0.7273
# ETA:0s/4s SUB:15
# epoch 3, loss=0.6797 acc=0.5467 f1=0.5526
# epoch 3, val, loss=0.7626 acc=0.4286 f1=0.0000
# ETA:0s/3s SUB:15
# epoch 4, loss=0.6914 acc=0.5333 f1=0.5742
# epoch 4, val, loss=0.6931 acc=0.5333 f1=0.3099
# ETA:0s/3s SUB:15
# epoch 5, loss=0.6616 acc=0.5973 f1=0.3105
# epoch 5, val, loss=0.6739 acc=0.6095 f1=0.6917
# ETA:0s/3s SUB:15
# epoch 6, loss=0.6459 acc=0.6480 f1=0.6733
# epoch 6, val, loss=0.6944 acc=0.5238 f1=0.3056
# ETA:0s/3s SUB:15
# epoch 7, loss=0.5747 acc=0.8267 f1=0.8048
# epoch 7, val, loss=0.6554 acc=0.6095 f1=0.6720
# ETA:0s/3s SUB:15
# epoch 8, loss=0.5168 acc=0.8267 f1=0.8209
# epoch 8, val, loss=0.7274 acc=0.5429 f1=0.5000
# ETA:0s/3s SUB:15
# epoch 9, loss=0.4692 acc=0.8640 f1=0.8547
# epoch 9, val, loss=0.7323 acc=0.5714 f1=0.5946
# ETA:0s/3s SUB:15
# epoch 10, loss=0.4701 acc=0.7893 f1=0.7847
# epoch 10, val, loss=1.0060 acc=0.5429 f1=0.4000
# ETA:0s/3s SUB:15
# epoch 11, loss=0.3716 acc=0.8960 f1=0.8901
# epoch 11, val, loss=0.9191 acc=0.5619 f1=0.5106
# ETA:0s/3s SUB:15
# epoch 12, loss=0.3511 acc=0.9227 f1=0.9188
# epoch 12, val, loss=0.9011 acc=0.5714 f1=0.6018
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_A/sub15_mlp.pth
# using gpu: 0
# >>> Test:  loss=0.6567 acc=0.5417 f1=0.5865
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 16 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss=0.7849 acc=0.5040 f1=0.4686
# epoch 1, val, loss=0.7170 acc=0.5714 f1=0.0000
# ETA:0s/3s SUB:16
# epoch 2, loss=0.6510 acc=0.6507 f1=0.6018
# epoch 2, val, loss=0.6488 acc=0.6000 f1=0.5962
# ETA:0s/3s SUB:16
# epoch 3, loss=0.5871 acc=0.6960 f1=0.6705
# epoch 3, val, loss=0.6315 acc=0.6095 f1=0.6019
# ETA:0s/3s SUB:16
# epoch 4, loss=0.5459 acc=0.7467 f1=0.7246
# epoch 4, val, loss=0.7119 acc=0.6476 f1=0.4127
# ETA:0s/3s SUB:16
# epoch 5, loss=0.5312 acc=0.7733 f1=0.7645
# epoch 5, val, loss=0.6375 acc=0.6857 f1=0.5600
# ETA:0s/3s SUB:16
# epoch 6, loss=0.5136 acc=0.7760 f1=0.7529
# epoch 6, val, loss=0.6543 acc=0.6190 f1=0.6000
# ETA:0s/3s SUB:16
# epoch 7, loss=0.4610 acc=0.8160 f1=0.7940
# epoch 7, val, loss=0.6976 acc=0.5905 f1=0.5981
# ETA:0s/3s SUB:16
# epoch 8, loss=0.4431 acc=0.8293 f1=0.8202
# epoch 8, val, loss=0.6815 acc=0.6286 f1=0.6061
# ETA:0s/3s SUB:16
# epoch 9, loss=0.4035 acc=0.8747 f1=0.8698
# epoch 9, val, loss=0.7120 acc=0.6571 f1=0.6000
# ETA:0s/2s SUB:16
# epoch 10, loss=0.3794 acc=0.8907 f1=0.8845
# epoch 10, val, loss=0.6927 acc=0.6762 f1=0.6222
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_A/sub16_mlp.pth
# using gpu: 0
# >>> Test:  loss=0.6689 acc=0.5417 f1=0.4554
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 17 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss=0.8558 acc=0.5360 f1=0.6434
# epoch 1, val, loss=1.0559 acc=0.4286 f1=0.6000
# ETA:0s/3s SUB:17
# epoch 2, loss=0.6339 acc=0.7173 f1=0.8354
# epoch 2, val, loss=0.7422 acc=0.4286 f1=0.6000
# ETA:0s/3s SUB:17
# epoch 3, loss=0.6275 acc=0.7227 f1=0.8380
# epoch 3, val, loss=0.8776 acc=0.4286 f1=0.6000
# ETA:0s/4s SUB:17
# epoch 4, loss=0.5982 acc=0.7200 f1=0.8372
# epoch 4, val, loss=0.8097 acc=0.4286 f1=0.6000
# ETA:0s/3s SUB:17
# epoch 5, loss=0.5932 acc=0.7200 f1=0.8372
# epoch 5, val, loss=0.8403 acc=0.4286 f1=0.6000
# ETA:0s/4s SUB:17
# epoch 6, loss=0.5752 acc=0.7200 f1=0.8372
# epoch 6, val, loss=0.8495 acc=0.4286 f1=0.6000
# ETA:0s/4s SUB:17
# epoch 7, loss=0.5609 acc=0.7200 f1=0.8372
# epoch 7, val, loss=0.9259 acc=0.4286 f1=0.6000
# ETA:0s/4s SUB:17
# epoch 8, loss=0.5351 acc=0.7413 f1=0.8472
# epoch 8, val, loss=0.9711 acc=0.4286 f1=0.6000
# ETA:0s/4s SUB:17
# epoch 9, loss=0.4937 acc=0.7947 f1=0.8744
# epoch 9, val, loss=0.9530 acc=0.4571 f1=0.6014
# ETA:0s/4s SUB:17
# epoch 10, loss=0.4350 acc=0.8533 f1=0.9060
# epoch 10, val, loss=0.7755 acc=0.5143 f1=0.5405
# ETA:0s/4s SUB:17
# epoch 11, loss=0.4203 acc=0.8613 f1=0.9048
# epoch 11, val, loss=1.1277 acc=0.4667 f1=0.5692
# ETA:0s/3s SUB:17
# epoch 12, loss=0.3851 acc=0.8960 f1=0.9302
# epoch 12, val, loss=0.9318 acc=0.5143 f1=0.5487
# ETA:0s/3s SUB:17
# epoch 13, loss=0.3833 acc=0.8853 f1=0.9220
# epoch 13, val, loss=0.8319 acc=0.5429 f1=0.4783
# ETA:1s/3s SUB:17
# epoch 14, loss=0.4339 acc=0.8693 f1=0.9114
# epoch 14, val, loss=0.7708 acc=0.5619 f1=0.4390
# ETA:1s/3s SUB:17
# epoch 15, loss=0.4228 acc=0.8507 f1=0.8993
# epoch 15, val, loss=0.8146 acc=0.5238 f1=0.5370
# ETA:1s/3s SUB:17
# epoch 16, loss=0.3625 acc=0.9067 f1=0.9367
# epoch 16, val, loss=0.9943 acc=0.4952 f1=0.5620
# ETA:1s/3s SUB:17
# epoch 17, loss=0.3715 acc=0.8907 f1=0.9253
# epoch 17, val, loss=0.9220 acc=0.5333 f1=0.5333
# ETA:1s/3s SUB:17
# epoch 18, loss=0.3780 acc=0.8827 f1=0.9200
# epoch 18, val, loss=0.9080 acc=0.5143 f1=0.4848
# ETA:1s/3s SUB:17
# epoch 19, loss=0.3465 acc=0.9013 f1=0.9316
# epoch 19, val, loss=1.0514 acc=0.4857 f1=0.5500
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_A/sub17_mlp.pth
# using gpu: 0
# >>> Test:  loss=0.8022 acc=0.5000 f1=0.2857
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 18 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss=0.6759 acc=0.6053 f1=0.7394
# epoch 1, val, loss=0.6748 acc=0.7143 f1=0.8333
# ETA:0s/3s SUB:18
# epoch 2, loss=0.6680 acc=0.6213 f1=0.7535
# epoch 2, val, loss=0.6229 acc=0.7143 f1=0.8333
# ETA:0s/3s SUB:18
# epoch 3, loss=0.6681 acc=0.6400 f1=0.7805
# epoch 3, val, loss=0.6580 acc=0.7143 f1=0.8333
# ETA:0s/3s SUB:18
# epoch 4, loss=0.6710 acc=0.6347 f1=0.7750
# epoch 4, val, loss=0.6390 acc=0.7143 f1=0.8333
# ETA:0s/3s SUB:18
# epoch 5, loss=0.6591 acc=0.6400 f1=0.7805
# epoch 5, val, loss=0.6271 acc=0.7143 f1=0.8333
# ETA:0s/3s SUB:18
# epoch 6, loss=0.6553 acc=0.6400 f1=0.7805
# epoch 6, val, loss=0.6295 acc=0.7143 f1=0.8333
# ETA:0s/4s SUB:18
# epoch 7, loss=0.6476 acc=0.6400 f1=0.7805
# epoch 7, val, loss=0.6117 acc=0.7143 f1=0.8333
# ETA:0s/4s SUB:18
# epoch 8, loss=0.6543 acc=0.6400 f1=0.7805
# epoch 8, val, loss=0.6282 acc=0.7143 f1=0.8333
# ETA:0s/4s SUB:18
# epoch 9, loss=0.6421 acc=0.6400 f1=0.7805
# epoch 9, val, loss=0.6333 acc=0.7143 f1=0.8333
# ETA:0s/4s SUB:18
# epoch 10, loss=0.6363 acc=0.6400 f1=0.7805
# epoch 10, val, loss=0.6247 acc=0.7143 f1=0.8333
# ETA:0s/4s SUB:18
# epoch 11, loss=0.6387 acc=0.6480 f1=0.7815
# epoch 11, val, loss=0.6010 acc=0.7143 f1=0.8333
# ETA:0s/4s SUB:18
# epoch 12, loss=0.6256 acc=0.6400 f1=0.7776
# epoch 12, val, loss=0.6134 acc=0.7143 f1=0.8333
# ETA:1s/4s SUB:18
# epoch 13, loss=0.5959 acc=0.6400 f1=0.7805
# epoch 13, val, loss=0.6171 acc=0.6571 f1=0.7931
# ETA:1s/4s SUB:18
# epoch 14, loss=0.5866 acc=0.6987 f1=0.7964
# epoch 14, val, loss=0.6054 acc=0.6857 f1=0.7755
# ETA:1s/4s SUB:18
# epoch 15, loss=0.5707 acc=0.7173 f1=0.7930
# epoch 15, val, loss=0.6347 acc=0.5714 f1=0.7273
# ETA:1s/4s SUB:18
# epoch 16, loss=0.5296 acc=0.7867 f1=0.8381
# epoch 16, val, loss=0.6422 acc=0.5714 f1=0.6667
# ETA:1s/4s SUB:18
# epoch 17, loss=0.5533 acc=0.7493 f1=0.8074
# epoch 17, val, loss=0.6957 acc=0.4381 f1=0.5042
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_A/sub18_mlp.pth
# using gpu: 0
# >>> Test:  loss=0.7206 acc=0.5000 f1=0.6667
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 19 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss=0.6775 acc=0.6347 f1=0.7658
# epoch 1, val, loss=0.8520 acc=0.5714 f1=0.7273
# ETA:0s/3s SUB:19
# epoch 2, loss=0.5965 acc=0.7600 f1=0.8636
# epoch 2, val, loss=0.7457 acc=0.5714 f1=0.7273
# ETA:0s/3s SUB:19
# epoch 3, loss=0.5665 acc=0.7600 f1=0.8636
# epoch 3, val, loss=0.7442 acc=0.5714 f1=0.7273
# ETA:0s/3s SUB:19
# epoch 4, loss=0.5584 acc=0.7600 f1=0.8636
# epoch 4, val, loss=0.8111 acc=0.5714 f1=0.7273
# ETA:0s/3s SUB:19
# epoch 5, loss=0.5440 acc=0.7707 f1=0.8685
# epoch 5, val, loss=0.7460 acc=0.5714 f1=0.7273
# ETA:0s/3s SUB:19
# epoch 6, loss=0.5016 acc=0.7760 f1=0.8716
# epoch 6, val, loss=0.7887 acc=0.5905 f1=0.7362
# ETA:0s/3s SUB:19
# epoch 7, loss=0.4641 acc=0.8240 f1=0.8946
# epoch 7, val, loss=0.9705 acc=0.6000 f1=0.7407
# ETA:0s/3s SUB:19
# epoch 8, loss=0.4324 acc=0.8293 f1=0.8944
# epoch 8, val, loss=0.9347 acc=0.6095 f1=0.7421
# ETA:0s/3s SUB:19
# epoch 9, loss=0.3970 acc=0.8827 f1=0.9254
# epoch 9, val, loss=0.9447 acc=0.6095 f1=0.7355
# ETA:0s/3s SUB:19
# epoch 10, loss=0.3667 acc=0.8853 f1=0.9257
# epoch 10, val, loss=1.0261 acc=0.6000 f1=0.7342
# ETA:0s/3s SUB:19
# epoch 11, loss=0.3587 acc=0.9147 f1=0.9446
# epoch 11, val, loss=1.0076 acc=0.5619 f1=0.6974
# ETA:0s/3s SUB:19
# epoch 12, loss=0.3405 acc=0.9120 f1=0.9436
# epoch 12, val, loss=0.9741 acc=0.5524 f1=0.6759
# ETA:0s/3s SUB:19
# epoch 13, loss=0.3680 acc=0.9013 f1=0.9365
# epoch 13, val, loss=0.9186 acc=0.4381 f1=0.5280
# ETA:0s/3s SUB:19
# epoch 14, loss=0.3720 acc=0.8747 f1=0.9197
# epoch 14, val, loss=0.8780 acc=0.5048 f1=0.6061
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_A/sub19_mlp.pth
# using gpu: 0
# >>> Test:  loss=1.0748 acc=0.4833 f1=0.5974
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 20 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss=0.5679 acc=0.7253 f1=0.8373
# epoch 1, val, loss=0.4928 acc=0.8571 f1=0.9231
# ETA:0s/3s SUB:20
# epoch 2, loss=0.4884 acc=0.8427 f1=0.9144
# epoch 2, val, loss=0.4661 acc=0.8571 f1=0.9231
# ETA:0s/3s SUB:20
# epoch 3, loss=0.4788 acc=0.8587 f1=0.9222
# epoch 3, val, loss=0.4781 acc=0.8571 f1=0.9223
# ETA:0s/3s SUB:20
# epoch 4, loss=0.4317 acc=0.8587 f1=0.9224
# epoch 4, val, loss=0.5095 acc=0.8000 f1=0.8877
# ETA:0s/3s SUB:20
# epoch 5, loss=0.3895 acc=0.8800 f1=0.9329
# epoch 5, val, loss=0.5245 acc=0.8095 f1=0.8936
# ETA:0s/2s SUB:20
# epoch 6, loss=0.3508 acc=0.9147 f1=0.9514
# epoch 6, val, loss=0.6115 acc=0.7810 f1=0.8743
# ETA:0s/2s SUB:20
# epoch 7, loss=0.3176 acc=0.9493 f1=0.9706
# epoch 7, val, loss=0.6166 acc=0.7810 f1=0.8743
# ETA:0s/2s SUB:20
# epoch 8, loss=0.3398 acc=0.9173 f1=0.9515
# epoch 8, val, loss=0.5935 acc=0.7714 f1=0.8667
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_A/sub20_mlp.pth
# using gpu: 0
# >>> Test:  loss=1.1170 acc=0.5000 f1=0.6667
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 21 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss=0.6231 acc=0.6667 f1=0.7927
# epoch 1, val, loss=0.5728 acc=0.8667 f1=0.9278
# ETA:0s/4s SUB:21
# epoch 2, loss=0.5697 acc=0.7680 f1=0.8659
# epoch 2, val, loss=0.4426 acc=0.8667 f1=0.9278
# ETA:0s/4s SUB:21
# epoch 3, loss=0.5458 acc=0.7733 f1=0.8694
# epoch 3, val, loss=0.5117 acc=0.8667 f1=0.9278
# ETA:0s/4s SUB:21
# epoch 4, loss=0.4852 acc=0.7760 f1=0.8716
# epoch 4, val, loss=0.4926 acc=0.8667 f1=0.9278
# ETA:0s/4s SUB:21
# epoch 5, loss=0.4243 acc=0.8693 f1=0.9201
# epoch 5, val, loss=0.5351 acc=0.8571 f1=0.9223
# ETA:0s/3s SUB:21
# epoch 6, loss=0.3586 acc=0.8960 f1=0.9342
# epoch 6, val, loss=0.6042 acc=0.7810 f1=0.8743
# ETA:0s/3s SUB:21
# epoch 7, loss=0.3168 acc=0.9307 f1=0.9542
# epoch 7, val, loss=0.6093 acc=0.8381 f1=0.9101
# ETA:0s/3s SUB:21
# epoch 8, loss=0.2898 acc=0.9467 f1=0.9650
# epoch 8, val, loss=0.6244 acc=0.7905 f1=0.8830
# ETA:0s/2s SUB:21
# epoch 9, loss=0.2630 acc=0.9760 f1=0.9842
# epoch 9, val, loss=0.6219 acc=0.7619 f1=0.8649
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_A/sub21_mlp.pth
# using gpu: 0
# >>> Test:  loss=0.3814 acc=0.8750 f1=0.9333
# ================================================
# >>> Data:(40, 15, 1, 32, 512) Label:(40, 15)
# 22 [] 40
# 25 7 8
# (375, 3166) (105, 3166) (375,) (105,)
# (120, 3166) (120,)
# using gpu: 0
# epoch 1, loss=0.6899 acc=0.5307 f1=0.6255
# epoch 1, val, loss=0.6951 acc=0.4095 f1=0.4918
# ETA:0s/4s SUB:22
# epoch 2, loss=0.6642 acc=0.6107 f1=0.7393
# epoch 2, val, loss=0.6357 acc=0.7143 f1=0.8333
# ETA:0s/4s SUB:22
# epoch 3, loss=0.6530 acc=0.6213 f1=0.7455
# epoch 3, val, loss=0.6381 acc=0.7048 f1=0.8268
# ETA:0s/3s SUB:22
# epoch 4, loss=0.6333 acc=0.6533 f1=0.7628
# epoch 4, val, loss=0.6792 acc=0.5810 f1=0.7143
# ETA:0s/3s SUB:22
# epoch 5, loss=0.5783 acc=0.7280 f1=0.8016
# epoch 5, val, loss=0.7029 acc=0.5810 f1=0.7105
# ETA:0s/3s SUB:22
# epoch 6, loss=0.5401 acc=0.7627 f1=0.8142
# epoch 6, val, loss=0.7737 acc=0.4667 f1=0.5556
# ETA:0s/2s SUB:22
# epoch 7, loss=0.5057 acc=0.7893 f1=0.8256
# epoch 7, val, loss=0.7838 acc=0.4762 f1=0.6043
# early stopping
# /content/drive/MyDrive/11777-Project-xs/MLP/save/T_64_pool_16/model_eeg_A/sub22_mlp.pth
# using gpu: 0
# >>> Test:  loss=0.7026 acc=0.5000 f1=0.6667
